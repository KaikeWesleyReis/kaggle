# %% [markdown]
# # Instalando novas bibliotecas

# %%
# %%capture
# !pip install optuna

# %%
# %%capture
# !pip install lightgbm

# %% [markdown]
# # Importando módulos

# %%
import warnings
import numpy as np
import pandas as pd
import optuna as opt
import seaborn as sns
import lightgbm as lgb
import matplotlib.pyplot as plt
from sklearn.metrics import f1_score
from sklearn.utils import compute_class_weight
from sklearn.model_selection import train_test_split
from optuna.integration.lightgbm import LightGBMTuner

# %%
# Só encher o saco uma vez
warnings.filterwarnings('once')

# %% [markdown]
# # __Execução I__
#
# Passos
# - Importar dados
# - Pré-processamento
# - Divisão treino e validação
# - Imputação de dados
# - Light GBM padrão com `class_weight`
# - Ensemble de modelos binários
#
# # Importando dados

# %%
# Importar tabelas
df_train = pd.read_csv('ml-olympiad-ensure-healthy-lives/train.csv', low_memory=False)
df_test = pd.read_csv('ml-olympiad-ensure-healthy-lives/test.csv', low_memory=False)
df_subm = pd.read_csv('ml-olympiad-ensure-healthy-lives/sample_submission.csv', low_memory=False)

# %%
# Montar base para previsão do desafio
df_sub_desafio = pd.DataFrame()
df_sub_desafio['ID'] = df_test['ID']
df_sub_desafio['CLASSI_FIN'] = np.nan

# %%
# Aplicar correcao nas variáveis coringa
df_train['FNT_IN_COV'].replace({1:'MANUAL',2:'INTEGRACAO',np.nan:'INFO_FALTANTE'}, inplace=True)
df_test['FNT_IN_COV'].replace({1:'MANUAL',2:'INTEGRACAO',np.nan:'INFO_FALTANTE'}, inplace=True)

df_train['COD_IDADE'].replace({np.nan:'INFO_FALTANTE'}, inplace=True)
df_test['COD_IDADE'].replace({np.nan:'INFO_FALTANTE'}, inplace=True)

# %% [markdown]
# # Pré-processamento

# %%
# Definir colunas para serem derrubadas
cols_to_drop = ['ID',         # Identificação
                'DELTA_UTI',  # Constante
                'PAC_COCBO',  # Completamente faltante
                'PAC_DSCBO',  # Completamente faltante
                'OBES_IMC',   # Completamente faltante
                'COD_IDADE',  # Redundante tendo as outras duas variáveis de idade
                'FNT_IN_COV'] # Não relacionado ao problema

# Derrubar
df_train.drop(columns=cols_to_drop, inplace=True)
df_test.drop(columns=cols_to_drop, inplace=True)

# %%
# Especificar label do desafio
label = 'CLASSI_FIN'

# %% [markdown]
# **Variáveis relacionadas a sexo + idade, porém o foco está em mães / bebês**

# %%
# Definir colunas de análise nesta seção
cols = ['CS_SEXO','CS_GESTANT','PUERPERA','NU_IDADE_N','TP_IDADE','MAE_VAC','M_AMAMENTA']

# %% [markdown]
# Alterações
# - Adicionar '99' para identificar que são homens, (código universal para não aplicável) nas colunas referentes a gestação e paridade
# - Demais que possuem 'F' em CS_SEXO, adicionar '9' para identificar as mulheres como ignorados, pois provavelmente não estavam classificadas neste grupo

# %% [markdown]
# `NU_IDADE_N` + `TP_IDADE`
#
# - Converter coluna de idade para anos
# - Remover idades impossíveis
#
# [Expectativa de vida no Brasil](https://pt.wikipedia.org/wiki/Lista_de_unidades_federativas_do_Brasil_por_expectativa_de_vida)

# %%
def corrigir_idade(nu_idade, tp_idade):
    '''
    Corrigir padrão de idade para anos
    '''
    if tp_idade == 3:
        return abs(nu_idade)
    elif tp_idade == 2:
        return abs(nu_idade)/12
    else:
        return abs(nu_idade)/365

# %%
# Aplicar correção de anos
df_train['NU_IDADE_N'] = df_train.apply(lambda df:corrigir_idade(df['NU_IDADE_N'], df['TP_IDADE']), axis=1).astype(int)

# Qualquer valor acima dos 95 serão tratados e fixados em 95 devido a impossibilidade + expectativa de vida no país
df_train.loc[df_train['NU_IDADE_N'] >= 95, 'NU_IDADE_N'] = 95

# %%
# Aplicar correção de anos
df_test['NU_IDADE_N'] = df_test.apply(lambda df:corrigir_idade(df['NU_IDADE_N'], df['TP_IDADE']), axis=1).astype(int)

# Qualquer valor acima dos 95 serão tratados e fixados em 95 devido a impossibilidade + expectativa de vida no país
df_test.loc[df_test['NU_IDADE_N'] >= 95, 'NU_IDADE_N'] = 95

# %% [markdown]
# `CS_SEXO`
#
# [Motivo de imputação em último nível](https://educa.ibge.gov.br/jovens/conheca-o-brasil/populacao/18320-quantidade-de-homens-e-mulheres.html#:~:text=Segundo%20dados%20da%20PNAD%20Cont%C3%ADnu,51%2C1%25%20de%20mulheres.)

# %%
# Remover classe desconhecida e rara
df_train.loc[df_train['CS_SEXO'] == 'I', 'CS_SEXO'] = np.nan

# Aplicar primeiro nível
c1 = (df_train['CS_SEXO'].isna()) & (df_train['CS_GESTANT'] == 6) & (df_train['NU_IDADE_N'] >= 9)
df_train.loc[c1, 'CS_SEXO'] = 'M'

# Aplicar segundo nível
c2 = (df_train['CS_GESTANT'] != 6) & (df_train['CS_SEXO'].isna())
df_train.loc[c2, 'CS_SEXO'] = 'F'

# Aplicar terceiro nível
c3 = df_train['CS_SEXO'].isna()
df_train.loc[c3, 'CS_SEXO'] = 'F'

# %%
# Remover classe desconhecida e rara
df_test.loc[df_test['CS_SEXO'] == 'I', 'CS_SEXO'] = np.nan

# Aplicar primeiro nível
c1 = (df_test['CS_SEXO'].isna()) & (df_test['CS_GESTANT'] == 6) & (df_test['NU_IDADE_N'] >= 9)
df_test.loc[c1, 'CS_SEXO'] = 'M'

# Aplicar segundo nível
c2 = (df_test['CS_GESTANT'] != 6) & (df_test['CS_SEXO'].isna())
df_test.loc[c2, 'CS_SEXO'] = 'F'

# Aplicar terceiro nível
c3 = df_test['CS_SEXO'].isna()
df_test.loc[c3, 'CS_SEXO'] = 'F'

# %% [markdown]
# `CS_GESTANT`

# %%
# Remover classe desconhecida e rara
df_train.loc[df_train['CS_GESTANT'] == 0, 'CS_GESTANT'] = np.nan

# Aplicar primeiro nível
c1 = (df_train['CS_GESTANT'].isna()) & ((df_train['CS_SEXO'] == 'M') | (df_train['NU_IDADE_N'] <= 9))
df_train.loc[c1, 'CS_GESTANT'] = 6

# Aplicar segundo nível
c2 = (df_train['CS_GESTANT'].isna()) & (df_train['CS_SEXO'] == 'F') & (df_train['NU_IDADE_N'] > 9)
df_train.loc[c2, 'CS_GESTANT'] = 5

# Aplicar terceiro e último nível
c3 = (df_train['CS_GESTANT'].isna())
df_train.loc[c3, 'CS_GESTANT'] = 9

# %%
# Remover classe desconhecida e rara
df_test.loc[df_test['CS_GESTANT'] == 0, 'CS_GESTANT'] = np.nan

# Aplicar primeiro nível
c1 = (df_test['CS_GESTANT'].isna()) & ((df_test['CS_SEXO'] == 'M') | (df_test['NU_IDADE_N'] <= 9))
df_test.loc[c1, 'CS_GESTANT'] = 6

# Aplicar segundo nível
c2 = (df_test['CS_GESTANT'].isna()) & (df_test['CS_SEXO'] == 'F') & (df_test['NU_IDADE_N'] > 9)
df_test.loc[c2, 'CS_GESTANT'] = 5

# Aplicar terceiro e último nível
c3 = (df_test['CS_GESTANT'].isna())
df_test.loc[c3, 'CS_GESTANT'] = 9

# %% [markdown]
# `PUERPERA`

# %%
# Aplicar primeiro nível
c1 = df_train['CS_SEXO'] == 'M'
df_train.loc[c1, 'PUERPERA'] = 99

# Aplicar segundo nível
c2 = (df_train['PUERPERA'].isna()) & (df_train['CS_SEXO'] == 'F') & (df_train['CS_GESTANT'] != 6)
df_train.loc[c2, 'PUERPERA'] = 2

# Aplicar terceiro nível
c3 = (df_train['CS_SEXO'] == 'F') & (df_train['PUERPERA'].isna())
df_train.loc[c3, 'PUERPERA'] = 9

# %%
# Aplicar primeiro nível
c1 = df_test['CS_SEXO'] == 'M'
df_test.loc[c1, 'PUERPERA'] = 99

# Aplicar segundo nível
c2 = (df_test['PUERPERA'].isna()) & (df_test['CS_SEXO'] == 'F') & (df_test['CS_GESTANT'] != 6)
df_test.loc[c2, 'PUERPERA'] = 2

# Aplicar terceiro nível
c3 = (df_test['CS_SEXO'] == 'F') & (df_test['PUERPERA'].isna())
df_test.loc[c3, 'PUERPERA'] = 9

# %% [markdown]
# `MAE_VAC` + `M_AMAMENTA`

# %%
# Aplicar primeiro nível
c1 = df_train['NU_IDADE_N'] > 0
df_train.loc[c1, ['MAE_VAC','M_AMAMENTA']] = 99

# Aplicar segundo nível
df_train.loc[df_train['MAE_VAC'].isna(), 'MAE_VAC'] = 9
df_train.loc[df_train['M_AMAMENTA'].isna(), 'M_AMAMENTA'] = 9

# %%
# Aplicar primeiro nível
c1 = df_test['NU_IDADE_N'] > 0
df_test.loc[c1, ['MAE_VAC','M_AMAMENTA']] = 99

# Aplicar segundo nível
df_test.loc[df_test['MAE_VAC'].isna(), 'MAE_VAC'] = 9
df_test.loc[df_test['M_AMAMENTA'].isna(), 'M_AMAMENTA'] = 9

# %% [markdown]
# **Variáveis relacionadas ao COVID**

# %%
# Definir colunas de análise nesta seção
cols = ['VACINA_COV','DOSE_1_COV','DOSE_2_COV','DOSE_REF']

# %% [markdown]
# `VACINA_COV`
#
# Possibilidade de binarizar e converter `9` em `2`
#
# OBS - Criar nova coluna com a contagem de doses tomadas.

# %%
# Aplicar primeiro nível
c1 = df_train[['DOSE_1_COV','DOSE_2_COV','DOSE_REF']].sum(axis=1) >= 1
df_train.loc[c1, 'VACINA_COV'] = 1

# Aplicar segundo nível
c2 = df_train['VACINA_COV'].isna()
df_train.loc[c2, 'VACINA_COV'] = 9

# %%
# Aplicar primeiro nível
c1 = df_test[['DOSE_1_COV','DOSE_2_COV','DOSE_REF']].sum(axis=1) >= 1
df_test.loc[c1, 'VACINA_COV'] = 1

# Aplicar segundo nível
c2 = df_test['VACINA_COV'].isna()
df_test.loc[c2, 'VACINA_COV'] = 9

# %%
# Criar nova coluna
df_train['DOSE_COV_N'] = df_train[['DOSE_1_COV','DOSE_2_COV','DOSE_REF']].sum(axis=1)
df_test['DOSE_COV_N'] = df_test[['DOSE_1_COV','DOSE_2_COV','DOSE_REF']].sum(axis=1)

# %% [markdown]
# **Variáveis relacionadas ao EXAME**

# %%
# Definir colunas de análise nesta seção
cols = ['RAIOX_RES','RAIOX_OUT','TOMO_RES','TOMO_OUT','AMOSTRA','OUT_AMOST','TP_AMOSTRA']

# %%
# Especificar todas as possibilidades de outros para raio x e tomografia
outros_raioX = list(set(df_train['RAIOX_OUT'].dropna().unique().tolist() + df_test['RAIOX_OUT'].dropna().unique().tolist()))
outros_tomog = list(set(df_train['TOMO_OUT'].dropna().unique().tolist() + df_test['TOMO_OUT'].dropna().unique().tolist()))
outros_amost = list(set(df_train['OUT_AMOST'].dropna().unique().tolist() + df_test['OUT_AMOST'].dropna().unique().tolist()))

# %% [markdown]
# Melhorar colunas referente a OUTROS

# %%
# Gerar listas hierarquicas especificas para consolidar categorias em tomografia (prioridade de baixo para cima)
outros_tomog_laudo = [c for c in outros_tomog if 'LAUDO' in c or 'AGUARDA' in c or 'EM ANDAMENTO' in c or 'SEM INFORMACAO' in c]
outros_tomog_norml = [c for c in outros_tomog if 'NORMAL' in c or 'SEM ALTERAC' in c or 'SEM SINAIS DE INFECCAO' in c]
outros_tomog_vidro = [c for c in outros_tomog if 'VIDRO' in c or 'OPACIDADE' in c]
outros_tomog_bronc = [c for c in outros_tomog if 'BRONCOPATIA' in c]
outros_tomog_covid = [c for c in outros_tomog if 'COVID' in c]
outros_tomog_derrp = [c for c in outros_tomog if 'DERRAME' in c and 'PLEURAL' in c]
outros_tomog_enfis = [c for c in outros_tomog if 'ENFISEMA' in c]
outros_tomog_pneum = [c for c in outros_tomog if 'PNEUMONIA' in c or 'PNM' in c]
outros_tomog_conso = [c for c in outros_tomog if 'CONSOLIDA' in c]
outros_tomog_solic = [c for c in outros_tomog if 'SOLICITADO' in c]
outros_tomog_atele = [c for c in outros_tomog if 'ATELECTAS' in c]
outros_tomog_tuber = [c for c in outros_tomog if 'TUBERCUL' in c or 'TB' in c]

# Especificar novas categorias de agrupamento
outros_tomog_nCats = ['REL_TUBERCULOSE', 'REL_OPACIDADE_VIDRO_FOSCO', 'REL_BRONCOPATIA', 'REL_COVID',
                      'REL_DERRAME', 'REL_ENFISEMA', 'REL_PNEUMONIA', 'REL_CONSOLIDACAO',
                      'REL_ATELECTASIA', 'REL_SEM_LAUDO', 'REL_RES_NORMAL', 'REL_SOLICITADO']

outros_tomog_oCats = [outros_tomog_tuber, outros_tomog_vidro, outros_tomog_bronc, outros_tomog_covid,
                      outros_tomog_derrp, outros_tomog_enfis, outros_tomog_pneum, outros_tomog_conso,
                      outros_tomog_atele, outros_tomog_laudo, outros_tomog_norml, outros_tomog_solic]

# Criar colunas
df_train['TOMO_OUT_NOVO'] = np.nan
df_test['TOMO_OUT_NOVO'] = np.nan

# Aplicar novas categorias evitando sobreposição
for n_cat, o_cats in zip(outros_tomog_nCats, outros_tomog_oCats):
    df_train.loc[(df_train['TOMO_OUT'].isin(o_cats)) & (df_train['TOMO_OUT_NOVO'].isna()), 'TOMO_OUT_NOVO'] = n_cat
    df_test.loc[(df_test['TOMO_OUT'].isin(o_cats)) & (df_test['TOMO_OUT_NOVO'].isna()), 'TOMO_OUT_NOVO'] = n_cat

# Converter todas as demais categorias restantes provalvemente raras em umas só para reduzir ruído ao modelo
c1 = (~df_train['TOMO_OUT_NOVO'].isin(outros_tomog_nCats)) & (df_train['TOMO_OUT'].notnull())
df_train.loc[c1, 'TOMO_OUT_NOVO'] = 'REL_OUTROS_RESULTADOS'
c1 = (~df_test['TOMO_OUT_NOVO'].isin(outros_tomog_nCats)) & (df_test['TOMO_OUT'].notnull())
df_test.loc[c1, 'TOMO_OUT_NOVO'] = n_cat

# %%
# Gerar listas hierarquicas especificas para consolidar categorias em raio X (prioridade de baixo para cima)
outros_raiox_infil = [c for c in outros_raioX if 'INFILT' in c]
outros_raiox_vidro = [c for c in outros_raioX if 'VIDRO' in c or 'FOSCO' in c]
outros_raiox_opaci = [c for c in outros_raioX if 'OPACIDADE' in c or 'OPACIF' in c]
outros_raiox_tomog = [c for c in outros_raioX if 'TC' in c or 'TOMOGRAFIA' in c or 'TOMO' in c or 'CT' in c]
outros_raiox_derrp = [c for c in outros_raioX if 'DERRAME' in c and 'PLEU' in c]
outros_raiox_atele = [c for c in outros_raioX if 'ATELECTAS' in c]
outros_raiox_congt = [c for c in outros_raioX if 'CONGESTAO' in c or 'CONGEST' in c]
outros_raiox_pneum = [c for c in outros_raioX if 'PNEUMONIA' in c or 'PNM' in c]
outros_raiox_infla = [c for c in outros_raioX if 'INFLAMA' in c]
outros_raiox_espes = [c for c in outros_raioX if 'ESPESSA' in c]
outros_raiox_solic = [c for c in outros_raioX if 'SOLICITADO' in c or 'PEDIDO' in c]
outros_raiox_conde = [c for c in outros_raioX if 'CONDENSA' in c]
outros_raiox_hiper = [c for c in outros_raioX if 'HIPERINSUF' in c]
outros_raiox_arcos = [c for c in outros_raioX if 'ARCO' in c or 'RETIFICACAO' in c or 'COSTAIS' in c]
outros_raiox_norml = [c for c in outros_raioX if 'NORMAL' in c or 'SEM ALTERAC' in c or 'SEM SINAIS DE INFECCAO' in c]
outros_raiox_laudo = [c for c in outros_raioX if 'LAUDO' in c or 'SEM DESCRICAO' in c or 'SEM RELATO' in c or 'SEM INFO' in c or 'AGUARDA' in c or 'NAO INFO' in c]

# Especificar novas categorias de agrupamento por ordem de prioridade
outros_raiox_nCats = ['REL_INFILTRACAO', 'REL_VIDRO_FOSCO','REL_OPACIDADE', 'REL_DERRAME_PLEURAL',
                      'REL_ATELECTASIA', 'REL_CONGESTAO', 'REL_PNEUMONIA', 'REL_INFLAMACAO', 
                      'REL_ESPESSAMENTO', 'REL_CONDENSACAO', 'REL_HIPERINSUFLACAO', 'REL_SOLICITADO',
                      'REL_ARCOS_COSTAIS', 'REL_SEM_LAUDO', 'REL_RES_NORMAL','REL_PEDIDO_TOMOG']
outros_raiox_oCats = [outros_raiox_infil, outros_raiox_vidro, outros_raiox_opaci, outros_raiox_derrp,
                      outros_raiox_atele, outros_raiox_congt, outros_raiox_pneum, outros_raiox_infla,
                      outros_raiox_espes, outros_raiox_conde, outros_raiox_hiper, outros_raiox_solic,
                      outros_raiox_arcos, outros_raiox_laudo, outros_raiox_norml, outros_raiox_tomog]

# Criar colunas
df_train['RAIOX_OUT_NOVO'] = np.nan
df_test['RAIOX_OUT_NOVO'] = np.nan

# Aplicar novas categorias evitando sobreposição
for n_cat, o_cats in zip(outros_raiox_nCats, outros_raiox_oCats):
    df_train.loc[(df_train['RAIOX_OUT'].isin(o_cats)) & (df_train['RAIOX_OUT_NOVO'].isna()), 'RAIOX_OUT_NOVO'] = n_cat
    df_test.loc[(df_test['RAIOX_OUT'].isin(o_cats)) & (df_test['RAIOX_OUT_NOVO'].isna()), 'RAIOX_OUT_NOVO'] = n_cat

# Converter todas as demais categorias restantes provalvemente raras em umas só para reduzir ruído ao modelo
c1 = (~df_train['RAIOX_OUT_NOVO'].isin(outros_raiox_nCats)) & (df_train['RAIOX_OUT'].notnull())
df_train.loc[c1, 'RAIOX_OUT_NOVO'] = 'REL_OUTROS_RESULTADOS'
c1 = (~df_test['RAIOX_OUT_NOVO'].isin(outros_raiox_nCats)) & (df_test['RAIOX_OUT'].notnull())
df_test.loc[c1, 'RAIOX_OUT_NOVO'] = n_cat

# %% [markdown]
# Corrigir variáveis relacionadas ao raio X

# %%
# Caso o motivo seja outro e não tenha descrição, adicionar string referente
c1 = (df_train['RAIOX_RES'].isin([5])) & (df_train['RAIOX_OUT'].isna())
df_train.loc[c1, 'RAIOX_OUT'] = 'FEITO_E_SEM_DETALHE'
df_train.loc[c1, 'RAIOX_OUT_NOVO'] = 'FEITO_E_SEM_DETALHE'

c1 = (df_test['RAIOX_RES'].isin([5])) & (df_test['RAIOX_OUT'].isna())
df_test.loc[c1, 'RAIOX_OUT'] = 'FEITO_E_SEM_DETALHE'
df_test.loc[c1, 'RAIOX_OUT_NOVO'] = 'FEITO_E_SEM_DETALHE'

# Caso seja nulo, será considerado que não foi feito nenhum exame
c2 = df_train['RAIOX_RES'].isna()
df_train.loc[c2, 'RAIOX_RES'] = 6
df_train.loc[c2, 'RAIOX_OUT'] = 'NDA'
df_train.loc[c2, 'RAIOX_OUT_NOVO'] = 'NDA'

c2 = df_test['RAIOX_RES'].isna()
df_test.loc[c2, 'RAIOX_RES'] = 6
df_test.loc[c2, 'RAIOX_OUT'] = 'NDA'
df_test.loc[c2, 'RAIOX_OUT_NOVO'] = 'NDA'

# %% [markdown]
# Corrigir variáveis relacionadas a tomografia

# %%
# Caso o motivo seja outro e não tenha descrição, adicionar string referente
c1 = (df_train['TOMO_RES'].isin([5])) & (df_train['TOMO_OUT'].isna())
df_train.loc[c1, 'TOMO_OUT'] = 'FEITO_E_SEM_DETALHE'
df_train.loc[c1, 'TOMO_OUT_NOVO'] = 'FEITO_E_SEM_DETALHE'

c1 = (df_test['TOMO_RES'].isin([5])) & (df_test['TOMO_OUT'].isna())
df_test.loc[c1, 'RAIOX_OUT'] = 'FEITO_E_SEM_DETALHE'
df_test.loc[c1, 'RAIOX_OUT_NOVO'] = 'FEITO_E_SEM_DETALHE'

# Caso seja nulo, será considerado que não foi feito nenhum exame
c2 = df_train['TOMO_RES'].isna()
df_train.loc[c2, 'TOMO_RES'] = 6
df_train.loc[c2, 'TOMO_OUT'] = 'NDA'
df_train.loc[c2, 'TOMO_OUT_NOVO'] = 'NDA'

c2 = df_test['TOMO_RES'].isna()
df_test.loc[c2, 'TOMO_RES'] = 6
df_test.loc[c2, 'TOMO_OUT'] = 'NDA'
df_test.loc[c2, 'TOMO_OUT_NOVO'] = 'NDA'

# %% [markdown]
# Corrigir variáveis referentes a amostra

# %%
# Caso seja nulo em AMOSTRA, será considerado que a coleta foi ignorada
c1 = df_train['AMOSTRA'].isna()
df_train.loc[c1, 'AMOSTRA'] = 9

# Caso AMOSTRA seja 2 ou 9 (não e ignorado respectivamente), ignoramos o tipo de amostra
c2 = df_train['AMOSTRA'].isin([2, 9])
df_train.loc[c2, 'TP_AMOSTRA'] = 9

# Caso TP_AMOSTRA seja 4 (outra) e não tenha informação em OUT_AMOST colocamos uma string especifica
c3 = (df_train['TP_AMOSTRA'] == 4) & (df_train['OUT_AMOST'].isna())
df_train.loc[c3, 'OUT_AMOST'] = 'TIPO_AMOST_NAO_ESPECIFICADO'

# Caso AMOSTRA seja 1 e TP_AMOSTRA seja diferente de 4, inserimos string especifica em OUT_AMOST
c4 = (df_train['AMOSTRA'] == 1) & (df_train['TP_AMOSTRA'].isin([1,2,3,5]))
df_train.loc[c4, 'OUT_AMOST'] = 'COLETA_FEITA_TIPO_DEFINIDO'

# Caso AMOSTRA seja 2 ou 9, inserimos string especifica em OUT_AMOSTRA
c5 = (df_train['AMOSTRA'].isin([2, 9]))
df_train.loc[c5, 'OUT_AMOST'] = 'COLETA_NAO_REALIZADA_OU_IGNORADA'

# Caso AMOSTRA seja 1 e TP_AMOSTRA seja nulo, inserimos 9
c6 = (df_train['AMOSTRA'] == 1) & (df_train['TP_AMOSTRA'].isna())
df_train.loc[c6, 'TP_AMOSTRA'] = 9

# Caso AMOSTRA seja 1 e TP_AMOSTRA seja diferente de 4, inserimos string especifica em OUT_AMOST
c7 = (df_train['AMOSTRA'] == 1) & (df_train['TP_AMOSTRA'] != 4)
df_train.loc[c7, 'OUT_AMOST'] = 'COLETA_FEITA_TIPO_IGNORADO'

# %%
# Caso seja nulo em AMOSTRA, será considerado que a coleta foi ignorada
c1 = df_test['AMOSTRA'].isna()
df_test.loc[c1, 'AMOSTRA'] = 9

# Caso AMOSTRA seja 2 ou 9 (não e ignorado respectivamente), ignoramos o tipo de amostra
c2 = df_test['AMOSTRA'].isin([2, 9])
df_test.loc[c2, 'TP_AMOSTRA'] = 9

# Caso TP_AMOSTRA seja 4 (outra) e não tenha informação em OUT_AMOST colocamos uma string especifica
c3 = (df_test['TP_AMOSTRA'] == 4) & (df_test['OUT_AMOST'].isna())
df_test.loc[c3, 'OUT_AMOST'] = 'TIPO_AMOST_NAO_ESPECIFICADO'

# Caso AMOSTRA seja 1 e TP_AMOSTRA seja diferente de 4, inserimos string especifica em OUT_AMOST
c4 = (df_test['AMOSTRA'] == 1) & (df_test['TP_AMOSTRA'].isin([1,2,3,5]))
df_test.loc[c4, 'OUT_AMOST'] = 'COLETA_FEITA_TIPO_DEFINIDO'

# Caso AMOSTRA seja 2 ou 9, inserimos string especifica em OUT_AMOSTRA
c5 = (df_test['AMOSTRA'].isin([2, 9]))
df_test.loc[c5, 'OUT_AMOST'] = 'COLETA_NAO_REALIZADA_OU_IGNORADA'

# Caso AMOSTRA seja 1 e TP_AMOSTRA seja nulo, inserimos 9
c6 = (df_test['AMOSTRA'] == 1) & (df_test['TP_AMOSTRA'].isna())
df_test.loc[c6, 'TP_AMOSTRA'] = 9

# Caso AMOSTRA seja 1 e TP_AMOSTRA seja diferente de 4, inserimos string especifica em OUT_AMOST
c7 = (df_test['AMOSTRA'] == 1) & (df_test['TP_AMOSTRA'] != 4)
df_test.loc[c7, 'OUT_AMOST'] = 'COLETA_FEITA_TIPO_IGNORADO'

# %% [markdown]
# Melhorar colunas referente a OUTROS II

# %%
# Gerar listas hierarquicas especificas para consolidar categorias em tipo de amostra X (prioridade de baixo para cima)
outros_amost_nasof = [c for c in outros_amost if 'NASOFARINGE' in c or 'NASO' in c or 'NF' in c or 'NOSOFARINGE' in c]
outros_amost_rapid = [c for c in outros_amost if 'TESTE RAPIDO' in c or 'RAPIDO' in c or 'TR' in c or 'ANTIGEN' in c]
outros_amost_blood = [c for c in outros_amost if 'SANGUE' in c or 'SAGUE' in c]
outros_amost_swab = [c for c in outros_amost if 'SWAB' in c]
outros_amost_soro = [c for c in outros_amost if 'SORO' in c]
outros_amost_tpcr = [c for c in outros_amost if 'PCR' in c]
outros_amost_nasal = [c for c in outros_amost if 'NASAL' in c]


# Especificar novas categorias de agrupamento por ordem de prioridade
outros_amost_nCats = ['REL_NASOFARINGE', 'REL_TESTE_RAPIDO','REL_PCR', 'REL_TESTE_SANGUE',
                      'REL_SWAB', 'REL_SORO', 'REL_NASAL']
outros_amost_oCats = [outros_amost_nasof, outros_amost_rapid, outros_amost_tpcr, outros_amost_blood,
                      outros_amost_swab, outros_amost_soro, outros_amost_nasal]

# Criar colunas
df_train['AMOSTRA_OUT_NOVO'] = np.nan
df_test['AMOSTRA_OUT_NOVO'] = np.nan

# Aplicar novas categorias evitando sobreposição
for n_cat, o_cats in zip(outros_amost_nCats, outros_amost_oCats):
    df_train.loc[(df_train['OUT_AMOST'].isin(o_cats)) & (df_train['AMOSTRA_OUT_NOVO'].isna()), 'AMOSTRA_OUT_NOVO'] = n_cat
    df_test.loc[(df_test['OUT_AMOST'].isin(o_cats)) & (df_test['AMOSTRA_OUT_NOVO'].isna()), 'AMOSTRA_OUT_NOVO'] = n_cat

# Converter todas as demais categorias restantes provalvemente raras em umas só para reduzir ruído ao modelo
c1 = (~df_train['AMOSTRA_OUT_NOVO'].isin(outros_amost_nCats)) & (df_train['OUT_AMOST'].notnull())
df_train.loc[c1, 'AMOSTRA_OUT_NOVO'] = 'REL_OUTROS_RESULTADOS'

c1 = (~df_test['AMOSTRA_OUT_NOVO'].isin(outros_amost_nCats)) & (df_test['OUT_AMOST'].notnull())
df_test.loc[c1, 'AMOSTRA_OUT_NOVO'] = n_cat

# %% [markdown]
# **Variáveis relacionadas ao SINTOMA**

# %%
# Definir colunas de análise nesta seção
cols = ['SEM_PRI','SEM_NOT','FEBRE','TOSSE','GARGANTA','DISPNEIA','DESC_RESP','SATURACAO','DIARREIA','VOMITO',
        'OUTRO_SIN','OUTRO_DES','PERD_PALA','PERD_OLFT','DOR_ABD','FADIGA']

# %%
# Checar nulos
df_train[cols].isna().sum()
# Out:
# SEM_PRI           0
# SEM_NOT           0
# FEBRE        231370
# TOSSE        172085
# GARGANTA     396565
# DISPNEIA     176050
# DESC_RESP    261255
# SATURACAO    223622
# DIARREIA     414223
# VOMITO       422753
# OUTRO_SIN    395283
# OUTRO_DES    904480
# PERD_PALA    434644
# PERD_OLFT    434124
# DOR_ABD      439039
# FADIGA       389988
# dtype: int64

# %%
# Criar coluna de acumulo de sintomas em dois formatos: progressivo
cols_sin = ['FEBRE','TOSSE','GARGANTA','DISPNEIA','DESC_RESP','SATURACAO','DIARREIA','VOMITO',
            'PERD_PALA','PERD_OLFT','DOR_ABD','FADIGA','OUTRO_SIN']
df_train['ACUMULADO_SINTOMAS'] = (df_train[cols_sin] == 1).sum(axis=1)
df_test['ACUMULADO_SINTOMAS'] = (df_test[cols_sin] == 1).sum(axis=1)

# %% [markdown]
# **Nota** - Não tem muito o que trabalhar nessas variáveis em relação a imputação.

# %% [markdown]
# **Variáveis relacionadas ao HOSPITAL**

# %%
# Definir colunas de análise nesta seção
cols = ['HOSPITAL','UTI','SUPORT_VEN','NOSOCOMIAL']

# %%
# Checar nulos
df_train[cols].isna().sum()
# Out:
# HOSPITAL       26483
# UTI           162527
# SUPORT_VEN    164962
# NOSOCOMIAL    201505
# dtype: int64

# %% [markdown]
# Imputar variáveis a partir de condições lógicas

# %%
# Caso HOSPITAL seja nulo, inserir como Sim caso certas condições sejam apresentadas
c1 = df_train['HOSPITAL'].isna()
c2 = (df_train['UTI'] == 1) | (df_train['SUPORT_VEN'].isin([1, 2])) | (df_train['NOSOCOMIAL'] == 1)
df_train.loc[c1 & c2, 'HOSPITAL'] = 1

# Caso HOSPITAL seja 1 e NOSOCOMIAL nulo, inserir 9
c3 = (df_train['HOSPITAL'] == 1) & (df_train['NOSOCOMIAL'].isna())
df_train.loc[c3, 'NOSOCOMIAL'] = 9

# %%
# Caso HOSPITAL seja nulo, inserir como Sim caso certas condições sejam apresentadas
c1 = df_test['HOSPITAL'].isna()
c2 = (df_test['UTI'] == 1) | (df_test['SUPORT_VEN'].isin([1, 2])) | (df_test['NOSOCOMIAL'] == 1)
df_test.loc[c1 & c2, 'HOSPITAL'] = 1

# Caso HOSPITAL seja 1 e NOSOCOMIAL nulo, inserir 9
c3 = (df_test['HOSPITAL'] == 1) & (df_test['NOSOCOMIAL'].isna())
df_test.loc[c3, 'NOSOCOMIAL'] = 9

# %% [markdown]
# **Variáveis relacionadas ao MEDICACAO**

# %%
# Definir colunas de análise nesta seção
cols = ['VACINA','ANTIVIRAL','TP_ANTIVIR']

# %%
# Checar nulos
df_train[cols].isna().sum()
# Out:
# VACINA         384795
# ANTIVIRAL      224350
# TP_ANTIVIR    1268247
# dtype: int64

# %%
# Caso ANTIVIRAL seja nulo, inserir como Sim caso certas condições sejam apresentadas
c1 = (df_train['ANTIVIRAL'].isna()) & (df_train['TP_ANTIVIR'].isin([1,2,3]))
df_train.loc[c1, 'ANTIVIRAL'] = 1

# %%
# Caso ANTIVIRAL seja, inserir como Não em TP_ANTIVIR como 99
c1 = (df_train['ANTIVIRAL'] == 2) & (df_train['TP_ANTIVIR'].isna())
df_train.loc[c1, 'TP_ANTIVIR'] = 99

# %% [markdown]
# **Variáveis relacionadas ao PACIENTE_SAUDE_DETALHE**

# %%
# Definir colunas de análise nesta seção
cols = ['FATOR_RISC','CARDIOPATI','HEMATOLOGI','SIND_DOWN','HEPATICA','ASMA','DIABETES','NEUROLOGIC','PNEUMOPATI',
        'IMUNODEPRE','RENAL','OBESIDADE','OBES_IMC','OUT_MORBI','MORB_DESC']

# %%
# Especificar colunas de SAUDE_DETALHE
cols_saude = ['CARDIOPATI','HEMATOLOGI','SIND_DOWN','HEPATICA','ASMA','DIABETES','NEUROLOGIC','PNEUMOPATI',
              'IMUNODEPRE','RENAL','OBESIDADE','OUT_MORBI','PUERPERA']

# Criar acumulado
df_train['ACUMULADO_SAUDE'] = (df_train[cols_saude] == 1).sum(axis=1)
df_test['ACUMULADO_SAUDE'] = (df_test[cols_saude] == 1).sum(axis=1)

# %%
# Criar outras variações
df_train['ACUMULADO_SAUDE_MAIS_SINTOMA'] = df_train[['ACUMULADO_SAUDE','ACUMULADO_SINTOMAS']].sum(axis=1)
df_test['ACUMULADO_SAUDE_MAIS_SINTOMA'] = df_test[['ACUMULADO_SAUDE','ACUMULADO_SINTOMAS']].sum(axis=1)

df_train['ACUMULADO_SAUDE_SINTOMA_VACCOV'] = df_train['ACUMULADO_SAUDE_MAIS_SINTOMA']+(df_train['VACINA_COV'] == 1).astype(int)
df_test['ACUMULADO_SAUDE_SINTOMA_VACCOV'] = df_test['ACUMULADO_SAUDE_MAIS_SINTOMA']+(df_test['VACINA_COV'] == 1).astype(int)

# %%
# Caso FATOR de RISCO seja 2, então para as variáveis saúde inserir 2 indicando ausência nas de fator de riso
df_train.loc[df_train['FATOR_RISC'] == 2, cols_saude] = 2
df_train.loc[(df_train['FATOR_RISC'] == 2)&(df_train['PUERPERA'] != 99), 'PUERPERA'] = 2

df_test.loc[df_test['FATOR_RISC'] == 2, cols_saude] = 2
df_test.loc[(df_test['FATOR_RISC'] == 2)&(df_test['PUERPERA'] != 99), 'PUERPERA'] = 2

# %%
# Caso tenha outro tipo de fator de risco porém sem info, adicionar string específica
df_train.loc[(df_train['OUT_MORBI'] == 1)&(df_train['MORB_DESC'].isna()), 'MORB_DESC'] = 'FATOR_RISCO_NAO_DESCRITO'
df_test.loc[(df_test['OUT_MORBI'] == 1)&(df_test['MORB_DESC'].isna()), 'MORB_DESC'] = 'FATOR_RISCO_NAO_DESCRITO'

# %%
# Caso tenha nulo em MORB_DESC inserir string de ignorado
df_train.loc[df_train['MORB_DESC'].isna(), 'MORB_DESC'] = 'IGNORADO'
df_test.loc[df_test['MORB_DESC'].isna(), 'MORB_DESC'] = 'IGNORADO'

# %% [markdown]
# **Variáveis relacionadas ao PACIENTE_INFORMACAO**

# %%
# Definir colunas de análise nesta seção
cols = ['SG_UF','SG_UF_NOT','ID_REGIONA','CO_REGIONA','ID_MUNICIP','CO_MUN_NOT','CS_SEXO','NU_IDADE_N','TP_IDADE',
        'CS_RACA','CS_ESCOL_N','CS_ZONA','AVE_SUINO','OUT_ANIM']

# %%
# Checar nulos
(100*df_train[cols].isna().sum()/len(df_train)).round(2)
# Out:
# SG_UF          0.02
# SG_UF_NOT      0.00
# ID_REGIONA    11.36
# CO_REGIONA    11.36
# ID_MUNICIP     0.00
# CO_MUN_NOT     0.00
# CS_SEXO        0.00
# NU_IDADE_N     0.00
# TP_IDADE       0.00
# CS_RACA        0.00
# CS_ESCOL_N    34.98
# CS_ZONA       10.36
# AVE_SUINO     16.90
# OUT_ANIM      99.91
# dtype: float64

# %%
# Imputar SG_UF através da versão not
c1 = (df_train['SG_UF'].isna())&(df_train['SG_UF_NOT'].notnull())
df_train.loc[c1, 'SG_UF'] = df_train.loc[c1, 'SG_UF_NOT']

c1 = (df_test['SG_UF'].isna())&(df_test['SG_UF_NOT'].notnull())
df_test.loc[c1, 'SG_UF'] = df_test.loc[c1, 'SG_UF_NOT']

# %%
# Definir colunas para derrubar - redundantes e repetidas
cols_to_drop = ['ID_REGIONA','CO_REGIONA','SG_UF','CO_MUN_NOT']

df_train.drop(columns=cols_to_drop, inplace=True)
df_test.drop(columns=cols_to_drop, inplace=True)

# %%
# Definir colunas de análise nesta seção novamente
cols = [c for c in cols if c not in cols_to_drop]

# %% [markdown]
# Aqui vamos otimizar a coluna `AVES_SUINO` unificando ela a `OUT_ANIM` criando uma nova variável:

# %%
# Criar
outros_anim = list(set(df_train['OUT_ANIM'].dropna().unique().tolist() + df_test['OUT_ANIM'].dropna().unique().tolist()))

# %%
# Gerar listas hierarquicas especificas para consolidar categorias em tipo de amostra X (prioridade de baixo para cima)
outros_anim_dog = [c for c in outros_anim if 'CACHOR' in c or 'CANINO' in c or 'CAES' in c or 'CAO' in c or 'CAHORRO' in c]
outros_anim_cat = [c for c in outros_anim if 'GATO' in c or 'FELIN' in c]
outros_anim_boi = [c for c in outros_anim if 'GADO' in c or 'BOVINO' in c or 'BOI' in c or 'VACA' in c]
outros_anim_gal = [c for c in outros_anim if 'GALINHA' in c]

# Especificar novas categorias de agrupamento por ordem de prioridade
outros_anim_nCats = ['REL_CACHORRO', 'REL_GATO','REL_BOI', 'REL_GALINHA']
outros_anim_oCats = [outros_anim_dog, outros_anim_cat, outros_anim_boi, outros_anim_gal]

# Criar colunas
df_train['ANIM_OUT_NOVO'] = np.nan
df_test['ANIM_OUT_NOVO'] = np.nan

# Aplicar novas categorias evitando sobreposição
for n_cat, o_cats in zip(outros_anim_nCats, outros_anim_oCats):
    df_train.loc[(df_train['OUT_ANIM'].isin(o_cats)) & (df_train['ANIM_OUT_NOVO'].isna()), 'ANIM_OUT_NOVO'] = n_cat
    df_test.loc[(df_test['OUT_ANIM'].isin(o_cats)) & (df_test['ANIM_OUT_NOVO'].isna()), 'ANIM_OUT_NOVO'] = n_cat

# Converter todas as demais categorias restantes provalvemente raras em umas só para reduzir ruído ao modelo
c1 = (~df_train['ANIM_OUT_NOVO'].isin(outros_anim_nCats)) & (df_train['OUT_ANIM'].notnull())
df_train.loc[c1, 'ANIM_OUT_NOVO'] = 'REL_OUTROS_RESULTADOS'

c1 = (~df_test['ANIM_OUT_NOVO'].isin(outros_anim_nCats)) & (df_test['OUT_ANIM'].notnull())
df_test.loc[c1, 'ANIM_OUT_NOVO'] = n_cat

# %%
# Caso AVE_SUINO seja vazio, inserir ignorado
df_train['AVE_SUINO'].fillna(9, inplace=True)
df_test['AVE_SUINO'].fillna(9, inplace=True)

# %%
# Converter AVE_SUINO em string
c1 = (df_train['AVE_SUINO'] == 1)
df_train.loc[c1, 'AVE_SUINO_NOVO'] = 'CONVIVIO_AVE_SUINO'

c2 = (df_train['AVE_SUINO'] == 2)
df_train.loc[c2, 'AVE_SUINO_NOVO'] = 'SEM_CONVIVIO_ANIMAL'

c3 = (df_train['AVE_SUINO'] == 3) & (df_train['ANIM_OUT_NOVO'].notnull())
df_train.loc[c3, 'AVE_SUINO_NOVO'] = df_train.loc[c3, 'ANIM_OUT_NOVO']

c4 = (df_train['AVE_SUINO'] == 3) & (df_train['ANIM_OUT_NOVO'].isna())
df_train.loc[c4, 'AVE_SUINO_NOVO'] = 'CONVIVIO_NAO_DETALHADO'

c5 = (df_train['AVE_SUINO'] == 9)
df_train.loc[c5, 'AVE_SUINO_NOVO'] = 'CONVIVIO_IGNORADO'

# Visualizar nova coluna
df_train['AVE_SUINO_NOVO'].value_counts(dropna=False)
# Out:
# SEM_CONVIVIO_ANIMAL      879296
# CONVIVIO_IGNORADO        409145
# CONVIVIO_AVE_SUINO        11375
# REL_CACHORRO                843
# REL_GATO                    158
# REL_OUTROS_RESULTADOS        77
# REL_BOI                      68
# REL_GALINHA                  18
# Name: AVE_SUINO_NOVO, dtype: int64

# %%
# Converter AVE_SUINO em string
c1 = (df_test['AVE_SUINO'] == 1)
df_test.loc[c1, 'AVE_SUINO_NOVO'] = 'CONVIVIO_AVE_SUINO'

c2 = (df_test['AVE_SUINO'] == 2)
df_test.loc[c2, 'AVE_SUINO_NOVO'] = 'SEM_CONVIVIO_ANIMAL'

c3 = (df_test['AVE_SUINO'] == 3) & (df_test['ANIM_OUT_NOVO'].notnull())
df_test.loc[c3, 'AVE_SUINO_NOVO'] = df_test.loc[c3, 'ANIM_OUT_NOVO']

c4 = (df_test['AVE_SUINO'] == 3) & (df_test['ANIM_OUT_NOVO'].isna())
df_test.loc[c4, 'AVE_SUINO_NOVO'] = 'CONVIVIO_NAO_DETALHADO'

c5 = (df_test['AVE_SUINO'] == 9)
df_test.loc[c5, 'AVE_SUINO_NOVO'] = 'CONVIVIO_IGNORADO'

# Visualizar nova coluna
df_test['AVE_SUINO_NOVO'].value_counts(dropna=False)
# Out:
# SEM_CONVIVIO_ANIMAL    586685
# CONVIVIO_IGNORADO      272295
# CONVIVIO_AVE_SUINO       7558
# REL_CACHORRO              561
# REL_GATO                  106
# REL_GALINHA                63
# REL_BOI                    53
# Name: AVE_SUINO_NOVO, dtype: int64

# %%
# Derrubar colunas
cols_to_drop = ['AVE_SUINO', 'OUT_ANIM','ANIM_OUT_NOVO']

df_train.drop(columns=cols_to_drop, inplace=True)
df_test.drop(columns=cols_to_drop, inplace=True)

# %%
# Modificar cols novamente
cols = ['SG_UF_NOT','ID_MUNICIP','CS_ZONA','CS_SEXO','CS_RACA','NU_IDADE_N','TP_IDADE','CS_ESCOL_N','AVE_SUINO_NOVO']

# %%
# Checar nulos
(100*df_train[cols].isna().sum()/len(df_train)).round(2).sort_values(ascending=False)
# Out:
# CS_ESCOL_N        34.98
# CS_ZONA           10.36
# SG_UF_NOT          0.00
# ID_MUNICIP         0.00
# CS_SEXO            0.00
# CS_RACA            0.00
# NU_IDADE_N         0.00
# TP_IDADE           0.00
# AVE_SUINO_NOVO     0.00
# dtype: float64

# %% [markdown]
# ### **Listar variáveis de acordo a natureza**

# %%
# Listar todas as colunas que são categóricas por definição e que podem estar codificadas como numéricas
cols_cat = ['SG_UF_NOT', 'ID_MUNICIP', 'CS_ZONA', 'SURTO_SG',                                              # LOCALIDADE
            'CS_SEXO', 'CS_GESTANT', 'CS_RACA', 'CS_ESCOL_N', 'HISTO_VGM','AVE_SUINO_NOVO',                # INFO PACIENTE
            'FEBRE', 'TOSSE', 'GARGANTA', 'DISPNEIA', 'DESC_RESP', 'SATURACAO', 'DIARREIA', 'VOMITO',      # SINTOMA
            'OUTRO_SIN', 'OUTRO_DES', 'DOR_ABD', 'FADIGA', 'PERD_OLFT', 'PERD_PALA',                       # SINTOMA
            'FATOR_RISC', 'PUERPERA', 'CARDIOPATI', 'HEMATOLOGI', 'SIND_DOWN', 'HEPATICA', 'ASMA',         # FATOR DE RISCO
            'DIABETES', 'NEUROLOGIC', 'PNEUMOPATI', 'IMUNODEPRE', 'RENAL', 'OBESIDADE',                    # FATOR DE RISCO 
            'MORB_DESC','OUT_MORBI',                                                                       # FATOR DE RISCO
            'RAIOX_RES', 'RAIOX_OUT_NOVO', 'TOMO_RES', 'TOMO_OUT_NOVO',                                    # EXAME
            'RAIOX_OUT', 'TOMO_OUT', 'OUT_AMOST',                                                          # OUTRO ORIGINAL
            'VACINA', 'ANTIVIRAL', 'TP_ANTIVIR',                                                           # GRIPE / ANTI VIRAL
            'VACINA_COV',                                                                                  # VACINA COVID
            'HOSPITAL', 'UTI', 'SUPORT_VEN', 'NOSOCOMIAL',                                                 # HOSPITALIZAÇÃO
            'AMOSTRA', 'TP_AMOSTRA', 'AMOSTRA_OUT_NOVO',                                                   # COLETA AMOSTRA
            'MAE_VAC', 'M_AMAMENTA']                                                                       # MAE RELACIONADO

# Listar colunas numéricas
cols_num = ['SEM_NOT','SEM_PRI',                      # INFECCAO
            'NU_IDADE_N','TP_IDADE',                  # INFO PACIENTE
            'DOSE_COV_N',                             # QTD DOSES TOMADAS
            'ACUMULADO_SINTOMAS',                     # ACUMULADO SINTOMAS
            'ACUMULADO_SAUDE',                        # ACUMULADO FATOR DE RISCO
            'ACUMULADO_SAUDE_MAIS_SINTOMA',           # ACUMULADO SINTOMAS + FATOR DE RISCO
            'ACUMULADO_SAUDE_SINTOMA_VACCOV']         # ACUMULADO SINTOMAS + FATOR DE RISCO + DOSES VACINA
# Listar colunas binárias por definição
cols_bin = ['DOSE_1_COV','DOSE_2_COV', 'DOSE_REF']    # VACINA COVID

# %% [markdown]
# ### Codificar corretamente variáveis categóricas

# %%
# Especificar dicionário para casos especificos
de_para_cat = {'CS_ZONA': {1:'URBANA', 2:'RURAL', 3:'PERIURBANA',9:'URBANA'},
               'HISTO_VGM':{1:'SIM', 2:'NAO', 9:'IGNORADO', 0:'IGNORADO'},
               'CS_GESTANT': {1:'PRI_TRI',2:'SEG_TRI',3:'TRC_TRI',4:'IDD_GEST_IGNORADA',5:'NAO',6:'NAO_APLICA',9:'IGNORADO'},
               'CS_RACA': {1:'BRANCA',2:'PRETA',3:'AMARELA',4:'PARDA',5:'INDIGENA',9:'IGNORADO'},
               'CS_ESCOL_N': {0:'ANALFAB',1:'1_5_SERIE',2:'6_9_SERIE',3:'ENS_MEDIO',4:'ENS_SUP',5:'NAO_APLICA',9:'IGNORADO'},
               'PUERPERA': {1:'SIM', 2:'NAO', 9:'IGNORADO',99:'NAO_SE_APLICA_HOMEM'},
               'RAIOX_RES': {1:'NORMAL',2:'INFILTRADO_INTERSTICIAL',3:'CONSOLIDACAO',
                             4:'MISTO',5:'OUTRO',6:'NAO_FEITO',9:'IGNORADO'},
               'TOMO_RES': {1:'TIPICO_COV19',2:'INDETERMINADO_COV19',3:'ATIPICO_COV19',
                            4:'NEGATIVO_PNM',5:'OUTRO',6:'NAO_FEITO',9:'IGNORADO'},
               'TP_ANTIVIR': {1:'OSELTAMIVIR',2:'ZANAMIVIR',3:'OUTRO'},
               'SUPORT_VEN': {1:'SIM_INVASIVO',2:'SIM_NAO_INVASIVO',3:'NAO',9:'IGNORADO'},
               'TP_AMOSTRA': {1:'SECREC_NASO_OROFARINGE',2:'LAVADO_BROCO_ALVEOLAR',3:'TECIDO_POST_MORTEM',
                              4:'OUTRA',5:'LCR',9:'IGNORADO'},
               'MAE_VAC': {1:'SIM', 2:'NAO', 9:'IGNORADO',99:'NAO_SE_APLICA_HOMEM'},
               'M_AMAMENTA': {1:'SIM', 2:'NAO', 9:'IGNORADO',99:'NAO_SE_APLICA_HOMEM'}}

# Loop para modificar
for c, d in de_para_cat.items():
    df_train[c].replace(d, inplace=True)
    df_test[c].replace(d, inplace=True)

# %%
# Especificar lista de colunas que possuem seus valores numéricos equivalentes as mesmas strings
cols_cat_gen = ['FEBRE', 'TOSSE', 'GARGANTA', 'DISPNEIA', 'DESC_RESP', 'SATURACAO', 'DIARREIA', 'VOMITO',
                'OUTRO_SIN', 'DOR_ABD', 'FADIGA', 'PERD_OLFT', 'PERD_PALA', 'FATOR_RISC', 'CARDIOPATI', 
                'HEMATOLOGI', 'SIND_DOWN', 'HEPATICA', 'ASMA', 'DIABETES', 'NEUROLOGIC', 'PNEUMOPATI', 
                'IMUNODEPRE', 'RENAL', 'OBESIDADE', 'OUT_MORBI', 
                 'SURTO_SG','VACINA','ANTIVIRAL','VACINA_COV','HOSPITAL','UTI','NOSOCOMIAL','AMOSTRA']
# Loop para modificar
for c in cols_cat_gen:
    df_train[c].replace({1:'SIM', 2:'NAO', 9:'IGNORADO'}, inplace=True)
    df_test[c].replace({1:'SIM', 2:'NAO', 9:'IGNORADO'}, inplace=True)

# %%
# Validação das colunas categoricas corrigida
for c in cols_cat_gen + list(de_para_cat.keys()):
    print(f'##################################### {c}')
    print(df_test[c].unique())
# Out:
# ##################################### FEBRE
# ['SIM' nan 'NAO' 'IGNORADO']
# ##################################### TOSSE
# ['SIM' nan 'NAO' 'IGNORADO']
# ##################################### GARGANTA
# ['NAO' nan 'SIM' 'IGNORADO']
# ##################################### DISPNEIA
# ['NAO' nan 'SIM' 'IGNORADO']
# ##################################### DESC_RESP
# ['SIM' nan 'NAO' 'IGNORADO']
# ##################################### SATURACAO
# ['NAO' nan 'SIM' 'IGNORADO']
# ##################################### DIARREIA
# ['NAO' nan 'IGNORADO' 'SIM']
# ##################################### VOMITO
# ['NAO' nan 'SIM' 'IGNORADO']
# ##################################### OUTRO_SIN
# ['NAO' nan 'SIM' 'IGNORADO']
# ##################################### DOR_ABD
# ['NAO' nan 'SIM' 'IGNORADO']
# ##################################### FADIGA
# ['NAO' nan 'SIM' 'IGNORADO']
# ##################################### PERD_OLFT
# ['NAO' nan 'IGNORADO' 'SIM']
# ##################################### PERD_PALA
# ['NAO' nan 'IGNORADO' 'SIM']
# ##################################### FATOR_RISC
# ['NAO' 'SIM']
# ##################################### CARDIOPATI
# ['NAO' 'SIM' nan 'IGNORADO']
# ##################################### HEMATOLOGI
# ['NAO' nan 'IGNORADO' 'SIM']
# ##################################### SIND_DOWN
# ['NAO' nan 'IGNORADO' 'SIM']
# ##################################### HEPATICA
# ['NAO' nan 'SIM' 'IGNORADO']
# ##################################### ASMA
# ['NAO' nan 'SIM' 'IGNORADO']
# ##################################### DIABETES
# ['NAO' nan 'SIM' 'IGNORADO']
# ##################################### NEUROLOGIC
# ['NAO' nan 'SIM' 'IGNORADO']
# ##################################### PNEUMOPATI
# ['NAO' nan 'IGNORADO' 'SIM']
# ##################################### IMUNODEPRE
# ['NAO' nan 'IGNORADO' 'SIM']
# ##################################### RENAL
# ['NAO' nan 'IGNORADO' 'SIM']
# ##################################### OBESIDADE
# ['NAO' nan 'SIM' 'IGNORADO']
# ##################################### OUT_MORBI
# ['NAO' nan 'SIM' 'IGNORADO']
# ##################################### SURTO_SG
# [nan 'NAO' 'SIM' 'IGNORADO']
# ##################################### VACINA
# ['SIM' nan 'NAO' 'IGNORADO']
# ##################################### ANTIVIRAL
# ['NAO' 'IGNORADO' nan 'SIM']
# ##################################### VACINA_COV
# ['NAO' 'SIM' 'IGNORADO']
# ##################################### HOSPITAL
# ['SIM' nan 'NAO' 'IGNORADO']
# ##################################### UTI
# ['NAO' nan 'SIM' 'IGNORADO']
# ##################################### NOSOCOMIAL
# ['NAO' 'IGNORADO' nan 'SIM']
# ##################################### AMOSTRA
# ['SIM' 'NAO' 'IGNORADO']
# ##################################### CS_ZONA
# ['RURAL' 'URBANA' nan 'PERIURBANA']
# ##################################### HISTO_VGM
# ['IGNORADO' 'NAO' 'SIM']
# ##################################### CS_GESTANT
# ['NAO_APLICA' 'NAO' 'IGNORADO' 'TRC_TRI' 'SEG_TRI' 'PRI_TRI'
#  'IDD_GEST_IGNORADA']
# ##################################### CS_RACA
# ['PARDA' 'BRANCA' 'PRETA' 'IGNORADO' 'AMARELA' 'INDIGENA']
# ##################################### CS_ESCOL_N
# [nan 'IGNORADO' '6_9_SERIE' 'ENS_SUP' 'ANALFAB' 'NAO_APLICA' 'ENS_MEDIO'
#  '1_5_SERIE']
# ##################################### PUERPERA
# ['NAO' 'NAO_SE_APLICA_HOMEM' 'IGNORADO' 'SIM']
# ##################################### RAIOX_RES
# ['NORMAL' 'NAO_FEITO' 'IGNORADO' 'INFILTRADO_INTERSTICIAL' 'OUTRO' 'MISTO'
#  'CONSOLIDACAO']
# ##################################### TOMO_RES
# ['NAO_FEITO' 'NEGATIVO_PNM' 'IGNORADO' 'INDETERMINADO_COV19' 'OUTRO'
#  'ATIPICO_COV19' 'TIPICO_COV19']
# ##################################### TP_ANTIVIR
# [nan 'OSELTAMIVIR' 'ZANAMIVIR' 'OUTRO']
# ##################################### SUPORT_VEN
# ['NAO' 'SIM_NAO_INVASIVO' nan 'IGNORADO' 'SIM_INVASIVO']
# ##################################### TP_AMOSTRA
# ['SECREC_NASO_OROFARINGE' 'OUTRA' 'IGNORADO' 'LAVADO_BROCO_ALVEOLAR' 'LCR'
#  'TECIDO_POST_MORTEM']
# ##################################### MAE_VAC
# ['NAO_SE_APLICA_HOMEM' 'IGNORADO' 'NAO' 'SIM']
# ##################################### M_AMAMENTA
# ['NAO_SE_APLICA_HOMEM' 'IGNORADO' 'NAO' 'SIM']

# %% [markdown]
# ### Aplicar + criação de variáveis

# %%
# Quando a notificao foi na semana dos primeiros sintomas
df_train['SEM_PRI_NOT_IGUAIS'] = (df_train['SEM_PRI'] == df_train['SEM_NOT']).astype(int)
df_test['SEM_PRI_NOT_IGUAIS'] = (df_test['SEM_PRI'] == df_test['SEM_NOT']).astype(int)

# Calcular diff absoluta
df_train['SEM_PRI_NOT_DIFF_ABS'] = (df_train['SEM_PRI'] - df_train['SEM_NOT']).abs()
df_test['SEM_PRI_NOT_DIFF_ABS'] = (df_test['SEM_PRI'] - df_test['SEM_NOT']).abs()

# %%
# Apontar realização de Raio X + TC e Ambos
df_train['FEZ_RAIOX'] = df_train['RAIOX_RES'].isin(['NORMAL','INFILTRADO_INTERSTICIAL','CONSOLIDACAO',
                                                    'MISTO','OUTRO']).astype(int)
df_train['FEZ_TOMOG'] = df_train['TOMO_RES'].isin(['TIPICO_COV19','INDETERMINADO_COV19','ATIPICO_COV19',
                                                   'NEGATIVO_PNM','OUTRO']).astype(int)
df_train['FEZ_RAIOX_TOMOG'] = df_train['FEZ_RAIOX'] + df_train['FEZ_TOMOG']

# Apontar realização de Raio X + TC e Ambos
df_test['FEZ_RAIOX'] = df_test['RAIOX_RES'].isin(['NORMAL','INFILTRADO_INTERSTICIAL','CONSOLIDACAO',
                                                    'MISTO','OUTRO']).astype(int)
df_test['FEZ_TOMOG'] = df_test['TOMO_RES'].isin(['TIPICO_COV19','INDETERMINADO_COV19','ATIPICO_COV19',
                                                   'NEGATIVO_PNM','OUTRO']).astype(int)
df_test['FEZ_RAIOX_TOMOG'] = df_test['FEZ_RAIOX'] + df_test['FEZ_TOMOG']

# %%
# Apontar TOMOG que apresentaram covid
df_train['TOMOG_COV19'] = ((df_train['TOMO_RES'] == 'TIPICO_COV19')|(df_train['TOMO_OUT_NOVO'] == 'REL_COVID')).astype(int)
df_test['TOMOG_COV19'] = ((df_test['TOMO_RES'] == 'TIPICO_COV19')|(df_test['TOMO_OUT_NOVO'] == 'REL_COVID')).astype(int)

# %%
# Aplicar a unidade de fato em TP para diferenciar melhor os valores
df_train.loc[df_train['TP_IDADE'] == 1, 'TP_IDADE'] = 1
df_train.loc[df_train['TP_IDADE'] == 2, 'TP_IDADE'] = 30
df_train.loc[df_train['TP_IDADE'] == 3, 'TP_IDADE'] = 365

df_test.loc[df_test['TP_IDADE'] == 1, 'TP_IDADE'] = 1
df_test.loc[df_test['TP_IDADE'] == 2, 'TP_IDADE'] = 30
df_test.loc[df_test['TP_IDADE'] == 3, 'TP_IDADE'] = 365

# %% [markdown]
# ### Listar novamente todas as variáveis por natureza II
#
# Adicionar as criadas anteriormente.

# %%
# Checar variáveis faltantes na listagem
[c for c in df_train.columns if c not in cols_cat + cols_num + cols_bin and c != 'CLASSI_FIN']
# Out:
# ['SEM_PRI_NOT_IGUAIS',
#  'SEM_PRI_NOT_DIFF_ABS',
#  'FEZ_RAIOX',
#  'FEZ_TOMOG',
#  'FEZ_RAIOX_TOMOG',
#  'TOMOG_COV19']

# %%
# Adicionar de acordo a natureza
cols_num += ['SEM_PRI_NOT_IGUAIS','SEM_PRI_NOT_DIFF_ABS','FEZ_RAIOX_TOMOG']
cols_bin += ['FEZ_RAIOX','FEZ_TOMOG','TOMOG_COV19']

# %%
# Checar variáveis faltantes na listagem
[c for c in df_train.columns if c not in cols_cat + cols_num + cols_bin and c != 'CLASSI_FIN']
# Out:
# []

# %% [markdown]
# # Divisão de treino e validação

# %%
# Separar dados em X e Y
X = df_train[cols_num + cols_bin + cols_cat].copy()
Y = df_train['CLASSI_FIN'].copy()

# %%
# Separar
x_train, x_valid, y_train, y_valid = train_test_split(X, Y, test_size=0.20, random_state=1206, stratify=Y)

# %%
# Criar teste seguindo a mesma ordem das colunas
x_test = df_test[cols_num + cols_bin + cols_cat].copy()

# %%
# Liberar espaço deletando dataframes antigos
del X, Y, df_test, df_train

# %%
# Checar distribuição de Y
y_train.value_counts(normalize=True)
# Out:
# 5    0.666859
# 4    0.292403
# 2    0.024164
# 1    0.012012
# 3    0.004562
# Name: CLASSI_FIN, dtype: float64

# %%
# Checar distribuição de Y
y_valid.value_counts(normalize=True)
# Out:
# 5    0.666859
# 4    0.292403
# 2    0.024163
# 1    0.012014
# 3    0.004562
# Name: CLASSI_FIN, dtype: float64

# %% [markdown]
# # Imputação de dados
#
# Estratégia:
# - Categóricas: Imputar string "INFO_FALTANTE"
# - Numéricas e Binárias: Imputar a moda

# %%
# Aplicar estratégia para categoricas
for c in cols_cat:
    x_train.loc[x_train[c].isna(), c] = 'INFO_FALTANTE'
    x_valid.loc[x_valid[c].isna(), c] = 'INFO_FALTANTE'
    x_test.loc[x_test[c].isna(), c] = 'INFO_FALTANTE'

# %%
# Aplicar estratégia para numéricas
for c in cols_num + cols_bin:
    # Calcular a moda no treino
    valor_moda = x_train[c].dropna().mode()[0]
    print(f'> {c} possui moda de {valor_moda}')
    # Imputar
    x_train.loc[x_train[c].isna(), c] = valor_moda
    x_valid.loc[x_valid[c].isna(), c] = valor_moda
    x_test.loc[x_test[c].isna(), c] = valor_moda
# Out:
# > SEM_NOT possui moda de 12
# > SEM_PRI possui moda de 9
# > NU_IDADE_N possui moda de 0
# > TP_IDADE possui moda de 365
# > DOSE_COV_N possui moda de 0
# > ACUMULADO_SINTOMAS possui moda de 4
# > ACUMULADO_SAUDE possui moda de 0
# > ACUMULADO_SAUDE_MAIS_SINTOMA possui moda de 5
# > ACUMULADO_SAUDE_SINTOMA_VACCOV possui moda de 5
# > SEM_PRI_NOT_IGUAIS possui moda de 0
# > SEM_PRI_NOT_DIFF_ABS possui moda de 1
# > FEZ_RAIOX_TOMOG possui moda de 1
# > DOSE_1_COV possui moda de 0
# > DOSE_2_COV possui moda de 0
# > DOSE_REF possui moda de 0
# > FEZ_RAIOX possui moda de 0
# > FEZ_TOMOG possui moda de 0
# > TOMOG_COV19 possui moda de 0

# %% [markdown]
# # Modelagem
#
# **Preparar dados**

# %%
# Criar conjuntos de treino Y binários
y1_train = (y_train == 1).astype(int)
y2_train = (y_train == 2).astype(int)
y3_train = (y_train == 3).astype(int)
y4_train = (y_train == 4).astype(int)
y5_train = (y_train == 5).astype(int)

# %%
# Criar conjuntos de validação Y binários
y1_valid = (y_valid == 1).astype(int)
y2_valid = (y_valid == 2).astype(int)
y3_valid = (y_valid == 3).astype(int)
y4_valid = (y_valid == 4).astype(int)
y5_valid = (y_valid == 5).astype(int)

# %%
# Converter para categorical type
for c in cols_cat:
    x_train[c] = x_train[c].astype('category')
    x_valid[c] = pd.Categorical(x_valid[c], x_train[c].astype('category').cat.categories) 
    x_test[c] = pd.Categorical(x_test[c], x_train[c].astype('category').cat.categories)

# %% [markdown]
# **Validação de Modelos já estabelecidos**
#
# [Referência](https://optuna.readthedocs.io/en/stable/reference/generated/optuna.integration.lightgbm.LightGBMTuner.html)
#
# [Parâmetros](https://lightgbm.readthedocs.io/en/latest/Parameters.html)

# %%
# Listar nomes das variáveis
feats_all = cols_num + cols_bin + cols_cat
feats_cat = cols_cat

# %%
# Converter X e Y para formato de dataset do lightgbm - treino
ds1_train = lgb.Dataset(data=x_train, label=y1_train, feature_name=feats_all, categorical_feature=feats_cat)
ds2_train = lgb.Dataset(data=x_train, label=y2_train, feature_name=feats_all, categorical_feature=feats_cat)
ds3_train = lgb.Dataset(data=x_train, label=y3_train, feature_name=feats_all, categorical_feature=feats_cat)
ds4_train = lgb.Dataset(data=x_train, label=y4_train, feature_name=feats_all, categorical_feature=feats_cat)
ds5_train = lgb.Dataset(data=x_train, label=y5_train, feature_name=feats_all, categorical_feature=feats_cat)

# Converter X e Y para formato de dataset do lightgbm - validação
ds1_valid = lgb.Dataset(data=x_valid, label=y1_valid, feature_name=feats_all, categorical_feature=feats_cat)
ds2_valid = lgb.Dataset(data=x_valid, label=y2_valid, feature_name=feats_all, categorical_feature=feats_cat)
ds3_valid = lgb.Dataset(data=x_valid, label=y3_valid, feature_name=feats_all, categorical_feature=feats_cat)
ds4_valid = lgb.Dataset(data=x_valid, label=y4_valid, feature_name=feats_all, categorical_feature=feats_cat)
ds5_valid = lgb.Dataset(data=x_valid, label=y5_valid, feature_name=feats_all, categorical_feature=feats_cat)

# %%
# Criar versões unificadas para novo treinamento
x_train_valid = pd.concat([x_train, x_valid])
y1_train_valid = pd.concat([y1_train, y1_valid])
y2_train_valid = pd.concat([y2_train, y2_valid])
y3_train_valid = pd.concat([y3_train, y3_valid])
y4_train_valid = pd.concat([y4_train, y4_valid])
y5_train_valid = pd.concat([y5_train, y5_valid])

# Converter X e Y para formato de dataset do lightgbm - validação
ds1_train_valid = lgb.Dataset(data=x_train_valid, label=y1_train_valid, feature_name=feats_all, categorical_feature=feats_cat)
ds2_train_valid = lgb.Dataset(data=x_train_valid, label=y2_train_valid, feature_name=feats_all, categorical_feature=feats_cat)
ds3_train_valid = lgb.Dataset(data=x_train_valid, label=y3_train_valid, feature_name=feats_all, categorical_feature=feats_cat)
ds4_train_valid = lgb.Dataset(data=x_train_valid, label=y4_train_valid, feature_name=feats_all, categorical_feature=feats_cat)
ds5_train_valid = lgb.Dataset(data=x_train_valid, label=y5_train_valid, feature_name=feats_all, categorical_feature=feats_cat)

# %%
# Lidar com excesso de warnings de usuário não solucionáveis do LGBM
warnings.filterwarnings('ignore')

# %% [markdown]
# **Montar modelos para avaliar em prompt a validação**

# %%
# Definir número de rounds
nbr = 2500

# %%
# Especificar hiper parâmetros finais
hp5 = {'objective':'binary',
       'is_unbalance': True,
       'boosting_type': 'gbdt',
       'metric': 'binary_logloss', 
       'eta': 0.01,
       'num_leaves': 224,
       'feature_fraction': 0.85,
       'early_stopping_round': 25,
       "lambda_l1":8.526,
       "lambda_l2":0.011,
       'seed': 1206,
       'verbosity': -1,
       'num_threads':4}
hp4 = {'objective':'binary',
       'is_unbalance': True,
       'boosting_type': 'gbdt',
       'metric': 'binary_logloss', 
       'eta': 0.01,
       'num_leaves': 243,
       'feature_fraction': 0.85,
       'early_stopping_round': 25,
       "lambda_l1":8.526,
       "lambda_l2":0.011,
       'seed': 1206, 
       'verbosity': -1,
       'num_threads':4}
hp3 = {'objective':'binary',
       'is_unbalance': True,
       'boosting_type': 'gbdt',
       'metric': 'binary_logloss', 
       'eta': 0.01,
       'num_leaves': 243,
       'feature_fraction': 0.85,
       'early_stopping_round': 25,
       "lambda_l1":8.526,
       "lambda_l2":0.011,
       'seed': 1206, 
       'verbosity': -1,
       'num_threads':4}
hp2 = {'objective':'binary',
       'is_unbalance': True,
       'boosting_type': 'gbdt',
       'metric': 'binary_logloss', 
       'eta': 0.01,
       'num_leaves': 243,
       'feature_fraction': 0.85,
       'early_stopping_round': 25,
       "lambda_l1":8.526,
       "lambda_l2":0.011,
       'seed': 1206, 
       'verbosity': -1,
       'num_threads':4}
hp1 = {'objective':'binary',
       'is_unbalance': True,
       'boosting_type': 'gbdt',
       'metric': 'binary_logloss', 
       'eta': 0.01,
       'num_leaves': 243,
       'feature_fraction': 0.85,
       'early_stopping_round': 25,
       "lambda_l1":8.526,
       "lambda_l2":0.011,
       'seed': 1206, 
       'verbosity': -1,
       'num_threads':4}

# %%
# Treinar 100% modelo da classe 5
m5 = lgb.train(params=hp5, num_boost_round=nbr, train_set=ds5_train, valid_sets=[ds5_valid], 
               verbose_eval=True, categorical_feature=feats_cat)
print('Modelo da classe 5 finalizado')
# Out:
# [1]	valid_0's binary_logloss: 0.632011
# Training until validation scores don't improve for 25 rounds
# [2]	valid_0's binary_logloss: 0.627744
# [3]	valid_0's binary_logloss: 0.623591
# [4]	valid_0's binary_logloss: 0.619528
# [5]	valid_0's binary_logloss: 0.615586
# [6]	valid_0's binary_logloss: 0.611977
# [7]	valid_0's binary_logloss: 0.608229
# [8]	valid_0's binary_logloss: 0.604568
# [9]	valid_0's binary_logloss: 0.600985
# [10]	valid_0's binary_logloss: 0.597697
# [11]	valid_0's binary_logloss: 0.594293
# [12]	valid_0's binary_logloss: 0.590935
# [13]	valid_0's binary_logloss: 0.587663
# [14]	valid_0's binary_logloss: 0.584648
# [15]	valid_0's binary_logloss: 0.581552
# [16]	valid_0's binary_logloss: 0.57848
# [17]	valid_0's binary_logloss: 0.575577
# [18]	valid_0's binary_logloss: 0.572652
# [19]	valid_0's binary_logloss: 0.569788
# [20]	valid_0's binary_logloss: 0.566981
# [21]	valid_0's binary_logloss: 0.564225
# [22]	valid_0's binary_logloss: 0.561534
# [23]	valid_0's binary_logloss: 0.558895
# [24]	valid_0's binary_logloss: 0.556325
# [25]	valid_0's binary_logloss: 0.553783
# [26]	valid_0's binary_logloss: 0.551287
# [27]	valid_0's binary_logloss: 0.548849
# [28]	valid_0's binary_logloss: 0.546683
# [29]	valid_0's binary_logloss: 0.544336
# [30]	valid_0's binary_logloss: 0.54204
# [31]	valid_0's binary_logloss: 0.539782
# [32]	valid_0's binary_logloss: 0.537701
# [33]	valid_0's binary_logloss: 0.535533
# [34]	valid_0's binary_logloss: 0.533398
# [35]	valid_0's binary_logloss: 0.531292
# [36]	valid_0's binary_logloss: 0.52933
# [37]	valid_0's binary_logloss: 0.527322
# [38]	valid_0's binary_logloss: 0.525321
# [39]	valid_0's binary_logloss: 0.523375
# [40]	valid_0's binary_logloss: 0.521481
# [41]	valid_0's binary_logloss: 0.519602
# [42]	valid_0's binary_logloss: 0.517778
# [43]	valid_0's binary_logloss: 0.515981
# [44]	valid_0's binary_logloss: 0.514211
# [45]	valid_0's binary_logloss: 0.512462
# [46]	valid_0's binary_logloss: 0.510757
# [47]	valid_0's binary_logloss: 0.509178
# [48]	valid_0's binary_logloss: 0.507509
# [49]	valid_0's binary_logloss: 0.505987
# [50]	valid_0's binary_logloss: 0.504391
# [51]	valid_0's binary_logloss: 0.502922
# [52]	valid_0's binary_logloss: 0.501368
# [53]	valid_0's binary_logloss: 0.499836
# [54]	valid_0's binary_logloss: 0.498334
# [55]	valid_0's binary_logloss: 0.496835
# [56]	valid_0's binary_logloss: 0.495389
# [57]	valid_0's binary_logloss: 0.493966
# [58]	valid_0's binary_logloss: 0.492582
# [59]	valid_0's binary_logloss: 0.491287
# [60]	valid_0's binary_logloss: 0.489931
# [61]	valid_0's binary_logloss: 0.488612
# [62]	valid_0's binary_logloss: 0.487295
# [63]	valid_0's binary_logloss: 0.486006
# [64]	valid_0's binary_logloss: 0.484809
# [65]	valid_0's binary_logloss: 0.483668
# [66]	valid_0's binary_logloss: 0.482544
# [67]	valid_0's binary_logloss: 0.481432
# [68]	valid_0's binary_logloss: 0.480235
# [69]	valid_0's binary_logloss: 0.479064
# [70]	valid_0's binary_logloss: 0.477921
# [71]	valid_0's binary_logloss: 0.476786
# [72]	valid_0's binary_logloss: 0.475671
# [73]	valid_0's binary_logloss: 0.474574
# [74]	valid_0's binary_logloss: 0.47348
# [75]	valid_0's binary_logloss: 0.472437
# [76]	valid_0's binary_logloss: 0.471382
# [77]	valid_0's binary_logloss: 0.470421
# [78]	valid_0's binary_logloss: 0.469412
# [79]	valid_0's binary_logloss: 0.468394
# [80]	valid_0's binary_logloss: 0.467386
# [81]	valid_0's binary_logloss: 0.466404
# [82]	valid_0's binary_logloss: 0.465438
# [83]	valid_0's binary_logloss: 0.464516
# [84]	valid_0's binary_logloss: 0.463573
# [85]	valid_0's binary_logloss: 0.462647
# [86]	valid_0's binary_logloss: 0.461746
# [87]	valid_0's binary_logloss: 0.460854
# [88]	valid_0's binary_logloss: 0.459981
# [89]	valid_0's binary_logloss: 0.459111
# [90]	valid_0's binary_logloss: 0.458254
# [91]	valid_0's binary_logloss: 0.457486
# [92]	valid_0's binary_logloss: 0.456641
# [93]	valid_0's binary_logloss: 0.455823
# [94]	valid_0's binary_logloss: 0.455019
# [95]	valid_0's binary_logloss: 0.454224
# [96]	valid_0's binary_logloss: 0.45343
# [97]	valid_0's binary_logloss: 0.45268
# [98]	valid_0's binary_logloss: 0.451922
# [99]	valid_0's binary_logloss: 0.45118
# [100]	valid_0's binary_logloss: 0.450448
# [101]	valid_0's binary_logloss: 0.449741
# [102]	valid_0's binary_logloss: 0.449092
# [103]	valid_0's binary_logloss: 0.44836
# [104]	valid_0's binary_logloss: 0.447665
# [105]	valid_0's binary_logloss: 0.44707
# [106]	valid_0's binary_logloss: 0.446368
# [107]	valid_0's binary_logloss: 0.445669
# [108]	valid_0's binary_logloss: 0.44508
# [109]	valid_0's binary_logloss: 0.44444
# [110]	valid_0's binary_logloss: 0.4438
# [111]	valid_0's binary_logloss: 0.443237
# [112]	valid_0's binary_logloss: 0.44267
# [113]	valid_0's binary_logloss: 0.442135
# [114]	valid_0's binary_logloss: 0.441515
# [115]	valid_0's binary_logloss: 0.440898
# [116]	valid_0's binary_logloss: 0.440289
# [117]	valid_0's binary_logloss: 0.439698
# [118]	valid_0's binary_logloss: 0.439142
# [119]	valid_0's binary_logloss: 0.438589
# [120]	valid_0's binary_logloss: 0.438014
# [121]	valid_0's binary_logloss: 0.43756
# [122]	valid_0's binary_logloss: 0.437021
# [123]	valid_0's binary_logloss: 0.436478
# [124]	valid_0's binary_logloss: 0.435955
# [125]	valid_0's binary_logloss: 0.43549
# [126]	valid_0's binary_logloss: 0.434948
# [127]	valid_0's binary_logloss: 0.434424
# [128]	valid_0's binary_logloss: 0.433911
# [129]	valid_0's binary_logloss: 0.433425
# [130]	valid_0's binary_logloss: 0.432913
# [131]	valid_0's binary_logloss: 0.432404
# [132]	valid_0's binary_logloss: 0.431916
# [133]	valid_0's binary_logloss: 0.431439
# [134]	valid_0's binary_logloss: 0.430981
# [135]	valid_0's binary_logloss: 0.430501
# [136]	valid_0's binary_logloss: 0.430042
# [137]	valid_0's binary_logloss: 0.429575
# [138]	valid_0's binary_logloss: 0.42912
# [139]	valid_0's binary_logloss: 0.428657
# [140]	valid_0's binary_logloss: 0.428213
# [141]	valid_0's binary_logloss: 0.427771
# [142]	valid_0's binary_logloss: 0.427349
# [143]	valid_0's binary_logloss: 0.426912
# [144]	valid_0's binary_logloss: 0.426473
# [145]	valid_0's binary_logloss: 0.426066
# [146]	valid_0's binary_logloss: 0.425663
# [147]	valid_0's binary_logloss: 0.425311
# [148]	valid_0's binary_logloss: 0.424926
# [149]	valid_0's binary_logloss: 0.424522
# [150]	valid_0's binary_logloss: 0.424111
# [151]	valid_0's binary_logloss: 0.423736
# [152]	valid_0's binary_logloss: 0.423363
# [153]	valid_0's binary_logloss: 0.422977
# [154]	valid_0's binary_logloss: 0.422606
# [155]	valid_0's binary_logloss: 0.422286
# [156]	valid_0's binary_logloss: 0.421905
# [157]	valid_0's binary_logloss: 0.421555
# [158]	valid_0's binary_logloss: 0.421166
# [159]	valid_0's binary_logloss: 0.420873
# [160]	valid_0's binary_logloss: 0.420509
# [161]	valid_0's binary_logloss: 0.420172
# [162]	valid_0's binary_logloss: 0.419832
# [163]	valid_0's binary_logloss: 0.419494
# [164]	valid_0's binary_logloss: 0.419136
# [165]	valid_0's binary_logloss: 0.418809
# [166]	valid_0's binary_logloss: 0.418489
# [167]	valid_0's binary_logloss: 0.418266
# [168]	valid_0's binary_logloss: 0.417925
# [169]	valid_0's binary_logloss: 0.417616
# [170]	valid_0's binary_logloss: 0.417312
# [171]	valid_0's binary_logloss: 0.417057
# [172]	valid_0's binary_logloss: 0.416764
# [173]	valid_0's binary_logloss: 0.416431
# [174]	valid_0's binary_logloss: 0.416194
# [175]	valid_0's binary_logloss: 0.415892
# [176]	valid_0's binary_logloss: 0.415608
# [177]	valid_0's binary_logloss: 0.415321
# [178]	valid_0's binary_logloss: 0.415041
# [179]	valid_0's binary_logloss: 0.414741
# [180]	valid_0's binary_logloss: 0.414459
# [181]	valid_0's binary_logloss: 0.414248
# [182]	valid_0's binary_logloss: 0.41399
# [183]	valid_0's binary_logloss: 0.413731
# [184]	valid_0's binary_logloss: 0.413435
# [185]	valid_0's binary_logloss: 0.413175
# [186]	valid_0's binary_logloss: 0.412889
# [187]	valid_0's binary_logloss: 0.412625
# [188]	valid_0's binary_logloss: 0.412333
# [189]	valid_0's binary_logloss: 0.41209
# [190]	valid_0's binary_logloss: 0.411807
# [191]	valid_0's binary_logloss: 0.411567
# [192]	valid_0's binary_logloss: 0.411312
# [193]	valid_0's binary_logloss: 0.411072
# [194]	valid_0's binary_logloss: 0.410802
# [195]	valid_0's binary_logloss: 0.410576
# [196]	valid_0's binary_logloss: 0.410351
# [197]	valid_0's binary_logloss: 0.410087
# [198]	valid_0's binary_logloss: 0.409867
# [199]	valid_0's binary_logloss: 0.409603
# [200]	valid_0's binary_logloss: 0.409384
# [201]	valid_0's binary_logloss: 0.409157
# [202]	valid_0's binary_logloss: 0.40894
# [203]	valid_0's binary_logloss: 0.40874
# [204]	valid_0's binary_logloss: 0.408506
# [205]	valid_0's binary_logloss: 0.408284
# [206]	valid_0's binary_logloss: 0.408067
# [207]	valid_0's binary_logloss: 0.407872
# [208]	valid_0's binary_logloss: 0.407701
# [209]	valid_0's binary_logloss: 0.407469
# [210]	valid_0's binary_logloss: 0.407243
# [211]	valid_0's binary_logloss: 0.40705
# [212]	valid_0's binary_logloss: 0.40683
# [213]	valid_0's binary_logloss: 0.406633
# [214]	valid_0's binary_logloss: 0.406408
# [215]	valid_0's binary_logloss: 0.406269
# [216]	valid_0's binary_logloss: 0.406076
# [217]	valid_0's binary_logloss: 0.405863
# [218]	valid_0's binary_logloss: 0.405675
# [219]	valid_0's binary_logloss: 0.405465
# [220]	valid_0's binary_logloss: 0.405299
# [221]	valid_0's binary_logloss: 0.405116
# [222]	valid_0's binary_logloss: 0.404963
# [223]	valid_0's binary_logloss: 0.404764
# [224]	valid_0's binary_logloss: 0.404585
# [225]	valid_0's binary_logloss: 0.404398
# [226]	valid_0's binary_logloss: 0.404275
# [227]	valid_0's binary_logloss: 0.404106
# [228]	valid_0's binary_logloss: 0.40395
# [229]	valid_0's binary_logloss: 0.403768
# [230]	valid_0's binary_logloss: 0.403594
# [231]	valid_0's binary_logloss: 0.403411
# [232]	valid_0's binary_logloss: 0.403246
# [233]	valid_0's binary_logloss: 0.403118
# [234]	valid_0's binary_logloss: 0.402955
# [235]	valid_0's binary_logloss: 0.4028
# [236]	valid_0's binary_logloss: 0.402615
# [237]	valid_0's binary_logloss: 0.402437
# [238]	valid_0's binary_logloss: 0.402282
# [239]	valid_0's binary_logloss: 0.402116
# [240]	valid_0's binary_logloss: 0.401963
# [241]	valid_0's binary_logloss: 0.401803
# [242]	valid_0's binary_logloss: 0.40165
# [243]	valid_0's binary_logloss: 0.401529
# [244]	valid_0's binary_logloss: 0.401375
# [245]	valid_0's binary_logloss: 0.401233
# [246]	valid_0's binary_logloss: 0.401081
# [247]	valid_0's binary_logloss: 0.40094
# [248]	valid_0's binary_logloss: 0.400803
# [249]	valid_0's binary_logloss: 0.400718
# [250]	valid_0's binary_logloss: 0.400575
# [251]	valid_0's binary_logloss: 0.400414
# [252]	valid_0's binary_logloss: 0.400324
# [253]	valid_0's binary_logloss: 0.400182
# [254]	valid_0's binary_logloss: 0.400047
# [255]	valid_0's binary_logloss: 0.399895
# [256]	valid_0's binary_logloss: 0.399744
# [257]	valid_0's binary_logloss: 0.399599
# [258]	valid_0's binary_logloss: 0.399526
# [259]	valid_0's binary_logloss: 0.399393
# [260]	valid_0's binary_logloss: 0.399262
# [261]	valid_0's binary_logloss: 0.399127
# [262]	valid_0's binary_logloss: 0.399003
# [263]	valid_0's binary_logloss: 0.398869
# [264]	valid_0's binary_logloss: 0.398737
# [265]	valid_0's binary_logloss: 0.39862
# [266]	valid_0's binary_logloss: 0.398522
# [267]	valid_0's binary_logloss: 0.398398
# [268]	valid_0's binary_logloss: 0.398293
# [269]	valid_0's binary_logloss: 0.398149
# [270]	valid_0's binary_logloss: 0.398028
# [271]	valid_0's binary_logloss: 0.397895
# [272]	valid_0's binary_logloss: 0.397775
# [273]	valid_0's binary_logloss: 0.397655
# [274]	valid_0's binary_logloss: 0.397521
# [275]	valid_0's binary_logloss: 0.397399
# [276]	valid_0's binary_logloss: 0.397266
# [277]	valid_0's binary_logloss: 0.397168
# [278]	valid_0's binary_logloss: 0.397035
# [279]	valid_0's binary_logloss: 0.396924
# [280]	valid_0's binary_logloss: 0.396825
# [281]	valid_0's binary_logloss: 0.396718
# [282]	valid_0's binary_logloss: 0.396597
# [283]	valid_0's binary_logloss: 0.396523
# [284]	valid_0's binary_logloss: 0.396451
# [285]	valid_0's binary_logloss: 0.396379
# [286]	valid_0's binary_logloss: 0.396277
# [287]	valid_0's binary_logloss: 0.396217
# [288]	valid_0's binary_logloss: 0.396144
# [289]	valid_0's binary_logloss: 0.396046
# [290]	valid_0's binary_logloss: 0.395935
# [291]	valid_0's binary_logloss: 0.395825
# [292]	valid_0's binary_logloss: 0.395722
# [293]	valid_0's binary_logloss: 0.395623
# [294]	valid_0's binary_logloss: 0.395522
# [295]	valid_0's binary_logloss: 0.395416
# [296]	valid_0's binary_logloss: 0.395307
# [297]	valid_0's binary_logloss: 0.395203
# [298]	valid_0's binary_logloss: 0.395111
# [299]	valid_0's binary_logloss: 0.395053
# [300]	valid_0's binary_logloss: 0.39499
# [301]	valid_0's binary_logloss: 0.394898
# [302]	valid_0's binary_logloss: 0.394802
# [303]	valid_0's binary_logloss: 0.3947
# [304]	valid_0's binary_logloss: 0.394593
# [305]	valid_0's binary_logloss: 0.394489
# [306]	valid_0's binary_logloss: 0.394389
# [307]	valid_0's binary_logloss: 0.394274
# [308]	valid_0's binary_logloss: 0.394216
# [309]	valid_0's binary_logloss: 0.394156
# [310]	valid_0's binary_logloss: 0.394075
# [311]	valid_0's binary_logloss: 0.394019
# [312]	valid_0's binary_logloss: 0.393918
# [313]	valid_0's binary_logloss: 0.393829
# [314]	valid_0's binary_logloss: 0.393738
# [315]	valid_0's binary_logloss: 0.39364
# [316]	valid_0's binary_logloss: 0.393558
# [317]	valid_0's binary_logloss: 0.393469
# [318]	valid_0's binary_logloss: 0.393355
# [319]	valid_0's binary_logloss: 0.393271
# [320]	valid_0's binary_logloss: 0.393168
# [321]	valid_0's binary_logloss: 0.393084
# [322]	valid_0's binary_logloss: 0.392982
# [323]	valid_0's binary_logloss: 0.392928
# [324]	valid_0's binary_logloss: 0.392825
# [325]	valid_0's binary_logloss: 0.392733
# [326]	valid_0's binary_logloss: 0.392641
# [327]	valid_0's binary_logloss: 0.392549
# [328]	valid_0's binary_logloss: 0.392467
# [329]	valid_0's binary_logloss: 0.392404
# [330]	valid_0's binary_logloss: 0.39231
# [331]	valid_0's binary_logloss: 0.392225
# [332]	valid_0's binary_logloss: 0.392152
# [333]	valid_0's binary_logloss: 0.392061
# [334]	valid_0's binary_logloss: 0.391969
# [335]	valid_0's binary_logloss: 0.391916
# [336]	valid_0's binary_logloss: 0.391831
# [337]	valid_0's binary_logloss: 0.391736
# [338]	valid_0's binary_logloss: 0.391643
# [339]	valid_0's binary_logloss: 0.391554
# [340]	valid_0's binary_logloss: 0.391472
# [341]	valid_0's binary_logloss: 0.391385
# [342]	valid_0's binary_logloss: 0.391304
# [343]	valid_0's binary_logloss: 0.39126
# [344]	valid_0's binary_logloss: 0.391207
# [345]	valid_0's binary_logloss: 0.391129
# [346]	valid_0's binary_logloss: 0.391039
# [347]	valid_0's binary_logloss: 0.390953
# [348]	valid_0's binary_logloss: 0.390868
# [349]	valid_0's binary_logloss: 0.390775
# [350]	valid_0's binary_logloss: 0.390693
# [351]	valid_0's binary_logloss: 0.390648
# [352]	valid_0's binary_logloss: 0.390573
# [353]	valid_0's binary_logloss: 0.390461
# [354]	valid_0's binary_logloss: 0.390416
# [355]	valid_0's binary_logloss: 0.390326
# [356]	valid_0's binary_logloss: 0.390283
# [357]	valid_0's binary_logloss: 0.390216
# [358]	valid_0's binary_logloss: 0.390131
# [359]	valid_0's binary_logloss: 0.390049
# [360]	valid_0's binary_logloss: 0.389968
# [361]	valid_0's binary_logloss: 0.389873
# [362]	valid_0's binary_logloss: 0.389783
# [363]	valid_0's binary_logloss: 0.389689
# [364]	valid_0's binary_logloss: 0.389637
# [365]	valid_0's binary_logloss: 0.389556
# [366]	valid_0's binary_logloss: 0.389476
# [367]	valid_0's binary_logloss: 0.389387
# [368]	valid_0's binary_logloss: 0.389295
# [369]	valid_0's binary_logloss: 0.389232
# [370]	valid_0's binary_logloss: 0.38915
# [371]	valid_0's binary_logloss: 0.389065
# [372]	valid_0's binary_logloss: 0.38899
# [373]	valid_0's binary_logloss: 0.38891
# [374]	valid_0's binary_logloss: 0.388817
# [375]	valid_0's binary_logloss: 0.388738
# [376]	valid_0's binary_logloss: 0.388687
# [377]	valid_0's binary_logloss: 0.388614
# [378]	valid_0's binary_logloss: 0.388543
# [379]	valid_0's binary_logloss: 0.388489
# [380]	valid_0's binary_logloss: 0.388413
# [381]	valid_0's binary_logloss: 0.388342
# [382]	valid_0's binary_logloss: 0.3883
# [383]	valid_0's binary_logloss: 0.388232
# [384]	valid_0's binary_logloss: 0.388163
# [385]	valid_0's binary_logloss: 0.388085
# [386]	valid_0's binary_logloss: 0.388017
# [387]	valid_0's binary_logloss: 0.387945
# [388]	valid_0's binary_logloss: 0.387862
# [389]	valid_0's binary_logloss: 0.387821
# [390]	valid_0's binary_logloss: 0.387785
# [391]	valid_0's binary_logloss: 0.387723
# [392]	valid_0's binary_logloss: 0.387656
# [393]	valid_0's binary_logloss: 0.387579
# [394]	valid_0's binary_logloss: 0.387516
# [395]	valid_0's binary_logloss: 0.387446
# [396]	valid_0's binary_logloss: 0.387389
# [397]	valid_0's binary_logloss: 0.387325
# [398]	valid_0's binary_logloss: 0.387261
# [399]	valid_0's binary_logloss: 0.387188
# [400]	valid_0's binary_logloss: 0.387107
# [401]	valid_0's binary_logloss: 0.387048
# [402]	valid_0's binary_logloss: 0.386984
# [403]	valid_0's binary_logloss: 0.386912
# [404]	valid_0's binary_logloss: 0.386828
# [405]	valid_0's binary_logloss: 0.386749
# [406]	valid_0's binary_logloss: 0.386667
# [407]	valid_0's binary_logloss: 0.386599
# [408]	valid_0's binary_logloss: 0.386529
# [409]	valid_0's binary_logloss: 0.386453
# [410]	valid_0's binary_logloss: 0.386379
# [411]	valid_0's binary_logloss: 0.386309
# [412]	valid_0's binary_logloss: 0.386235
# [413]	valid_0's binary_logloss: 0.3862
# [414]	valid_0's binary_logloss: 0.386122
# [415]	valid_0's binary_logloss: 0.386064
# [416]	valid_0's binary_logloss: 0.385984
# [417]	valid_0's binary_logloss: 0.385909
# [418]	valid_0's binary_logloss: 0.385843
# [419]	valid_0's binary_logloss: 0.385772
# [420]	valid_0's binary_logloss: 0.385709
# [421]	valid_0's binary_logloss: 0.385675
# [422]	valid_0's binary_logloss: 0.385643
# [423]	valid_0's binary_logloss: 0.385586
# [424]	valid_0's binary_logloss: 0.385523
# [425]	valid_0's binary_logloss: 0.385457
# [426]	valid_0's binary_logloss: 0.385392
# [427]	valid_0's binary_logloss: 0.3853
# [428]	valid_0's binary_logloss: 0.385241
# [429]	valid_0's binary_logloss: 0.385192
# [430]	valid_0's binary_logloss: 0.385127
# [431]	valid_0's binary_logloss: 0.385061
# [432]	valid_0's binary_logloss: 0.385
# [433]	valid_0's binary_logloss: 0.384954
# [434]	valid_0's binary_logloss: 0.384896
# [435]	valid_0's binary_logloss: 0.384845
# [436]	valid_0's binary_logloss: 0.384781
# [437]	valid_0's binary_logloss: 0.384713
# [438]	valid_0's binary_logloss: 0.384626
# [439]	valid_0's binary_logloss: 0.384574
# [440]	valid_0's binary_logloss: 0.384506
# [441]	valid_0's binary_logloss: 0.384426
# [442]	valid_0's binary_logloss: 0.384393
# [443]	valid_0's binary_logloss: 0.384337
# [444]	valid_0's binary_logloss: 0.384291
# [445]	valid_0's binary_logloss: 0.384226
# [446]	valid_0's binary_logloss: 0.384167
# [447]	valid_0's binary_logloss: 0.384125
# [448]	valid_0's binary_logloss: 0.38406
# [449]	valid_0's binary_logloss: 0.384004
# [450]	valid_0's binary_logloss: 0.383948
# [451]	valid_0's binary_logloss: 0.383898
# [452]	valid_0's binary_logloss: 0.383845
# [453]	valid_0's binary_logloss: 0.383785
# [454]	valid_0's binary_logloss: 0.383715
# [455]	valid_0's binary_logloss: 0.383668
# [456]	valid_0's binary_logloss: 0.383613
# [457]	valid_0's binary_logloss: 0.383565
# [458]	valid_0's binary_logloss: 0.383539
# [459]	valid_0's binary_logloss: 0.383472
# [460]	valid_0's binary_logloss: 0.383424
# [461]	valid_0's binary_logloss: 0.383362
# [462]	valid_0's binary_logloss: 0.383315
# [463]	valid_0's binary_logloss: 0.383273
# [464]	valid_0's binary_logloss: 0.38323
# [465]	valid_0's binary_logloss: 0.383195
# [466]	valid_0's binary_logloss: 0.383153
# [467]	valid_0's binary_logloss: 0.383091
# [468]	valid_0's binary_logloss: 0.383028
# [469]	valid_0's binary_logloss: 0.382972
# [470]	valid_0's binary_logloss: 0.382926
# [471]	valid_0's binary_logloss: 0.382868
# [472]	valid_0's binary_logloss: 0.382833
# [473]	valid_0's binary_logloss: 0.382773
# [474]	valid_0's binary_logloss: 0.382708
# [475]	valid_0's binary_logloss: 0.382662
# [476]	valid_0's binary_logloss: 0.3826
# [477]	valid_0's binary_logloss: 0.382542
# [478]	valid_0's binary_logloss: 0.382485
# [479]	valid_0's binary_logloss: 0.382433
# [480]	valid_0's binary_logloss: 0.382393
# [481]	valid_0's binary_logloss: 0.382337
# [482]	valid_0's binary_logloss: 0.382286
# [483]	valid_0's binary_logloss: 0.382228
# [484]	valid_0's binary_logloss: 0.382182
# [485]	valid_0's binary_logloss: 0.382115
# [486]	valid_0's binary_logloss: 0.382046
# [487]	valid_0's binary_logloss: 0.382002
# [488]	valid_0's binary_logloss: 0.381957
# [489]	valid_0's binary_logloss: 0.381879
# [490]	valid_0's binary_logloss: 0.38183
# [491]	valid_0's binary_logloss: 0.381776
# [492]	valid_0's binary_logloss: 0.381714
# [493]	valid_0's binary_logloss: 0.381667
# [494]	valid_0's binary_logloss: 0.381606
# [495]	valid_0's binary_logloss: 0.381565
# [496]	valid_0's binary_logloss: 0.381501
# [497]	valid_0's binary_logloss: 0.381457
# [498]	valid_0's binary_logloss: 0.381431
# [499]	valid_0's binary_logloss: 0.381388
# [500]	valid_0's binary_logloss: 0.381341
# [501]	valid_0's binary_logloss: 0.381274
# [502]	valid_0's binary_logloss: 0.381229
# [503]	valid_0's binary_logloss: 0.381186
# [504]	valid_0's binary_logloss: 0.381142
# [505]	valid_0's binary_logloss: 0.381098
# [506]	valid_0's binary_logloss: 0.381054
# [507]	valid_0's binary_logloss: 0.380977
# [508]	valid_0's binary_logloss: 0.380936
# [509]	valid_0's binary_logloss: 0.380899
# [510]	valid_0's binary_logloss: 0.380847
# [511]	valid_0's binary_logloss: 0.380807
# [512]	valid_0's binary_logloss: 0.380767
# [513]	valid_0's binary_logloss: 0.38074
# [514]	valid_0's binary_logloss: 0.380699
# [515]	valid_0's binary_logloss: 0.380645
# [516]	valid_0's binary_logloss: 0.380596
# [517]	valid_0's binary_logloss: 0.380559
# [518]	valid_0's binary_logloss: 0.380518
# [519]	valid_0's binary_logloss: 0.380462
# [520]	valid_0's binary_logloss: 0.380403
# [521]	valid_0's binary_logloss: 0.380331
# [522]	valid_0's binary_logloss: 0.380305
# [523]	valid_0's binary_logloss: 0.38027
# [524]	valid_0's binary_logloss: 0.380203
# [525]	valid_0's binary_logloss: 0.380137
# [526]	valid_0's binary_logloss: 0.380101
# [527]	valid_0's binary_logloss: 0.380051
# [528]	valid_0's binary_logloss: 0.380004
# [529]	valid_0's binary_logloss: 0.379948
# [530]	valid_0's binary_logloss: 0.37991
# [531]	valid_0's binary_logloss: 0.379872
# [532]	valid_0's binary_logloss: 0.379812
# [533]	valid_0's binary_logloss: 0.379725
# [534]	valid_0's binary_logloss: 0.379676
# [535]	valid_0's binary_logloss: 0.379612
# [536]	valid_0's binary_logloss: 0.379564
# [537]	valid_0's binary_logloss: 0.379529
# [538]	valid_0's binary_logloss: 0.379485
# [539]	valid_0's binary_logloss: 0.379454
# [540]	valid_0's binary_logloss: 0.37942
# [541]	valid_0's binary_logloss: 0.379382
# [542]	valid_0's binary_logloss: 0.379344
# [543]	valid_0's binary_logloss: 0.379299
# [544]	valid_0's binary_logloss: 0.379265
# [545]	valid_0's binary_logloss: 0.379245
# [546]	valid_0's binary_logloss: 0.37921
# [547]	valid_0's binary_logloss: 0.379176
# [548]	valid_0's binary_logloss: 0.379109
# [549]	valid_0's binary_logloss: 0.379072
# [550]	valid_0's binary_logloss: 0.379041
# [551]	valid_0's binary_logloss: 0.379013
# [552]	valid_0's binary_logloss: 0.378946
# [553]	valid_0's binary_logloss: 0.378869
# [554]	valid_0's binary_logloss: 0.378823
# [555]	valid_0's binary_logloss: 0.378771
# [556]	valid_0's binary_logloss: 0.378749
# [557]	valid_0's binary_logloss: 0.378723
# [558]	valid_0's binary_logloss: 0.378666
# [559]	valid_0's binary_logloss: 0.378605
# [560]	valid_0's binary_logloss: 0.378571
# [561]	valid_0's binary_logloss: 0.378539
# [562]	valid_0's binary_logloss: 0.378502
# [563]	valid_0's binary_logloss: 0.378467
# [564]	valid_0's binary_logloss: 0.378437
# [565]	valid_0's binary_logloss: 0.378362
# [566]	valid_0's binary_logloss: 0.378314
# [567]	valid_0's binary_logloss: 0.378241
# [568]	valid_0's binary_logloss: 0.378208
# [569]	valid_0's binary_logloss: 0.378165
# [570]	valid_0's binary_logloss: 0.378118
# [571]	valid_0's binary_logloss: 0.378084
# [572]	valid_0's binary_logloss: 0.378016
# [573]	valid_0's binary_logloss: 0.377962
# [574]	valid_0's binary_logloss: 0.377926
# [575]	valid_0's binary_logloss: 0.377901
# [576]	valid_0's binary_logloss: 0.377856
# [577]	valid_0's binary_logloss: 0.377832
# [578]	valid_0's binary_logloss: 0.377763
# [579]	valid_0's binary_logloss: 0.377721
# [580]	valid_0's binary_logloss: 0.377691
# [581]	valid_0's binary_logloss: 0.377653
# [582]	valid_0's binary_logloss: 0.377629
# [583]	valid_0's binary_logloss: 0.377602
# [584]	valid_0's binary_logloss: 0.377578
# [585]	valid_0's binary_logloss: 0.377545
# [586]	valid_0's binary_logloss: 0.377468
# [587]	valid_0's binary_logloss: 0.377419
# [588]	valid_0's binary_logloss: 0.377379
# [589]	valid_0's binary_logloss: 0.377345
# [590]	valid_0's binary_logloss: 0.377315
# [591]	valid_0's binary_logloss: 0.377275
# [592]	valid_0's binary_logloss: 0.37725
# [593]	valid_0's binary_logloss: 0.377176
# [594]	valid_0's binary_logloss: 0.377139
# [595]	valid_0's binary_logloss: 0.377092
# [596]	valid_0's binary_logloss: 0.377057
# [597]	valid_0's binary_logloss: 0.377025
# [598]	valid_0's binary_logloss: 0.376963
# [599]	valid_0's binary_logloss: 0.376905
# [600]	valid_0's binary_logloss: 0.376874
# [601]	valid_0's binary_logloss: 0.376836
# [602]	valid_0's binary_logloss: 0.376806
# [603]	valid_0's binary_logloss: 0.376791
# [604]	valid_0's binary_logloss: 0.376766
# [605]	valid_0's binary_logloss: 0.376733
# [606]	valid_0's binary_logloss: 0.376705
# [607]	valid_0's binary_logloss: 0.37667
# [608]	valid_0's binary_logloss: 0.376635
# [609]	valid_0's binary_logloss: 0.376608
# [610]	valid_0's binary_logloss: 0.376579
# [611]	valid_0's binary_logloss: 0.376536
# [612]	valid_0's binary_logloss: 0.376484
# [613]	valid_0's binary_logloss: 0.376458
# [614]	valid_0's binary_logloss: 0.376433
# [615]	valid_0's binary_logloss: 0.376405
# [616]	valid_0's binary_logloss: 0.376375
# [617]	valid_0's binary_logloss: 0.376341
# [618]	valid_0's binary_logloss: 0.376297
# [619]	valid_0's binary_logloss: 0.376269
# [620]	valid_0's binary_logloss: 0.376235
# [621]	valid_0's binary_logloss: 0.376211
# [622]	valid_0's binary_logloss: 0.376188
# [623]	valid_0's binary_logloss: 0.37617
# [624]	valid_0's binary_logloss: 0.376148
# [625]	valid_0's binary_logloss: 0.376096
# [626]	valid_0's binary_logloss: 0.37607
# [627]	valid_0's binary_logloss: 0.376041
# [628]	valid_0's binary_logloss: 0.37601
# [629]	valid_0's binary_logloss: 0.375975
# [630]	valid_0's binary_logloss: 0.375943
# [631]	valid_0's binary_logloss: 0.375902
# [632]	valid_0's binary_logloss: 0.37588
# [633]	valid_0's binary_logloss: 0.375817
# [634]	valid_0's binary_logloss: 0.375792
# [635]	valid_0's binary_logloss: 0.375767
# [636]	valid_0's binary_logloss: 0.375733
# [637]	valid_0's binary_logloss: 0.375701
# [638]	valid_0's binary_logloss: 0.375672
# [639]	valid_0's binary_logloss: 0.375638
# [640]	valid_0's binary_logloss: 0.375605
# [641]	valid_0's binary_logloss: 0.375582
# [642]	valid_0's binary_logloss: 0.375551
# [643]	valid_0's binary_logloss: 0.375514
# [644]	valid_0's binary_logloss: 0.375474
# [645]	valid_0's binary_logloss: 0.375437
# [646]	valid_0's binary_logloss: 0.375408
# [647]	valid_0's binary_logloss: 0.375369
# [648]	valid_0's binary_logloss: 0.37534
# [649]	valid_0's binary_logloss: 0.375269
# [650]	valid_0's binary_logloss: 0.375252
# [651]	valid_0's binary_logloss: 0.375204
# [652]	valid_0's binary_logloss: 0.375177
# [653]	valid_0's binary_logloss: 0.37516
# [654]	valid_0's binary_logloss: 0.375135
# [655]	valid_0's binary_logloss: 0.375099
# [656]	valid_0's binary_logloss: 0.375077
# [657]	valid_0's binary_logloss: 0.375039
# [658]	valid_0's binary_logloss: 0.375009
# [659]	valid_0's binary_logloss: 0.374963
# [660]	valid_0's binary_logloss: 0.374911
# [661]	valid_0's binary_logloss: 0.374889
# [662]	valid_0's binary_logloss: 0.374855
# [663]	valid_0's binary_logloss: 0.374837
# [664]	valid_0's binary_logloss: 0.37481
# [665]	valid_0's binary_logloss: 0.374794
# [666]	valid_0's binary_logloss: 0.374767
# [667]	valid_0's binary_logloss: 0.374712
# [668]	valid_0's binary_logloss: 0.374682
# [669]	valid_0's binary_logloss: 0.374653
# [670]	valid_0's binary_logloss: 0.374607
# [671]	valid_0's binary_logloss: 0.374577
# [672]	valid_0's binary_logloss: 0.37455
# [673]	valid_0's binary_logloss: 0.374516
# [674]	valid_0's binary_logloss: 0.374491
# [675]	valid_0's binary_logloss: 0.374464
# [676]	valid_0's binary_logloss: 0.374448
# [677]	valid_0's binary_logloss: 0.374427
# [678]	valid_0's binary_logloss: 0.374407
# [679]	valid_0's binary_logloss: 0.37435
# [680]	valid_0's binary_logloss: 0.374328
# [681]	valid_0's binary_logloss: 0.37431
# [682]	valid_0's binary_logloss: 0.374284
# [683]	valid_0's binary_logloss: 0.374251
# [684]	valid_0's binary_logloss: 0.374212
# [685]	valid_0's binary_logloss: 0.374181
# [686]	valid_0's binary_logloss: 0.374138
# [687]	valid_0's binary_logloss: 0.37411
# [688]	valid_0's binary_logloss: 0.374062
# [689]	valid_0's binary_logloss: 0.374021
# [690]	valid_0's binary_logloss: 0.374
# [691]	valid_0's binary_logloss: 0.373969
# [692]	valid_0's binary_logloss: 0.373954
# [693]	valid_0's binary_logloss: 0.373932
# [694]	valid_0's binary_logloss: 0.373901
# [695]	valid_0's binary_logloss: 0.373865
# [696]	valid_0's binary_logloss: 0.373838
# [697]	valid_0's binary_logloss: 0.373802
# [698]	valid_0's binary_logloss: 0.373776
# [699]	valid_0's binary_logloss: 0.373746
# [700]	valid_0's binary_logloss: 0.373722
# [701]	valid_0's binary_logloss: 0.373696
# [702]	valid_0's binary_logloss: 0.373671
# [703]	valid_0's binary_logloss: 0.373658
# [704]	valid_0's binary_logloss: 0.373616
# [705]	valid_0's binary_logloss: 0.373592
# [706]	valid_0's binary_logloss: 0.37358
# [707]	valid_0's binary_logloss: 0.373564
# [708]	valid_0's binary_logloss: 0.373509
# [709]	valid_0's binary_logloss: 0.373483
# [710]	valid_0's binary_logloss: 0.37347
# [711]	valid_0's binary_logloss: 0.373421
# [712]	valid_0's binary_logloss: 0.373389
# [713]	valid_0's binary_logloss: 0.373345
# [714]	valid_0's binary_logloss: 0.373286
# [715]	valid_0's binary_logloss: 0.373269
# [716]	valid_0's binary_logloss: 0.373225
# [717]	valid_0's binary_logloss: 0.373202
# [718]	valid_0's binary_logloss: 0.373175
# [719]	valid_0's binary_logloss: 0.373152
# [720]	valid_0's binary_logloss: 0.373114
# [721]	valid_0's binary_logloss: 0.373097
# [722]	valid_0's binary_logloss: 0.373068
# [723]	valid_0's binary_logloss: 0.373031
# [724]	valid_0's binary_logloss: 0.373001
# [725]	valid_0's binary_logloss: 0.372975
# [726]	valid_0's binary_logloss: 0.37295
# [727]	valid_0's binary_logloss: 0.37293
# [728]	valid_0's binary_logloss: 0.372894
# [729]	valid_0's binary_logloss: 0.372876
# [730]	valid_0's binary_logloss: 0.372827
# [731]	valid_0's binary_logloss: 0.372802
# [732]	valid_0's binary_logloss: 0.372781
# [733]	valid_0's binary_logloss: 0.372744
# [734]	valid_0's binary_logloss: 0.372722
# [735]	valid_0's binary_logloss: 0.372666
# [736]	valid_0's binary_logloss: 0.37265
# [737]	valid_0's binary_logloss: 0.372634
# [738]	valid_0's binary_logloss: 0.372622
# [739]	valid_0's binary_logloss: 0.372587
# [740]	valid_0's binary_logloss: 0.372541
# [741]	valid_0's binary_logloss: 0.372519
# [742]	valid_0's binary_logloss: 0.372509
# [743]	valid_0's binary_logloss: 0.372489
# [744]	valid_0's binary_logloss: 0.372467
# [745]	valid_0's binary_logloss: 0.372452
# [746]	valid_0's binary_logloss: 0.372424
# [747]	valid_0's binary_logloss: 0.372411
# [748]	valid_0's binary_logloss: 0.372378
# [749]	valid_0's binary_logloss: 0.372318
# [750]	valid_0's binary_logloss: 0.372306
# [751]	valid_0's binary_logloss: 0.372286
# [752]	valid_0's binary_logloss: 0.372251
# [753]	valid_0's binary_logloss: 0.37223
# [754]	valid_0's binary_logloss: 0.372213
# [755]	valid_0's binary_logloss: 0.372167
# [756]	valid_0's binary_logloss: 0.372118
# [757]	valid_0's binary_logloss: 0.372097
# [758]	valid_0's binary_logloss: 0.372073
# [759]	valid_0's binary_logloss: 0.372058
# [760]	valid_0's binary_logloss: 0.372029
# [761]	valid_0's binary_logloss: 0.372002
# [762]	valid_0's binary_logloss: 0.371973
# [763]	valid_0's binary_logloss: 0.371951
# [764]	valid_0's binary_logloss: 0.371895
# [765]	valid_0's binary_logloss: 0.371859
# [766]	valid_0's binary_logloss: 0.371846
# [767]	valid_0's binary_logloss: 0.371828
# [768]	valid_0's binary_logloss: 0.371794
# [769]	valid_0's binary_logloss: 0.371769
# [770]	valid_0's binary_logloss: 0.371708
# [771]	valid_0's binary_logloss: 0.371699
# [772]	valid_0's binary_logloss: 0.371668
# [773]	valid_0's binary_logloss: 0.371636
# [774]	valid_0's binary_logloss: 0.371621
# [775]	valid_0's binary_logloss: 0.371599
# [776]	valid_0's binary_logloss: 0.37154
# [777]	valid_0's binary_logloss: 0.37153
# [778]	valid_0's binary_logloss: 0.371522
# [779]	valid_0's binary_logloss: 0.371484
# [780]	valid_0's binary_logloss: 0.371462
# [781]	valid_0's binary_logloss: 0.371438
# [782]	valid_0's binary_logloss: 0.371402
# [783]	valid_0's binary_logloss: 0.371376
# [784]	valid_0's binary_logloss: 0.371351
# [785]	valid_0's binary_logloss: 0.371329
# [786]	valid_0's binary_logloss: 0.371291
# [787]	valid_0's binary_logloss: 0.371267
# [788]	valid_0's binary_logloss: 0.371243
# [789]	valid_0's binary_logloss: 0.371213
# [790]	valid_0's binary_logloss: 0.371191
# [791]	valid_0's binary_logloss: 0.371154
# [792]	valid_0's binary_logloss: 0.371135
# [793]	valid_0's binary_logloss: 0.37112
# [794]	valid_0's binary_logloss: 0.371088
# [795]	valid_0's binary_logloss: 0.371046
# [796]	valid_0's binary_logloss: 0.371008
# [797]	valid_0's binary_logloss: 0.370981
# [798]	valid_0's binary_logloss: 0.370936
# [799]	valid_0's binary_logloss: 0.370921
# [800]	valid_0's binary_logloss: 0.370907
# [801]	valid_0's binary_logloss: 0.370883
# [802]	valid_0's binary_logloss: 0.370865
# [803]	valid_0's binary_logloss: 0.37081
# [804]	valid_0's binary_logloss: 0.370794
# [805]	valid_0's binary_logloss: 0.370767
# [806]	valid_0's binary_logloss: 0.370738
# [807]	valid_0's binary_logloss: 0.370693
# [808]	valid_0's binary_logloss: 0.37067
# [809]	valid_0's binary_logloss: 0.370655
# [810]	valid_0's binary_logloss: 0.370615
# [811]	valid_0's binary_logloss: 0.370592
# [812]	valid_0's binary_logloss: 0.370575
# [813]	valid_0's binary_logloss: 0.370558
# [814]	valid_0's binary_logloss: 0.370545
# [815]	valid_0's binary_logloss: 0.37053
# [816]	valid_0's binary_logloss: 0.370478
# [817]	valid_0's binary_logloss: 0.370446
# [818]	valid_0's binary_logloss: 0.370414
# [819]	valid_0's binary_logloss: 0.370393
# [820]	valid_0's binary_logloss: 0.370363
# [821]	valid_0's binary_logloss: 0.370354
# [822]	valid_0's binary_logloss: 0.370311
# [823]	valid_0's binary_logloss: 0.370285
# [824]	valid_0's binary_logloss: 0.370254
# [825]	valid_0's binary_logloss: 0.370241
# [826]	valid_0's binary_logloss: 0.370215
# [827]	valid_0's binary_logloss: 0.370175
# [828]	valid_0's binary_logloss: 0.370157
# [829]	valid_0's binary_logloss: 0.370141
# [830]	valid_0's binary_logloss: 0.370115
# [831]	valid_0's binary_logloss: 0.370099
# [832]	valid_0's binary_logloss: 0.370065
# [833]	valid_0's binary_logloss: 0.370048
# [834]	valid_0's binary_logloss: 0.370015
# [835]	valid_0's binary_logloss: 0.369964
# [836]	valid_0's binary_logloss: 0.36994
# [837]	valid_0's binary_logloss: 0.36991
# [838]	valid_0's binary_logloss: 0.36987
# [839]	valid_0's binary_logloss: 0.369865
# [840]	valid_0's binary_logloss: 0.369844
# [841]	valid_0's binary_logloss: 0.369825
# [842]	valid_0's binary_logloss: 0.369817
# [843]	valid_0's binary_logloss: 0.369774
# [844]	valid_0's binary_logloss: 0.369739
# [845]	valid_0's binary_logloss: 0.369723
# [846]	valid_0's binary_logloss: 0.369709
# [847]	valid_0's binary_logloss: 0.36968
# [848]	valid_0's binary_logloss: 0.369674
# [849]	valid_0's binary_logloss: 0.369652
# [850]	valid_0's binary_logloss: 0.369638
# [851]	valid_0's binary_logloss: 0.369612
# [852]	valid_0's binary_logloss: 0.369574
# [853]	valid_0's binary_logloss: 0.369558
# [854]	valid_0's binary_logloss: 0.369534
# [855]	valid_0's binary_logloss: 0.369518
# [856]	valid_0's binary_logloss: 0.36951
# [857]	valid_0's binary_logloss: 0.36945
# [858]	valid_0's binary_logloss: 0.369439
# [859]	valid_0's binary_logloss: 0.369404
# [860]	valid_0's binary_logloss: 0.369388
# [861]	valid_0's binary_logloss: 0.369364
# [862]	valid_0's binary_logloss: 0.369351
# [863]	valid_0's binary_logloss: 0.369323
# [864]	valid_0's binary_logloss: 0.369309
# [865]	valid_0's binary_logloss: 0.369291
# [866]	valid_0's binary_logloss: 0.36926
# [867]	valid_0's binary_logloss: 0.369246
# [868]	valid_0's binary_logloss: 0.369231
# [869]	valid_0's binary_logloss: 0.369223
# [870]	valid_0's binary_logloss: 0.369206
# [871]	valid_0's binary_logloss: 0.369186
# [872]	valid_0's binary_logloss: 0.369164
# [873]	valid_0's binary_logloss: 0.369135
# [874]	valid_0's binary_logloss: 0.369109
# [875]	valid_0's binary_logloss: 0.369078
# [876]	valid_0's binary_logloss: 0.369071
# [877]	valid_0's binary_logloss: 0.369051
# [878]	valid_0's binary_logloss: 0.369032
# [879]	valid_0's binary_logloss: 0.369025
# [880]	valid_0's binary_logloss: 0.369012
# [881]	valid_0's binary_logloss: 0.368974
# [882]	valid_0's binary_logloss: 0.368933
# [883]	valid_0's binary_logloss: 0.368902
# [884]	valid_0's binary_logloss: 0.36888
# [885]	valid_0's binary_logloss: 0.368868
# [886]	valid_0's binary_logloss: 0.368842
# [887]	valid_0's binary_logloss: 0.368832
# [888]	valid_0's binary_logloss: 0.368805
# [889]	valid_0's binary_logloss: 0.368784
# [890]	valid_0's binary_logloss: 0.368729
# [891]	valid_0's binary_logloss: 0.368708
# [892]	valid_0's binary_logloss: 0.368699
# [893]	valid_0's binary_logloss: 0.368681
# [894]	valid_0's binary_logloss: 0.368659
# [895]	valid_0's binary_logloss: 0.368642
# [896]	valid_0's binary_logloss: 0.3686
# [897]	valid_0's binary_logloss: 0.368566
# [898]	valid_0's binary_logloss: 0.368534
# [899]	valid_0's binary_logloss: 0.368527
# [900]	valid_0's binary_logloss: 0.368511
# [901]	valid_0's binary_logloss: 0.368501
# [902]	valid_0's binary_logloss: 0.368486
# [903]	valid_0's binary_logloss: 0.368454
# [904]	valid_0's binary_logloss: 0.368444
# [905]	valid_0's binary_logloss: 0.368428
# [906]	valid_0's binary_logloss: 0.368409
# [907]	valid_0's binary_logloss: 0.368375
# [908]	valid_0's binary_logloss: 0.368355
# [909]	valid_0's binary_logloss: 0.368342
# [910]	valid_0's binary_logloss: 0.368312
# [911]	valid_0's binary_logloss: 0.368294
# [912]	valid_0's binary_logloss: 0.368287
# [913]	valid_0's binary_logloss: 0.368275
# [914]	valid_0's binary_logloss: 0.368271
# [915]	valid_0's binary_logloss: 0.368234
# [916]	valid_0's binary_logloss: 0.368216
# [917]	valid_0's binary_logloss: 0.368185
# [918]	valid_0's binary_logloss: 0.368166
# [919]	valid_0's binary_logloss: 0.368132
# [920]	valid_0's binary_logloss: 0.368118
# [921]	valid_0's binary_logloss: 0.368112
# [922]	valid_0's binary_logloss: 0.368101
# [923]	valid_0's binary_logloss: 0.368066
# [924]	valid_0's binary_logloss: 0.368056
# [925]	valid_0's binary_logloss: 0.368044
# [926]	valid_0's binary_logloss: 0.368032
# [927]	valid_0's binary_logloss: 0.368016
# [928]	valid_0's binary_logloss: 0.367986
# [929]	valid_0's binary_logloss: 0.367955
# [930]	valid_0's binary_logloss: 0.36794
# [931]	valid_0's binary_logloss: 0.367924
# [932]	valid_0's binary_logloss: 0.367871
# [933]	valid_0's binary_logloss: 0.367861
# [934]	valid_0's binary_logloss: 0.367845
# [935]	valid_0's binary_logloss: 0.367842
# [936]	valid_0's binary_logloss: 0.36783
# [937]	valid_0's binary_logloss: 0.367806
# [938]	valid_0's binary_logloss: 0.367788
# [939]	valid_0's binary_logloss: 0.367771
# [940]	valid_0's binary_logloss: 0.367746
# [941]	valid_0's binary_logloss: 0.367742
# [942]	valid_0's binary_logloss: 0.367703
# [943]	valid_0's binary_logloss: 0.367695
# [944]	valid_0's binary_logloss: 0.36768
# [945]	valid_0's binary_logloss: 0.367662
# [946]	valid_0's binary_logloss: 0.367637
# [947]	valid_0's binary_logloss: 0.367617
# [948]	valid_0's binary_logloss: 0.36759
# [949]	valid_0's binary_logloss: 0.367576
# [950]	valid_0's binary_logloss: 0.367566
# [951]	valid_0's binary_logloss: 0.367558
# [952]	valid_0's binary_logloss: 0.367534
# [953]	valid_0's binary_logloss: 0.367521
# [954]	valid_0's binary_logloss: 0.367511
# [955]	valid_0's binary_logloss: 0.367495
# [956]	valid_0's binary_logloss: 0.367458
# [957]	valid_0's binary_logloss: 0.367418
# [958]	valid_0's binary_logloss: 0.367404
# [959]	valid_0's binary_logloss: 0.367374
# [960]	valid_0's binary_logloss: 0.367365
# [961]	valid_0's binary_logloss: 0.367347
# [962]	valid_0's binary_logloss: 0.367327
# [963]	valid_0's binary_logloss: 0.367315
# [964]	valid_0's binary_logloss: 0.367301
# [965]	valid_0's binary_logloss: 0.367289
# [966]	valid_0's binary_logloss: 0.36727
# [967]	valid_0's binary_logloss: 0.367265
# [968]	valid_0's binary_logloss: 0.367251
# [969]	valid_0's binary_logloss: 0.367219
# [970]	valid_0's binary_logloss: 0.367212
# [971]	valid_0's binary_logloss: 0.367173
# [972]	valid_0's binary_logloss: 0.367164
# [973]	valid_0's binary_logloss: 0.367147
# [974]	valid_0's binary_logloss: 0.36714
# [975]	valid_0's binary_logloss: 0.367133
# [976]	valid_0's binary_logloss: 0.36711
# [977]	valid_0's binary_logloss: 0.367091
# [978]	valid_0's binary_logloss: 0.367062
# [979]	valid_0's binary_logloss: 0.367053
# [980]	valid_0's binary_logloss: 0.367026
# [981]	valid_0's binary_logloss: 0.367006
# [982]	valid_0's binary_logloss: 0.366989
# [983]	valid_0's binary_logloss: 0.366977
# [984]	valid_0's binary_logloss: 0.366969
# [985]	valid_0's binary_logloss: 0.366962
# [986]	valid_0's binary_logloss: 0.366935
# [987]	valid_0's binary_logloss: 0.366918
# [988]	valid_0's binary_logloss: 0.366913
# [989]	valid_0's binary_logloss: 0.366891
# [990]	valid_0's binary_logloss: 0.366875
# [991]	valid_0's binary_logloss: 0.366863
# [992]	valid_0's binary_logloss: 0.366849
# [993]	valid_0's binary_logloss: 0.366838
# [994]	valid_0's binary_logloss: 0.366815
# [995]	valid_0's binary_logloss: 0.366785
# [996]	valid_0's binary_logloss: 0.366775
# [997]	valid_0's binary_logloss: 0.366755
# [998]	valid_0's binary_logloss: 0.366735
# [999]	valid_0's binary_logloss: 0.366699
# [1000]	valid_0's binary_logloss: 0.366683
# [1001]	valid_0's binary_logloss: 0.366671
# [1002]	valid_0's binary_logloss: 0.366658
# [1003]	valid_0's binary_logloss: 0.366647
# [1004]	valid_0's binary_logloss: 0.366643
# [1005]	valid_0's binary_logloss: 0.366631
# [1006]	valid_0's binary_logloss: 0.366617
# [1007]	valid_0's binary_logloss: 0.366596
# [1008]	valid_0's binary_logloss: 0.366576
# [1009]	valid_0's binary_logloss: 0.366572
# [1010]	valid_0's binary_logloss: 0.366548
# [1011]	valid_0's binary_logloss: 0.366541
# [1012]	valid_0's binary_logloss: 0.366522
# [1013]	valid_0's binary_logloss: 0.366505
# [1014]	valid_0's binary_logloss: 0.366493
# [1015]	valid_0's binary_logloss: 0.366483
# [1016]	valid_0's binary_logloss: 0.366478
# [1017]	valid_0's binary_logloss: 0.366448
# [1018]	valid_0's binary_logloss: 0.366439
# [1019]	valid_0's binary_logloss: 0.366416
# [1020]	valid_0's binary_logloss: 0.366401
# [1021]	valid_0's binary_logloss: 0.366397
# [1022]	valid_0's binary_logloss: 0.366365
# [1023]	valid_0's binary_logloss: 0.366338
# [1024]	valid_0's binary_logloss: 0.366327
# [1025]	valid_0's binary_logloss: 0.366299
# [1026]	valid_0's binary_logloss: 0.366279
# [1027]	valid_0's binary_logloss: 0.366271
# [1028]	valid_0's binary_logloss: 0.36626
# [1029]	valid_0's binary_logloss: 0.366251
# [1030]	valid_0's binary_logloss: 0.366239
# [1031]	valid_0's binary_logloss: 0.366221
# [1032]	valid_0's binary_logloss: 0.366202
# [1033]	valid_0's binary_logloss: 0.366188
# [1034]	valid_0's binary_logloss: 0.366184
# [1035]	valid_0's binary_logloss: 0.366172
# [1036]	valid_0's binary_logloss: 0.366161
# [1037]	valid_0's binary_logloss: 0.366153
# [1038]	valid_0's binary_logloss: 0.366141
# [1039]	valid_0's binary_logloss: 0.36612
# [1040]	valid_0's binary_logloss: 0.366103
# [1041]	valid_0's binary_logloss: 0.366084
# [1042]	valid_0's binary_logloss: 0.366067
# [1043]	valid_0's binary_logloss: 0.366061
# [1044]	valid_0's binary_logloss: 0.366057
# [1045]	valid_0's binary_logloss: 0.366046
# [1046]	valid_0's binary_logloss: 0.366029
# [1047]	valid_0's binary_logloss: 0.366019
# [1048]	valid_0's binary_logloss: 0.366011
# [1049]	valid_0's binary_logloss: 0.365996
# [1050]	valid_0's binary_logloss: 0.365981
# [1051]	valid_0's binary_logloss: 0.365953
# [1052]	valid_0's binary_logloss: 0.365945
# [1053]	valid_0's binary_logloss: 0.365914
# [1054]	valid_0's binary_logloss: 0.3659
# [1055]	valid_0's binary_logloss: 0.365881
# [1056]	valid_0's binary_logloss: 0.365876
# [1057]	valid_0's binary_logloss: 0.365858
# [1058]	valid_0's binary_logloss: 0.365832
# [1059]	valid_0's binary_logloss: 0.365822
# [1060]	valid_0's binary_logloss: 0.365807
# [1061]	valid_0's binary_logloss: 0.365786
# [1062]	valid_0's binary_logloss: 0.365774
# [1063]	valid_0's binary_logloss: 0.365762
# [1064]	valid_0's binary_logloss: 0.365749
# [1065]	valid_0's binary_logloss: 0.365746
# [1066]	valid_0's binary_logloss: 0.365744
# [1067]	valid_0's binary_logloss: 0.365707
# [1068]	valid_0's binary_logloss: 0.365698
# [1069]	valid_0's binary_logloss: 0.365682
# [1070]	valid_0's binary_logloss: 0.365679
# [1071]	valid_0's binary_logloss: 0.365669
# [1072]	valid_0's binary_logloss: 0.365666
# [1073]	valid_0's binary_logloss: 0.365663
# [1074]	valid_0's binary_logloss: 0.365653
# [1075]	valid_0's binary_logloss: 0.365635
# [1076]	valid_0's binary_logloss: 0.365618
# [1077]	valid_0's binary_logloss: 0.365606
# [1078]	valid_0's binary_logloss: 0.365591
# [1079]	valid_0's binary_logloss: 0.365575
# [1080]	valid_0's binary_logloss: 0.365571
# [1081]	valid_0's binary_logloss: 0.365567
# [1082]	valid_0's binary_logloss: 0.36553
# [1083]	valid_0's binary_logloss: 0.36552
# [1084]	valid_0's binary_logloss: 0.365498
# [1085]	valid_0's binary_logloss: 0.365483
# [1086]	valid_0's binary_logloss: 0.365476
# [1087]	valid_0's binary_logloss: 0.36547
# [1088]	valid_0's binary_logloss: 0.365454
# [1089]	valid_0's binary_logloss: 0.365451
# [1090]	valid_0's binary_logloss: 0.365435
# [1091]	valid_0's binary_logloss: 0.365417
# [1092]	valid_0's binary_logloss: 0.365413
# [1093]	valid_0's binary_logloss: 0.365388
# [1094]	valid_0's binary_logloss: 0.365382
# [1095]	valid_0's binary_logloss: 0.365369
# [1096]	valid_0's binary_logloss: 0.365359
# [1097]	valid_0's binary_logloss: 0.365346
# [1098]	valid_0's binary_logloss: 0.365327
# [1099]	valid_0's binary_logloss: 0.365302
# [1100]	valid_0's binary_logloss: 0.365294
# [1101]	valid_0's binary_logloss: 0.365284
# [1102]	valid_0's binary_logloss: 0.365272
# [1103]	valid_0's binary_logloss: 0.365263
# [1104]	valid_0's binary_logloss: 0.36524
# [1105]	valid_0's binary_logloss: 0.365215
# [1106]	valid_0's binary_logloss: 0.365203
# [1107]	valid_0's binary_logloss: 0.365192
# [1108]	valid_0's binary_logloss: 0.365164
# [1109]	valid_0's binary_logloss: 0.365154
# [1110]	valid_0's binary_logloss: 0.365141
# [1111]	valid_0's binary_logloss: 0.365131
# [1112]	valid_0's binary_logloss: 0.365098
# [1113]	valid_0's binary_logloss: 0.365094
# [1114]	valid_0's binary_logloss: 0.365075
# [1115]	valid_0's binary_logloss: 0.365064
# [1116]	valid_0's binary_logloss: 0.365047
# [1117]	valid_0's binary_logloss: 0.36504
# [1118]	valid_0's binary_logloss: 0.365022
# [1119]	valid_0's binary_logloss: 0.36501
# [1120]	valid_0's binary_logloss: 0.365005
# [1121]	valid_0's binary_logloss: 0.364992
# [1122]	valid_0's binary_logloss: 0.364988
# [1123]	valid_0's binary_logloss: 0.364965
# [1124]	valid_0's binary_logloss: 0.364953
# [1125]	valid_0's binary_logloss: 0.364945
# [1126]	valid_0's binary_logloss: 0.364933
# [1127]	valid_0's binary_logloss: 0.364925
# [1128]	valid_0's binary_logloss: 0.364913
# [1129]	valid_0's binary_logloss: 0.364908
# [1130]	valid_0's binary_logloss: 0.36487
# [1131]	valid_0's binary_logloss: 0.36486
# [1132]	valid_0's binary_logloss: 0.364849
# [1133]	valid_0's binary_logloss: 0.364848
# [1134]	valid_0's binary_logloss: 0.364841
# [1135]	valid_0's binary_logloss: 0.364831
# [1136]	valid_0's binary_logloss: 0.36482
# [1137]	valid_0's binary_logloss: 0.364784
# [1138]	valid_0's binary_logloss: 0.364774
# [1139]	valid_0's binary_logloss: 0.364766
# [1140]	valid_0's binary_logloss: 0.36475
# [1141]	valid_0's binary_logloss: 0.36473
# [1142]	valid_0's binary_logloss: 0.364719
# [1143]	valid_0's binary_logloss: 0.364705
# [1144]	valid_0's binary_logloss: 0.364689
# [1145]	valid_0's binary_logloss: 0.364685
# [1146]	valid_0's binary_logloss: 0.364682
# [1147]	valid_0's binary_logloss: 0.364651
# [1148]	valid_0's binary_logloss: 0.364636
# [1149]	valid_0's binary_logloss: 0.36461
# [1150]	valid_0's binary_logloss: 0.364595
# [1151]	valid_0's binary_logloss: 0.364591
# [1152]	valid_0's binary_logloss: 0.364567
# [1153]	valid_0's binary_logloss: 0.364558
# [1154]	valid_0's binary_logloss: 0.364543
# [1155]	valid_0's binary_logloss: 0.364542
# [1156]	valid_0's binary_logloss: 0.364531
# [1157]	valid_0's binary_logloss: 0.364527
# [1158]	valid_0's binary_logloss: 0.364503
# [1159]	valid_0's binary_logloss: 0.364477
# [1160]	valid_0's binary_logloss: 0.36446
# [1161]	valid_0's binary_logloss: 0.364447
# [1162]	valid_0's binary_logloss: 0.36444
# [1163]	valid_0's binary_logloss: 0.36443
# [1164]	valid_0's binary_logloss: 0.364408
# [1165]	valid_0's binary_logloss: 0.364406
# [1166]	valid_0's binary_logloss: 0.3644
# [1167]	valid_0's binary_logloss: 0.364386
# [1168]	valid_0's binary_logloss: 0.364367
# [1169]	valid_0's binary_logloss: 0.364354
# [1170]	valid_0's binary_logloss: 0.364349
# ...
# [2122]	valid_0's binary_logloss: 0.358516
# [2123]	valid_0's binary_logloss: 0.358512
# [2124]	valid_0's binary_logloss: 0.358509
# [2125]	valid_0's binary_logloss: 0.358508
# [2126]	valid_0's binary_logloss: 0.358501
# [2127]	valid_0's binary_logloss: 0.358495
# [2128]	valid_0's binary_logloss: 0.358495
# [2129]	valid_0's binary_logloss: 0.35849
# [2130]	valid_0's binary_logloss: 0.358491
# [2131]	valid_0's binary_logloss: 0.358493
# [2132]	valid_0's binary_logloss: 0.358489
# [2133]	valid_0's binary_logloss: 0.358481
# [2134]	valid_0's binary_logloss: 0.35848
# [2135]	valid_0's binary_logloss: 0.358475
# [2136]	valid_0's binary_logloss: 0.358474
# [2137]	valid_0's binary_logloss: 0.358475
# [2138]	valid_0's binary_logloss: 0.358473
# [2139]	valid_0's binary_logloss: 0.358468
# [2140]	valid_0's binary_logloss: 0.358467
# [2141]	valid_0's binary_logloss: 0.358464
# [2142]	valid_0's binary_logloss: 0.35846
# [2143]	valid_0's binary_logloss: 0.358452
# [2144]	valid_0's binary_logloss: 0.358454
# [2145]	valid_0's binary_logloss: 0.358453
# [2146]	valid_0's binary_logloss: 0.358452
# [2147]	valid_0's binary_logloss: 0.358444
# [2148]	valid_0's binary_logloss: 0.358441
# [2149]	valid_0's binary_logloss: 0.358441
# [2150]	valid_0's binary_logloss: 0.358434
# [2151]	valid_0's binary_logloss: 0.358431
# [2152]	valid_0's binary_logloss: 0.35843
# [2153]	valid_0's binary_logloss: 0.35843
# [2154]	valid_0's binary_logloss: 0.35843
# [2155]	valid_0's binary_logloss: 0.358431
# [2156]	valid_0's binary_logloss: 0.358426
# [2157]	valid_0's binary_logloss: 0.358424
# [2158]	valid_0's binary_logloss: 0.358422
# [2159]	valid_0's binary_logloss: 0.358423
# [2160]	valid_0's binary_logloss: 0.358417
# [2161]	valid_0's binary_logloss: 0.358413
# [2162]	valid_0's binary_logloss: 0.358411
# [2163]	valid_0's binary_logloss: 0.358411
# [2164]	valid_0's binary_logloss: 0.358408
# [2165]	valid_0's binary_logloss: 0.358407
# [2166]	valid_0's binary_logloss: 0.358408
# [2167]	valid_0's binary_logloss: 0.358406
# [2168]	valid_0's binary_logloss: 0.358402
# [2169]	valid_0's binary_logloss: 0.3584
# [2170]	valid_0's binary_logloss: 0.358397
# [2171]	valid_0's binary_logloss: 0.358396
# [2172]	valid_0's binary_logloss: 0.358397
# [2173]	valid_0's binary_logloss: 0.358391
# [2174]	valid_0's binary_logloss: 0.358389
# [2175]	valid_0's binary_logloss: 0.358388
# [2176]	valid_0's binary_logloss: 0.358386
# [2177]	valid_0's binary_logloss: 0.35838
# [2178]	valid_0's binary_logloss: 0.358379
# [2179]	valid_0's binary_logloss: 0.358371
# [2180]	valid_0's binary_logloss: 0.358371
# [2181]	valid_0's binary_logloss: 0.358371
# [2182]	valid_0's binary_logloss: 0.35837
# [2183]	valid_0's binary_logloss: 0.358363
# [2184]	valid_0's binary_logloss: 0.358362
# [2185]	valid_0's binary_logloss: 0.358357
# [2186]	valid_0's binary_logloss: 0.358352
# [2187]	valid_0's binary_logloss: 0.358345
# [2188]	valid_0's binary_logloss: 0.358345
# [2189]	valid_0's binary_logloss: 0.358338
# [2190]	valid_0's binary_logloss: 0.35833
# [2191]	valid_0's binary_logloss: 0.35833
# [2192]	valid_0's binary_logloss: 0.358331
# [2193]	valid_0's binary_logloss: 0.35833
# [2194]	valid_0's binary_logloss: 0.358325
# [2195]	valid_0's binary_logloss: 0.35832
# [2196]	valid_0's binary_logloss: 0.358315
# [2197]	valid_0's binary_logloss: 0.358311
# [2198]	valid_0's binary_logloss: 0.358307
# [2199]	valid_0's binary_logloss: 0.3583
# [2200]	valid_0's binary_logloss: 0.358297
# [2201]	valid_0's binary_logloss: 0.358292
# [2202]	valid_0's binary_logloss: 0.358283
# [2203]	valid_0's binary_logloss: 0.358284
# [2204]	valid_0's binary_logloss: 0.358285
# [2205]	valid_0's binary_logloss: 0.35828
# [2206]	valid_0's binary_logloss: 0.358275
# [2207]	valid_0's binary_logloss: 0.358266
# [2208]	valid_0's binary_logloss: 0.358264
# [2209]	valid_0's binary_logloss: 0.358266
# [2210]	valid_0's binary_logloss: 0.358265
# [2211]	valid_0's binary_logloss: 0.358256
# [2212]	valid_0's binary_logloss: 0.358255
# [2213]	valid_0's binary_logloss: 0.358254
# [2214]	valid_0's binary_logloss: 0.358253
# [2215]	valid_0's binary_logloss: 0.358249
# [2216]	valid_0's binary_logloss: 0.358247
# [2217]	valid_0's binary_logloss: 0.358244
# [2218]	valid_0's binary_logloss: 0.358243
# [2219]	valid_0's binary_logloss: 0.358244
# [2220]	valid_0's binary_logloss: 0.358243
# [2221]	valid_0's binary_logloss: 0.358243
# [2222]	valid_0's binary_logloss: 0.358237
# [2223]	valid_0's binary_logloss: 0.358232
# [2224]	valid_0's binary_logloss: 0.358227
# [2225]	valid_0's binary_logloss: 0.358219
# [2226]	valid_0's binary_logloss: 0.358212
# [2227]	valid_0's binary_logloss: 0.358206
# [2228]	valid_0's binary_logloss: 0.358204
# [2229]	valid_0's binary_logloss: 0.358198
# [2230]	valid_0's binary_logloss: 0.358195
# [2231]	valid_0's binary_logloss: 0.358182
# [2232]	valid_0's binary_logloss: 0.358181
# [2233]	valid_0's binary_logloss: 0.358179
# [2234]	valid_0's binary_logloss: 0.358169
# [2235]	valid_0's binary_logloss: 0.358167
# [2236]	valid_0's binary_logloss: 0.358162
# [2237]	valid_0's binary_logloss: 0.358157
# [2238]	valid_0's binary_logloss: 0.358156
# [2239]	valid_0's binary_logloss: 0.358148
# [2240]	valid_0's binary_logloss: 0.358146
# [2241]	valid_0's binary_logloss: 0.358145
# [2242]	valid_0's binary_logloss: 0.358141
# [2243]	valid_0's binary_logloss: 0.35814
# [2244]	valid_0's binary_logloss: 0.358137
# [2245]	valid_0's binary_logloss: 0.358135
# [2246]	valid_0's binary_logloss: 0.358129
# [2247]	valid_0's binary_logloss: 0.358126
# [2248]	valid_0's binary_logloss: 0.358109
# [2249]	valid_0's binary_logloss: 0.358101
# [2250]	valid_0's binary_logloss: 0.358096
# [2251]	valid_0's binary_logloss: 0.358089
# [2252]	valid_0's binary_logloss: 0.35809
# [2253]	valid_0's binary_logloss: 0.358092
# [2254]	valid_0's binary_logloss: 0.358091
# [2255]	valid_0's binary_logloss: 0.358088
# [2256]	valid_0's binary_logloss: 0.358086
# [2257]	valid_0's binary_logloss: 0.358081
# [2258]	valid_0's binary_logloss: 0.358081
# [2259]	valid_0's binary_logloss: 0.358074
# [2260]	valid_0's binary_logloss: 0.358069
# [2261]	valid_0's binary_logloss: 0.358067
# [2262]	valid_0's binary_logloss: 0.358066
# [2263]	valid_0's binary_logloss: 0.358056
# [2264]	valid_0's binary_logloss: 0.358059
# [2265]	valid_0's binary_logloss: 0.358059
# [2266]	valid_0's binary_logloss: 0.358058
# [2267]	valid_0's binary_logloss: 0.358056
# [2268]	valid_0's binary_logloss: 0.35805
# [2269]	valid_0's binary_logloss: 0.358047
# [2270]	valid_0's binary_logloss: 0.358047
# [2271]	valid_0's binary_logloss: 0.358046
# [2272]	valid_0's binary_logloss: 0.358043
# [2273]	valid_0's binary_logloss: 0.358043
# [2274]	valid_0's binary_logloss: 0.358042
# [2275]	valid_0's binary_logloss: 0.358041
# [2276]	valid_0's binary_logloss: 0.35804
# [2277]	valid_0's binary_logloss: 0.35804
# [2278]	valid_0's binary_logloss: 0.35804
# [2279]	valid_0's binary_logloss: 0.358038
# [2280]	valid_0's binary_logloss: 0.358037
# [2281]	valid_0's binary_logloss: 0.358035
# [2282]	valid_0's binary_logloss: 0.358031
# [2283]	valid_0's binary_logloss: 0.35803
# [2284]	valid_0's binary_logloss: 0.358029
# [2285]	valid_0's binary_logloss: 0.358027
# [2286]	valid_0's binary_logloss: 0.358021
# [2287]	valid_0's binary_logloss: 0.358022
# [2288]	valid_0's binary_logloss: 0.358021
# [2289]	valid_0's binary_logloss: 0.358022
# [2290]	valid_0's binary_logloss: 0.358022
# [2291]	valid_0's binary_logloss: 0.358019
# [2292]	valid_0's binary_logloss: 0.358019
# [2293]	valid_0's binary_logloss: 0.358015
# [2294]	valid_0's binary_logloss: 0.358013
# [2295]	valid_0's binary_logloss: 0.358009
# [2296]	valid_0's binary_logloss: 0.358009
# [2297]	valid_0's binary_logloss: 0.357991
# [2298]	valid_0's binary_logloss: 0.357989
# [2299]	valid_0's binary_logloss: 0.35799
# [2300]	valid_0's binary_logloss: 0.357988
# [2301]	valid_0's binary_logloss: 0.357985
# [2302]	valid_0's binary_logloss: 0.357983
# [2303]	valid_0's binary_logloss: 0.357974
# [2304]	valid_0's binary_logloss: 0.357971
# [2305]	valid_0's binary_logloss: 0.35797
# [2306]	valid_0's binary_logloss: 0.357968
# [2307]	valid_0's binary_logloss: 0.357962
# [2308]	valid_0's binary_logloss: 0.357956
# [2309]	valid_0's binary_logloss: 0.357952
# [2310]	valid_0's binary_logloss: 0.357953
# [2311]	valid_0's binary_logloss: 0.357949
# [2312]	valid_0's binary_logloss: 0.357945
# [2313]	valid_0's binary_logloss: 0.357946
# [2314]	valid_0's binary_logloss: 0.357943
# [2315]	valid_0's binary_logloss: 0.357942
# [2316]	valid_0's binary_logloss: 0.357938
# [2317]	valid_0's binary_logloss: 0.357936
# [2318]	valid_0's binary_logloss: 0.357939
# [2319]	valid_0's binary_logloss: 0.357931
# [2320]	valid_0's binary_logloss: 0.35793
# [2321]	valid_0's binary_logloss: 0.357928
# [2322]	valid_0's binary_logloss: 0.357928
# [2323]	valid_0's binary_logloss: 0.357926
# [2324]	valid_0's binary_logloss: 0.357924
# [2325]	valid_0's binary_logloss: 0.357922
# [2326]	valid_0's binary_logloss: 0.357921
# [2327]	valid_0's binary_logloss: 0.357919
# [2328]	valid_0's binary_logloss: 0.357919
# [2329]	valid_0's binary_logloss: 0.357915
# [2330]	valid_0's binary_logloss: 0.357915
# [2331]	valid_0's binary_logloss: 0.357912
# [2332]	valid_0's binary_logloss: 0.357908
# [2333]	valid_0's binary_logloss: 0.357903
# [2334]	valid_0's binary_logloss: 0.357901
# [2335]	valid_0's binary_logloss: 0.357895
# [2336]	valid_0's binary_logloss: 0.35789
# [2337]	valid_0's binary_logloss: 0.35789
# [2338]	valid_0's binary_logloss: 0.357888
# [2339]	valid_0's binary_logloss: 0.357884
# [2340]	valid_0's binary_logloss: 0.357881
# [2341]	valid_0's binary_logloss: 0.357883
# [2342]	valid_0's binary_logloss: 0.357881
# [2343]	valid_0's binary_logloss: 0.357878
# [2344]	valid_0's binary_logloss: 0.357872
# [2345]	valid_0's binary_logloss: 0.35787
# [2346]	valid_0's binary_logloss: 0.357867
# [2347]	valid_0's binary_logloss: 0.357865
# [2348]	valid_0's binary_logloss: 0.357865
# [2349]	valid_0's binary_logloss: 0.357857
# [2350]	valid_0's binary_logloss: 0.357856
# [2351]	valid_0's binary_logloss: 0.357855
# [2352]	valid_0's binary_logloss: 0.357851
# [2353]	valid_0's binary_logloss: 0.35785
# [2354]	valid_0's binary_logloss: 0.35785
# [2355]	valid_0's binary_logloss: 0.35785
# [2356]	valid_0's binary_logloss: 0.357848
# [2357]	valid_0's binary_logloss: 0.357843
# [2358]	valid_0's binary_logloss: 0.357844
# [2359]	valid_0's binary_logloss: 0.357829
# [2360]	valid_0's binary_logloss: 0.357827
# [2361]	valid_0's binary_logloss: 0.357821
# [2362]	valid_0's binary_logloss: 0.357821
# [2363]	valid_0's binary_logloss: 0.357822
# [2364]	valid_0's binary_logloss: 0.35782
# [2365]	valid_0's binary_logloss: 0.357818
# [2366]	valid_0's binary_logloss: 0.357817
# [2367]	valid_0's binary_logloss: 0.35781
# [2368]	valid_0's binary_logloss: 0.357809
# [2369]	valid_0's binary_logloss: 0.357809
# [2370]	valid_0's binary_logloss: 0.357807
# [2371]	valid_0's binary_logloss: 0.357807
# [2372]	valid_0's binary_logloss: 0.357806
# [2373]	valid_0's binary_logloss: 0.357806
# [2374]	valid_0's binary_logloss: 0.357798
# [2375]	valid_0's binary_logloss: 0.357796
# [2376]	valid_0's binary_logloss: 0.357791
# [2377]	valid_0's binary_logloss: 0.35779
# [2378]	valid_0's binary_logloss: 0.35779
# [2379]	valid_0's binary_logloss: 0.35779
# [2380]	valid_0's binary_logloss: 0.357785
# [2381]	valid_0's binary_logloss: 0.357783
# [2382]	valid_0's binary_logloss: 0.357779
# [2383]	valid_0's binary_logloss: 0.357777
# [2384]	valid_0's binary_logloss: 0.357769
# [2385]	valid_0's binary_logloss: 0.357769
# [2386]	valid_0's binary_logloss: 0.357768
# [2387]	valid_0's binary_logloss: 0.357764
# [2388]	valid_0's binary_logloss: 0.357766
# [2389]	valid_0's binary_logloss: 0.357764
# [2390]	valid_0's binary_logloss: 0.357764
# [2391]	valid_0's binary_logloss: 0.357764
# [2392]	valid_0's binary_logloss: 0.357762
# [2393]	valid_0's binary_logloss: 0.357761
# [2394]	valid_0's binary_logloss: 0.357757
# [2395]	valid_0's binary_logloss: 0.357754
# [2396]	valid_0's binary_logloss: 0.357754
# [2397]	valid_0's binary_logloss: 0.357754
# [2398]	valid_0's binary_logloss: 0.35775
# [2399]	valid_0's binary_logloss: 0.357745
# [2400]	valid_0's binary_logloss: 0.357743
# [2401]	valid_0's binary_logloss: 0.35774
# [2402]	valid_0's binary_logloss: 0.357743
# [2403]	valid_0's binary_logloss: 0.357744
# [2404]	valid_0's binary_logloss: 0.357741
# [2405]	valid_0's binary_logloss: 0.357739
# [2406]	valid_0's binary_logloss: 0.357738
# [2407]	valid_0's binary_logloss: 0.35773
# [2408]	valid_0's binary_logloss: 0.357725
# [2409]	valid_0's binary_logloss: 0.357724
# [2410]	valid_0's binary_logloss: 0.357724
# [2411]	valid_0's binary_logloss: 0.357719
# [2412]	valid_0's binary_logloss: 0.357716
# [2413]	valid_0's binary_logloss: 0.357714
# [2414]	valid_0's binary_logloss: 0.357712
# [2415]	valid_0's binary_logloss: 0.357712
# [2416]	valid_0's binary_logloss: 0.35771
# [2417]	valid_0's binary_logloss: 0.357708
# [2418]	valid_0's binary_logloss: 0.357708
# [2419]	valid_0's binary_logloss: 0.357703
# [2420]	valid_0's binary_logloss: 0.357699
# [2421]	valid_0's binary_logloss: 0.357698
# [2422]	valid_0's binary_logloss: 0.357697
# [2423]	valid_0's binary_logloss: 0.357689
# [2424]	valid_0's binary_logloss: 0.357689
# [2425]	valid_0's binary_logloss: 0.357689
# [2426]	valid_0's binary_logloss: 0.357688
# [2427]	valid_0's binary_logloss: 0.357687
# [2428]	valid_0's binary_logloss: 0.357686
# [2429]	valid_0's binary_logloss: 0.357683
# [2430]	valid_0's binary_logloss: 0.35768
# [2431]	valid_0's binary_logloss: 0.357681
# [2432]	valid_0's binary_logloss: 0.357675
# [2433]	valid_0's binary_logloss: 0.357676
# [2434]	valid_0's binary_logloss: 0.357676
# [2435]	valid_0's binary_logloss: 0.357676
# [2436]	valid_0's binary_logloss: 0.357674
# [2437]	valid_0's binary_logloss: 0.357674
# [2438]	valid_0's binary_logloss: 0.357672
# [2439]	valid_0's binary_logloss: 0.357671
# [2440]	valid_0's binary_logloss: 0.357664
# [2441]	valid_0's binary_logloss: 0.357661
# [2442]	valid_0's binary_logloss: 0.357658
# [2443]	valid_0's binary_logloss: 0.357657
# [2444]	valid_0's binary_logloss: 0.357655
# [2445]	valid_0's binary_logloss: 0.357653
# [2446]	valid_0's binary_logloss: 0.357651
# [2447]	valid_0's binary_logloss: 0.357646
# [2448]	valid_0's binary_logloss: 0.357645
# [2449]	valid_0's binary_logloss: 0.357647
# [2450]	valid_0's binary_logloss: 0.357644
# [2451]	valid_0's binary_logloss: 0.357642
# [2452]	valid_0's binary_logloss: 0.357641
# [2453]	valid_0's binary_logloss: 0.35764
# [2454]	valid_0's binary_logloss: 0.357638
# [2455]	valid_0's binary_logloss: 0.357637
# [2456]	valid_0's binary_logloss: 0.357638
# [2457]	valid_0's binary_logloss: 0.357634
# [2458]	valid_0's binary_logloss: 0.357634
# [2459]	valid_0's binary_logloss: 0.357633
# [2460]	valid_0's binary_logloss: 0.357633
# [2461]	valid_0's binary_logloss: 0.35763
# [2462]	valid_0's binary_logloss: 0.357624
# [2463]	valid_0's binary_logloss: 0.357622
# [2464]	valid_0's binary_logloss: 0.357619
# [2465]	valid_0's binary_logloss: 0.357614
# [2466]	valid_0's binary_logloss: 0.357608
# [2467]	valid_0's binary_logloss: 0.357609
# [2468]	valid_0's binary_logloss: 0.357608
# [2469]	valid_0's binary_logloss: 0.357603
# [2470]	valid_0's binary_logloss: 0.357601
# [2471]	valid_0's binary_logloss: 0.357598
# [2472]	valid_0's binary_logloss: 0.357596
# [2473]	valid_0's binary_logloss: 0.357598
# [2474]	valid_0's binary_logloss: 0.357597
# [2475]	valid_0's binary_logloss: 0.357594
# [2476]	valid_0's binary_logloss: 0.357593
# [2477]	valid_0's binary_logloss: 0.357591
# [2478]	valid_0's binary_logloss: 0.357587
# [2479]	valid_0's binary_logloss: 0.357585
# [2480]	valid_0's binary_logloss: 0.357584
# [2481]	valid_0's binary_logloss: 0.35758
# [2482]	valid_0's binary_logloss: 0.357575
# [2483]	valid_0's binary_logloss: 0.357573
# [2484]	valid_0's binary_logloss: 0.357569
# [2485]	valid_0's binary_logloss: 0.357564
# [2486]	valid_0's binary_logloss: 0.357559
# [2487]	valid_0's binary_logloss: 0.35755
# [2488]	valid_0's binary_logloss: 0.35755
# [2489]	valid_0's binary_logloss: 0.357549
# [2490]	valid_0's binary_logloss: 0.357544
# [2491]	valid_0's binary_logloss: 0.357543
# [2492]	valid_0's binary_logloss: 0.357543
# [2493]	valid_0's binary_logloss: 0.357544
# [2494]	valid_0's binary_logloss: 0.357542
# [2495]	valid_0's binary_logloss: 0.357541
# [2496]	valid_0's binary_logloss: 0.357538
# [2497]	valid_0's binary_logloss: 0.357537
# [2498]	valid_0's binary_logloss: 0.357535
# [2499]	valid_0's binary_logloss: 0.357534
# [2500]	valid_0's binary_logloss: 0.357535
# Did not meet early stopping. Best iteration is:
# [2499]	valid_0's binary_logloss: 0.357534
# Modelo da classe 5 finalizado

# %%
# Treinar 100% modelo da classe 4
m4 = lgb.train(params=hp4, num_boost_round=nbr, train_set=ds4_train, valid_sets=[ds4_valid], 
               verbose_eval=True, categorical_feature=feats_cat)
print('Modelo da classe 4 finalizado')
# Out:
# [1]	valid_0's binary_logloss: 0.600664
# Training until validation scores don't improve for 25 rounds
# [2]	valid_0's binary_logloss: 0.597133
# [3]	valid_0's binary_logloss: 0.593722
# [4]	valid_0's binary_logloss: 0.590392
# [5]	valid_0's binary_logloss: 0.587165
# [6]	valid_0's binary_logloss: 0.584307
# [7]	valid_0's binary_logloss: 0.581266
# [8]	valid_0's binary_logloss: 0.578323
# [9]	valid_0's binary_logloss: 0.575455
# [10]	valid_0's binary_logloss: 0.572909
# [11]	valid_0's binary_logloss: 0.570193
# [12]	valid_0's binary_logloss: 0.567523
# [13]	valid_0's binary_logloss: 0.564936
# [14]	valid_0's binary_logloss: 0.562643
# [15]	valid_0's binary_logloss: 0.5602
# [16]	valid_0's binary_logloss: 0.557797
# [17]	valid_0's binary_logloss: 0.555526
# [18]	valid_0's binary_logloss: 0.55325
# [19]	valid_0's binary_logloss: 0.551029
# [20]	valid_0's binary_logloss: 0.548845
# [21]	valid_0's binary_logloss: 0.546743
# [22]	valid_0's binary_logloss: 0.544678
# [23]	valid_0's binary_logloss: 0.542672
# [24]	valid_0's binary_logloss: 0.540701
# [25]	valid_0's binary_logloss: 0.538793
# [26]	valid_0's binary_logloss: 0.536921
# [27]	valid_0's binary_logloss: 0.53509
# [28]	valid_0's binary_logloss: 0.53353
# [29]	valid_0's binary_logloss: 0.531772
# [30]	valid_0's binary_logloss: 0.530069
# [31]	valid_0's binary_logloss: 0.528401
# [32]	valid_0's binary_logloss: 0.526935
# [33]	valid_0's binary_logloss: 0.525324
# [34]	valid_0's binary_logloss: 0.523771
# [35]	valid_0's binary_logloss: 0.522237
# [36]	valid_0's binary_logloss: 0.520824
# [37]	valid_0's binary_logloss: 0.519373
# [38]	valid_0's binary_logloss: 0.517921
# [39]	valid_0's binary_logloss: 0.516539
# [40]	valid_0's binary_logloss: 0.515174
# [41]	valid_0's binary_logloss: 0.513846
# [42]	valid_0's binary_logloss: 0.512541
# [43]	valid_0's binary_logloss: 0.511269
# [44]	valid_0's binary_logloss: 0.510023
# [45]	valid_0's binary_logloss: 0.508791
# [46]	valid_0's binary_logloss: 0.507596
# [47]	valid_0's binary_logloss: 0.506544
# [48]	valid_0's binary_logloss: 0.505388
# [49]	valid_0's binary_logloss: 0.504393
# [50]	valid_0's binary_logloss: 0.5033
# [51]	valid_0's binary_logloss: 0.502352
# [52]	valid_0's binary_logloss: 0.501295
# [53]	valid_0's binary_logloss: 0.500257
# [54]	valid_0's binary_logloss: 0.499227
# [55]	valid_0's binary_logloss: 0.498192
# [56]	valid_0's binary_logloss: 0.497212
# [57]	valid_0's binary_logloss: 0.496237
# [58]	valid_0's binary_logloss: 0.495328
# [59]	valid_0's binary_logloss: 0.494534
# [60]	valid_0's binary_logloss: 0.493628
# [61]	valid_0's binary_logloss: 0.492747
# [62]	valid_0's binary_logloss: 0.491884
# [63]	valid_0's binary_logloss: 0.491037
# [64]	valid_0's binary_logloss: 0.490299
# [65]	valid_0's binary_logloss: 0.489548
# [66]	valid_0's binary_logloss: 0.488891
# [67]	valid_0's binary_logloss: 0.48822
# [68]	valid_0's binary_logloss: 0.487452
# [69]	valid_0's binary_logloss: 0.486688
# [70]	valid_0's binary_logloss: 0.485944
# [71]	valid_0's binary_logloss: 0.48523
# [72]	valid_0's binary_logloss: 0.484513
# [73]	valid_0's binary_logloss: 0.483841
# [74]	valid_0's binary_logloss: 0.483158
# [75]	valid_0's binary_logloss: 0.482501
# [76]	valid_0's binary_logloss: 0.481842
# [77]	valid_0's binary_logloss: 0.481295
# [78]	valid_0's binary_logloss: 0.480673
# [79]	valid_0's binary_logloss: 0.480045
# [80]	valid_0's binary_logloss: 0.479441
# [81]	valid_0's binary_logloss: 0.478843
# [82]	valid_0's binary_logloss: 0.47828
# [83]	valid_0's binary_logloss: 0.477742
# [84]	valid_0's binary_logloss: 0.47719
# [85]	valid_0's binary_logloss: 0.476656
# [86]	valid_0's binary_logloss: 0.476144
# [87]	valid_0's binary_logloss: 0.475626
# [88]	valid_0's binary_logloss: 0.475105
# [89]	valid_0's binary_logloss: 0.47461
# [90]	valid_0's binary_logloss: 0.474111
# [91]	valid_0's binary_logloss: 0.47371
# [92]	valid_0's binary_logloss: 0.473191
# [93]	valid_0's binary_logloss: 0.47272
# [94]	valid_0's binary_logloss: 0.47226
# [95]	valid_0's binary_logloss: 0.471794
# [96]	valid_0's binary_logloss: 0.471346
# [97]	valid_0's binary_logloss: 0.470923
# [98]	valid_0's binary_logloss: 0.470465
# [99]	valid_0's binary_logloss: 0.470043
# [100]	valid_0's binary_logloss: 0.469631
# [101]	valid_0's binary_logloss: 0.469233
# [102]	valid_0's binary_logloss: 0.46893
# [103]	valid_0's binary_logloss: 0.468507
# [104]	valid_0's binary_logloss: 0.468112
# [105]	valid_0's binary_logloss: 0.467849
# [106]	valid_0's binary_logloss: 0.467446
# [107]	valid_0's binary_logloss: 0.467054
# [108]	valid_0's binary_logloss: 0.46678
# [109]	valid_0's binary_logloss: 0.466429
# [110]	valid_0's binary_logloss: 0.466088
# [111]	valid_0's binary_logloss: 0.465825
# [112]	valid_0's binary_logloss: 0.465563
# [113]	valid_0's binary_logloss: 0.465319
# [114]	valid_0's binary_logloss: 0.464974
# [115]	valid_0's binary_logloss: 0.464655
# [116]	valid_0's binary_logloss: 0.464321
# [117]	valid_0's binary_logloss: 0.464008
# [118]	valid_0's binary_logloss: 0.463697
# [119]	valid_0's binary_logloss: 0.463413
# [120]	valid_0's binary_logloss: 0.463111
# [121]	valid_0's binary_logloss: 0.462903
# [122]	valid_0's binary_logloss: 0.462645
# [123]	valid_0's binary_logloss: 0.462349
# [124]	valid_0's binary_logloss: 0.462073
# [125]	valid_0's binary_logloss: 0.461867
# [126]	valid_0's binary_logloss: 0.461595
# [127]	valid_0's binary_logloss: 0.461336
# [128]	valid_0's binary_logloss: 0.461067
# [129]	valid_0's binary_logloss: 0.460813
# [130]	valid_0's binary_logloss: 0.460522
# [131]	valid_0's binary_logloss: 0.460268
# [132]	valid_0's binary_logloss: 0.46002
# [133]	valid_0's binary_logloss: 0.459787
# [134]	valid_0's binary_logloss: 0.459544
# [135]	valid_0's binary_logloss: 0.459297
# [136]	valid_0's binary_logloss: 0.459062
# [137]	valid_0's binary_logloss: 0.458829
# [138]	valid_0's binary_logloss: 0.458602
# [139]	valid_0's binary_logloss: 0.458381
# [140]	valid_0's binary_logloss: 0.458162
# [141]	valid_0's binary_logloss: 0.457917
# [142]	valid_0's binary_logloss: 0.457708
# [143]	valid_0's binary_logloss: 0.457478
# [144]	valid_0's binary_logloss: 0.457252
# [145]	valid_0's binary_logloss: 0.457047
# [146]	valid_0's binary_logloss: 0.456843
# [147]	valid_0's binary_logloss: 0.456723
# [148]	valid_0's binary_logloss: 0.45653
# [149]	valid_0's binary_logloss: 0.456344
# [150]	valid_0's binary_logloss: 0.456153
# [151]	valid_0's binary_logloss: 0.455965
# [152]	valid_0's binary_logloss: 0.455782
# [153]	valid_0's binary_logloss: 0.455607
# [154]	valid_0's binary_logloss: 0.455433
# [155]	valid_0's binary_logloss: 0.455273
# [156]	valid_0's binary_logloss: 0.455112
# [157]	valid_0's binary_logloss: 0.454961
# [158]	valid_0's binary_logloss: 0.45478
# [159]	valid_0's binary_logloss: 0.454684
# [160]	valid_0's binary_logloss: 0.454525
# [161]	valid_0's binary_logloss: 0.454337
# [162]	valid_0's binary_logloss: 0.454185
# [163]	valid_0's binary_logloss: 0.454004
# [164]	valid_0's binary_logloss: 0.45384
# [165]	valid_0's binary_logloss: 0.453681
# [166]	valid_0's binary_logloss: 0.453538
# [167]	valid_0's binary_logloss: 0.453476
# [168]	valid_0's binary_logloss: 0.453318
# [169]	valid_0's binary_logloss: 0.453147
# [170]	valid_0's binary_logloss: 0.453002
# [171]	valid_0's binary_logloss: 0.45294
# [172]	valid_0's binary_logloss: 0.452796
# [173]	valid_0's binary_logloss: 0.45267
# [174]	valid_0's binary_logloss: 0.452601
# [175]	valid_0's binary_logloss: 0.452465
# [176]	valid_0's binary_logloss: 0.452333
# [177]	valid_0's binary_logloss: 0.452188
# [178]	valid_0's binary_logloss: 0.452055
# [179]	valid_0's binary_logloss: 0.451879
# [180]	valid_0's binary_logloss: 0.451757
# [181]	valid_0's binary_logloss: 0.4517
# [182]	valid_0's binary_logloss: 0.451557
# [183]	valid_0's binary_logloss: 0.451413
# [184]	valid_0's binary_logloss: 0.451302
# [185]	valid_0's binary_logloss: 0.451189
# [186]	valid_0's binary_logloss: 0.451054
# [187]	valid_0's binary_logloss: 0.450904
# [188]	valid_0's binary_logloss: 0.450786
# [189]	valid_0's binary_logloss: 0.450659
# [190]	valid_0's binary_logloss: 0.450545
# [191]	valid_0's binary_logloss: 0.450435
# [192]	valid_0's binary_logloss: 0.45033
# [193]	valid_0's binary_logloss: 0.450205
# [194]	valid_0's binary_logloss: 0.4501
# [195]	valid_0's binary_logloss: 0.450001
# [196]	valid_0's binary_logloss: 0.449898
# [197]	valid_0's binary_logloss: 0.4498
# [198]	valid_0's binary_logloss: 0.449692
# [199]	valid_0's binary_logloss: 0.44954
# [200]	valid_0's binary_logloss: 0.449432
# [201]	valid_0's binary_logloss: 0.449328
# [202]	valid_0's binary_logloss: 0.449229
# [203]	valid_0's binary_logloss: 0.449155
# [204]	valid_0's binary_logloss: 0.449066
# [205]	valid_0's binary_logloss: 0.448935
# [206]	valid_0's binary_logloss: 0.448851
# [207]	valid_0's binary_logloss: 0.448747
# [208]	valid_0's binary_logloss: 0.448713
# [209]	valid_0's binary_logloss: 0.44862
# [210]	valid_0's binary_logloss: 0.448486
# [211]	valid_0's binary_logloss: 0.448386
# [212]	valid_0's binary_logloss: 0.448295
# [213]	valid_0's binary_logloss: 0.448203
# [214]	valid_0's binary_logloss: 0.448105
# [215]	valid_0's binary_logloss: 0.448069
# [216]	valid_0's binary_logloss: 0.447964
# [217]	valid_0's binary_logloss: 0.447875
# [218]	valid_0's binary_logloss: 0.447796
# [219]	valid_0's binary_logloss: 0.447712
# [220]	valid_0's binary_logloss: 0.447662
# [221]	valid_0's binary_logloss: 0.447558
# [222]	valid_0's binary_logloss: 0.447469
# [223]	valid_0's binary_logloss: 0.447389
# [224]	valid_0's binary_logloss: 0.447292
# [225]	valid_0's binary_logloss: 0.447206
# [226]	valid_0's binary_logloss: 0.447179
# [227]	valid_0's binary_logloss: 0.447099
# [228]	valid_0's binary_logloss: 0.447046
# [229]	valid_0's binary_logloss: 0.446961
# [230]	valid_0's binary_logloss: 0.44686
# [231]	valid_0's binary_logloss: 0.446773
# [232]	valid_0's binary_logloss: 0.446675
# [233]	valid_0's binary_logloss: 0.446636
# [234]	valid_0's binary_logloss: 0.446558
# [235]	valid_0's binary_logloss: 0.44647
# [236]	valid_0's binary_logloss: 0.446378
# [237]	valid_0's binary_logloss: 0.446295
# [238]	valid_0's binary_logloss: 0.446219
# [239]	valid_0's binary_logloss: 0.446142
# [240]	valid_0's binary_logloss: 0.446065
# [241]	valid_0's binary_logloss: 0.445986
# [242]	valid_0's binary_logloss: 0.445894
# [243]	valid_0's binary_logloss: 0.445872
# [244]	valid_0's binary_logloss: 0.445779
# [245]	valid_0's binary_logloss: 0.445705
# [246]	valid_0's binary_logloss: 0.445625
# [247]	valid_0's binary_logloss: 0.445546
# [248]	valid_0's binary_logloss: 0.445485
# [249]	valid_0's binary_logloss: 0.445477
# [250]	valid_0's binary_logloss: 0.44539
# [251]	valid_0's binary_logloss: 0.44531
# [252]	valid_0's binary_logloss: 0.445287
# [253]	valid_0's binary_logloss: 0.445214
# [254]	valid_0's binary_logloss: 0.445125
# [255]	valid_0's binary_logloss: 0.445053
# [256]	valid_0's binary_logloss: 0.444974
# [257]	valid_0's binary_logloss: 0.444878
# [258]	valid_0's binary_logloss: 0.444873
# [259]	valid_0's binary_logloss: 0.444793
# [260]	valid_0's binary_logloss: 0.444697
# [261]	valid_0's binary_logloss: 0.444606
# [262]	valid_0's binary_logloss: 0.444526
# [263]	valid_0's binary_logloss: 0.444448
# [264]	valid_0's binary_logloss: 0.444345
# [265]	valid_0's binary_logloss: 0.444261
# [266]	valid_0's binary_logloss: 0.444254
# [267]	valid_0's binary_logloss: 0.444174
# [268]	valid_0's binary_logloss: 0.444109
# [269]	valid_0's binary_logloss: 0.444004
# [270]	valid_0's binary_logloss: 0.443938
# [271]	valid_0's binary_logloss: 0.443868
# [272]	valid_0's binary_logloss: 0.443794
# [273]	valid_0's binary_logloss: 0.443728
# [274]	valid_0's binary_logloss: 0.443649
# [275]	valid_0's binary_logloss: 0.443581
# [276]	valid_0's binary_logloss: 0.443504
# [277]	valid_0's binary_logloss: 0.443471
# [278]	valid_0's binary_logloss: 0.443402
# [279]	valid_0's binary_logloss: 0.443333
# [280]	valid_0's binary_logloss: 0.443268
# [281]	valid_0's binary_logloss: 0.443205
# [282]	valid_0's binary_logloss: 0.443146
# [283]	valid_0's binary_logloss: 0.443127
# [284]	valid_0's binary_logloss: 0.443112
# [285]	valid_0's binary_logloss: 0.443082
# [286]	valid_0's binary_logloss: 0.443007
# [287]	valid_0's binary_logloss: 0.442975
# [288]	valid_0's binary_logloss: 0.442955
# [289]	valid_0's binary_logloss: 0.442887
# [290]	valid_0's binary_logloss: 0.442806
# [291]	valid_0's binary_logloss: 0.442731
# [292]	valid_0's binary_logloss: 0.442645
# [293]	valid_0's binary_logloss: 0.442573
# [294]	valid_0's binary_logloss: 0.442511
# [295]	valid_0's binary_logloss: 0.442439
# [296]	valid_0's binary_logloss: 0.44238
# [297]	valid_0's binary_logloss: 0.442317
# [298]	valid_0's binary_logloss: 0.442241
# [299]	valid_0's binary_logloss: 0.442205
# [300]	valid_0's binary_logloss: 0.442182
# [301]	valid_0's binary_logloss: 0.44213
# [302]	valid_0's binary_logloss: 0.44206
# [303]	valid_0's binary_logloss: 0.442006
# [304]	valid_0's binary_logloss: 0.441948
# [305]	valid_0's binary_logloss: 0.4419
# [306]	valid_0's binary_logloss: 0.441826
# [307]	valid_0's binary_logloss: 0.441752
# [308]	valid_0's binary_logloss: 0.441734
# [309]	valid_0's binary_logloss: 0.441715
# [310]	valid_0's binary_logloss: 0.441643
# [311]	valid_0's binary_logloss: 0.441622
# [312]	valid_0's binary_logloss: 0.441547
# [313]	valid_0's binary_logloss: 0.441487
# [314]	valid_0's binary_logloss: 0.441436
# [315]	valid_0's binary_logloss: 0.441369
# [316]	valid_0's binary_logloss: 0.441312
# [317]	valid_0's binary_logloss: 0.441266
# [318]	valid_0's binary_logloss: 0.441209
# [319]	valid_0's binary_logloss: 0.441143
# [320]	valid_0's binary_logloss: 0.441074
# [321]	valid_0's binary_logloss: 0.44101
# [322]	valid_0's binary_logloss: 0.440948
# [323]	valid_0's binary_logloss: 0.440923
# [324]	valid_0's binary_logloss: 0.440829
# [325]	valid_0's binary_logloss: 0.440767
# [326]	valid_0's binary_logloss: 0.440707
# [327]	valid_0's binary_logloss: 0.440619
# [328]	valid_0's binary_logloss: 0.44054
# [329]	valid_0's binary_logloss: 0.440517
# [330]	valid_0's binary_logloss: 0.440432
# [331]	valid_0's binary_logloss: 0.440385
# [332]	valid_0's binary_logloss: 0.440321
# [333]	valid_0's binary_logloss: 0.440272
# [334]	valid_0's binary_logloss: 0.440203
# [335]	valid_0's binary_logloss: 0.440173
# [336]	valid_0's binary_logloss: 0.440116
# [337]	valid_0's binary_logloss: 0.44003
# [338]	valid_0's binary_logloss: 0.439956
# [339]	valid_0's binary_logloss: 0.439899
# [340]	valid_0's binary_logloss: 0.439845
# [341]	valid_0's binary_logloss: 0.439781
# [342]	valid_0's binary_logloss: 0.439713
# [343]	valid_0's binary_logloss: 0.439683
# [344]	valid_0's binary_logloss: 0.439651
# [345]	valid_0's binary_logloss: 0.439595
# [346]	valid_0's binary_logloss: 0.439527
# [347]	valid_0's binary_logloss: 0.439449
# [348]	valid_0's binary_logloss: 0.439382
# [349]	valid_0's binary_logloss: 0.439308
# [350]	valid_0's binary_logloss: 0.439234
# [351]	valid_0's binary_logloss: 0.439211
# [352]	valid_0's binary_logloss: 0.439158
# [353]	valid_0's binary_logloss: 0.439072
# [354]	valid_0's binary_logloss: 0.439043
# [355]	valid_0's binary_logloss: 0.438971
# [356]	valid_0's binary_logloss: 0.438944
# [357]	valid_0's binary_logloss: 0.438886
# [358]	valid_0's binary_logloss: 0.438829
# [359]	valid_0's binary_logloss: 0.438761
# [360]	valid_0's binary_logloss: 0.438692
# [361]	valid_0's binary_logloss: 0.438616
# [362]	valid_0's binary_logloss: 0.438534
# [363]	valid_0's binary_logloss: 0.438467
# [364]	valid_0's binary_logloss: 0.43845
# [365]	valid_0's binary_logloss: 0.438375
# [366]	valid_0's binary_logloss: 0.438316
# [367]	valid_0's binary_logloss: 0.438241
# [368]	valid_0's binary_logloss: 0.438155
# [369]	valid_0's binary_logloss: 0.438088
# [370]	valid_0's binary_logloss: 0.438009
# [371]	valid_0's binary_logloss: 0.437939
# [372]	valid_0's binary_logloss: 0.437869
# [373]	valid_0's binary_logloss: 0.437804
# [374]	valid_0's binary_logloss: 0.437724
# [375]	valid_0's binary_logloss: 0.437665
# [376]	valid_0's binary_logloss: 0.437646
# [377]	valid_0's binary_logloss: 0.437591
# [378]	valid_0's binary_logloss: 0.437533
# [379]	valid_0's binary_logloss: 0.437489
# [380]	valid_0's binary_logloss: 0.437429
# [381]	valid_0's binary_logloss: 0.437371
# [382]	valid_0's binary_logloss: 0.437344
# [383]	valid_0's binary_logloss: 0.437276
# [384]	valid_0's binary_logloss: 0.437213
# [385]	valid_0's binary_logloss: 0.437146
# [386]	valid_0's binary_logloss: 0.43709
# [387]	valid_0's binary_logloss: 0.437018
# [388]	valid_0's binary_logloss: 0.436949
# [389]	valid_0's binary_logloss: 0.436934
# [390]	valid_0's binary_logloss: 0.436913
# [391]	valid_0's binary_logloss: 0.436854
# [392]	valid_0's binary_logloss: 0.436806
# [393]	valid_0's binary_logloss: 0.436746
# [394]	valid_0's binary_logloss: 0.436662
# [395]	valid_0's binary_logloss: 0.436576
# [396]	valid_0's binary_logloss: 0.436521
# [397]	valid_0's binary_logloss: 0.436455
# [398]	valid_0's binary_logloss: 0.436397
# [399]	valid_0's binary_logloss: 0.43635
# [400]	valid_0's binary_logloss: 0.4363
# [401]	valid_0's binary_logloss: 0.436235
# [402]	valid_0's binary_logloss: 0.436188
# [403]	valid_0's binary_logloss: 0.436128
# [404]	valid_0's binary_logloss: 0.436063
# [405]	valid_0's binary_logloss: 0.435985
# [406]	valid_0's binary_logloss: 0.435904
# [407]	valid_0's binary_logloss: 0.435837
# [408]	valid_0's binary_logloss: 0.435771
# [409]	valid_0's binary_logloss: 0.435718
# [410]	valid_0's binary_logloss: 0.435628
# [411]	valid_0's binary_logloss: 0.43558
# [412]	valid_0's binary_logloss: 0.435525
# [413]	valid_0's binary_logloss: 0.435502
# [414]	valid_0's binary_logloss: 0.435447
# [415]	valid_0's binary_logloss: 0.435391
# [416]	valid_0's binary_logloss: 0.435326
# [417]	valid_0's binary_logloss: 0.435267
# [418]	valid_0's binary_logloss: 0.435195
# [419]	valid_0's binary_logloss: 0.435118
# [420]	valid_0's binary_logloss: 0.435067
# [421]	valid_0's binary_logloss: 0.435038
# [422]	valid_0's binary_logloss: 0.435014
# [423]	valid_0's binary_logloss: 0.434961
# [424]	valid_0's binary_logloss: 0.434898
# [425]	valid_0's binary_logloss: 0.434841
# [426]	valid_0's binary_logloss: 0.434792
# [427]	valid_0's binary_logloss: 0.434737
# [428]	valid_0's binary_logloss: 0.434689
# [429]	valid_0's binary_logloss: 0.434644
# [430]	valid_0's binary_logloss: 0.434607
# [431]	valid_0's binary_logloss: 0.434543
# [432]	valid_0's binary_logloss: 0.434472
# [433]	valid_0's binary_logloss: 0.434442
# [434]	valid_0's binary_logloss: 0.434385
# [435]	valid_0's binary_logloss: 0.43433
# [436]	valid_0's binary_logloss: 0.434287
# [437]	valid_0's binary_logloss: 0.434222
# [438]	valid_0's binary_logloss: 0.434153
# [439]	valid_0's binary_logloss: 0.434091
# [440]	valid_0's binary_logloss: 0.434005
# [441]	valid_0's binary_logloss: 0.433956
# [442]	valid_0's binary_logloss: 0.433935
# [443]	valid_0's binary_logloss: 0.433884
# [444]	valid_0's binary_logloss: 0.433848
# [445]	valid_0's binary_logloss: 0.433791
# [446]	valid_0's binary_logloss: 0.433732
# [447]	valid_0's binary_logloss: 0.433687
# [448]	valid_0's binary_logloss: 0.433628
# [449]	valid_0's binary_logloss: 0.433571
# [450]	valid_0's binary_logloss: 0.433528
# [451]	valid_0's binary_logloss: 0.433482
# [452]	valid_0's binary_logloss: 0.433435
# [453]	valid_0's binary_logloss: 0.433365
# [454]	valid_0's binary_logloss: 0.433308
# [455]	valid_0's binary_logloss: 0.433252
# [456]	valid_0's binary_logloss: 0.4332
# [457]	valid_0's binary_logloss: 0.43314
# [458]	valid_0's binary_logloss: 0.433113
# [459]	valid_0's binary_logloss: 0.433042
# [460]	valid_0's binary_logloss: 0.432971
# [461]	valid_0's binary_logloss: 0.432931
# [462]	valid_0's binary_logloss: 0.432891
# [463]	valid_0's binary_logloss: 0.432835
# [464]	valid_0's binary_logloss: 0.432792
# [465]	valid_0's binary_logloss: 0.432746
# [466]	valid_0's binary_logloss: 0.432699
# [467]	valid_0's binary_logloss: 0.432633
# [468]	valid_0's binary_logloss: 0.432564
# [469]	valid_0's binary_logloss: 0.432517
# [470]	valid_0's binary_logloss: 0.432464
# [471]	valid_0's binary_logloss: 0.432411
# [472]	valid_0's binary_logloss: 0.432381
# [473]	valid_0's binary_logloss: 0.432338
# [474]	valid_0's binary_logloss: 0.43225
# [475]	valid_0's binary_logloss: 0.432205
# [476]	valid_0's binary_logloss: 0.432132
# [477]	valid_0's binary_logloss: 0.432056
# [478]	valid_0's binary_logloss: 0.431975
# [479]	valid_0's binary_logloss: 0.431917
# [480]	valid_0's binary_logloss: 0.431882
# [481]	valid_0's binary_logloss: 0.431845
# [482]	valid_0's binary_logloss: 0.431811
# [483]	valid_0's binary_logloss: 0.43176
# [484]	valid_0's binary_logloss: 0.43169
# [485]	valid_0's binary_logloss: 0.431631
# [486]	valid_0's binary_logloss: 0.4316
# [487]	valid_0's binary_logloss: 0.431555
# [488]	valid_0's binary_logloss: 0.431503
# [489]	valid_0's binary_logloss: 0.43145
# [490]	valid_0's binary_logloss: 0.431402
# [491]	valid_0's binary_logloss: 0.431335
# [492]	valid_0's binary_logloss: 0.431266
# [493]	valid_0's binary_logloss: 0.431213
# [494]	valid_0's binary_logloss: 0.431161
# [495]	valid_0's binary_logloss: 0.431126
# [496]	valid_0's binary_logloss: 0.431077
# [497]	valid_0's binary_logloss: 0.431033
# [498]	valid_0's binary_logloss: 0.43101
# [499]	valid_0's binary_logloss: 0.430974
# [500]	valid_0's binary_logloss: 0.430921
# [501]	valid_0's binary_logloss: 0.430852
# [502]	valid_0's binary_logloss: 0.430801
# [503]	valid_0's binary_logloss: 0.430743
# [504]	valid_0's binary_logloss: 0.430696
# [505]	valid_0's binary_logloss: 0.430644
# [506]	valid_0's binary_logloss: 0.430607
# [507]	valid_0's binary_logloss: 0.430553
# [508]	valid_0's binary_logloss: 0.430516
# [509]	valid_0's binary_logloss: 0.430452
# [510]	valid_0's binary_logloss: 0.430414
# [511]	valid_0's binary_logloss: 0.43037
# [512]	valid_0's binary_logloss: 0.430332
# [513]	valid_0's binary_logloss: 0.430288
# [514]	valid_0's binary_logloss: 0.430231
# [515]	valid_0's binary_logloss: 0.430183
# [516]	valid_0's binary_logloss: 0.430129
# [517]	valid_0's binary_logloss: 0.430061
# [518]	valid_0's binary_logloss: 0.429983
# [519]	valid_0's binary_logloss: 0.429947
# [520]	valid_0's binary_logloss: 0.429894
# [521]	valid_0's binary_logloss: 0.429844
# [522]	valid_0's binary_logloss: 0.429816
# [523]	valid_0's binary_logloss: 0.429782
# [524]	valid_0's binary_logloss: 0.4297
# [525]	valid_0's binary_logloss: 0.429648
# [526]	valid_0's binary_logloss: 0.429603
# [527]	valid_0's binary_logloss: 0.429564
# [528]	valid_0's binary_logloss: 0.429515
# [529]	valid_0's binary_logloss: 0.429463
# [530]	valid_0's binary_logloss: 0.429425
# [531]	valid_0's binary_logloss: 0.429357
# [532]	valid_0's binary_logloss: 0.429323
# [533]	valid_0's binary_logloss: 0.42928
# [534]	valid_0's binary_logloss: 0.429226
# [535]	valid_0's binary_logloss: 0.429158
# [536]	valid_0's binary_logloss: 0.429101
# [537]	valid_0's binary_logloss: 0.429065
# [538]	valid_0's binary_logloss: 0.429025
# [539]	valid_0's binary_logloss: 0.428988
# [540]	valid_0's binary_logloss: 0.428951
# [541]	valid_0's binary_logloss: 0.428895
# [542]	valid_0's binary_logloss: 0.428859
# [543]	valid_0's binary_logloss: 0.428828
# [544]	valid_0's binary_logloss: 0.428798
# [545]	valid_0's binary_logloss: 0.428775
# [546]	valid_0's binary_logloss: 0.428737
# [547]	valid_0's binary_logloss: 0.428694
# [548]	valid_0's binary_logloss: 0.428665
# [549]	valid_0's binary_logloss: 0.428621
# [550]	valid_0's binary_logloss: 0.428594
# [551]	valid_0's binary_logloss: 0.42854
# [552]	valid_0's binary_logloss: 0.428505
# [553]	valid_0's binary_logloss: 0.428469
# [554]	valid_0's binary_logloss: 0.428402
# [555]	valid_0's binary_logloss: 0.428353
# [556]	valid_0's binary_logloss: 0.428334
# [557]	valid_0's binary_logloss: 0.428282
# [558]	valid_0's binary_logloss: 0.428245
# [559]	valid_0's binary_logloss: 0.428188
# [560]	valid_0's binary_logloss: 0.428143
# [561]	valid_0's binary_logloss: 0.42811
# [562]	valid_0's binary_logloss: 0.428057
# [563]	valid_0's binary_logloss: 0.428011
# [564]	valid_0's binary_logloss: 0.427967
# [565]	valid_0's binary_logloss: 0.427925
# [566]	valid_0's binary_logloss: 0.427879
# [567]	valid_0's binary_logloss: 0.427807
# [568]	valid_0's binary_logloss: 0.427776
# [569]	valid_0's binary_logloss: 0.427742
# [570]	valid_0's binary_logloss: 0.427701
# [571]	valid_0's binary_logloss: 0.427662
# [572]	valid_0's binary_logloss: 0.427627
# [573]	valid_0's binary_logloss: 0.427591
# [574]	valid_0's binary_logloss: 0.427544
# [575]	valid_0's binary_logloss: 0.427509
# [576]	valid_0's binary_logloss: 0.427467
# [577]	valid_0's binary_logloss: 0.427429
# [578]	valid_0's binary_logloss: 0.427402
# [579]	valid_0's binary_logloss: 0.427357
# [580]	valid_0's binary_logloss: 0.427318
# [581]	valid_0's binary_logloss: 0.427282
# [582]	valid_0's binary_logloss: 0.427235
# [583]	valid_0's binary_logloss: 0.42719
# [584]	valid_0's binary_logloss: 0.427138
# [585]	valid_0's binary_logloss: 0.42711
# [586]	valid_0's binary_logloss: 0.427067
# [587]	valid_0's binary_logloss: 0.427009
# [588]	valid_0's binary_logloss: 0.426972
# [589]	valid_0's binary_logloss: 0.426938
# [590]	valid_0's binary_logloss: 0.426903
# [591]	valid_0's binary_logloss: 0.426869
# [592]	valid_0's binary_logloss: 0.426832
# [593]	valid_0's binary_logloss: 0.426803
# [594]	valid_0's binary_logloss: 0.426781
# [595]	valid_0's binary_logloss: 0.426737
# [596]	valid_0's binary_logloss: 0.426683
# [597]	valid_0's binary_logloss: 0.426661
# [598]	valid_0's binary_logloss: 0.426615
# [599]	valid_0's binary_logloss: 0.426564
# [600]	valid_0's binary_logloss: 0.42651
# [601]	valid_0's binary_logloss: 0.426449
# [602]	valid_0's binary_logloss: 0.426427
# [603]	valid_0's binary_logloss: 0.426397
# [604]	valid_0's binary_logloss: 0.426358
# [605]	valid_0's binary_logloss: 0.426323
# [606]	valid_0's binary_logloss: 0.426274
# [607]	valid_0's binary_logloss: 0.426233
# [608]	valid_0's binary_logloss: 0.426202
# [609]	valid_0's binary_logloss: 0.42616
# [610]	valid_0's binary_logloss: 0.426128
# [611]	valid_0's binary_logloss: 0.426087
# [612]	valid_0's binary_logloss: 0.426033
# [613]	valid_0's binary_logloss: 0.426013
# [614]	valid_0's binary_logloss: 0.425963
# [615]	valid_0's binary_logloss: 0.425934
# [616]	valid_0's binary_logloss: 0.425911
# [617]	valid_0's binary_logloss: 0.425888
# [618]	valid_0's binary_logloss: 0.425842
# [619]	valid_0's binary_logloss: 0.425815
# [620]	valid_0's binary_logloss: 0.425776
# [621]	valid_0's binary_logloss: 0.425747
# [622]	valid_0's binary_logloss: 0.425711
# [623]	valid_0's binary_logloss: 0.425689
# [624]	valid_0's binary_logloss: 0.425668
# [625]	valid_0's binary_logloss: 0.425624
# [626]	valid_0's binary_logloss: 0.425606
# [627]	valid_0's binary_logloss: 0.425575
# [628]	valid_0's binary_logloss: 0.425535
# [629]	valid_0's binary_logloss: 0.425521
# [630]	valid_0's binary_logloss: 0.425488
# [631]	valid_0's binary_logloss: 0.425442
# [632]	valid_0's binary_logloss: 0.425403
# [633]	valid_0's binary_logloss: 0.42536
# [634]	valid_0's binary_logloss: 0.425335
# [635]	valid_0's binary_logloss: 0.425307
# [636]	valid_0's binary_logloss: 0.425276
# [637]	valid_0's binary_logloss: 0.425242
# [638]	valid_0's binary_logloss: 0.425219
# [639]	valid_0's binary_logloss: 0.425175
# [640]	valid_0's binary_logloss: 0.425153
# [641]	valid_0's binary_logloss: 0.425132
# [642]	valid_0's binary_logloss: 0.425097
# [643]	valid_0's binary_logloss: 0.425065
# [644]	valid_0's binary_logloss: 0.425027
# [645]	valid_0's binary_logloss: 0.424963
# [646]	valid_0's binary_logloss: 0.424933
# [647]	valid_0's binary_logloss: 0.424897
# [648]	valid_0's binary_logloss: 0.424877
# [649]	valid_0's binary_logloss: 0.424818
# [650]	valid_0's binary_logloss: 0.424797
# [651]	valid_0's binary_logloss: 0.424741
# [652]	valid_0's binary_logloss: 0.424718
# [653]	valid_0's binary_logloss: 0.424682
# [654]	valid_0's binary_logloss: 0.424663
# [655]	valid_0's binary_logloss: 0.42464
# [656]	valid_0's binary_logloss: 0.424617
# [657]	valid_0's binary_logloss: 0.424577
# [658]	valid_0's binary_logloss: 0.424516
# [659]	valid_0's binary_logloss: 0.424471
# [660]	valid_0's binary_logloss: 0.424452
# [661]	valid_0's binary_logloss: 0.424422
# [662]	valid_0's binary_logloss: 0.424398
# [663]	valid_0's binary_logloss: 0.424363
# [664]	valid_0's binary_logloss: 0.424298
# [665]	valid_0's binary_logloss: 0.424279
# [666]	valid_0's binary_logloss: 0.424246
# [667]	valid_0's binary_logloss: 0.424181
# [668]	valid_0's binary_logloss: 0.424149
# [669]	valid_0's binary_logloss: 0.424133
# [670]	valid_0's binary_logloss: 0.424077
# [671]	valid_0's binary_logloss: 0.424023
# [672]	valid_0's binary_logloss: 0.423978
# [673]	valid_0's binary_logloss: 0.423945
# [674]	valid_0's binary_logloss: 0.423912
# [675]	valid_0's binary_logloss: 0.423869
# [676]	valid_0's binary_logloss: 0.423846
# [677]	valid_0's binary_logloss: 0.423831
# [678]	valid_0's binary_logloss: 0.423779
# [679]	valid_0's binary_logloss: 0.423757
# [680]	valid_0's binary_logloss: 0.423736
# [681]	valid_0's binary_logloss: 0.42372
# [682]	valid_0's binary_logloss: 0.423694
# [683]	valid_0's binary_logloss: 0.423668
# [684]	valid_0's binary_logloss: 0.423586
# [685]	valid_0's binary_logloss: 0.423564
# [686]	valid_0's binary_logloss: 0.42353
# [687]	valid_0's binary_logloss: 0.423494
# [688]	valid_0's binary_logloss: 0.423479
# [689]	valid_0's binary_logloss: 0.423435
# [690]	valid_0's binary_logloss: 0.423406
# [691]	valid_0's binary_logloss: 0.423339
# [692]	valid_0's binary_logloss: 0.423324
# [693]	valid_0's binary_logloss: 0.42329
# [694]	valid_0's binary_logloss: 0.423254
# [695]	valid_0's binary_logloss: 0.423207
# [696]	valid_0's binary_logloss: 0.423156
# [697]	valid_0's binary_logloss: 0.423118
# [698]	valid_0's binary_logloss: 0.423081
# [699]	valid_0's binary_logloss: 0.423038
# [700]	valid_0's binary_logloss: 0.423023
# [701]	valid_0's binary_logloss: 0.422996
# [702]	valid_0's binary_logloss: 0.422963
# [703]	valid_0's binary_logloss: 0.422921
# [704]	valid_0's binary_logloss: 0.422881
# [705]	valid_0's binary_logloss: 0.422826
# [706]	valid_0's binary_logloss: 0.422794
# [707]	valid_0's binary_logloss: 0.422765
# [708]	valid_0's binary_logloss: 0.422737
# [709]	valid_0's binary_logloss: 0.422702
# [710]	valid_0's binary_logloss: 0.422685
# [711]	valid_0's binary_logloss: 0.422667
# [712]	valid_0's binary_logloss: 0.422638
# [713]	valid_0's binary_logloss: 0.422605
# [714]	valid_0's binary_logloss: 0.422571
# [715]	valid_0's binary_logloss: 0.422554
# [716]	valid_0's binary_logloss: 0.422502
# [717]	valid_0's binary_logloss: 0.422464
# [718]	valid_0's binary_logloss: 0.422429
# [719]	valid_0's binary_logloss: 0.42239
# [720]	valid_0's binary_logloss: 0.422362
# [721]	valid_0's binary_logloss: 0.422344
# [722]	valid_0's binary_logloss: 0.4223
# [723]	valid_0's binary_logloss: 0.422287
# [724]	valid_0's binary_logloss: 0.422256
# [725]	valid_0's binary_logloss: 0.422219
# [726]	valid_0's binary_logloss: 0.422195
# [727]	valid_0's binary_logloss: 0.422176
# [728]	valid_0's binary_logloss: 0.422146
# [729]	valid_0's binary_logloss: 0.422109
# [730]	valid_0's binary_logloss: 0.422084
# [731]	valid_0's binary_logloss: 0.422062
# [732]	valid_0's binary_logloss: 0.422032
# [733]	valid_0's binary_logloss: 0.42199
# [734]	valid_0's binary_logloss: 0.421951
# [735]	valid_0's binary_logloss: 0.421924
# [736]	valid_0's binary_logloss: 0.421891
# [737]	valid_0's binary_logloss: 0.421876
# [738]	valid_0's binary_logloss: 0.421856
# [739]	valid_0's binary_logloss: 0.421831
# [740]	valid_0's binary_logloss: 0.42179
# [741]	valid_0's binary_logloss: 0.421774
# [742]	valid_0's binary_logloss: 0.421747
# [743]	valid_0's binary_logloss: 0.421727
# [744]	valid_0's binary_logloss: 0.42169
# [745]	valid_0's binary_logloss: 0.421661
# [746]	valid_0's binary_logloss: 0.421631
# [747]	valid_0's binary_logloss: 0.421595
# [748]	valid_0's binary_logloss: 0.421557
# [749]	valid_0's binary_logloss: 0.421507
# [750]	valid_0's binary_logloss: 0.421471
# [751]	valid_0's binary_logloss: 0.421455
# [752]	valid_0's binary_logloss: 0.421429
# [753]	valid_0's binary_logloss: 0.421401
# [754]	valid_0's binary_logloss: 0.421386
# [755]	valid_0's binary_logloss: 0.421345
# [756]	valid_0's binary_logloss: 0.421323
# [757]	valid_0's binary_logloss: 0.421304
# [758]	valid_0's binary_logloss: 0.421263
# [759]	valid_0's binary_logloss: 0.421245
# [760]	valid_0's binary_logloss: 0.42122
# [761]	valid_0's binary_logloss: 0.421179
# [762]	valid_0's binary_logloss: 0.421147
# [763]	valid_0's binary_logloss: 0.421129
# [764]	valid_0's binary_logloss: 0.421116
# [765]	valid_0's binary_logloss: 0.421099
# [766]	valid_0's binary_logloss: 0.421086
# [767]	valid_0's binary_logloss: 0.421021
# [768]	valid_0's binary_logloss: 0.420968
# [769]	valid_0's binary_logloss: 0.420957
# [770]	valid_0's binary_logloss: 0.420935
# [771]	valid_0's binary_logloss: 0.420907
# [772]	valid_0's binary_logloss: 0.420865
# [773]	valid_0's binary_logloss: 0.420842
# [774]	valid_0's binary_logloss: 0.420826
# [775]	valid_0's binary_logloss: 0.4208
# [776]	valid_0's binary_logloss: 0.420769
# [777]	valid_0's binary_logloss: 0.420749
# [778]	valid_0's binary_logloss: 0.420725
# [779]	valid_0's binary_logloss: 0.420681
# [780]	valid_0's binary_logloss: 0.420659
# [781]	valid_0's binary_logloss: 0.42063
# [782]	valid_0's binary_logloss: 0.4206
# [783]	valid_0's binary_logloss: 0.420561
# [784]	valid_0's binary_logloss: 0.420519
# [785]	valid_0's binary_logloss: 0.420483
# [786]	valid_0's binary_logloss: 0.42043
# [787]	valid_0's binary_logloss: 0.420379
# [788]	valid_0's binary_logloss: 0.420357
# [789]	valid_0's binary_logloss: 0.420319
# [790]	valid_0's binary_logloss: 0.420294
# [791]	valid_0's binary_logloss: 0.42025
# [792]	valid_0's binary_logloss: 0.420231
# [793]	valid_0's binary_logloss: 0.420195
# [794]	valid_0's binary_logloss: 0.420178
# [795]	valid_0's binary_logloss: 0.420148
# [796]	valid_0's binary_logloss: 0.420107
# [797]	valid_0's binary_logloss: 0.420082
# [798]	valid_0's binary_logloss: 0.420057
# [799]	valid_0's binary_logloss: 0.420031
# [800]	valid_0's binary_logloss: 0.420013
# [801]	valid_0's binary_logloss: 0.419988
# [802]	valid_0's binary_logloss: 0.419973
# [803]	valid_0's binary_logloss: 0.419941
# [804]	valid_0's binary_logloss: 0.419923
# [805]	valid_0's binary_logloss: 0.4199
# [806]	valid_0's binary_logloss: 0.419864
# [807]	valid_0's binary_logloss: 0.419834
# [808]	valid_0's binary_logloss: 0.419808
# [809]	valid_0's binary_logloss: 0.419793
# [810]	valid_0's binary_logloss: 0.41977
# [811]	valid_0's binary_logloss: 0.419727
# [812]	valid_0's binary_logloss: 0.419713
# [813]	valid_0's binary_logloss: 0.419692
# [814]	valid_0's binary_logloss: 0.419675
# [815]	valid_0's binary_logloss: 0.419655
# [816]	valid_0's binary_logloss: 0.419634
# [817]	valid_0's binary_logloss: 0.4196
# [818]	valid_0's binary_logloss: 0.419573
# [819]	valid_0's binary_logloss: 0.41956
# [820]	valid_0's binary_logloss: 0.41953
# [821]	valid_0's binary_logloss: 0.41951
# [822]	valid_0's binary_logloss: 0.419498
# [823]	valid_0's binary_logloss: 0.419481
# [824]	valid_0's binary_logloss: 0.419435
# [825]	valid_0's binary_logloss: 0.419378
# [826]	valid_0's binary_logloss: 0.419364
# [827]	valid_0's binary_logloss: 0.41934
# [828]	valid_0's binary_logloss: 0.419316
# [829]	valid_0's binary_logloss: 0.419295
# [830]	valid_0's binary_logloss: 0.419253
# [831]	valid_0's binary_logloss: 0.419223
# [832]	valid_0's binary_logloss: 0.419167
# [833]	valid_0's binary_logloss: 0.419147
# [834]	valid_0's binary_logloss: 0.419123
# [835]	valid_0's binary_logloss: 0.419106
# [836]	valid_0's binary_logloss: 0.419092
# [837]	valid_0's binary_logloss: 0.419051
# [838]	valid_0's binary_logloss: 0.419021
# [839]	valid_0's binary_logloss: 0.418999
# [840]	valid_0's binary_logloss: 0.418969
# [841]	valid_0's binary_logloss: 0.418947
# [842]	valid_0's binary_logloss: 0.41893
# [843]	valid_0's binary_logloss: 0.418888
# [844]	valid_0's binary_logloss: 0.418858
# [845]	valid_0's binary_logloss: 0.418833
# [846]	valid_0's binary_logloss: 0.418816
# [847]	valid_0's binary_logloss: 0.418804
# [848]	valid_0's binary_logloss: 0.41879
# [849]	valid_0's binary_logloss: 0.418768
# [850]	valid_0's binary_logloss: 0.418744
# [851]	valid_0's binary_logloss: 0.418693
# [852]	valid_0's binary_logloss: 0.418669
# [853]	valid_0's binary_logloss: 0.418659
# [854]	valid_0's binary_logloss: 0.418616
# [855]	valid_0's binary_logloss: 0.418581
# [856]	valid_0's binary_logloss: 0.418564
# [857]	valid_0's binary_logloss: 0.418532
# [858]	valid_0's binary_logloss: 0.418504
# [859]	valid_0's binary_logloss: 0.418482
# [860]	valid_0's binary_logloss: 0.418462
# [861]	valid_0's binary_logloss: 0.418431
# [862]	valid_0's binary_logloss: 0.418423
# [863]	valid_0's binary_logloss: 0.418403
# [864]	valid_0's binary_logloss: 0.41839
# [865]	valid_0's binary_logloss: 0.418374
# [866]	valid_0's binary_logloss: 0.418354
# [867]	valid_0's binary_logloss: 0.418323
# [868]	valid_0's binary_logloss: 0.418298
# [869]	valid_0's binary_logloss: 0.418288
# [870]	valid_0's binary_logloss: 0.418254
# [871]	valid_0's binary_logloss: 0.418226
# [872]	valid_0's binary_logloss: 0.418195
# [873]	valid_0's binary_logloss: 0.418159
# [874]	valid_0's binary_logloss: 0.418133
# [875]	valid_0's binary_logloss: 0.418078
# [876]	valid_0's binary_logloss: 0.41805
# [877]	valid_0's binary_logloss: 0.418026
# [878]	valid_0's binary_logloss: 0.418011
# [879]	valid_0's binary_logloss: 0.417979
# [880]	valid_0's binary_logloss: 0.417959
# [881]	valid_0's binary_logloss: 0.41792
# [882]	valid_0's binary_logloss: 0.417901
# [883]	valid_0's binary_logloss: 0.417866
# [884]	valid_0's binary_logloss: 0.417821
# [885]	valid_0's binary_logloss: 0.417779
# [886]	valid_0's binary_logloss: 0.417756
# [887]	valid_0's binary_logloss: 0.417743
# [888]	valid_0's binary_logloss: 0.417719
# [889]	valid_0's binary_logloss: 0.417706
# [890]	valid_0's binary_logloss: 0.417676
# [891]	valid_0's binary_logloss: 0.417646
# [892]	valid_0's binary_logloss: 0.417628
# [893]	valid_0's binary_logloss: 0.417597
# [894]	valid_0's binary_logloss: 0.417563
# [895]	valid_0's binary_logloss: 0.41755
# [896]	valid_0's binary_logloss: 0.417524
# [897]	valid_0's binary_logloss: 0.417508
# [898]	valid_0's binary_logloss: 0.417476
# [899]	valid_0's binary_logloss: 0.417451
# [900]	valid_0's binary_logloss: 0.417436
# [901]	valid_0's binary_logloss: 0.417406
# [902]	valid_0's binary_logloss: 0.417367
# [903]	valid_0's binary_logloss: 0.417349
# [904]	valid_0's binary_logloss: 0.417328
# [905]	valid_0's binary_logloss: 0.417308
# [906]	valid_0's binary_logloss: 0.417291
# [907]	valid_0's binary_logloss: 0.417252
# [908]	valid_0's binary_logloss: 0.417239
# [909]	valid_0's binary_logloss: 0.417201
# [910]	valid_0's binary_logloss: 0.417173
# [911]	valid_0's binary_logloss: 0.417163
# [912]	valid_0's binary_logloss: 0.417147
# [913]	valid_0's binary_logloss: 0.417126
# [914]	valid_0's binary_logloss: 0.417114
# [915]	valid_0's binary_logloss: 0.417057
# [916]	valid_0's binary_logloss: 0.417046
# [917]	valid_0's binary_logloss: 0.416964
# [918]	valid_0's binary_logloss: 0.416955
# [919]	valid_0's binary_logloss: 0.41693
# [920]	valid_0's binary_logloss: 0.416918
# [921]	valid_0's binary_logloss: 0.416903
# [922]	valid_0's binary_logloss: 0.416842
# [923]	valid_0's binary_logloss: 0.41681
# [924]	valid_0's binary_logloss: 0.41679
# [925]	valid_0's binary_logloss: 0.416767
# [926]	valid_0's binary_logloss: 0.416758
# [927]	valid_0's binary_logloss: 0.416726
# [928]	valid_0's binary_logloss: 0.41669
# [929]	valid_0's binary_logloss: 0.416624
# [930]	valid_0's binary_logloss: 0.416616
# [931]	valid_0's binary_logloss: 0.41659
# [932]	valid_0's binary_logloss: 0.416525
# [933]	valid_0's binary_logloss: 0.416498
# [934]	valid_0's binary_logloss: 0.416488
# [935]	valid_0's binary_logloss: 0.416465
# [936]	valid_0's binary_logloss: 0.416435
# [937]	valid_0's binary_logloss: 0.416413
# [938]	valid_0's binary_logloss: 0.416398
# [939]	valid_0's binary_logloss: 0.416376
# [940]	valid_0's binary_logloss: 0.41636
# [941]	valid_0's binary_logloss: 0.416351
# [942]	valid_0's binary_logloss: 0.416328
# [943]	valid_0's binary_logloss: 0.416312
# [944]	valid_0's binary_logloss: 0.416249
# [945]	valid_0's binary_logloss: 0.416231
# [946]	valid_0's binary_logloss: 0.41622
# [947]	valid_0's binary_logloss: 0.416186
# [948]	valid_0's binary_logloss: 0.416167
# [949]	valid_0's binary_logloss: 0.41615
# [950]	valid_0's binary_logloss: 0.416134
# [951]	valid_0's binary_logloss: 0.416121
# [952]	valid_0's binary_logloss: 0.416088
# [953]	valid_0's binary_logloss: 0.416071
# [954]	valid_0's binary_logloss: 0.416064
# [955]	valid_0's binary_logloss: 0.416056
# [956]	valid_0's binary_logloss: 0.416028
# [957]	valid_0's binary_logloss: 0.415997
# [958]	valid_0's binary_logloss: 0.415949
# [959]	valid_0's binary_logloss: 0.415935
# [960]	valid_0's binary_logloss: 0.415922
# [961]	valid_0's binary_logloss: 0.415913
# [962]	valid_0's binary_logloss: 0.415893
# [963]	valid_0's binary_logloss: 0.415849
# [964]	valid_0's binary_logloss: 0.41584
# [965]	valid_0's binary_logloss: 0.415826
# [966]	valid_0's binary_logloss: 0.415801
# [967]	valid_0's binary_logloss: 0.415786
# [968]	valid_0's binary_logloss: 0.415751
# [969]	valid_0's binary_logloss: 0.415741
# [970]	valid_0's binary_logloss: 0.415733
# [971]	valid_0's binary_logloss: 0.415706
# [972]	valid_0's binary_logloss: 0.415666
# [973]	valid_0's binary_logloss: 0.415653
# [974]	valid_0's binary_logloss: 0.415641
# [975]	valid_0's binary_logloss: 0.415619
# [976]	valid_0's binary_logloss: 0.415577
# [977]	valid_0's binary_logloss: 0.415563
# [978]	valid_0's binary_logloss: 0.415533
# [979]	valid_0's binary_logloss: 0.415497
# [980]	valid_0's binary_logloss: 0.415483
# [981]	valid_0's binary_logloss: 0.415458
# [982]	valid_0's binary_logloss: 0.415424
# [983]	valid_0's binary_logloss: 0.415408
# [984]	valid_0's binary_logloss: 0.415394
# [985]	valid_0's binary_logloss: 0.415366
# [986]	valid_0's binary_logloss: 0.415344
# [987]	valid_0's binary_logloss: 0.415335
# [988]	valid_0's binary_logloss: 0.415328
# [989]	valid_0's binary_logloss: 0.415299
# [990]	valid_0's binary_logloss: 0.415271
# [991]	valid_0's binary_logloss: 0.415258
# [992]	valid_0's binary_logloss: 0.415237
# [993]	valid_0's binary_logloss: 0.415226
# [994]	valid_0's binary_logloss: 0.41521
# [995]	valid_0's binary_logloss: 0.415194
# [996]	valid_0's binary_logloss: 0.415162
# [997]	valid_0's binary_logloss: 0.415153
# [998]	valid_0's binary_logloss: 0.415135
# [999]	valid_0's binary_logloss: 0.415106
# [1000]	valid_0's binary_logloss: 0.415092
# [1001]	valid_0's binary_logloss: 0.415081
# [1002]	valid_0's binary_logloss: 0.41504
# [1003]	valid_0's binary_logloss: 0.415029
# [1004]	valid_0's binary_logloss: 0.41501
# [1005]	valid_0's binary_logloss: 0.414988
# [1006]	valid_0's binary_logloss: 0.414979
# [1007]	valid_0's binary_logloss: 0.414957
# [1008]	valid_0's binary_logloss: 0.414925
# [1009]	valid_0's binary_logloss: 0.414915
# [1010]	valid_0's binary_logloss: 0.414887
# [1011]	valid_0's binary_logloss: 0.414872
# [1012]	valid_0's binary_logloss: 0.41486
# [1013]	valid_0's binary_logloss: 0.414806
# [1014]	valid_0's binary_logloss: 0.414786
# [1015]	valid_0's binary_logloss: 0.414761
# [1016]	valid_0's binary_logloss: 0.414723
# [1017]	valid_0's binary_logloss: 0.41469
# [1018]	valid_0's binary_logloss: 0.41468
# [1019]	valid_0's binary_logloss: 0.414664
# [1020]	valid_0's binary_logloss: 0.414646
# [1021]	valid_0's binary_logloss: 0.414639
# [1022]	valid_0's binary_logloss: 0.414628
# [1023]	valid_0's binary_logloss: 0.414598
# [1024]	valid_0's binary_logloss: 0.41458
# [1025]	valid_0's binary_logloss: 0.414567
# [1026]	valid_0's binary_logloss: 0.414549
# [1027]	valid_0's binary_logloss: 0.414536
# [1028]	valid_0's binary_logloss: 0.414491
# [1029]	valid_0's binary_logloss: 0.414458
# [1030]	valid_0's binary_logloss: 0.414437
# [1031]	valid_0's binary_logloss: 0.414421
# [1032]	valid_0's binary_logloss: 0.414367
# [1033]	valid_0's binary_logloss: 0.414339
# [1034]	valid_0's binary_logloss: 0.414303
# [1035]	valid_0's binary_logloss: 0.414297
# [1036]	valid_0's binary_logloss: 0.414279
# [1037]	valid_0's binary_logloss: 0.414266
# [1038]	valid_0's binary_logloss: 0.414253
# [1039]	valid_0's binary_logloss: 0.414236
# [1040]	valid_0's binary_logloss: 0.414215
# [1041]	valid_0's binary_logloss: 0.414157
# [1042]	valid_0's binary_logloss: 0.414141
# [1043]	valid_0's binary_logloss: 0.414114
# [1044]	valid_0's binary_logloss: 0.414107
# [1045]	valid_0's binary_logloss: 0.414077
# [1046]	valid_0's binary_logloss: 0.414057
# [1047]	valid_0's binary_logloss: 0.414028
# [1048]	valid_0's binary_logloss: 0.414
# [1049]	valid_0's binary_logloss: 0.413974
# [1050]	valid_0's binary_logloss: 0.413956
# [1051]	valid_0's binary_logloss: 0.41394
# [1052]	valid_0's binary_logloss: 0.413918
# [1053]	valid_0's binary_logloss: 0.413894
# [1054]	valid_0's binary_logloss: 0.413876
# [1055]	valid_0's binary_logloss: 0.413855
# [1056]	valid_0's binary_logloss: 0.413847
# [1057]	valid_0's binary_logloss: 0.413823
# [1058]	valid_0's binary_logloss: 0.413812
# [1059]	valid_0's binary_logloss: 0.413796
# [1060]	valid_0's binary_logloss: 0.413786
# [1061]	valid_0's binary_logloss: 0.413765
# [1062]	valid_0's binary_logloss: 0.413734
# [1063]	valid_0's binary_logloss: 0.413717
# [1064]	valid_0's binary_logloss: 0.413712
# [1065]	valid_0's binary_logloss: 0.413703
# [1066]	valid_0's binary_logloss: 0.413685
# [1067]	valid_0's binary_logloss: 0.413654
# [1068]	valid_0's binary_logloss: 0.413607
# [1069]	valid_0's binary_logloss: 0.413591
# [1070]	valid_0's binary_logloss: 0.413578
# [1071]	valid_0's binary_logloss: 0.413569
# [1072]	valid_0's binary_logloss: 0.413554
# [1073]	valid_0's binary_logloss: 0.413532
# [1074]	valid_0's binary_logloss: 0.413519
# [1075]	valid_0's binary_logloss: 0.413509
# [1076]	valid_0's binary_logloss: 0.413485
# [1077]	valid_0's binary_logloss: 0.413473
# [1078]	valid_0's binary_logloss: 0.413462
# [1079]	valid_0's binary_logloss: 0.413445
# [1080]	valid_0's binary_logloss: 0.413414
# [1081]	valid_0's binary_logloss: 0.413385
# [1082]	valid_0's binary_logloss: 0.413342
# [1083]	valid_0's binary_logloss: 0.413321
# [1084]	valid_0's binary_logloss: 0.413316
# [1085]	valid_0's binary_logloss: 0.413281
# [1086]	valid_0's binary_logloss: 0.413256
# [1087]	valid_0's binary_logloss: 0.413223
# [1088]	valid_0's binary_logloss: 0.413214
# [1089]	valid_0's binary_logloss: 0.413203
# [1090]	valid_0's binary_logloss: 0.413186
# [1091]	valid_0's binary_logloss: 0.413179
# [1092]	valid_0's binary_logloss: 0.413168
# [1093]	valid_0's binary_logloss: 0.413133
# [1094]	valid_0's binary_logloss: 0.413114
# [1095]	valid_0's binary_logloss: 0.413104
# [1096]	valid_0's binary_logloss: 0.413095
# [1097]	valid_0's binary_logloss: 0.413075
# [1098]	valid_0's binary_logloss: 0.413046
# [1099]	valid_0's binary_logloss: 0.413035
# [1100]	valid_0's binary_logloss: 0.41299
# [1101]	valid_0's binary_logloss: 0.412972
# [1102]	valid_0's binary_logloss: 0.412935
# [1103]	valid_0's binary_logloss: 0.412921
# [1104]	valid_0's binary_logloss: 0.412913
# [1105]	valid_0's binary_logloss: 0.412905
# [1106]	valid_0's binary_logloss: 0.412892
# [1107]	valid_0's binary_logloss: 0.412876
# [1108]	valid_0's binary_logloss: 0.412863
# [1109]	valid_0's binary_logloss: 0.412853
# [1110]	valid_0's binary_logloss: 0.412815
# [1111]	valid_0's binary_logloss: 0.412807
# [1112]	valid_0's binary_logloss: 0.412782
# [1113]	valid_0's binary_logloss: 0.412778
# [1114]	valid_0's binary_logloss: 0.412759
# [1115]	valid_0's binary_logloss: 0.412754
# [1116]	valid_0's binary_logloss: 0.41274
# [1117]	valid_0's binary_logloss: 0.412724
# [1118]	valid_0's binary_logloss: 0.412704
# [1119]	valid_0's binary_logloss: 0.412677
# [1120]	valid_0's binary_logloss: 0.412661
# [1121]	valid_0's binary_logloss: 0.412649
# [1122]	valid_0's binary_logloss: 0.412638
# [1123]	valid_0's binary_logloss: 0.412612
# [1124]	valid_0's binary_logloss: 0.412575
# [1125]	valid_0's binary_logloss: 0.412565
# [1126]	valid_0's binary_logloss: 0.412555
# [1127]	valid_0's binary_logloss: 0.412547
# [1128]	valid_0's binary_logloss: 0.412535
# [1129]	valid_0's binary_logloss: 0.412526
# [1130]	valid_0's binary_logloss: 0.412505
# [1131]	valid_0's binary_logloss: 0.412486
# [1132]	valid_0's binary_logloss: 0.412476
# [1133]	valid_0's binary_logloss: 0.412464
# [1134]	valid_0's binary_logloss: 0.41242
# [1135]	valid_0's binary_logloss: 0.412413
# [1136]	valid_0's binary_logloss: 0.412376
# [1137]	valid_0's binary_logloss: 0.412371
# [1138]	valid_0's binary_logloss: 0.41236
# [1139]	valid_0's binary_logloss: 0.412334
# [1140]	valid_0's binary_logloss: 0.412319
# [1141]	valid_0's binary_logloss: 0.412309
# [1142]	valid_0's binary_logloss: 0.412289
# [1143]	valid_0's binary_logloss: 0.412248
# [1144]	valid_0's binary_logloss: 0.412233
# [1145]	valid_0's binary_logloss: 0.412216
# [1146]	valid_0's binary_logloss: 0.41219
# [1147]	valid_0's binary_logloss: 0.412187
# [1148]	valid_0's binary_logloss: 0.412161
# [1149]	valid_0's binary_logloss: 0.412145
# [1150]	valid_0's binary_logloss: 0.412126
# [1151]	valid_0's binary_logloss: 0.412109
# [1152]	valid_0's binary_logloss: 0.412096
# [1153]	valid_0's binary_logloss: 0.412082
# [1154]	valid_0's binary_logloss: 0.412068
# [1155]	valid_0's binary_logloss: 0.412065
# [1156]	valid_0's binary_logloss: 0.412052
# [1157]	valid_0's binary_logloss: 0.412043
# [1158]	valid_0's binary_logloss: 0.41203
# [1159]	valid_0's binary_logloss: 0.412012
# [1160]	valid_0's binary_logloss: 0.411965
# [1161]	valid_0's binary_logloss: 0.411953
# [1162]	valid_0's binary_logloss: 0.411944
# [1163]	valid_0's binary_logloss: 0.411939
# [1164]	valid_0's binary_logloss: 0.411929
# [1165]	valid_0's binary_logloss: 0.411923
# [1166]	valid_0's binary_logloss: 0.411917
# [1167]	valid_0's binary_logloss: 0.411886
# [1168]	valid_0's binary_logloss: 0.411843
# [1169]	valid_0's binary_logloss: 0.411812
# [1170]	valid_0's binary_logloss: 0.411806
# ...
# [2122]	valid_0's binary_logloss: 0.403135
# [2123]	valid_0's binary_logloss: 0.403125
# [2124]	valid_0's binary_logloss: 0.403118
# [2125]	valid_0's binary_logloss: 0.403111
# [2126]	valid_0's binary_logloss: 0.403103
# [2127]	valid_0's binary_logloss: 0.403096
# [2128]	valid_0's binary_logloss: 0.403096
# [2129]	valid_0's binary_logloss: 0.403093
# [2130]	valid_0's binary_logloss: 0.403091
# [2131]	valid_0's binary_logloss: 0.403091
# [2132]	valid_0's binary_logloss: 0.40309
# [2133]	valid_0's binary_logloss: 0.403083
# [2134]	valid_0's binary_logloss: 0.40308
# [2135]	valid_0's binary_logloss: 0.403079
# [2136]	valid_0's binary_logloss: 0.403067
# [2137]	valid_0's binary_logloss: 0.403067
# [2138]	valid_0's binary_logloss: 0.403063
# [2139]	valid_0's binary_logloss: 0.403057
# [2140]	valid_0's binary_logloss: 0.403048
# [2141]	valid_0's binary_logloss: 0.403041
# [2142]	valid_0's binary_logloss: 0.403038
# [2143]	valid_0's binary_logloss: 0.403024
# [2144]	valid_0's binary_logloss: 0.403016
# [2145]	valid_0's binary_logloss: 0.403014
# [2146]	valid_0's binary_logloss: 0.403011
# [2147]	valid_0's binary_logloss: 0.403007
# [2148]	valid_0's binary_logloss: 0.403004
# [2149]	valid_0's binary_logloss: 0.403003
# [2150]	valid_0's binary_logloss: 0.402997
# [2151]	valid_0's binary_logloss: 0.402993
# [2152]	valid_0's binary_logloss: 0.402992
# [2153]	valid_0's binary_logloss: 0.402986
# [2154]	valid_0's binary_logloss: 0.402978
# [2155]	valid_0's binary_logloss: 0.402976
# [2156]	valid_0's binary_logloss: 0.402969
# [2157]	valid_0's binary_logloss: 0.402968
# [2158]	valid_0's binary_logloss: 0.402963
# [2159]	valid_0's binary_logloss: 0.402954
# [2160]	valid_0's binary_logloss: 0.402948
# [2161]	valid_0's binary_logloss: 0.40294
# [2162]	valid_0's binary_logloss: 0.402935
# [2163]	valid_0's binary_logloss: 0.402932
# [2164]	valid_0's binary_logloss: 0.402925
# [2165]	valid_0's binary_logloss: 0.402925
# [2166]	valid_0's binary_logloss: 0.40292
# [2167]	valid_0's binary_logloss: 0.402913
# [2168]	valid_0's binary_logloss: 0.402911
# [2169]	valid_0's binary_logloss: 0.402906
# [2170]	valid_0's binary_logloss: 0.402899
# [2171]	valid_0's binary_logloss: 0.402896
# [2172]	valid_0's binary_logloss: 0.402893
# [2173]	valid_0's binary_logloss: 0.40289
# [2174]	valid_0's binary_logloss: 0.402888
# [2175]	valid_0's binary_logloss: 0.402886
# [2176]	valid_0's binary_logloss: 0.402878
# [2177]	valid_0's binary_logloss: 0.402866
# [2178]	valid_0's binary_logloss: 0.402865
# [2179]	valid_0's binary_logloss: 0.402854
# [2180]	valid_0's binary_logloss: 0.402852
# [2181]	valid_0's binary_logloss: 0.402844
# [2182]	valid_0's binary_logloss: 0.402843
# [2183]	valid_0's binary_logloss: 0.402835
# [2184]	valid_0's binary_logloss: 0.40283
# [2185]	valid_0's binary_logloss: 0.40283
# [2186]	valid_0's binary_logloss: 0.402828
# [2187]	valid_0's binary_logloss: 0.40281
# [2188]	valid_0's binary_logloss: 0.402806
# [2189]	valid_0's binary_logloss: 0.402793
# [2190]	valid_0's binary_logloss: 0.402781
# [2191]	valid_0's binary_logloss: 0.402779
# [2192]	valid_0's binary_logloss: 0.402778
# [2193]	valid_0's binary_logloss: 0.402778
# [2194]	valid_0's binary_logloss: 0.402772
# [2195]	valid_0's binary_logloss: 0.402767
# [2196]	valid_0's binary_logloss: 0.402764
# [2197]	valid_0's binary_logloss: 0.402762
# [2198]	valid_0's binary_logloss: 0.402754
# [2199]	valid_0's binary_logloss: 0.402741
# [2200]	valid_0's binary_logloss: 0.402735
# [2201]	valid_0's binary_logloss: 0.402733
# [2202]	valid_0's binary_logloss: 0.402723
# [2203]	valid_0's binary_logloss: 0.40272
# [2204]	valid_0's binary_logloss: 0.402719
# [2205]	valid_0's binary_logloss: 0.402719
# [2206]	valid_0's binary_logloss: 0.402714
# [2207]	valid_0's binary_logloss: 0.402702
# [2208]	valid_0's binary_logloss: 0.4027
# [2209]	valid_0's binary_logloss: 0.402694
# [2210]	valid_0's binary_logloss: 0.402693
# [2211]	valid_0's binary_logloss: 0.402679
# [2212]	valid_0's binary_logloss: 0.402675
# [2213]	valid_0's binary_logloss: 0.402673
# [2214]	valid_0's binary_logloss: 0.402672
# [2215]	valid_0's binary_logloss: 0.402669
# [2216]	valid_0's binary_logloss: 0.402667
# [2217]	valid_0's binary_logloss: 0.402661
# [2218]	valid_0's binary_logloss: 0.402658
# [2219]	valid_0's binary_logloss: 0.402653
# [2220]	valid_0's binary_logloss: 0.40265
# [2221]	valid_0's binary_logloss: 0.402645
# [2222]	valid_0's binary_logloss: 0.40264
# [2223]	valid_0's binary_logloss: 0.40263
# [2224]	valid_0's binary_logloss: 0.402627
# [2225]	valid_0's binary_logloss: 0.402621
# [2226]	valid_0's binary_logloss: 0.402614
# [2227]	valid_0's binary_logloss: 0.402611
# [2228]	valid_0's binary_logloss: 0.402606
# [2229]	valid_0's binary_logloss: 0.402601
# [2230]	valid_0's binary_logloss: 0.402599
# [2231]	valid_0's binary_logloss: 0.402593
# [2232]	valid_0's binary_logloss: 0.402589
# [2233]	valid_0's binary_logloss: 0.402586
# [2234]	valid_0's binary_logloss: 0.402572
# [2235]	valid_0's binary_logloss: 0.402567
# [2236]	valid_0's binary_logloss: 0.402559
# [2237]	valid_0's binary_logloss: 0.402556
# [2238]	valid_0's binary_logloss: 0.402555
# [2239]	valid_0's binary_logloss: 0.402549
# [2240]	valid_0's binary_logloss: 0.402546
# [2241]	valid_0's binary_logloss: 0.402541
# [2242]	valid_0's binary_logloss: 0.40253
# [2243]	valid_0's binary_logloss: 0.402527
# [2244]	valid_0's binary_logloss: 0.402521
# [2245]	valid_0's binary_logloss: 0.40252
# [2246]	valid_0's binary_logloss: 0.402516
# [2247]	valid_0's binary_logloss: 0.402513
# [2248]	valid_0's binary_logloss: 0.402491
# [2249]	valid_0's binary_logloss: 0.402487
# [2250]	valid_0's binary_logloss: 0.402484
# [2251]	valid_0's binary_logloss: 0.40248
# [2252]	valid_0's binary_logloss: 0.402477
# [2253]	valid_0's binary_logloss: 0.402476
# [2254]	valid_0's binary_logloss: 0.402475
# [2255]	valid_0's binary_logloss: 0.402471
# [2256]	valid_0's binary_logloss: 0.402463
# [2257]	valid_0's binary_logloss: 0.402457
# [2258]	valid_0's binary_logloss: 0.402455
# [2259]	valid_0's binary_logloss: 0.402452
# [2260]	valid_0's binary_logloss: 0.40245
# [2261]	valid_0's binary_logloss: 0.402446
# [2262]	valid_0's binary_logloss: 0.402444
# [2263]	valid_0's binary_logloss: 0.402439
# [2264]	valid_0's binary_logloss: 0.402435
# [2265]	valid_0's binary_logloss: 0.402431
# [2266]	valid_0's binary_logloss: 0.402426
# [2267]	valid_0's binary_logloss: 0.402423
# [2268]	valid_0's binary_logloss: 0.402422
# [2269]	valid_0's binary_logloss: 0.402421
# [2270]	valid_0's binary_logloss: 0.402418
# [2271]	valid_0's binary_logloss: 0.402416
# [2272]	valid_0's binary_logloss: 0.402414
# [2273]	valid_0's binary_logloss: 0.402412
# [2274]	valid_0's binary_logloss: 0.402408
# [2275]	valid_0's binary_logloss: 0.402407
# [2276]	valid_0's binary_logloss: 0.402403
# [2277]	valid_0's binary_logloss: 0.402398
# [2278]	valid_0's binary_logloss: 0.402389
# [2279]	valid_0's binary_logloss: 0.402381
# [2280]	valid_0's binary_logloss: 0.402378
# [2281]	valid_0's binary_logloss: 0.402378
# [2282]	valid_0's binary_logloss: 0.402377
# [2283]	valid_0's binary_logloss: 0.402373
# [2284]	valid_0's binary_logloss: 0.402372
# [2285]	valid_0's binary_logloss: 0.402368
# [2286]	valid_0's binary_logloss: 0.402365
# [2287]	valid_0's binary_logloss: 0.402359
# [2288]	valid_0's binary_logloss: 0.402358
# [2289]	valid_0's binary_logloss: 0.402355
# [2290]	valid_0's binary_logloss: 0.402354
# [2291]	valid_0's binary_logloss: 0.402352
# [2292]	valid_0's binary_logloss: 0.402345
# [2293]	valid_0's binary_logloss: 0.402343
# [2294]	valid_0's binary_logloss: 0.402342
# [2295]	valid_0's binary_logloss: 0.40234
# [2296]	valid_0's binary_logloss: 0.402338
# [2297]	valid_0's binary_logloss: 0.402327
# [2298]	valid_0's binary_logloss: 0.402327
# [2299]	valid_0's binary_logloss: 0.402326
# [2300]	valid_0's binary_logloss: 0.402324
# [2301]	valid_0's binary_logloss: 0.402318
# [2302]	valid_0's binary_logloss: 0.402315
# [2303]	valid_0's binary_logloss: 0.402309
# [2304]	valid_0's binary_logloss: 0.402305
# [2305]	valid_0's binary_logloss: 0.402298
# [2306]	valid_0's binary_logloss: 0.402292
# [2307]	valid_0's binary_logloss: 0.402284
# [2308]	valid_0's binary_logloss: 0.402281
# [2309]	valid_0's binary_logloss: 0.402276
# [2310]	valid_0's binary_logloss: 0.402274
# [2311]	valid_0's binary_logloss: 0.402273
# [2312]	valid_0's binary_logloss: 0.402269
# [2313]	valid_0's binary_logloss: 0.402269
# [2314]	valid_0's binary_logloss: 0.402267
# [2315]	valid_0's binary_logloss: 0.402263
# [2316]	valid_0's binary_logloss: 0.40226
# [2317]	valid_0's binary_logloss: 0.402255
# [2318]	valid_0's binary_logloss: 0.402252
# [2319]	valid_0's binary_logloss: 0.402247
# [2320]	valid_0's binary_logloss: 0.402245
# [2321]	valid_0's binary_logloss: 0.402239
# [2322]	valid_0's binary_logloss: 0.402237
# [2323]	valid_0's binary_logloss: 0.402233
# [2324]	valid_0's binary_logloss: 0.40223
# [2325]	valid_0's binary_logloss: 0.402226
# [2326]	valid_0's binary_logloss: 0.402221
# [2327]	valid_0's binary_logloss: 0.40222
# [2328]	valid_0's binary_logloss: 0.402217
# [2329]	valid_0's binary_logloss: 0.402216
# [2330]	valid_0's binary_logloss: 0.402212
# [2331]	valid_0's binary_logloss: 0.402209
# [2332]	valid_0's binary_logloss: 0.402205
# [2333]	valid_0's binary_logloss: 0.402193
# [2334]	valid_0's binary_logloss: 0.402191
# [2335]	valid_0's binary_logloss: 0.402186
# [2336]	valid_0's binary_logloss: 0.402174
# [2337]	valid_0's binary_logloss: 0.40217
# [2338]	valid_0's binary_logloss: 0.402165
# [2339]	valid_0's binary_logloss: 0.402163
# [2340]	valid_0's binary_logloss: 0.40216
# [2341]	valid_0's binary_logloss: 0.402156
# [2342]	valid_0's binary_logloss: 0.402152
# [2343]	valid_0's binary_logloss: 0.402148
# [2344]	valid_0's binary_logloss: 0.402147
# [2345]	valid_0's binary_logloss: 0.402141
# [2346]	valid_0's binary_logloss: 0.402141
# [2347]	valid_0's binary_logloss: 0.402135
# [2348]	valid_0's binary_logloss: 0.402132
# [2349]	valid_0's binary_logloss: 0.402121
# [2350]	valid_0's binary_logloss: 0.402118
# [2351]	valid_0's binary_logloss: 0.40211
# [2352]	valid_0's binary_logloss: 0.402098
# [2353]	valid_0's binary_logloss: 0.402095
# [2354]	valid_0's binary_logloss: 0.402094
# [2355]	valid_0's binary_logloss: 0.402093
# [2356]	valid_0's binary_logloss: 0.402092
# [2357]	valid_0's binary_logloss: 0.402086
# [2358]	valid_0's binary_logloss: 0.40208
# [2359]	valid_0's binary_logloss: 0.402071
# [2360]	valid_0's binary_logloss: 0.402065
# [2361]	valid_0's binary_logloss: 0.402064
# [2362]	valid_0's binary_logloss: 0.402057
# [2363]	valid_0's binary_logloss: 0.402056
# [2364]	valid_0's binary_logloss: 0.402055
# [2365]	valid_0's binary_logloss: 0.402052
# [2366]	valid_0's binary_logloss: 0.402048
# [2367]	valid_0's binary_logloss: 0.402041
# [2368]	valid_0's binary_logloss: 0.402039
# [2369]	valid_0's binary_logloss: 0.402035
# [2370]	valid_0's binary_logloss: 0.402031
# [2371]	valid_0's binary_logloss: 0.402029
# [2372]	valid_0's binary_logloss: 0.402028
# [2373]	valid_0's binary_logloss: 0.402025
# [2374]	valid_0's binary_logloss: 0.402015
# [2375]	valid_0's binary_logloss: 0.402011
# [2376]	valid_0's binary_logloss: 0.402006
# [2377]	valid_0's binary_logloss: 0.402003
# [2378]	valid_0's binary_logloss: 0.401997
# [2379]	valid_0's binary_logloss: 0.401995
# [2380]	valid_0's binary_logloss: 0.401987
# [2381]	valid_0's binary_logloss: 0.401982
# [2382]	valid_0's binary_logloss: 0.401979
# [2383]	valid_0's binary_logloss: 0.40197
# [2384]	valid_0's binary_logloss: 0.401963
# [2385]	valid_0's binary_logloss: 0.401962
# [2386]	valid_0's binary_logloss: 0.40196
# [2387]	valid_0's binary_logloss: 0.401953
# [2388]	valid_0's binary_logloss: 0.401952
# [2389]	valid_0's binary_logloss: 0.401949
# [2390]	valid_0's binary_logloss: 0.401947
# [2391]	valid_0's binary_logloss: 0.401944
# [2392]	valid_0's binary_logloss: 0.40194
# [2393]	valid_0's binary_logloss: 0.401934
# [2394]	valid_0's binary_logloss: 0.401929
# [2395]	valid_0's binary_logloss: 0.401923
# [2396]	valid_0's binary_logloss: 0.40192
# [2397]	valid_0's binary_logloss: 0.401919
# [2398]	valid_0's binary_logloss: 0.401917
# [2399]	valid_0's binary_logloss: 0.401911
# [2400]	valid_0's binary_logloss: 0.401907
# [2401]	valid_0's binary_logloss: 0.401904
# [2402]	valid_0's binary_logloss: 0.401903
# [2403]	valid_0's binary_logloss: 0.401904
# [2404]	valid_0's binary_logloss: 0.401902
# [2405]	valid_0's binary_logloss: 0.401887
# [2406]	valid_0's binary_logloss: 0.401886
# [2407]	valid_0's binary_logloss: 0.401883
# [2408]	valid_0's binary_logloss: 0.40188
# [2409]	valid_0's binary_logloss: 0.401876
# [2410]	valid_0's binary_logloss: 0.401874
# [2411]	valid_0's binary_logloss: 0.401868
# [2412]	valid_0's binary_logloss: 0.401864
# [2413]	valid_0's binary_logloss: 0.401863
# [2414]	valid_0's binary_logloss: 0.40186
# [2415]	valid_0's binary_logloss: 0.401859
# [2416]	valid_0's binary_logloss: 0.401856
# [2417]	valid_0's binary_logloss: 0.401854
# [2418]	valid_0's binary_logloss: 0.401849
# [2419]	valid_0's binary_logloss: 0.401837
# [2420]	valid_0's binary_logloss: 0.401836
# [2421]	valid_0's binary_logloss: 0.401833
# [2422]	valid_0's binary_logloss: 0.40183
# [2423]	valid_0's binary_logloss: 0.401824
# [2424]	valid_0's binary_logloss: 0.401822
# [2425]	valid_0's binary_logloss: 0.401816
# [2426]	valid_0's binary_logloss: 0.401815
# [2427]	valid_0's binary_logloss: 0.401815
# [2428]	valid_0's binary_logloss: 0.401813
# [2429]	valid_0's binary_logloss: 0.401808
# [2430]	valid_0's binary_logloss: 0.4018
# [2431]	valid_0's binary_logloss: 0.401796
# [2432]	valid_0's binary_logloss: 0.401788
# [2433]	valid_0's binary_logloss: 0.401784
# [2434]	valid_0's binary_logloss: 0.401781
# [2435]	valid_0's binary_logloss: 0.401777
# [2436]	valid_0's binary_logloss: 0.401775
# [2437]	valid_0's binary_logloss: 0.401761
# [2438]	valid_0's binary_logloss: 0.401754
# [2439]	valid_0's binary_logloss: 0.401752
# [2440]	valid_0's binary_logloss: 0.401747
# [2441]	valid_0's binary_logloss: 0.401746
# [2442]	valid_0's binary_logloss: 0.401736
# [2443]	valid_0's binary_logloss: 0.401734
# [2444]	valid_0's binary_logloss: 0.40173
# [2445]	valid_0's binary_logloss: 0.40173
# [2446]	valid_0's binary_logloss: 0.401729
# [2447]	valid_0's binary_logloss: 0.401725
# [2448]	valid_0's binary_logloss: 0.40172
# [2449]	valid_0's binary_logloss: 0.401719
# [2450]	valid_0's binary_logloss: 0.401718
# [2451]	valid_0's binary_logloss: 0.401717
# [2452]	valid_0's binary_logloss: 0.401715
# [2453]	valid_0's binary_logloss: 0.401704
# [2454]	valid_0's binary_logloss: 0.401703
# [2455]	valid_0's binary_logloss: 0.401703
# [2456]	valid_0's binary_logloss: 0.4017
# [2457]	valid_0's binary_logloss: 0.401698
# [2458]	valid_0's binary_logloss: 0.401693
# [2459]	valid_0's binary_logloss: 0.401689
# [2460]	valid_0's binary_logloss: 0.401685
# [2461]	valid_0's binary_logloss: 0.401683
# [2462]	valid_0's binary_logloss: 0.401682
# [2463]	valid_0's binary_logloss: 0.40168
# [2464]	valid_0's binary_logloss: 0.401674
# [2465]	valid_0's binary_logloss: 0.401674
# [2466]	valid_0's binary_logloss: 0.401674
# [2467]	valid_0's binary_logloss: 0.401667
# [2468]	valid_0's binary_logloss: 0.401664
# [2469]	valid_0's binary_logloss: 0.401657
# [2470]	valid_0's binary_logloss: 0.401653
# [2471]	valid_0's binary_logloss: 0.401653
# [2472]	valid_0's binary_logloss: 0.401643
# [2473]	valid_0's binary_logloss: 0.401642
# [2474]	valid_0's binary_logloss: 0.401634
# [2475]	valid_0's binary_logloss: 0.401627
# [2476]	valid_0's binary_logloss: 0.401619
# [2477]	valid_0's binary_logloss: 0.401617
# [2478]	valid_0's binary_logloss: 0.401617
# [2479]	valid_0's binary_logloss: 0.401611
# [2480]	valid_0's binary_logloss: 0.401601
# [2481]	valid_0's binary_logloss: 0.401601
# [2482]	valid_0's binary_logloss: 0.401596
# [2483]	valid_0's binary_logloss: 0.40159
# [2484]	valid_0's binary_logloss: 0.401587
# [2485]	valid_0's binary_logloss: 0.401586
# [2486]	valid_0's binary_logloss: 0.401578
# [2487]	valid_0's binary_logloss: 0.401564
# [2488]	valid_0's binary_logloss: 0.401561
# [2489]	valid_0's binary_logloss: 0.401559
# [2490]	valid_0's binary_logloss: 0.401547
# [2491]	valid_0's binary_logloss: 0.401545
# [2492]	valid_0's binary_logloss: 0.401545
# [2493]	valid_0's binary_logloss: 0.401544
# [2494]	valid_0's binary_logloss: 0.401537
# [2495]	valid_0's binary_logloss: 0.401531
# [2496]	valid_0's binary_logloss: 0.401529
# [2497]	valid_0's binary_logloss: 0.401522
# [2498]	valid_0's binary_logloss: 0.40152
# [2499]	valid_0's binary_logloss: 0.401518
# [2500]	valid_0's binary_logloss: 0.401516
# Did not meet early stopping. Best iteration is:
# [2500]	valid_0's binary_logloss: 0.401516
# Modelo da classe 4 finalizado

# %%
# Treinar 100% modelo da classe 3
m3 = lgb.train(params=hp3, num_boost_round=nbr, train_set=ds3_train, valid_sets=[ds3_valid], 
               verbose_eval=True, categorical_feature=feats_cat)
print('Modelo da classe 3 finalizado')
# Out:
# [1]	valid_0's binary_logloss: 0.0264888
# Training until validation scores don't improve for 25 rounds
# [2]	valid_0's binary_logloss: 0.0268237
# [3]	valid_0's binary_logloss: 0.0273197
# [4]	valid_0's binary_logloss: 0.0279168
# [5]	valid_0's binary_logloss: 0.0285636
# [6]	valid_0's binary_logloss: 0.029417
# [7]	valid_0's binary_logloss: 0.0301252
# [8]	valid_0's binary_logloss: 0.0307773
# [9]	valid_0's binary_logloss: 0.0314689
# [10]	valid_0's binary_logloss: 0.0322604
# [11]	valid_0's binary_logloss: 0.032888
# [12]	valid_0's binary_logloss: 0.0335434
# [13]	valid_0's binary_logloss: 0.0341167
# [14]	valid_0's binary_logloss: 0.0348912
# [15]	valid_0's binary_logloss: 0.035461
# [16]	valid_0's binary_logloss: 0.0360104
# [17]	valid_0's binary_logloss: 0.036666
# [18]	valid_0's binary_logloss: 0.0372043
# [19]	valid_0's binary_logloss: 0.0377281
# [20]	valid_0's binary_logloss: 0.0382782
# [21]	valid_0's binary_logloss: 0.0387899
# [22]	valid_0's binary_logloss: 0.0392837
# [23]	valid_0's binary_logloss: 0.0397643
# [24]	valid_0's binary_logloss: 0.0402778
# [25]	valid_0's binary_logloss: 0.0407664
# [26]	valid_0's binary_logloss: 0.0412355
# Early stopping, best iteration is:
# [1]	valid_0's binary_logloss: 0.0264888
# Modelo da classe 3 finalizado

# %%
# Treinar 100% modelo da classe 2
m2 = lgb.train(params=hp2, num_boost_round=nbr, train_set=ds2_train, valid_sets=[ds2_valid], 
               verbose_eval=True, categorical_feature=feats_cat)
print('Modelo da classe 2 finalizado')
# Out:
# [1]	valid_0's binary_logloss: 0.106742
# Training until validation scores don't improve for 25 rounds
# [2]	valid_0's binary_logloss: 0.102128
# [3]	valid_0's binary_logloss: 0.0987775
# [4]	valid_0's binary_logloss: 0.0961718
# [5]	valid_0's binary_logloss: 0.0941027
# [6]	valid_0's binary_logloss: 0.0925107
# [7]	valid_0's binary_logloss: 0.0911198
# [8]	valid_0's binary_logloss: 0.0899318
# [9]	valid_0's binary_logloss: 0.0889502
# [10]	valid_0's binary_logloss: 0.0881923
# [11]	valid_0's binary_logloss: 0.087496
# [12]	valid_0's binary_logloss: 0.08689
# [13]	valid_0's binary_logloss: 0.0863897
# [14]	valid_0's binary_logloss: 0.0860275
# [15]	valid_0's binary_logloss: 0.0856501
# [16]	valid_0's binary_logloss: 0.0853342
# [17]	valid_0's binary_logloss: 0.0850899
# [18]	valid_0's binary_logloss: 0.0848879
# [19]	valid_0's binary_logloss: 0.0847479
# [20]	valid_0's binary_logloss: 0.0846526
# [21]	valid_0's binary_logloss: 0.0845822
# [22]	valid_0's binary_logloss: 0.0845497
# [23]	valid_0's binary_logloss: 0.0845351
# [24]	valid_0's binary_logloss: 0.0845388
# [25]	valid_0's binary_logloss: 0.0845409
# [26]	valid_0's binary_logloss: 0.0845995
# [27]	valid_0's binary_logloss: 0.0846792
# [28]	valid_0's binary_logloss: 0.0847997
# [29]	valid_0's binary_logloss: 0.084922
# [30]	valid_0's binary_logloss: 0.0850513
# [31]	valid_0's binary_logloss: 0.0852056
# [32]	valid_0's binary_logloss: 0.0854416
# [33]	valid_0's binary_logloss: 0.0856293
# [34]	valid_0's binary_logloss: 0.0858162
# [35]	valid_0's binary_logloss: 0.0860391
# [36]	valid_0's binary_logloss: 0.0862759
# [37]	valid_0's binary_logloss: 0.0865073
# [38]	valid_0's binary_logloss: 0.0867554
# [39]	valid_0's binary_logloss: 0.0869851
# [40]	valid_0's binary_logloss: 0.0872428
# [41]	valid_0's binary_logloss: 0.0874863
# [42]	valid_0's binary_logloss: 0.0877403
# [43]	valid_0's binary_logloss: 0.0880035
# [44]	valid_0's binary_logloss: 0.0882869
# [45]	valid_0's binary_logloss: 0.0885624
# [46]	valid_0's binary_logloss: 0.0888426
# [47]	valid_0's binary_logloss: 0.0891803
# [48]	valid_0's binary_logloss: 0.0894906
# Early stopping, best iteration is:
# [23]	valid_0's binary_logloss: 0.0845351
# Modelo da classe 2 finalizado

# %%
# Treinar 100% modelo da classe 1
m1 = lgb.train(params=hp1, num_boost_round=nbr, train_set=ds1_train, valid_sets=[ds1_valid], 
               verbose_eval=True, categorical_feature=feats_cat)
print('Modelo da classe 1 finalizado')
# Out:
# [1]	valid_0's binary_logloss: 0.0591568
# Training until validation scores don't improve for 25 rounds
# [2]	valid_0's binary_logloss: 0.0568595
# [3]	valid_0's binary_logloss: 0.0555816
# [4]	valid_0's binary_logloss: 0.0548287
# [5]	valid_0's binary_logloss: 0.0543482
# [6]	valid_0's binary_logloss: 0.0541915
# [7]	valid_0's binary_logloss: 0.0540331
# [8]	valid_0's binary_logloss: 0.0540578
# [9]	valid_0's binary_logloss: 0.0541581
# [10]	valid_0's binary_logloss: 0.0544385
# [11]	valid_0's binary_logloss: 0.0546682
# [12]	valid_0's binary_logloss: 0.0549474
# [13]	valid_0's binary_logloss: 0.0552308
# [14]	valid_0's binary_logloss: 0.0556381
# [15]	valid_0's binary_logloss: 0.0559757
# [16]	valid_0's binary_logloss: 0.0562794
# [17]	valid_0's binary_logloss: 0.056782
# [18]	valid_0's binary_logloss: 0.0571563
# [19]	valid_0's binary_logloss: 0.057509
# [20]	valid_0's binary_logloss: 0.0578782
# [21]	valid_0's binary_logloss: 0.0582834
# [22]	valid_0's binary_logloss: 0.0586759
# [23]	valid_0's binary_logloss: 0.0590431
# [24]	valid_0's binary_logloss: 0.0594388
# [25]	valid_0's binary_logloss: 0.0598485
# [26]	valid_0's binary_logloss: 0.0602863
# [27]	valid_0's binary_logloss: 0.0607229
# [28]	valid_0's binary_logloss: 0.0611775
# [29]	valid_0's binary_logloss: 0.0616311
# [30]	valid_0's binary_logloss: 0.0620622
# [31]	valid_0's binary_logloss: 0.0625008
# [32]	valid_0's binary_logloss: 0.0630897
# Early stopping, best iteration is:
# [7]	valid_0's binary_logloss: 0.0540331
# Modelo da classe 1 finalizado

# %% [markdown]
# **Avaliação do F1-Score em conjunto de validação com thresholding móvel**

# %%
def calcular_f1_score(yt, yp):
    '''
    
    '''
    # Calcular F1-Score Macro para cada threshold
    vTo = list()
    vF1 = list()
    maxF1 = 0
    maxTo = 0
    
    # Loop em diversas possibilidades
    for threshold in np.linspace(0,1, 100):
        # Calcular
        yd = (yp >= threshold).astype(int)
        f1s = f1_score(yt, yd, average='macro')
        # Adicionar
        vTo.append(threshold)
        vF1.append(f1s)
        # Salvar valor maior caso possível
        if f1s > maxF1:
            maxF1 = f1s
            maxTo = threshold
            
    
    # Pegar a mediana para report
    mF1 = round(np.median(vF1), 3)
    # Report
    print(f'> F1 Score Macro mediano = {mF1}')
    
    # Retornar
    return maxF1, maxTo, mF1

# %%
# Fazer previsões
y1_pred_valid = m1.predict(x_valid)
print(f' # Para classe 1, feito!')
# Out:
#  # Para classe 1, feito!

# %%
# Fazer previsões
y2_pred_valid = m2.predict(x_valid)
print(f' # Para classe 2, feito!')
# Out:
#  # Para classe 2, feito!

# %%
# Fazer previsões
y3_pred_valid = m3.predict(x_valid)
print(f' # Para classe 3, feito!')
# Out:
#  # Para classe 3, feito!

# %%
# Fazer previsões
y4_pred_valid = m4.predict(x_valid)
print(f' # Para classe 4, feito!')
# Out:
#  # Para classe 4, feito!

# %%
# Fazer previsões
y5_pred_valid = m5.predict(x_valid)
print(f' # Para classe 5, feito!')
# Out:
#  # Para classe 5, feito!

# %%
# Calcular F1 Score Macro para todos modelos
print(f' ############ Classe 1')
v1 = calcular_f1_score(y1_valid.values, y1_pred_valid)
print(f' ############ Classe 2')
v2 = calcular_f1_score(y2_valid.values, y2_pred_valid)
print(f' ############ Classe 3')
v3 = calcular_f1_score(y3_valid.values, y3_pred_valid)
print(f' ############ Classe 4')
v4 = calcular_f1_score(y4_valid.values, y4_pred_valid)
print(f' ############ Classe 5')
v5 = calcular_f1_score(y5_valid.values, y5_pred_valid)
print(f' ############ Média Geral')
mg = round(np.mean([v1[2], v2[2], v3[2], v4[2], v5[2]]), 5)
print(f'> F1 Score Macro = {mg}')
# Out:
#  ############ Classe 1
# > F1 Score Macro mediano = 0.497
#  ############ Classe 2
# > F1 Score Macro mediano = 0.494
#  ############ Classe 3
# > F1 Score Macro mediano = 0.499
#  ############ Classe 4
# > F1 Score Macro mediano = 0.739
#  ############ Classe 5
# > F1 Score Macro mediano = 0.79
#  ############ Média Geral
# > F1 Score Macro = 0.6038

# %%
# Ver valores
for i, v in enumerate([v1, v2, v3, v4, v5]):
    print(f'> Classe {i+1} tem Máximo F1 Score de {v[0]} com threhsold de {v[1]}')
# Out:
# > Classe 1 tem Máximo F1 Score de 0.6588207906117378 com threhsold de 0.08080808080808081
# > Classe 2 tem Máximo F1 Score de 0.7275155748521854 com threhsold de 0.21212121212121213
# > Classe 3 tem Máximo F1 Score de 0.5614070056353214 com threhsold de 0.030303030303030304
# > Classe 4 tem Máximo F1 Score de 0.7923044107993006 com threhsold de 0.5858585858585859
# > Classe 5 tem Máximo F1 Score de 0.8296986843489476 com threhsold de 0.393939393939394

# %% [markdown]
# **Construção de Modelos Finais (treino e validação) após tentativas de otimização**

# %%
# Especificar hiper parâmetros finais
hp5 = {'objective':'binary',
       'is_unbalance': True,
       'boosting_type': 'gbdt',
       'metric': 'binary_logloss', 
       'eta': 0.01,
       'num_leaves': 224,
       'feature_fraction': 0.85,
#       'early_stopping_round': 25,
       "lambda_l1":8.526,
       "lambda_l2":0.011,
       'seed': 1206,
       'verbosity': -1,
       'num_threads':4}
hp4 = {'objective':'binary',
       'is_unbalance': True,
       'boosting_type': 'gbdt',
       'metric': 'binary_logloss', 
       'eta': 0.01,
       'num_leaves': 243,
       'feature_fraction': 0.85,
#       'early_stopping_round': 25,
       "lambda_l1":8.526,
       "lambda_l2":0.011,
       'seed': 1206, 
       'verbosity': -1,
       'num_threads':4}
hp3 = {'objective':'binary',
       'is_unbalance': True,
       'boosting_type': 'gbdt',
       'metric': 'binary_logloss', 
       'eta': 0.01,
       'num_leaves': 243,
       'feature_fraction': 0.85,
#       'early_stopping_round': 25,
       "lambda_l1":8.526,
       "lambda_l2":0.011,
       'seed': 1206, 
       'verbosity': -1,
       'num_threads':4}
hp2 = {'objective':'binary',
       'is_unbalance': True,
       'boosting_type': 'gbdt',
       'metric': 'binary_logloss', 
       'eta': 0.01,
       'num_leaves': 243,
       'feature_fraction': 0.85,
#       'early_stopping_round': 25,
       "lambda_l1":8.526,
       "lambda_l2":0.011,
       'seed': 1206, 
       'verbosity': -1,
       'num_threads':4}
hp1 = {'objective':'binary',
       'is_unbalance': True,
       'boosting_type': 'gbdt',
       'metric': 'binary_logloss', 
       'eta': 0.01,
       'num_leaves': 243,
       'feature_fraction': 0.85,
#       'early_stopping_round': 25,
       "lambda_l1":8.526,
       "lambda_l2":0.011,
       'seed': 1206, 
       'verbosity': -1,
       'num_threads':4}

# %%
# Definir número de rounds
nbr = 2500
print('Inicio de treinamento ...')
# Treinar 100% modelo da classe 5
m5f = lgb.train(params=hp5, num_boost_round=nbr, train_set=ds5_train_valid, verbose_eval=False, categorical_feature=feats_cat)
print('Modelo da classe 5 finalizado')
# Treinar 100% modelo da classe 4
m4f = lgb.train(params=hp4, num_boost_round=nbr, train_set=ds4_train_valid, verbose_eval=False, categorical_feature=feats_cat)
print('Modelo da classe 4 finalizado')
# Treinar 100% modelo da classe 3
m3f = lgb.train(params=hp3, num_boost_round=nbr, train_set=ds3_train_valid, verbose_eval=False, categorical_feature=feats_cat)
print('Modelo da classe 3 finalizado')
# Treinar 100% modelo da classe 2
m2f = lgb.train(params=hp2, num_boost_round=nbr, train_set=ds2_train_valid, verbose_eval=False, categorical_feature=feats_cat)
print('Modelo da classe 2 finalizado')
# Treinar 100% modelo da classe 1
m1f = lgb.train(params=hp1, num_boost_round=nbr, train_set=ds1_train_valid, verbose_eval=False, categorical_feature=feats_cat)
print('Modelo da classe 1 finalizado')
# Out:
# Inicio de treinamento ...
# Modelo da classe 5 finalizado
# Modelo da classe 4 finalizado
# Modelo da classe 3 finalizado
# Modelo da classe 2 finalizado
# Modelo da classe 1 finalizado

# %% [markdown]
# # Previsão
#
# **Probabilidade Máxima**

# %%
# Carregar modelos
#m1_fl = lgb.Booster(model_file='modelos/m1.txt')
#m2_fl = lgb.Booster(model_file='modelos/m2.txt')
#m3_fl = lgb.Booster(model_file='modelos/m3.txt')
#m4_fl = lgb.Booster(model_file='modelos/m4.txt')
#m5_fl = lgb.Booster(model_file='modelos/m5.txt')

# %%
# Fazer previsões
print('Inicio de previsao ...')
y1_pred = m1f.predict(x_test)
print('Previsão da classe 1 finalizado')
y2_pred = m2f.predict(x_test)
print('Previsão da classe 2 finalizado')
y3_pred = m3f.predict(x_test)
print('Previsão da classe 3 finalizado')
y4_pred = m4f.predict(x_test)
print('Previsão da classe 4 finalizado')
y5_pred = m5f.predict(x_test)
print('Previsão da classe 5 finalizado')
# Out:
# Inicio de previsao ...
# Previsão da classe 1 finalizado
# Previsão da classe 2 finalizado
# Previsão da classe 3 finalizado
# Previsão da classe 4 finalizado
# Previsão da classe 5 finalizado

# %%
# Unificar
y_pred = list()

# Loop em cada previsão
for y1,y2,y3,y4,y5 in zip(y1_pred, y2_pred, y3_pred, y4_pred, y5_pred):
    # Listar sequencialmente as previsoes
    l = [y1,y2,y3,y4,y5]
    # Puxar maior previsão
    y_pred.append(l.index(max(l)) + 1)

# %%
# Salvar previsão final
df_sub_desafio['CLASSI_FIN'] = y_pred

# Salvar probabilidades
df_sub_desafio['PROBA_1'] = y1_pred
df_sub_desafio['PROBA_2'] = y2_pred
df_sub_desafio['PROBA_3'] = y3_pred
df_sub_desafio['PROBA_4'] = y4_pred
df_sub_desafio['PROBA_5'] = y5_pred

# %%
# Viz
df_sub_desafio.head()
# Out:
#                                      ID  CLASSI_FIN   PROBA_1   PROBA_2  \
# 0  c42342a4-cfca-497f-8ee6-a6c76ed4bc67           4  0.003598  0.001004
# 1  6c86b555-8bf2-4306-8f2e-db809a98e3c3           4  0.000007  0.000230
# 2  0ac9582e-2683-474b-8316-5e9c0ea6edd5           4  0.000556  0.000063
# 3  7bc6de6f-041c-4866-8778-7542c230a498           4  0.000100  0.000098
# 4  8eefb2e4-626e-4f40-9b93-5146906fe07b           4  0.000077  0.000004
#
#     PROBA_3   PROBA_4   PROBA_5
# 0  0.000171  0.937172  0.092696
# 1  0.000004  0.978485  0.021220
# 2  0.001715  0.535169  0.454708
# 3  0.000692  0.925828  0.084859
# 4  0.000172  0.640977  0.478363

# %% [markdown]
# **Camada Adicional: Melhor modelo(s)**

# %%
# Adicionar previsão do melhor modelo com threshold optimizado
df_sub_desafio_to = df_sub_desafio.copy()
df_sub_desafio_to['THRESH_OPT5'] = (y5_pred >= 0.393939393939394).astype(int)
df_sub_desafio_to['THRESH_OPT4'] = (y4_pred >= 0.5858585858585859).astype(int)

# Checar contagem de previsoes considerando TO
df_sub_desafio_to.loc[df_sub_desafio_to['THRESH_OPT5'] == 1, 'CLASSI_FIN'].value_counts()
# Out:
# 5    536098
# 4     47083
# 1       880
# 3       478
# 2       304
# Name: CLASSI_FIN, dtype: int64

# %%
# Aplicar TO
df_sub_desafio_to.loc[(df_sub_desafio_to['THRESH_OPT5'] == 1), 'CLASSI_FIN'] = 5

# %%
# Salvar
df_sub_desafio_to[['ID','CLASSI_FIN']].to_csv('ml-olympiad-ensure-healthy-lives/submissao_try_9_pm_mais_to5.csv', index=False)

# %%
# Salvar localmente
df_sub_desafio[['ID','CLASSI_FIN']].to_csv('ml-olympiad-ensure-healthy-lives/submissao_try_9_pm.csv', index=False)

# %%
# Salvar localmente
df_sub_desafio.to_csv('ml-olympiad-ensure-healthy-lives/completo_try_9_pm.csv', index=False)
df_sub_desafio_to.to_csv('ml-olympiad-ensure-healthy-lives/completo_try_9_pm_mais_to5.csv', index=False)

# %% [markdown]
# # Salvar modelos treinados

# %%
# Salvar modelos localmente
m1f.save_model('modelos/m1_v9.txt')
m2f.save_model('modelos/m2_v9.txt')
m3f.save_model('modelos/m3_v9.txt')
m4f.save_model('modelos/m4_v9.txt')
m5f.save_model('modelos/m5_v9.txt')

# %% [markdown]
# # Checar Feature Importance de cada modelo

# %%
# Criar
df_fi = pd.DataFrame()
df_fi['FEAT'] = x_train.columns
df_fi['FI_M1'] = (100*m1f.feature_importance() / m1f.feature_importance().sum()).round(2)
df_fi['FI_M2'] = (100*m2f.feature_importance() / m2f.feature_importance().sum()).round(2)
df_fi['FI_M3'] = (100*m3f.feature_importance() / m3f.feature_importance().sum()).round(2)
df_fi['FI_M4'] = (100*m4f.feature_importance() / m4f.feature_importance().sum()).round(2)
df_fi['FI_M5'] = (100*m5f.feature_importance() / m5f.feature_importance().sum()).round(2)
df_fi['FI_ORDER'] = df_fi[[c for c in df_fi.columns if 'FI_M' in c]].sum(axis=1)

# %%
# Salvar localmente
df_fi.to_csv('ml-olympiad-ensure-healthy-lives/feature_importance_models_9.csv', index=False)
