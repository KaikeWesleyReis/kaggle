# %% [markdown]
# # Instalando novas bibliotecas

# %%
# %%capture
# !pip install optuna

# %%
# %%capture
# !pip install lightgbm

# %% [markdown]
# # Importando módulos

# %%
import warnings
import numpy as np
import pandas as pd
import optuna as opt
import seaborn as sns
import lightgbm as lgb
import matplotlib.pyplot as plt
from sklearn.metrics import f1_score
from sklearn.utils import compute_class_weight
from sklearn.model_selection import train_test_split
from optuna.integration.lightgbm import LightGBMTuner

# %%
# Só encher o saco uma vez
warnings.filterwarnings('once')

# %% [markdown]
# # __Execução I__
#
# Passos
# - Importar dados
# - Pré-processamento
# - Divisão treino e validação usando *Kennard-Stone*
# - Imputação de dados - Mode
# - Light GBM padrão com class_weight
# - Ensemble de modelos binários
#
# # Importando dados

# %%
# Importar tabelas
df_train = pd.read_csv('ml-olympiad-ensure-healthy-lives/train.csv', low_memory=False)
df_test = pd.read_csv('ml-olympiad-ensure-healthy-lives/test.csv', low_memory=False)
df_subm = pd.read_csv('ml-olympiad-ensure-healthy-lives/sample_submission.csv', low_memory=False)

# %%
# Montar base para previsão do desafio
df_sub_desafio = pd.DataFrame()
df_sub_desafio['ID'] = df_test['ID']
df_sub_desafio['CLASSI_FIN'] = np.nan

# %%
# Aplicar correcao nas variáveis coringa
df_train['FNT_IN_COV'].replace({1:'MANUAL',2:'INTEGRACAO',np.nan:'FALTANTE'}, inplace=True)
df_test['FNT_IN_COV'].replace({1:'MANUAL',2:'INTEGRACAO',np.nan:'FALTANTE'}, inplace=True)

df_train['COD_IDADE'].replace({np.nan:'FALTANTE'}, inplace=True)
df_test['COD_IDADE'].replace({np.nan:'FALTANTE'}, inplace=True)

# %% [markdown]
# # Pré-processamento

# %%
# Definir colunas para serem derrubadas
cols_to_drop = ['ID',         # Identificação
                'DELTA_UTI',  # Constante
                'PAC_COCBO',  # Completamente faltante
                'PAC_DSCBO',  # Completamente faltante
                'OBES_IMC',   # Completamente faltante
                'COD_IDADE',  # Redundante tendo as outras duas variáveis de idade
                'FNT_IN_COV'] # Não relacionado ao problema

# Derrubar
df_train.drop(columns=cols_to_drop, inplace=True)
df_test.drop(columns=cols_to_drop, inplace=True)

# %%
# Especificar label do desafio
label = 'CLASSI_FIN'

# %% [markdown]
# **Variáveis relacionadas a sexo + idade, porém o foco está em mães / bebês**

# %%
# Definir colunas de análise nesta seção
cols = ['CS_SEXO','CS_GESTANT','PUERPERA','NU_IDADE_N','TP_IDADE','MAE_VAC','M_AMAMENTA']

# %% [markdown]
# Alterações
# - Adicionar '99' para identificar que são homens, (código universal para não aplicável) nas colunas referentes a gestação e paridade
# - Demais que possuem 'F' em CS_SEXO, adicionar '9' para identificar as mulheres como ignorados, pois provavelmente não estavam classificadas neste grupo

# %% [markdown]
# `NU_IDADE_N` + `TP_IDADE`
#
# - Converter coluna de idade para anos
# - Remover idades impossíveis
#
# [Expectativa de vida no Brasil](https://pt.wikipedia.org/wiki/Lista_de_unidades_federativas_do_Brasil_por_expectativa_de_vida)

# %%
def corrigir_idade(nu_idade, tp_idade):
    '''
    Corrigir padrão de idade para anos
    '''
    if tp_idade == 3:
        return abs(nu_idade)
    elif tp_idade == 2:
        return abs(nu_idade)/12
    else:
        return abs(nu_idade)/365

# %%
# Aplicar correção de anos
df_train['NU_IDADE_N'] = df_train.apply(lambda df:corrigir_idade(df['NU_IDADE_N'], df['TP_IDADE']), axis=1).astype(int)

# Qualquer valor acima dos 95 serão tratados e fixados em 95 devido a impossibilidade + expectativa de vida no país
df_train.loc[df_train['NU_IDADE_N'] >= 95, 'NU_IDADE_N'] = 95

# %%
# Aplicar correção de anos
df_test['NU_IDADE_N'] = df_test.apply(lambda df:corrigir_idade(df['NU_IDADE_N'], df['TP_IDADE']), axis=1).astype(int)

# Qualquer valor acima dos 95 serão tratados e fixados em 95 devido a impossibilidade + expectativa de vida no país
df_test.loc[df_test['NU_IDADE_N'] >= 95, 'NU_IDADE_N'] = 95

# %% [markdown]
# `CS_SEXO`
#
# [Motivo de imputação em último nível](https://educa.ibge.gov.br/jovens/conheca-o-brasil/populacao/18320-quantidade-de-homens-e-mulheres.html#:~:text=Segundo%20dados%20da%20PNAD%20Cont%C3%ADnu,51%2C1%25%20de%20mulheres.)

# %%
# Remover classe desconhecida e rara
df_train.loc[df_train['CS_SEXO'] == 'I', 'CS_SEXO'] = np.nan

# Aplicar primeiro nível
c1 = (df_train['CS_SEXO'].isna()) & (df_train['CS_GESTANT'] == 6) & (df_train['NU_IDADE_N'] >= 9)
df_train.loc[c1, 'CS_SEXO'] = 'M'

# Aplicar segundo nível
c2 = (df_train['CS_GESTANT'] != 6) & (df_train['CS_SEXO'].isna())
df_train.loc[c2, 'CS_SEXO'] = 'F'

# Aplicar terceiro nível
c3 = df_train['CS_SEXO'].isna()
df_train.loc[c3, 'CS_SEXO'] = 'F'

# %%
# Remover classe desconhecida e rara
df_test.loc[df_test['CS_SEXO'] == 'I', 'CS_SEXO'] = np.nan

# Aplicar primeiro nível
c1 = (df_test['CS_SEXO'].isna()) & (df_test['CS_GESTANT'] == 6) & (df_test['NU_IDADE_N'] >= 9)
df_test.loc[c1, 'CS_SEXO'] = 'M'

# Aplicar segundo nível
c2 = (df_test['CS_GESTANT'] != 6) & (df_test['CS_SEXO'].isna())
df_test.loc[c2, 'CS_SEXO'] = 'F'

# Aplicar terceiro nível
c3 = df_test['CS_SEXO'].isna()
df_test.loc[c3, 'CS_SEXO'] = 'F'

# %% [markdown]
# `CS_GESTANT`

# %%
# Remover classe desconhecida e rara
df_train.loc[df_train['CS_GESTANT'] == 0, 'CS_GESTANT'] = np.nan

# Aplicar primeiro nível
c1 = (df_train['CS_GESTANT'].isna()) & ((df_train['CS_SEXO'] == 'M') | (df_train['NU_IDADE_N'] <= 9))
df_train.loc[c1, 'CS_GESTANT'] = 6

# Aplicar segundo nível
c2 = (df_train['CS_GESTANT'].isna()) & (df_train['CS_SEXO'] == 'F') & (df_train['NU_IDADE_N'] > 9)
df_train.loc[c2, 'CS_GESTANT'] = 5

# Aplicar terceiro e último nível
c3 = (df_train['CS_GESTANT'].isna())
df_train.loc[c3, 'CS_GESTANT'] = 9

# %%
# Remover classe desconhecida e rara
df_test.loc[df_test['CS_GESTANT'] == 0, 'CS_GESTANT'] = np.nan

# Aplicar primeiro nível
c1 = (df_test['CS_GESTANT'].isna()) & ((df_test['CS_SEXO'] == 'M') | (df_test['NU_IDADE_N'] <= 9))
df_test.loc[c1, 'CS_GESTANT'] = 6

# Aplicar segundo nível
c2 = (df_test['CS_GESTANT'].isna()) & (df_test['CS_SEXO'] == 'F') & (df_test['NU_IDADE_N'] > 9)
df_test.loc[c2, 'CS_GESTANT'] = 5

# Aplicar terceiro e último nível
c3 = (df_test['CS_GESTANT'].isna())
df_test.loc[c3, 'CS_GESTANT'] = 9

# %% [markdown]
# `PUERPERA`

# %%
# Aplicar primeiro nível
c1 = df_train['CS_SEXO'] == 'M'
df_train.loc[c1, 'PUERPERA'] = 99

# Aplicar segundo nível
c2 = (df_train['PUERPERA'].isna()) & (df_train['CS_SEXO'] == 'F') & (df_train['CS_GESTANT'] != 6)
df_train.loc[c2, 'PUERPERA'] = 2

# Aplicar terceiro nível
c3 = (df_train['CS_SEXO'] == 'F') & (df_train['PUERPERA'].isna())
df_train.loc[c3, 'PUERPERA'] = 9

# %%
# Aplicar primeiro nível
c1 = df_test['CS_SEXO'] == 'M'
df_test.loc[c1, 'PUERPERA'] = 99

# Aplicar segundo nível
c2 = (df_test['PUERPERA'].isna()) & (df_test['CS_SEXO'] == 'F') & (df_test['CS_GESTANT'] != 6)
df_test.loc[c2, 'PUERPERA'] = 2

# Aplicar terceiro nível
c3 = (df_test['CS_SEXO'] == 'F') & (df_test['PUERPERA'].isna())
df_test.loc[c3, 'PUERPERA'] = 9

# %% [markdown]
# `MAE_VAC` + `M_AMAMENTA`

# %%
# Aplicar primeiro nível
c1 = df_train['NU_IDADE_N'] > 0
df_train.loc[c1, ['MAE_VAC','M_AMAMENTA']] = 99

# Aplicar segundo nível
df_train.loc[df_train['MAE_VAC'].isna(), 'MAE_VAC'] = 9
df_train.loc[df_train['M_AMAMENTA'].isna(), 'M_AMAMENTA'] = 9

# %%
# Aplicar primeiro nível
c1 = df_test['NU_IDADE_N'] > 0
df_test.loc[c1, ['MAE_VAC','M_AMAMENTA']] = 99

# Aplicar segundo nível
df_test.loc[df_test['MAE_VAC'].isna(), 'MAE_VAC'] = 9
df_test.loc[df_test['M_AMAMENTA'].isna(), 'M_AMAMENTA'] = 9

# %% [markdown]
# **Variáveis relacionadas ao COVID**

# %%
# Definir colunas de análise nesta seção
cols = ['VACINA_COV','DOSE_1_COV','DOSE_2_COV','DOSE_REF']

# %% [markdown]
# `VACINA_COV`
#
# Possibilidade de binarizar e converter `9` em `2`
#
# OBS - Criar nova coluna com a contagem de doses tomadas.

# %%
# Aplicar primeiro nível
c1 = df_train[['DOSE_1_COV','DOSE_2_COV','DOSE_REF']].sum(axis=1) >= 1
df_train.loc[c1, 'VACINA_COV'] = 1

# Aplicar segundo nível
c2 = df_train['VACINA_COV'].isna()
df_train.loc[c2, 'VACINA_COV'] = 9

# %%
# Aplicar primeiro nível
c1 = df_test[['DOSE_1_COV','DOSE_2_COV','DOSE_REF']].sum(axis=1) >= 1
df_test.loc[c1, 'VACINA_COV'] = 1

# Aplicar segundo nível
c2 = df_test['VACINA_COV'].isna()
df_test.loc[c2, 'VACINA_COV'] = 9

# %%
# Criar nova coluna
df_train['DOSE_COV_N'] = df_train[['DOSE_1_COV','DOSE_2_COV','DOSE_REF']].sum(axis=1)
df_test['DOSE_COV_N'] = df_test[['DOSE_1_COV','DOSE_2_COV','DOSE_REF']].sum(axis=1)

# %% [markdown]
# **Variáveis relacionadas ao EXAME**

# %%
# Definir colunas de análise nesta seção
cols = ['RAIOX_RES','RAIOX_OUT','TOMO_RES','TOMO_OUT','AMOSTRA','OUT_AMOST','TP_AMOSTRA']

# %%
# Especificar todas as possibilidades de outros para raio x e tomografia
outros_raioX = list(set(df_train['RAIOX_OUT'].dropna().unique().tolist() + df_test['RAIOX_OUT'].dropna().unique().tolist()))
outros_tomog = list(set(df_train['TOMO_OUT'].dropna().unique().tolist() + df_test['TOMO_OUT'].dropna().unique().tolist()))
outros_amost = list(set(df_train['OUT_AMOST'].dropna().unique().tolist() + df_test['OUT_AMOST'].dropna().unique().tolist()))

# %% [markdown]
# Melhorar colunas referente a OUTROS

# %%
# Gerar listas hierarquicas especificas para consolidar categorias em tomografia (prioridade de baixo para cima)
outros_tomog_laudo = [c for c in outros_tomog if 'LAUDO' in c or 'AGUARDA' in c or 'EM ANDAMENTO' in c or 'SEM INFORMACAO' in c]
outros_tomog_norml = [c for c in outros_tomog if 'NORMAL' in c or 'SEM ALTERAC' in c or 'SEM SINAIS DE INFECCAO' in c]
outros_tomog_vidro = [c for c in outros_tomog if 'VIDRO' in c or 'OPACIDADE' in c]
outros_tomog_bronc = [c for c in outros_tomog if 'BRONCOPATIA' in c]
outros_tomog_covid = [c for c in outros_tomog if 'COVID' in c]
outros_tomog_derrp = [c for c in outros_tomog if 'DERRAME' in c and 'PLEURAL' in c]
outros_tomog_enfis = [c for c in outros_tomog if 'ENFISEMA' in c]
outros_tomog_pneum = [c for c in outros_tomog if 'PNEUMONIA' in c or 'PNM' in c]
outros_tomog_conso = [c for c in outros_tomog if 'CONSOLIDA' in c]
outros_tomog_solic = [c for c in outros_tomog if 'SOLICITADO' in c]
outros_tomog_atele = [c for c in outros_tomog if 'ATELECTAS' in c]
outros_tomog_tuber = [c for c in outros_tomog if 'TUBERCUL' in c or 'TB' in c]

# Especificar novas categorias de agrupamento
outros_tomog_nCats = ['REL_TUBERCULOSE', 'REL_OPACIDADE_VIDRO_FOSCO', 'REL_BRONCOPATIA', 'REL_COVID',
                      'REL_DERRAME', 'REL_ENFISEMA', 'REL_PNEUMONIA', 'REL_CONSOLIDACAO',
                      'REL_ATELECTASIA', 'REL_SEM_LAUDO', 'REL_RES_NORMAL', 'REL_SOLICITADO']

outros_tomog_oCats = [outros_tomog_tuber, outros_tomog_vidro, outros_tomog_bronc, outros_tomog_covid,
                      outros_tomog_derrp, outros_tomog_enfis, outros_tomog_pneum, outros_tomog_conso,
                      outros_tomog_atele, outros_tomog_laudo, outros_tomog_norml, outros_tomog_solic]

# Criar colunas
df_train['TOMO_OUT_NOVO'] = np.nan
df_test['TOMO_OUT_NOVO'] = np.nan

# Aplicar novas categorias evitando sobreposição
for n_cat, o_cats in zip(outros_tomog_nCats, outros_tomog_oCats):
    df_train.loc[(df_train['TOMO_OUT'].isin(o_cats)) & (df_train['TOMO_OUT_NOVO'].isna()), 'TOMO_OUT_NOVO'] = n_cat
    df_test.loc[(df_test['TOMO_OUT'].isin(o_cats)) & (df_test['TOMO_OUT_NOVO'].isna()), 'TOMO_OUT_NOVO'] = n_cat

# Converter todas as demais categorias restantes provalvemente raras em umas só para reduzir ruído ao modelo
c1 = (~df_train['TOMO_OUT_NOVO'].isin(outros_tomog_nCats)) & (df_train['TOMO_OUT'].notnull())
df_train.loc[c1, 'TOMO_OUT_NOVO'] = 'REL_OUTROS_RESULTADOS'
c1 = (~df_test['TOMO_OUT_NOVO'].isin(outros_tomog_nCats)) & (df_test['TOMO_OUT'].notnull())
df_test.loc[c1, 'TOMO_OUT_NOVO'] = n_cat

# %%
# Gerar listas hierarquicas especificas para consolidar categorias em raio X (prioridade de baixo para cima)
outros_raiox_infil = [c for c in outros_raioX if 'INFILT' in c]
outros_raiox_vidro = [c for c in outros_raioX if 'VIDRO' in c or 'FOSCO' in c]
outros_raiox_opaci = [c for c in outros_raioX if 'OPACIDADE' in c or 'OPACIF' in c]
outros_raiox_tomog = [c for c in outros_raioX if 'TC' in c or 'TOMOGRAFIA' in c or 'TOMO' in c or 'CT' in c]
outros_raiox_derrp = [c for c in outros_raioX if 'DERRAME' in c and 'PLEU' in c]
outros_raiox_atele = [c for c in outros_raioX if 'ATELECTAS' in c]
outros_raiox_congt = [c for c in outros_raioX if 'CONGESTAO' in c or 'CONGEST' in c]
outros_raiox_pneum = [c for c in outros_raioX if 'PNEUMONIA' in c or 'PNM' in c]
outros_raiox_infla = [c for c in outros_raioX if 'INFLAMA' in c]
outros_raiox_espes = [c for c in outros_raioX if 'ESPESSA' in c]
outros_raiox_solic = [c for c in outros_raioX if 'SOLICITADO' in c or 'PEDIDO' in c]
outros_raiox_conde = [c for c in outros_raioX if 'CONDENSA' in c]
outros_raiox_hiper = [c for c in outros_raioX if 'HIPERINSUF' in c]
outros_raiox_arcos = [c for c in outros_raioX if 'ARCO' in c or 'RETIFICACAO' in c or 'COSTAIS' in c]
outros_raiox_norml = [c for c in outros_raioX if 'NORMAL' in c or 'SEM ALTERAC' in c or 'SEM SINAIS DE INFECCAO' in c]
outros_raiox_laudo = [c for c in outros_raioX if 'LAUDO' in c or 'SEM DESCRICAO' in c or 'SEM RELATO' in c or 'SEM INFO' in c or 'AGUARDA' in c or 'NAO INFO' in c]

# Especificar novas categorias de agrupamento por ordem de prioridade
outros_raiox_nCats = ['REL_INFILTRACAO', 'REL_VIDRO_FOSCO','REL_OPACIDADE', 'REL_DERRAME_PLEURAL',
                      'REL_ATELECTASIA', 'REL_CONGESTAO', 'REL_PNEUMONIA', 'REL_INFLAMACAO', 
                      'REL_ESPESSAMENTO', 'REL_CONDENSACAO', 'REL_HIPERINSUFLACAO', 'REL_SOLICITADO',
                      'REL_ARCOS_COSTAIS', 'REL_SEM_LAUDO', 'REL_RES_NORMAL','REL_PEDIDO_TOMOG']
outros_raiox_oCats = [outros_raiox_infil, outros_raiox_vidro, outros_raiox_opaci, outros_raiox_derrp,
                      outros_raiox_atele, outros_raiox_congt, outros_raiox_pneum, outros_raiox_infla,
                      outros_raiox_espes, outros_raiox_conde, outros_raiox_hiper, outros_raiox_solic,
                      outros_raiox_arcos, outros_raiox_laudo, outros_raiox_norml, outros_raiox_tomog]

# Criar colunas
df_train['RAIOX_OUT_NOVO'] = np.nan
df_test['RAIOX_OUT_NOVO'] = np.nan

# Aplicar novas categorias evitando sobreposição
for n_cat, o_cats in zip(outros_raiox_nCats, outros_raiox_oCats):
    df_train.loc[(df_train['RAIOX_OUT'].isin(o_cats)) & (df_train['RAIOX_OUT_NOVO'].isna()), 'RAIOX_OUT_NOVO'] = n_cat
    df_test.loc[(df_test['RAIOX_OUT'].isin(o_cats)) & (df_test['RAIOX_OUT_NOVO'].isna()), 'RAIOX_OUT_NOVO'] = n_cat

# Converter todas as demais categorias restantes provalvemente raras em umas só para reduzir ruído ao modelo
c1 = (~df_train['RAIOX_OUT_NOVO'].isin(outros_raiox_nCats)) & (df_train['RAIOX_OUT'].notnull())
df_train.loc[c1, 'RAIOX_OUT_NOVO'] = 'REL_OUTROS_RESULTADOS'
c1 = (~df_test['RAIOX_OUT_NOVO'].isin(outros_raiox_nCats)) & (df_test['RAIOX_OUT'].notnull())
df_test.loc[c1, 'RAIOX_OUT_NOVO'] = n_cat

# %% [markdown]
# Corrigir variáveis relacionadas ao raio X

# %%
# Caso o motivo seja outro e não tenha descrição, adicionar string referente
c1 = (df_train['RAIOX_RES'].isin([5])) & (df_train['RAIOX_OUT'].isna())
df_train.loc[c1, 'RAIOX_OUT'] = 'FEITO_E_SEM_DETALHE'
df_train.loc[c1, 'RAIOX_OUT_NOVO'] = 'FEITO_E_SEM_DETALHE'

c1 = (df_test['RAIOX_RES'].isin([5])) & (df_test['RAIOX_OUT'].isna())
df_test.loc[c1, 'RAIOX_OUT'] = 'FEITO_E_SEM_DETALHE'
df_test.loc[c1, 'RAIOX_OUT_NOVO'] = 'FEITO_E_SEM_DETALHE'

# Caso seja nulo, será considerado que não foi feito nenhum exame
c2 = df_train['RAIOX_RES'].isna()
df_train.loc[c2, 'RAIOX_RES'] = 6
df_train.loc[c2, 'RAIOX_OUT'] = 'NDA'
df_train.loc[c2, 'RAIOX_OUT_NOVO'] = 'NDA'

c2 = df_test['RAIOX_RES'].isna()
df_test.loc[c2, 'RAIOX_RES'] = 6
df_test.loc[c2, 'RAIOX_OUT'] = 'NDA'
df_test.loc[c2, 'RAIOX_OUT_NOVO'] = 'NDA'

# %% [markdown]
# Corrigir variáveis relacionadas a tomografia

# %%
# Caso o motivo seja outro e não tenha descrição, adicionar string referente
c1 = (df_train['TOMO_RES'].isin([5])) & (df_train['TOMO_OUT'].isna())
df_train.loc[c1, 'TOMO_OUT'] = 'FEITO_E_SEM_DETALHE'
df_train.loc[c1, 'TOMO_OUT_NOVO'] = 'FEITO_E_SEM_DETALHE'

c1 = (df_test['TOMO_RES'].isin([5])) & (df_test['TOMO_OUT'].isna())
df_test.loc[c1, 'RAIOX_OUT'] = 'FEITO_E_SEM_DETALHE'
df_test.loc[c1, 'RAIOX_OUT_NOVO'] = 'FEITO_E_SEM_DETALHE'

# Caso seja nulo, será considerado que não foi feito nenhum exame
c2 = df_train['TOMO_RES'].isna()
df_train.loc[c2, 'TOMO_RES'] = 6
df_train.loc[c2, 'TOMO_OUT'] = 'NDA'
df_train.loc[c2, 'TOMO_OUT_NOVO'] = 'NDA'

c2 = df_test['TOMO_RES'].isna()
df_test.loc[c2, 'TOMO_RES'] = 6
df_test.loc[c2, 'TOMO_OUT'] = 'NDA'
df_test.loc[c2, 'TOMO_OUT_NOVO'] = 'NDA'

# %% [markdown]
# Corrigir variáveis referentes a amostra

# %%
# Caso seja nulo em AMOSTRA, será considerado que a coleta foi ignorada
c1 = df_train['AMOSTRA'].isna()
df_train.loc[c1, 'AMOSTRA'] = 9

# Caso AMOSTRA seja 2 ou 9 (não e ignorado respectivamente), ignoramos o tipo de amostra
c2 = df_train['AMOSTRA'].isin([2, 9])
df_train.loc[c2, 'TP_AMOSTRA'] = 9

# Caso TP_AMOSTRA seja 4 (outra) e não tenha informação em OUT_AMOST colocamos uma string especifica
c3 = (df_train['TP_AMOSTRA'] == 4) & (df_train['OUT_AMOST'].isna())
df_train.loc[c3, 'OUT_AMOST'] = 'TIPO_AMOST_NAO_ESPECIFICADO'

# Caso AMOSTRA seja 1 e TP_AMOSTRA seja diferente de 4, inserimos string especifica em OUT_AMOST
c4 = (df_train['AMOSTRA'] == 1) & (df_train['TP_AMOSTRA'].isin([1,2,3,5]))
df_train.loc[c4, 'OUT_AMOST'] = 'COLETA_FEITA_TIPO_DEFINIDO'

# Caso AMOSTRA seja 2 ou 9, inserimos string especifica em OUT_AMOSTRA
c5 = (df_train['AMOSTRA'].isin([2, 9]))
df_train.loc[c5, 'OUT_AMOST'] = 'COLETA_NAO_REALIZADA_OU_IGNORADA'

# Caso AMOSTRA seja 1 e TP_AMOSTRA seja nulo, inserimos 9
c6 = (df_train['AMOSTRA'] == 1) & (df_train['TP_AMOSTRA'].isna())
df_train.loc[c6, 'TP_AMOSTRA'] = 9

# Caso AMOSTRA seja 1 e TP_AMOSTRA seja diferente de 4, inserimos string especifica em OUT_AMOST
c7 = (df_train['AMOSTRA'] == 1) & (df_train['TP_AMOSTRA'] != 4)
df_train.loc[c7, 'OUT_AMOST'] = 'COLETA_FEITA_TIPO_IGNORADO'

# %%
# Caso seja nulo em AMOSTRA, será considerado que a coleta foi ignorada
c1 = df_test['AMOSTRA'].isna()
df_test.loc[c1, 'AMOSTRA'] = 9

# Caso AMOSTRA seja 2 ou 9 (não e ignorado respectivamente), ignoramos o tipo de amostra
c2 = df_test['AMOSTRA'].isin([2, 9])
df_test.loc[c2, 'TP_AMOSTRA'] = 9

# Caso TP_AMOSTRA seja 4 (outra) e não tenha informação em OUT_AMOST colocamos uma string especifica
c3 = (df_test['TP_AMOSTRA'] == 4) & (df_test['OUT_AMOST'].isna())
df_test.loc[c3, 'OUT_AMOST'] = 'TIPO_AMOST_NAO_ESPECIFICADO'

# Caso AMOSTRA seja 1 e TP_AMOSTRA seja diferente de 4, inserimos string especifica em OUT_AMOST
c4 = (df_test['AMOSTRA'] == 1) & (df_test['TP_AMOSTRA'].isin([1,2,3,5]))
df_test.loc[c4, 'OUT_AMOST'] = 'COLETA_FEITA_TIPO_DEFINIDO'

# Caso AMOSTRA seja 2 ou 9, inserimos string especifica em OUT_AMOSTRA
c5 = (df_test['AMOSTRA'].isin([2, 9]))
df_test.loc[c5, 'OUT_AMOST'] = 'COLETA_NAO_REALIZADA_OU_IGNORADA'

# Caso AMOSTRA seja 1 e TP_AMOSTRA seja nulo, inserimos 9
c6 = (df_test['AMOSTRA'] == 1) & (df_test['TP_AMOSTRA'].isna())
df_test.loc[c6, 'TP_AMOSTRA'] = 9

# Caso AMOSTRA seja 1 e TP_AMOSTRA seja diferente de 4, inserimos string especifica em OUT_AMOST
c7 = (df_test['AMOSTRA'] == 1) & (df_test['TP_AMOSTRA'] != 4)
df_test.loc[c7, 'OUT_AMOST'] = 'COLETA_FEITA_TIPO_IGNORADO'

# %% [markdown]
# Melhorar colunas referente a OUTROS II

# %%
# Gerar listas hierarquicas especificas para consolidar categorias em tipo de amostra X (prioridade de baixo para cima)
outros_amost_nasof = [c for c in outros_amost if 'NASOFARINGE' in c or 'NASO' in c or 'NF' in c or 'NOSOFARINGE' in c]
outros_amost_rapid = [c for c in outros_amost if 'TESTE RAPIDO' in c or 'RAPIDO' in c or 'TR' in c or 'ANTIGEN' in c]
outros_amost_blood = [c for c in outros_amost if 'SANGUE' in c or 'SAGUE' in c]
outros_amost_swab = [c for c in outros_amost if 'SWAB' in c]
outros_amost_soro = [c for c in outros_amost if 'SORO' in c]
outros_amost_tpcr = [c for c in outros_amost if 'PCR' in c]
outros_amost_nasal = [c for c in outros_amost if 'NASAL' in c]


# Especificar novas categorias de agrupamento por ordem de prioridade
outros_amost_nCats = ['REL_NASOFARINGE', 'REL_TESTE_RAPIDO','REL_PCR', 'REL_TESTE_SANGUE',
                      'REL_SWAB', 'REL_SORO', 'REL_NASAL']
outros_amost_oCats = [outros_amost_nasof, outros_amost_rapid, outros_amost_tpcr, outros_amost_blood,
                      outros_amost_swab, outros_amost_soro, outros_amost_nasal]

# Criar colunas
df_train['AMOSTRA_OUT_NOVO'] = np.nan
df_test['AMOSTRA_OUT_NOVO'] = np.nan

# Aplicar novas categorias evitando sobreposição
for n_cat, o_cats in zip(outros_amost_nCats, outros_amost_oCats):
    df_train.loc[(df_train['OUT_AMOST'].isin(o_cats)) & (df_train['AMOSTRA_OUT_NOVO'].isna()), 'AMOSTRA_OUT_NOVO'] = n_cat
    df_test.loc[(df_test['OUT_AMOST'].isin(o_cats)) & (df_test['AMOSTRA_OUT_NOVO'].isna()), 'AMOSTRA_OUT_NOVO'] = n_cat

# Converter todas as demais categorias restantes provalvemente raras em umas só para reduzir ruído ao modelo
c1 = (~df_train['AMOSTRA_OUT_NOVO'].isin(outros_amost_nCats)) & (df_train['OUT_AMOST'].notnull())
df_train.loc[c1, 'AMOSTRA_OUT_NOVO'] = 'REL_OUTROS_RESULTADOS'

c1 = (~df_test['AMOSTRA_OUT_NOVO'].isin(outros_amost_nCats)) & (df_test['OUT_AMOST'].notnull())
df_test.loc[c1, 'AMOSTRA_OUT_NOVO'] = n_cat

# %% [markdown]
# **Variáveis relacionadas ao SINTOMA**

# %%
# Definir colunas de análise nesta seção
cols = ['SEM_PRI','SEM_NOT','FEBRE','TOSSE','GARGANTA','DISPNEIA','DESC_RESP','SATURACAO','DIARREIA','VOMITO',
        'OUTRO_SIN','OUTRO_DES','PERD_PALA','PERD_OLFT','DOR_ABD','FADIGA']

# %%
# Checar nulos
df_train[cols].isna().sum()
# Out:
# SEM_PRI           0
# SEM_NOT           0
# FEBRE        231370
# TOSSE        172085
# GARGANTA     396565
# DISPNEIA     176050
# DESC_RESP    261255
# SATURACAO    223622
# DIARREIA     414223
# VOMITO       422753
# OUTRO_SIN    395283
# OUTRO_DES    904480
# PERD_PALA    434644
# PERD_OLFT    434124
# DOR_ABD      439039
# FADIGA       389988
# dtype: int64

# %%
# Criar coluna de acumulo de sintomas em dois formatos: progressivo
cols_sin = ['FEBRE','TOSSE','GARGANTA','DISPNEIA','DESC_RESP','SATURACAO','DIARREIA','VOMITO',
            'PERD_PALA','PERD_OLFT','DOR_ABD','FADIGA','OUTRO_SIN']
df_train['ACUMULADO_SINTOMAS'] = (df_train[cols_sin] == 1).sum(axis=1)
df_test['ACUMULADO_SINTOMAS'] = (df_test[cols_sin] == 1).sum(axis=1)

# %% [markdown]
# **Nota** - Não tem muito o que trabalhar nessas variáveis em relação a imputação.

# %% [markdown]
# **Variáveis relacionadas ao HOSPITAL**

# %%
# Definir colunas de análise nesta seção
cols = ['HOSPITAL','UTI','SUPORT_VEN','NOSOCOMIAL']

# %%
# Checar nulos
df_train[cols].isna().sum()
# Out:
# HOSPITAL       26483
# UTI           162527
# SUPORT_VEN    164962
# NOSOCOMIAL    201505
# dtype: int64

# %% [markdown]
# Imputar variáveis a partir de condições lógicas

# %%
# Caso HOSPITAL seja nulo, inserir como Sim caso certas condições sejam apresentadas
c1 = df_train['HOSPITAL'].isna()
c2 = (df_train['UTI'] == 1) | (df_train['SUPORT_VEN'].isin([1, 2])) | (df_train['NOSOCOMIAL'] == 1)
df_train.loc[c1 & c2, 'HOSPITAL'] = 1

# Caso HOSPITAL seja 1 e NOSOCOMIAL nulo, inserir 9
c3 = (df_train['HOSPITAL'] == 1) & (df_train['NOSOCOMIAL'].isna())
df_train.loc[c3, 'NOSOCOMIAL'] = 9

# %%
# Caso HOSPITAL seja nulo, inserir como Sim caso certas condições sejam apresentadas
c1 = df_test['HOSPITAL'].isna()
c2 = (df_test['UTI'] == 1) | (df_test['SUPORT_VEN'].isin([1, 2])) | (df_test['NOSOCOMIAL'] == 1)
df_test.loc[c1 & c2, 'HOSPITAL'] = 1

# Caso HOSPITAL seja 1 e NOSOCOMIAL nulo, inserir 9
c3 = (df_test['HOSPITAL'] == 1) & (df_test['NOSOCOMIAL'].isna())
df_test.loc[c3, 'NOSOCOMIAL'] = 9

# %% [markdown]
# **Variáveis relacionadas ao MEDICACAO**

# %%
# Definir colunas de análise nesta seção
cols = ['VACINA','ANTIVIRAL','TP_ANTIVIR']

# %%
# Checar nulos
df_train[cols].isna().sum()
# Out:
# VACINA         384795
# ANTIVIRAL      224350
# TP_ANTIVIR    1268247
# dtype: int64

# %%
# Caso ANTIVIRAL seja nulo, inserir como Sim caso certas condições sejam apresentadas
c1 = (df_train['ANTIVIRAL'].isna()) & (df_train['TP_ANTIVIR'].isin([1,2,3]))
df_train.loc[c1, 'ANTIVIRAL'] = 1

# %%
# Caso ANTIVIRAL seja, inserir como Não em TP_ANTIVIR como 99
c1 = (df_train['ANTIVIRAL'] == 2) & (df_train['TP_ANTIVIR'].isna())
df_train.loc[c1, 'TP_ANTIVIR'] = 99

# %% [markdown]
# **Variáveis relacionadas ao PACIENTE_SAUDE_DETALHE**

# %%
# Definir colunas de análise nesta seção
cols = ['FATOR_RISC','CARDIOPATI','HEMATOLOGI','SIND_DOWN','HEPATICA','ASMA','DIABETES','NEUROLOGIC','PNEUMOPATI',
        'IMUNODEPRE','RENAL','OBESIDADE','OBES_IMC','OUT_MORBI','MORB_DESC']

# %%
# Especificar colunas de SAUDE_DETALHE
cols_saude = ['CARDIOPATI','HEMATOLOGI','SIND_DOWN','HEPATICA','ASMA','DIABETES','NEUROLOGIC','PNEUMOPATI',
              'IMUNODEPRE','RENAL','OBESIDADE','OUT_MORBI','PUERPERA']

# Criar acumulado
df_train['ACUMULADO_SAUDE'] = (df_train[cols_saude] == 1).sum(axis=1)
df_test['ACUMULADO_SAUDE'] = (df_test[cols_saude] == 1).sum(axis=1)

# %%
# Criar outras variações
df_train['ACUMULADO_SAUDE_MAIS_SINTOMA'] = df_train[['ACUMULADO_SAUDE','ACUMULADO_SINTOMAS']].sum(axis=1)
df_test['ACUMULADO_SAUDE_MAIS_SINTOMA'] = df_test[['ACUMULADO_SAUDE','ACUMULADO_SINTOMAS']].sum(axis=1)

df_train['ACUMULADO_SAUDE_SINTOMA_VACCOV'] = df_train['ACUMULADO_SAUDE_MAIS_SINTOMA']+(df_train['VACINA_COV'] == 1).astype(int)
df_test['ACUMULADO_SAUDE_SINTOMA_VACCOV'] = df_test['ACUMULADO_SAUDE_MAIS_SINTOMA']+(df_test['VACINA_COV'] == 1).astype(int)

# %%
# Caso FATOR de RISCO seja 2, então para as variáveis saúde inserir 2 indicando ausência nas de fator de riso
df_train.loc[df_train['FATOR_RISC'] == 2, cols_saude] = 2
df_train.loc[(df_train['FATOR_RISC'] == 2)&(df_train['PUERPERA'] != 99), 'PUERPERA'] = 2

df_test.loc[df_test['FATOR_RISC'] == 2, cols_saude] = 2
df_test.loc[(df_test['FATOR_RISC'] == 2)&(df_test['PUERPERA'] != 99), 'PUERPERA'] = 2

# %%
# Caso tenha outro tipo de fator de risco porém sem info, adicionar string específica
df_train.loc[(df_train['OUT_MORBI'] == 1)&(df_train['MORB_DESC'].isna()), 'MORB_DESC'] = 'FATOR_RISCO_NAO_DESCRITO'
df_test.loc[(df_test['OUT_MORBI'] == 1)&(df_test['MORB_DESC'].isna()), 'MORB_DESC'] = 'FATOR_RISCO_NAO_DESCRITO'

# %%
# Caso tenha nulo em MORB_DESC inserir string de ignorado
df_train.loc[df_train['MORB_DESC'].isna(), 'MORB_DESC'] = 'IGNORADO'
df_test.loc[df_test['MORB_DESC'].isna(), 'MORB_DESC'] = 'IGNORADO'

# %% [markdown]
# **Variáveis relacionadas ao PACIENTE_INFORMACAO**

# %%
# Definir colunas de análise nesta seção
cols = ['SG_UF','SG_UF_NOT','ID_REGIONA','CO_REGIONA','ID_MUNICIP','CO_MUN_NOT','CS_SEXO','NU_IDADE_N','TP_IDADE',
        'CS_RACA','CS_ESCOL_N','CS_ZONA','AVE_SUINO','OUT_ANIM']

# %%
# Checar nulos
(100*df_train[cols].isna().sum()/len(df_train)).round(2)
# Out:
# SG_UF          0.02
# SG_UF_NOT      0.00
# ID_REGIONA    11.36
# CO_REGIONA    11.36
# ID_MUNICIP     0.00
# CO_MUN_NOT     0.00
# CS_SEXO        0.00
# NU_IDADE_N     0.00
# TP_IDADE       0.00
# CS_RACA        0.00
# CS_ESCOL_N    34.98
# CS_ZONA       10.36
# AVE_SUINO     16.90
# OUT_ANIM      99.91
# dtype: float64

# %%
# Imputar SG_UF através da versão not
c1 = (df_train['SG_UF'].isna())&(df_train['SG_UF_NOT'].notnull())
df_train.loc[c1, 'SG_UF'] = df_train.loc[c1, 'SG_UF_NOT']

c1 = (df_test['SG_UF'].isna())&(df_test['SG_UF_NOT'].notnull())
df_test.loc[c1, 'SG_UF'] = df_test.loc[c1, 'SG_UF_NOT']

# %%
# Definir colunas para derrubar - redundantes e repetidas
cols_to_drop = ['ID_REGIONA','CO_REGIONA','SG_UF','CO_MUN_NOT']

df_train.drop(columns=cols_to_drop, inplace=True)
df_test.drop(columns=cols_to_drop, inplace=True)

# %%
# Definir colunas de análise nesta seção novamente
cols = [c for c in cols if c not in cols_to_drop]

# %% [markdown]
# Aqui vamos otimizar a coluna `AVES_SUINO` unificando ela a `OUT_ANIM` criando uma nova variável:

# %%
# Criar
outros_anim = list(set(df_train['OUT_ANIM'].dropna().unique().tolist() + df_test['OUT_ANIM'].dropna().unique().tolist()))

# %%
# Gerar listas hierarquicas especificas para consolidar categorias em tipo de amostra X (prioridade de baixo para cima)
outros_anim_dog = [c for c in outros_anim if 'CACHOR' in c or 'CANINO' in c or 'CAES' in c or 'CAO' in c or 'CAHORRO' in c]
outros_anim_cat = [c for c in outros_anim if 'GATO' in c or 'FELIN' in c]
outros_anim_boi = [c for c in outros_anim if 'GADO' in c or 'BOVINO' in c or 'BOI' in c or 'VACA' in c]
outros_anim_gal = [c for c in outros_anim if 'GALINHA' in c]

# Especificar novas categorias de agrupamento por ordem de prioridade
outros_anim_nCats = ['REL_CACHORRO', 'REL_GATO','REL_BOI', 'REL_GALINHA']
outros_anim_oCats = [outros_anim_dog, outros_anim_cat, outros_anim_boi, outros_anim_gal]

# Criar colunas
df_train['ANIM_OUT_NOVO'] = np.nan
df_test['ANIM_OUT_NOVO'] = np.nan

# Aplicar novas categorias evitando sobreposição
for n_cat, o_cats in zip(outros_anim_nCats, outros_anim_oCats):
    df_train.loc[(df_train['OUT_ANIM'].isin(o_cats)) & (df_train['ANIM_OUT_NOVO'].isna()), 'ANIM_OUT_NOVO'] = n_cat
    df_test.loc[(df_test['OUT_ANIM'].isin(o_cats)) & (df_test['ANIM_OUT_NOVO'].isna()), 'ANIM_OUT_NOVO'] = n_cat

# Converter todas as demais categorias restantes provalvemente raras em umas só para reduzir ruído ao modelo
c1 = (~df_train['ANIM_OUT_NOVO'].isin(outros_anim_nCats)) & (df_train['OUT_ANIM'].notnull())
df_train.loc[c1, 'ANIM_OUT_NOVO'] = 'REL_OUTROS_RESULTADOS'

c1 = (~df_test['ANIM_OUT_NOVO'].isin(outros_anim_nCats)) & (df_test['OUT_ANIM'].notnull())
df_test.loc[c1, 'ANIM_OUT_NOVO'] = n_cat

# %%
# Caso AVE_SUINO seja vazio, inserir ignorado
df_train['AVE_SUINO'].fillna(9, inplace=True)
df_test['AVE_SUINO'].fillna(9, inplace=True)

# %%
# Converter AVE_SUINO em string
c1 = (df_train['AVE_SUINO'] == 1)
df_train.loc[c1, 'AVE_SUINO_NOVO'] = 'CONVIVIO_AVE_SUINO'

c2 = (df_train['AVE_SUINO'] == 2)
df_train.loc[c2, 'AVE_SUINO_NOVO'] = 'SEM_CONVIVIO_ANIMAL'

c3 = (df_train['AVE_SUINO'] == 3) & (df_train['ANIM_OUT_NOVO'].notnull())
df_train.loc[c3, 'AVE_SUINO_NOVO'] = df_train.loc[c3, 'ANIM_OUT_NOVO']

c4 = (df_train['AVE_SUINO'] == 3) & (df_train['ANIM_OUT_NOVO'].isna())
df_train.loc[c4, 'AVE_SUINO_NOVO'] = 'CONVIVIO_NAO_DETALHADO'

c5 = (df_train['AVE_SUINO'] == 9)
df_train.loc[c5, 'AVE_SUINO_NOVO'] = 'CONVIVIO_IGNORADO'

# Visualizar nova coluna
df_train['AVE_SUINO_NOVO'].value_counts(dropna=False)
# Out:
# SEM_CONVIVIO_ANIMAL      879296
# CONVIVIO_IGNORADO        409145
# CONVIVIO_AVE_SUINO        11375
# REL_CACHORRO                843
# REL_GATO                    158
# REL_OUTROS_RESULTADOS        77
# REL_BOI                      68
# REL_GALINHA                  18
# Name: AVE_SUINO_NOVO, dtype: int64

# %%
# Converter AVE_SUINO em string
c1 = (df_test['AVE_SUINO'] == 1)
df_test.loc[c1, 'AVE_SUINO_NOVO'] = 'CONVIVIO_AVE_SUINO'

c2 = (df_test['AVE_SUINO'] == 2)
df_test.loc[c2, 'AVE_SUINO_NOVO'] = 'SEM_CONVIVIO_ANIMAL'

c3 = (df_test['AVE_SUINO'] == 3) & (df_test['ANIM_OUT_NOVO'].notnull())
df_test.loc[c3, 'AVE_SUINO_NOVO'] = df_test.loc[c3, 'ANIM_OUT_NOVO']

c4 = (df_test['AVE_SUINO'] == 3) & (df_test['ANIM_OUT_NOVO'].isna())
df_test.loc[c4, 'AVE_SUINO_NOVO'] = 'CONVIVIO_NAO_DETALHADO'

c5 = (df_test['AVE_SUINO'] == 9)
df_test.loc[c5, 'AVE_SUINO_NOVO'] = 'CONVIVIO_IGNORADO'

# Visualizar nova coluna
df_test['AVE_SUINO_NOVO'].value_counts(dropna=False)
# Out:
# SEM_CONVIVIO_ANIMAL    586685
# CONVIVIO_IGNORADO      272295
# CONVIVIO_AVE_SUINO       7558
# REL_CACHORRO              561
# REL_GATO                  106
# REL_GALINHA                63
# REL_BOI                    53
# Name: AVE_SUINO_NOVO, dtype: int64

# %%
# Derrubar colunas
cols_to_drop = ['AVE_SUINO', 'OUT_ANIM','ANIM_OUT_NOVO']

df_train.drop(columns=cols_to_drop, inplace=True)
df_test.drop(columns=cols_to_drop, inplace=True)

# %%
# Modificar cols novamente
cols = ['SG_UF_NOT','ID_MUNICIP','CS_ZONA','CS_SEXO','CS_RACA','NU_IDADE_N','TP_IDADE','CS_ESCOL_N','AVE_SUINO_NOVO']

# %%
# Checar nulos
(100*df_train[cols].isna().sum()/len(df_train)).round(2).sort_values(ascending=False)
# Out:
# CS_ESCOL_N        34.98
# CS_ZONA           10.36
# SG_UF_NOT          0.00
# ID_MUNICIP         0.00
# CS_SEXO            0.00
# CS_RACA            0.00
# NU_IDADE_N         0.00
# TP_IDADE           0.00
# AVE_SUINO_NOVO     0.00
# dtype: float64

# %% [markdown]
# ### **Listar variáveis de acordo a natureza**

# %%
# Listar todas as colunas que são categóricas por definição e que podem estar codificadas como numéricas
cols_cat = ['SG_UF_NOT', 'ID_MUNICIP', 'CS_ZONA', 'SURTO_SG',                                              # LOCALIDADE
            'CS_SEXO', 'CS_GESTANT', 'CS_RACA', 'CS_ESCOL_N', 'HISTO_VGM','AVE_SUINO_NOVO',                # INFO PACIENTE
            'FEBRE', 'TOSSE', 'GARGANTA', 'DISPNEIA', 'DESC_RESP', 'SATURACAO', 'DIARREIA', 'VOMITO',      # SINTOMA
            'OUTRO_SIN', 'OUTRO_DES', 'DOR_ABD', 'FADIGA', 'PERD_OLFT', 'PERD_PALA',                       # SINTOMA
            'FATOR_RISC', 'PUERPERA', 'CARDIOPATI', 'HEMATOLOGI', 'SIND_DOWN', 'HEPATICA', 'ASMA',         # FATOR DE RISCO
            'DIABETES', 'NEUROLOGIC', 'PNEUMOPATI', 'IMUNODEPRE', 'RENAL', 'OBESIDADE',                    # FATOR DE RISCO 
            'MORB_DESC','OUT_MORBI',                                                                       # FATOR DE RISCO
            'RAIOX_RES',  'RAIOX_OUT_NOVO', 'TOMO_RES', 'TOMO_OUT_NOVO',                                   # EXAME
            #'TOMO_OUT', 'RAIOX_OUT',
            'VACINA', 'ANTIVIRAL', 'TP_ANTIVIR',                                                           # GRIPE / ANTI VIRAL
            'VACINA_COV',                                                                                  # VACINA COVID
            'HOSPITAL', 'UTI', 'SUPORT_VEN', 'NOSOCOMIAL',                                                 # HOSPITALIZAÇÃO
            'AMOSTRA', 'TP_AMOSTRA', 'AMOSTRA_OUT_NOVO',                                                   # COLETA AMOSTRA
            #'OUT_AMOST', 
            'MAE_VAC', 'M_AMAMENTA']                                                                       # MAE RELACIONADO

# Listar colunas numéricas
cols_num = ['SEM_NOT','SEM_PRI',                      # INFECCAO
            'NU_IDADE_N','TP_IDADE',                  # INFO PACIENTE
            'DOSE_COV_N',                             # QTD DOSES TOMADAS
            'ACUMULADO_SINTOMAS',                     # ACUMULADO SINTOMAS
            'ACUMULADO_SAUDE',                        # ACUMULADO FATOR DE RISCO
            'ACUMULADO_SAUDE_MAIS_SINTOMA',           # ACUMULADO SINTOMAS + FATOR DE RISCO
            'ACUMULADO_SAUDE_SINTOMA_VACCOV']         # ACUMULADO SINTOMAS + FATOR DE RISCO + DOSES VACINA
# Listar colunas binárias por definição
cols_bin = ['DOSE_1_COV','DOSE_2_COV', 'DOSE_REF']    # VACINA COVID

# %% [markdown]
# ### Codificar corretamente variáveis categóricas

# %%
# Especificar dicionário para casos especificos
de_para_cat = {'CS_ZONA': {1:'URBANA', 2:'RURAL', 3:'PERIURBANA',9:'URBANA'},
               'HISTO_VGM':{1:'SIM', 2:'NAO', 9:'IGNORADO', 0:'IGNORADO'},
               'CS_GESTANT': {1:'PRI_TRI',2:'SEG_TRI',3:'TRC_TRI',4:'IDD_GEST_IGNORADA',5:'NAO',6:'NAO_APLICA',9:'IGNORADO'},
               'CS_RACA': {1:'BRANCA',2:'PRETA',3:'AMARELA',4:'PARDA',5:'INDIGENA',9:'IGNORADO'},
               'CS_ESCOL_N': {0:'ANALFAB',1:'1_5_SERIE',2:'6_9_SERIE',3:'ENS_MEDIO',4:'ENS_SUP',5:'NAO_APLICA',9:'IGNORADO'},
               'PUERPERA': {1:'SIM', 2:'NAO', 9:'IGNORADO',99:'NAO_SE_APLICA_HOMEM'},
               'RAIOX_RES': {1:'NORMAL',2:'INFILTRADO_INTERSTICIAL',3:'CONSOLIDACAO',
                             4:'MISTO',5:'OUTRO',6:'NAO_FEITO',9:'IGNORADO'},
               'TOMO_RES': {1:'TIPICO_COV19',2:'INDETERMINADO_COV19',3:'ATIPICO_COV19',
                            4:'NEGATIVO_PNM',5:'OUTRO',6:'NAO_FEITO',9:'IGNORADO'},
               'TP_ANTIVIR': {1:'OSELTAMIVIR',2:'ZANAMIVIR',3:'OUTRO'},
               'SUPORT_VEN': {1:'SIM_INVASIVO',2:'SIM_NAO_INVASIVO',3:'NAO',9:'IGNORADO'},
               'TP_AMOSTRA': {1:'SECREC_NASO_OROFARINGE',2:'LAVADO_BROCO_ALVEOLAR',3:'TECIDO_POST_MORTEM',
                              4:'OUTRA',5:'LCR',9:'IGNORADO'},
               'MAE_VAC': {1:'SIM', 2:'NAO', 9:'IGNORADO',99:'NAO_SE_APLICA_HOMEM'},
               'M_AMAMENTA': {1:'SIM', 2:'NAO', 9:'IGNORADO',99:'NAO_SE_APLICA_HOMEM'}}

# Loop para modificar
for c, d in de_para_cat.items():
    df_train[c].replace(d, inplace=True)
    df_test[c].replace(d, inplace=True)

# %%
# Especificar lista de colunas que possuem seus valores numéricos equivalentes as mesmas strings
cols_cat_gen = ['FEBRE', 'TOSSE', 'GARGANTA', 'DISPNEIA', 'DESC_RESP', 'SATURACAO', 'DIARREIA', 'VOMITO',
                'OUTRO_SIN', 'DOR_ABD', 'FADIGA', 'PERD_OLFT', 'PERD_PALA', 'FATOR_RISC', 'CARDIOPATI', 
                'HEMATOLOGI', 'SIND_DOWN', 'HEPATICA', 'ASMA', 'DIABETES', 'NEUROLOGIC', 'PNEUMOPATI', 
                'IMUNODEPRE', 'RENAL', 'OBESIDADE', 'OUT_MORBI', 
                 'SURTO_SG','VACINA','ANTIVIRAL','VACINA_COV','HOSPITAL','UTI','NOSOCOMIAL','AMOSTRA']
# Loop para modificar
for c in cols_cat_gen:
    df_train[c].replace({1:'SIM', 2:'NAO', 9:'IGNORADO'}, inplace=True)
    df_test[c].replace({1:'SIM', 2:'NAO', 9:'IGNORADO'}, inplace=True)

# %%
# Validação das colunas categoricas corrigida
for c in cols_cat_gen + list(de_para_cat.keys()):
    print(f'##################################### {c}')
    print(df_test[c].unique())
# Out:
# ##################################### FEBRE
# ['SIM' nan 'NAO' 'IGNORADO']
# ##################################### TOSSE
# ['SIM' nan 'NAO' 'IGNORADO']
# ##################################### GARGANTA
# ['NAO' nan 'SIM' 'IGNORADO']
# ##################################### DISPNEIA
# ['NAO' nan 'SIM' 'IGNORADO']
# ##################################### DESC_RESP
# ['SIM' nan 'NAO' 'IGNORADO']
# ##################################### SATURACAO
# ['NAO' nan 'SIM' 'IGNORADO']
# ##################################### DIARREIA
# ['NAO' nan 'IGNORADO' 'SIM']
# ##################################### VOMITO
# ['NAO' nan 'SIM' 'IGNORADO']
# ##################################### OUTRO_SIN
# ['NAO' nan 'SIM' 'IGNORADO']
# ##################################### DOR_ABD
# ['NAO' nan 'SIM' 'IGNORADO']
# ##################################### FADIGA
# ['NAO' nan 'SIM' 'IGNORADO']
# ##################################### PERD_OLFT
# ['NAO' nan 'IGNORADO' 'SIM']
# ##################################### PERD_PALA
# ['NAO' nan 'IGNORADO' 'SIM']
# ##################################### FATOR_RISC
# ['NAO' 'SIM']
# ##################################### CARDIOPATI
# ['NAO' 'SIM' nan 'IGNORADO']
# ##################################### HEMATOLOGI
# ['NAO' nan 'IGNORADO' 'SIM']
# ##################################### SIND_DOWN
# ['NAO' nan 'IGNORADO' 'SIM']
# ##################################### HEPATICA
# ['NAO' nan 'SIM' 'IGNORADO']
# ##################################### ASMA
# ['NAO' nan 'SIM' 'IGNORADO']
# ##################################### DIABETES
# ['NAO' nan 'SIM' 'IGNORADO']
# ##################################### NEUROLOGIC
# ['NAO' nan 'SIM' 'IGNORADO']
# ##################################### PNEUMOPATI
# ['NAO' nan 'IGNORADO' 'SIM']
# ##################################### IMUNODEPRE
# ['NAO' nan 'IGNORADO' 'SIM']
# ##################################### RENAL
# ['NAO' nan 'IGNORADO' 'SIM']
# ##################################### OBESIDADE
# ['NAO' nan 'SIM' 'IGNORADO']
# ##################################### OUT_MORBI
# ['NAO' nan 'SIM' 'IGNORADO']
# ##################################### SURTO_SG
# [nan 'NAO' 'SIM' 'IGNORADO']
# ##################################### VACINA
# ['SIM' nan 'NAO' 'IGNORADO']
# ##################################### ANTIVIRAL
# ['NAO' 'IGNORADO' nan 'SIM']
# ##################################### VACINA_COV
# ['NAO' 'SIM' 'IGNORADO']
# ##################################### HOSPITAL
# ['SIM' nan 'NAO' 'IGNORADO']
# ##################################### UTI
# ['NAO' nan 'SIM' 'IGNORADO']
# ##################################### NOSOCOMIAL
# ['NAO' 'IGNORADO' nan 'SIM']
# ##################################### AMOSTRA
# ['SIM' 'NAO' 'IGNORADO']
# ##################################### CS_ZONA
# ['RURAL' 'URBANA' nan 'PERIURBANA']
# ##################################### HISTO_VGM
# ['IGNORADO' 'NAO' 'SIM']
# ##################################### CS_GESTANT
# ['NAO_APLICA' 'NAO' 'IGNORADO' 'TRC_TRI' 'SEG_TRI' 'PRI_TRI'
#  'IDD_GEST_IGNORADA']
# ##################################### CS_RACA
# ['PARDA' 'BRANCA' 'PRETA' 'IGNORADO' 'AMARELA' 'INDIGENA']
# ##################################### CS_ESCOL_N
# [nan 'IGNORADO' '6_9_SERIE' 'ENS_SUP' 'ANALFAB' 'NAO_APLICA' 'ENS_MEDIO'
#  '1_5_SERIE']
# ##################################### PUERPERA
# ['NAO' 'NAO_SE_APLICA_HOMEM' 'IGNORADO' 'SIM']
# ##################################### RAIOX_RES
# ['NORMAL' 'NAO_FEITO' 'IGNORADO' 'INFILTRADO_INTERSTICIAL' 'OUTRO' 'MISTO'
#  'CONSOLIDACAO']
# ##################################### TOMO_RES
# ['NAO_FEITO' 'NEGATIVO_PNM' 'IGNORADO' 'INDETERMINADO_COV19' 'OUTRO'
#  'ATIPICO_COV19' 'TIPICO_COV19']
# ##################################### TP_ANTIVIR
# [nan 'OSELTAMIVIR' 'ZANAMIVIR' 'OUTRO']
# ##################################### SUPORT_VEN
# ['NAO' 'SIM_NAO_INVASIVO' nan 'IGNORADO' 'SIM_INVASIVO']
# ##################################### TP_AMOSTRA
# ['SECREC_NASO_OROFARINGE' 'OUTRA' 'IGNORADO' 'LAVADO_BROCO_ALVEOLAR' 'LCR'
#  'TECIDO_POST_MORTEM']
# ##################################### MAE_VAC
# ['NAO_SE_APLICA_HOMEM' 'IGNORADO' 'NAO' 'SIM']
# ##################################### M_AMAMENTA
# ['NAO_SE_APLICA_HOMEM' 'IGNORADO' 'NAO' 'SIM']

# %% [markdown]
# ### Aplicar + criação de variáveis

# %%
# Quando a notificao foi na semana dos primeiros sintomas
df_train['SEM_PRI_NOT_IGUAIS'] = (df_train['SEM_PRI'] == df_train['SEM_NOT']).astype(int)
df_test['SEM_PRI_NOT_IGUAIS'] = (df_test['SEM_PRI'] == df_test['SEM_NOT']).astype(int)

# Calcular diff absoluta
df_train['SEM_PRI_NOT_DIFF_ABS'] = (df_train['SEM_PRI'] - df_train['SEM_NOT']).abs()
df_test['SEM_PRI_NOT_DIFF_ABS'] = (df_test['SEM_PRI'] - df_test['SEM_NOT']).abs()

# %%
# Apontar realização de Raio X + TC e Ambos
df_train['FEZ_RAIOX'] = df_train['RAIOX_RES'].isin(['NORMAL','INFILTRADO_INTERSTICIAL','CONSOLIDACAO',
                                                    'MISTO','OUTRO']).astype(int)
df_train['FEZ_TOMOG'] = df_train['TOMO_RES'].isin(['TIPICO_COV19','INDETERMINADO_COV19','ATIPICO_COV19',
                                                   'NEGATIVO_PNM','OUTRO']).astype(int)
df_train['FEZ_RAIOX_TOMOG'] = df_train['FEZ_RAIOX'] + df_train['FEZ_TOMOG']

# Apontar realização de Raio X + TC e Ambos
df_test['FEZ_RAIOX'] = df_test['RAIOX_RES'].isin(['NORMAL','INFILTRADO_INTERSTICIAL','CONSOLIDACAO',
                                                    'MISTO','OUTRO']).astype(int)
df_test['FEZ_TOMOG'] = df_test['TOMO_RES'].isin(['TIPICO_COV19','INDETERMINADO_COV19','ATIPICO_COV19',
                                                   'NEGATIVO_PNM','OUTRO']).astype(int)
df_test['FEZ_RAIOX_TOMOG'] = df_test['FEZ_RAIOX'] + df_test['FEZ_TOMOG']

# %%
# Apontar TOMOG que apresentaram covid
df_train['TOMOG_COV19'] = ((df_train['TOMO_RES'] == 'TIPICO_COV19')|(df_train['TOMO_OUT_NOVO'] == 'REL_COVID')).astype(int)
df_test['TOMOG_COV19'] = ((df_test['TOMO_RES'] == 'TIPICO_COV19')|(df_test['TOMO_OUT_NOVO'] == 'REL_COVID')).astype(int)

# %%
# Aplicar a unidade de fato em TP para diferenciar melhor os valores
df_train.loc[df_train['TP_IDADE'] == 1, 'TP_IDADE'] = 1
df_train.loc[df_train['TP_IDADE'] == 2, 'TP_IDADE'] = 30
df_train.loc[df_train['TP_IDADE'] == 3, 'TP_IDADE'] = 365

df_test.loc[df_test['TP_IDADE'] == 1, 'TP_IDADE'] = 1
df_test.loc[df_test['TP_IDADE'] == 2, 'TP_IDADE'] = 30
df_test.loc[df_test['TP_IDADE'] == 3, 'TP_IDADE'] = 365

# %% [markdown]
# ### Listar novamente todas as variáveis por natureza II
#
# Adicionar as criadas anteriormente.

# %%
# Checar variáveis faltantes na listagem
[c for c in df_train.columns if c not in cols_cat + cols_num + cols_bin and c != 'CLASSI_FIN']
# Out:
# ['RAIOX_OUT',
#  'OUT_AMOST',
#  'TOMO_OUT',
#  'SEM_PRI_NOT_IGUAIS',
#  'SEM_PRI_NOT_DIFF_ABS',
#  'FEZ_RAIOX',
#  'FEZ_TOMOG',
#  'FEZ_RAIOX_TOMOG',
#  'TOMOG_COV19']

# %%
# Adicionar de acordo a natureza
cols_num += ['SEM_PRI_NOT_IGUAIS','SEM_PRI_NOT_DIFF_ABS','FEZ_RAIOX_TOMOG']
cols_bin += ['FEZ_RAIOX','FEZ_TOMOG','TOMOG_COV19']

# %%
# Checar variáveis faltantes na listagem
[c for c in df_train.columns if c not in cols_cat + cols_num + cols_bin and c != 'CLASSI_FIN']
# Out:
# ['RAIOX_OUT', 'OUT_AMOST', 'TOMO_OUT']

# %% [markdown]
# ### Trocar `IGNORADO` por nulo para reduzir complexidade

# %%
# Aplicar
#df_train.replace({'IGNORADO':np.nan}, inplace=True)
#df_test.replace({'IGNORADO':np.nan}, inplace=True)

# %% [markdown]
# # Divisão de treino e validação

# %%
# Separar dados em X e Y
X = df_train[cols_num + cols_bin + cols_cat].copy()
Y = df_train['CLASSI_FIN'].copy()

# %%
# Separar
x_train, x_valid, y_train, y_valid = train_test_split(X, Y, test_size=0.20, random_state=1206, stratify=Y)

# %%
# Criar teste seguindo a mesma ordem das colunas
x_test = df_test[cols_num + cols_bin + cols_cat].copy()

# %%
# Liberar espaço deletando dataframes antigos
del X, Y, df_test, df_train

# %%
# Checar distribuição de Y
y_train.value_counts(normalize=True)
# Out:
# 5    0.666859
# 4    0.292403
# 2    0.024164
# 1    0.012012
# 3    0.004562
# Name: CLASSI_FIN, dtype: float64

# %%
# Checar distribuição de Y
y_valid.value_counts(normalize=True)
# Out:
# 5    0.666859
# 4    0.292403
# 2    0.024163
# 1    0.012014
# 3    0.004562
# Name: CLASSI_FIN, dtype: float64

# %% [markdown]
# # Imputação de dados
#
# Estratégia:
# - Categóricas: Imputar string "INFO_FALTANTE"
# - Numéricas e Binárias: Imputar a moda

# %%
# Aplicar estratégia para categoricas
for c in cols_cat:
    x_train.loc[x_train[c].isna(), c] = 'INFO_FALTANTE'
    x_valid.loc[x_valid[c].isna(), c] = 'INFO_FALTANTE'
    x_test.loc[x_test[c].isna(), c] = 'INFO_FALTANTE'

# %%
# Aplicar estratégia para numéricas
for c in cols_num + cols_bin:
    # Calcular a moda no treino
    valor_moda = x_train[c].dropna().mode()[0]
    print(f'> {c} possui moda de {valor_moda}')
    # Imputar
    x_train.loc[x_train[c].isna(), c] = valor_moda
    x_valid.loc[x_valid[c].isna(), c] = valor_moda
    x_test.loc[x_test[c].isna(), c] = valor_moda
# Out:
# > SEM_NOT possui moda de 12
# > SEM_PRI possui moda de 9
# > NU_IDADE_N possui moda de 0
# > TP_IDADE possui moda de 365
# > DOSE_COV_N possui moda de 0
# > ACUMULADO_SINTOMAS possui moda de 4
# > ACUMULADO_SAUDE possui moda de 0
# > ACUMULADO_SAUDE_MAIS_SINTOMA possui moda de 5
# > ACUMULADO_SAUDE_SINTOMA_VACCOV possui moda de 5
# > SEM_PRI_NOT_IGUAIS possui moda de 0
# > SEM_PRI_NOT_DIFF_ABS possui moda de 1
# > FEZ_RAIOX_TOMOG possui moda de 1
# > DOSE_1_COV possui moda de 0
# > DOSE_2_COV possui moda de 0
# > DOSE_REF possui moda de 0
# > FEZ_RAIOX possui moda de 0
# > FEZ_TOMOG possui moda de 0
# > TOMOG_COV19 possui moda de 0

# %% [markdown]
# # Modelagem
#
# **Preparar dados**

# %%
# Criar conjuntos de treino Y binários
y1_train = (y_train == 1).astype(int)
y2_train = (y_train == 2).astype(int)
y3_train = (y_train == 3).astype(int)
y4_train = (y_train == 4).astype(int)
y5_train = (y_train == 5).astype(int)

# %%
# Criar conjuntos de validação Y binários
y1_valid = (y_valid == 1).astype(int)
y2_valid = (y_valid == 2).astype(int)
y3_valid = (y_valid == 3).astype(int)
y4_valid = (y_valid == 4).astype(int)
y5_valid = (y_valid == 5).astype(int)

# %%
# Converter para categorical type
for c in cols_cat:
    x_train[c] = x_train[c].astype('category')
    x_valid[c] = pd.Categorical(x_valid[c], x_train[c].astype('category').cat.categories) 
    x_test[c] = pd.Categorical(x_test[c], x_train[c].astype('category').cat.categories)

# %% [markdown]
# **Validação de Modelos já estabelecidos**
#
# [Referência](https://optuna.readthedocs.io/en/stable/reference/generated/optuna.integration.lightgbm.LightGBMTuner.html)
#
# [Parâmetros](https://lightgbm.readthedocs.io/en/latest/Parameters.html)

# %%
# Listar nomes das variáveis
feats_all = cols_num + cols_bin + cols_cat
feats_cat = cols_cat

# %%
# Converter X e Y para formato de dataset do lightgbm - treino
ds1_train = lgb.Dataset(data=x_train, label=y1_train, feature_name=feats_all, categorical_feature=feats_cat)
ds2_train = lgb.Dataset(data=x_train, label=y2_train, feature_name=feats_all, categorical_feature=feats_cat)
ds3_train = lgb.Dataset(data=x_train, label=y3_train, feature_name=feats_all, categorical_feature=feats_cat)
ds4_train = lgb.Dataset(data=x_train, label=y4_train, feature_name=feats_all, categorical_feature=feats_cat)
ds5_train = lgb.Dataset(data=x_train, label=y5_train, feature_name=feats_all, categorical_feature=feats_cat)

# Converter X e Y para formato de dataset do lightgbm - validação
ds1_valid = lgb.Dataset(data=x_valid, label=y1_valid, feature_name=feats_all, categorical_feature=feats_cat)
ds2_valid = lgb.Dataset(data=x_valid, label=y2_valid, feature_name=feats_all, categorical_feature=feats_cat)
ds3_valid = lgb.Dataset(data=x_valid, label=y3_valid, feature_name=feats_all, categorical_feature=feats_cat)
ds4_valid = lgb.Dataset(data=x_valid, label=y4_valid, feature_name=feats_all, categorical_feature=feats_cat)
ds5_valid = lgb.Dataset(data=x_valid, label=y5_valid, feature_name=feats_all, categorical_feature=feats_cat)

# %%
# Criar versões unificadas para novo treinamento
x_train_valid = pd.concat([x_train, x_valid])
y1_train_valid = pd.concat([y1_train, y1_valid])
y2_train_valid = pd.concat([y2_train, y2_valid])
y3_train_valid = pd.concat([y3_train, y3_valid])
y4_train_valid = pd.concat([y4_train, y4_valid])
y5_train_valid = pd.concat([y5_train, y5_valid])

# Converter X e Y para formato de dataset do lightgbm - validação
ds1_train_valid = lgb.Dataset(data=x_train_valid, label=y1_train_valid, feature_name=feats_all, categorical_feature=feats_cat)
ds2_train_valid = lgb.Dataset(data=x_train_valid, label=y2_train_valid, feature_name=feats_all, categorical_feature=feats_cat)
ds3_train_valid = lgb.Dataset(data=x_train_valid, label=y3_train_valid, feature_name=feats_all, categorical_feature=feats_cat)
ds4_train_valid = lgb.Dataset(data=x_train_valid, label=y4_train_valid, feature_name=feats_all, categorical_feature=feats_cat)
ds5_train_valid = lgb.Dataset(data=x_train_valid, label=y5_train_valid, feature_name=feats_all, categorical_feature=feats_cat)

# %%
# Lidar com excesso de warnings de usuário não solucionáveis do LGBM
warnings.filterwarnings('ignore')

# %% [markdown]
# **Montar modelos para avaliar em prompt a validação**

# %%
# Definir número de rounds
nbr = 2500

# %%
# Especificar hiper parâmetros finais
hp5 = {'objective':'binary',
       'is_unbalance': False,
       'boosting_type': 'gbdt',
       'metric': 'binary_logloss', 
       'eta': 0.01,
       'num_leaves': 224,
       'feature_fraction': 0.85,
       'early_stopping_round': 25,
       "lambda_l1":8.791369324758216,
       "lambda_l2":0.05026876807406415,
       'seed': 1206,
       'verbosity': -1,
       'num_threads':4}
hp4 = {'objective':'binary',
       'is_unbalance': False,
       'boosting_type': 'gbdt',
       'metric': 'binary_logloss', 
       'eta': 0.01,
       'num_leaves': 243,
       'feature_fraction': 0.85,
       'early_stopping_round': 25,
       "lambda_l1":8.791369324758216,
       "lambda_l2":0.05026876807406415,
       'seed': 1206, 
       'verbosity': -1,
       'num_threads':4}
hp3 = {'objective':'binary',
       'is_unbalance': False,
       'boosting_type': 'gbdt',
       'metric': 'binary_logloss', 
       'eta': 0.01,
       'num_leaves': 243,
       'feature_fraction': 0.85,
       'early_stopping_round': 25,
       "lambda_l1":8.791369324758216,
       "lambda_l2":0.05026876807406415,
       'seed': 1206, 
       'verbosity': -1,
       'num_threads':4}
hp2 = {'objective':'binary',
       'is_unbalance': False,
       'boosting_type': 'gbdt',
       'metric': 'binary_logloss', 
       'eta': 0.01,
       'num_leaves': 243,
       'feature_fraction': 0.85,
       'early_stopping_round': 25,
       "lambda_l1":8.791369324758216,
       "lambda_l2":0.05026876807406415,
       'seed': 1206, 
       'verbosity': -1,
       'num_threads':4}
hp1 = {'objective':'binary',
       'is_unbalance': False,
       'boosting_type': 'gbdt',
       'metric': 'binary_logloss', 
       'eta': 0.01,
       'num_leaves': 243,
       'feature_fraction': 0.85,
       'early_stopping_round': 25,
       "lambda_l1":8.791369324758216,
       "lambda_l2":0.05026876807406415,
       'seed': 1206, 
       'verbosity': -1,
       'num_threads':4}

# %%
# Treinar 100% modelo da classe 5
m5 = lgb.train(params=hp5, num_boost_round=nbr, train_set=ds5_train, valid_sets=[ds5_valid], 
               verbose_eval=True, categorical_feature=feats_cat)
print('Modelo da classe 5 finalizado')
# Out:
# [1]	valid_0's binary_logloss: 0.632241
# Training until validation scores don't improve for 25 rounds
# [2]	valid_0's binary_logloss: 0.628736
# [3]	valid_0's binary_logloss: 0.624749
# [4]	valid_0's binary_logloss: 0.621175
# [5]	valid_0's binary_logloss: 0.617342
# [6]	valid_0's binary_logloss: 0.613589
# [7]	valid_0's binary_logloss: 0.609917
# [8]	valid_0's binary_logloss: 0.606326
# [9]	valid_0's binary_logloss: 0.602816
# [10]	valid_0's binary_logloss: 0.599361
# [11]	valid_0's binary_logloss: 0.595987
# [12]	valid_0's binary_logloss: 0.59268
# [13]	valid_0's binary_logloss: 0.589755
# [14]	valid_0's binary_logloss: 0.586573
# [15]	valid_0's binary_logloss: 0.58345
# [16]	valid_0's binary_logloss: 0.580391
# [17]	valid_0's binary_logloss: 0.577382
# [18]	valid_0's binary_logloss: 0.574433
# [19]	valid_0's binary_logloss: 0.571983
# [20]	valid_0's binary_logloss: 0.56914
# [21]	valid_0's binary_logloss: 0.566662
# [22]	valid_0's binary_logloss: 0.564028
# [23]	valid_0's binary_logloss: 0.561317
# [24]	valid_0's binary_logloss: 0.558787
# [25]	valid_0's binary_logloss: 0.556178
# [26]	valid_0's binary_logloss: 0.553629
# [27]	valid_0's binary_logloss: 0.551108
# [28]	valid_0's binary_logloss: 0.548864
# [29]	valid_0's binary_logloss: 0.546673
# [30]	valid_0's binary_logloss: 0.544266
# [31]	valid_0's binary_logloss: 0.541914
# [32]	valid_0's binary_logloss: 0.539607
# [33]	valid_0's binary_logloss: 0.537327
# [34]	valid_0's binary_logloss: 0.535088
# [35]	valid_0's binary_logloss: 0.533224
# [36]	valid_0's binary_logloss: 0.531271
# [37]	valid_0's binary_logloss: 0.529113
# [38]	valid_0's binary_logloss: 0.526997
# [39]	valid_0's binary_logloss: 0.524931
# [40]	valid_0's binary_logloss: 0.522904
# [41]	valid_0's binary_logloss: 0.520995
# [42]	valid_0's binary_logloss: 0.519036
# [43]	valid_0's binary_logloss: 0.517106
# [44]	valid_0's binary_logloss: 0.515216
# [45]	valid_0's binary_logloss: 0.513514
# [46]	valid_0's binary_logloss: 0.511744
# [47]	valid_0's binary_logloss: 0.509909
# [48]	valid_0's binary_logloss: 0.508122
# [49]	valid_0's binary_logloss: 0.506345
# [50]	valid_0's binary_logloss: 0.504583
# [51]	valid_0's binary_logloss: 0.503015
# [52]	valid_0's binary_logloss: 0.501311
# [53]	valid_0's binary_logloss: 0.499641
# [54]	valid_0's binary_logloss: 0.497983
# [55]	valid_0's binary_logloss: 0.496364
# [56]	valid_0's binary_logloss: 0.494766
# [57]	valid_0's binary_logloss: 0.493312
# [58]	valid_0's binary_logloss: 0.492036
# [59]	valid_0's binary_logloss: 0.490524
# [60]	valid_0's binary_logloss: 0.48901
# [61]	valid_0's binary_logloss: 0.487619
# [62]	valid_0's binary_logloss: 0.48615
# [63]	valid_0's binary_logloss: 0.484715
# [64]	valid_0's binary_logloss: 0.483286
# [65]	valid_0's binary_logloss: 0.481874
# [66]	valid_0's binary_logloss: 0.480497
# [67]	valid_0's binary_logloss: 0.479217
# [68]	valid_0's binary_logloss: 0.477874
# [69]	valid_0's binary_logloss: 0.476551
# [70]	valid_0's binary_logloss: 0.475245
# [71]	valid_0's binary_logloss: 0.47397
# [72]	valid_0's binary_logloss: 0.472708
# [73]	valid_0's binary_logloss: 0.471465
# [74]	valid_0's binary_logloss: 0.470388
# [75]	valid_0's binary_logloss: 0.469145
# [76]	valid_0's binary_logloss: 0.467941
# [77]	valid_0's binary_logloss: 0.466764
# [78]	valid_0's binary_logloss: 0.465619
# [79]	valid_0's binary_logloss: 0.464485
# [80]	valid_0's binary_logloss: 0.46334
# [81]	valid_0's binary_logloss: 0.462232
# [82]	valid_0's binary_logloss: 0.461217
# [83]	valid_0's binary_logloss: 0.4602
# [84]	valid_0's binary_logloss: 0.459118
# [85]	valid_0's binary_logloss: 0.458039
# [86]	valid_0's binary_logloss: 0.457068
# [87]	valid_0's binary_logloss: 0.456025
# [88]	valid_0's binary_logloss: 0.455093
# [89]	valid_0's binary_logloss: 0.454079
# [90]	valid_0's binary_logloss: 0.453156
# [91]	valid_0's binary_logloss: 0.452156
# [92]	valid_0's binary_logloss: 0.451189
# [93]	valid_0's binary_logloss: 0.450235
# [94]	valid_0's binary_logloss: 0.449305
# [95]	valid_0's binary_logloss: 0.448376
# [96]	valid_0's binary_logloss: 0.44746
# [97]	valid_0's binary_logloss: 0.446561
# [98]	valid_0's binary_logloss: 0.445835
# [99]	valid_0's binary_logloss: 0.444947
# [100]	valid_0's binary_logloss: 0.444131
# [101]	valid_0's binary_logloss: 0.443269
# [102]	valid_0's binary_logloss: 0.442425
# [103]	valid_0's binary_logloss: 0.441591
# [104]	valid_0's binary_logloss: 0.440816
# [105]	valid_0's binary_logloss: 0.440001
# [106]	valid_0's binary_logloss: 0.439198
# [107]	valid_0's binary_logloss: 0.438396
# [108]	valid_0's binary_logloss: 0.437595
# [109]	valid_0's binary_logloss: 0.436808
# [110]	valid_0's binary_logloss: 0.436043
# [111]	valid_0's binary_logloss: 0.435279
# [112]	valid_0's binary_logloss: 0.434527
# [113]	valid_0's binary_logloss: 0.433775
# [114]	valid_0's binary_logloss: 0.433099
# [115]	valid_0's binary_logloss: 0.432386
# [116]	valid_0's binary_logloss: 0.431657
# [117]	valid_0's binary_logloss: 0.430962
# [118]	valid_0's binary_logloss: 0.430259
# [119]	valid_0's binary_logloss: 0.429572
# [120]	valid_0's binary_logloss: 0.428884
# [121]	valid_0's binary_logloss: 0.428248
# [122]	valid_0's binary_logloss: 0.427623
# [123]	valid_0's binary_logloss: 0.426952
# [124]	valid_0's binary_logloss: 0.426296
# [125]	valid_0's binary_logloss: 0.425729
# [126]	valid_0's binary_logloss: 0.425098
# [127]	valid_0's binary_logloss: 0.424444
# [128]	valid_0's binary_logloss: 0.423811
# [129]	valid_0's binary_logloss: 0.423251
# [130]	valid_0's binary_logloss: 0.42269
# [131]	valid_0's binary_logloss: 0.422086
# [132]	valid_0's binary_logloss: 0.421461
# [133]	valid_0's binary_logloss: 0.42088
# [134]	valid_0's binary_logloss: 0.420288
# [135]	valid_0's binary_logloss: 0.419717
# [136]	valid_0's binary_logloss: 0.419176
# [137]	valid_0's binary_logloss: 0.41866
# [138]	valid_0's binary_logloss: 0.418103
# [139]	valid_0's binary_logloss: 0.417563
# [140]	valid_0's binary_logloss: 0.417016
# [141]	valid_0's binary_logloss: 0.416488
# [142]	valid_0's binary_logloss: 0.415949
# [143]	valid_0's binary_logloss: 0.415458
# [144]	valid_0's binary_logloss: 0.414939
# [145]	valid_0's binary_logloss: 0.414426
# [146]	valid_0's binary_logloss: 0.413923
# [147]	valid_0's binary_logloss: 0.413429
# [148]	valid_0's binary_logloss: 0.412945
# [149]	valid_0's binary_logloss: 0.412461
# [150]	valid_0's binary_logloss: 0.41199
# [151]	valid_0's binary_logloss: 0.411523
# [152]	valid_0's binary_logloss: 0.41105
# [153]	valid_0's binary_logloss: 0.410578
# [154]	valid_0's binary_logloss: 0.410133
# [155]	valid_0's binary_logloss: 0.409663
# [156]	valid_0's binary_logloss: 0.409202
# [157]	valid_0's binary_logloss: 0.408746
# [158]	valid_0's binary_logloss: 0.40831
# [159]	valid_0's binary_logloss: 0.407876
# [160]	valid_0's binary_logloss: 0.407427
# [161]	valid_0's binary_logloss: 0.407006
# [162]	valid_0's binary_logloss: 0.406605
# [163]	valid_0's binary_logloss: 0.406224
# [164]	valid_0's binary_logloss: 0.405795
# [165]	valid_0's binary_logloss: 0.405382
# [166]	valid_0's binary_logloss: 0.40498
# [167]	valid_0's binary_logloss: 0.404567
# [168]	valid_0's binary_logloss: 0.404164
# [169]	valid_0's binary_logloss: 0.403765
# [170]	valid_0's binary_logloss: 0.403373
# [171]	valid_0's binary_logloss: 0.402994
# [172]	valid_0's binary_logloss: 0.402615
# [173]	valid_0's binary_logloss: 0.402236
# [174]	valid_0's binary_logloss: 0.401868
# [175]	valid_0's binary_logloss: 0.401505
# [176]	valid_0's binary_logloss: 0.401139
# [177]	valid_0's binary_logloss: 0.400786
# [178]	valid_0's binary_logloss: 0.400424
# [179]	valid_0's binary_logloss: 0.400064
# [180]	valid_0's binary_logloss: 0.399721
# [181]	valid_0's binary_logloss: 0.399431
# [182]	valid_0's binary_logloss: 0.399101
# [183]	valid_0's binary_logloss: 0.398758
# [184]	valid_0's binary_logloss: 0.398411
# [185]	valid_0's binary_logloss: 0.398092
# [186]	valid_0's binary_logloss: 0.397817
# [187]	valid_0's binary_logloss: 0.397496
# [188]	valid_0's binary_logloss: 0.397158
# [189]	valid_0's binary_logloss: 0.396829
# [190]	valid_0's binary_logloss: 0.396508
# [191]	valid_0's binary_logloss: 0.396194
# [192]	valid_0's binary_logloss: 0.395942
# [193]	valid_0's binary_logloss: 0.39563
# [194]	valid_0's binary_logloss: 0.395326
# [195]	valid_0's binary_logloss: 0.395068
# [196]	valid_0's binary_logloss: 0.394811
# [197]	valid_0's binary_logloss: 0.394509
# [198]	valid_0's binary_logloss: 0.39421
# [199]	valid_0's binary_logloss: 0.393926
# [200]	valid_0's binary_logloss: 0.393628
# [201]	valid_0's binary_logloss: 0.393351
# [202]	valid_0's binary_logloss: 0.393072
# [203]	valid_0's binary_logloss: 0.392786
# [204]	valid_0's binary_logloss: 0.392504
# [205]	valid_0's binary_logloss: 0.392236
# [206]	valid_0's binary_logloss: 0.391997
# [207]	valid_0's binary_logloss: 0.391729
# [208]	valid_0's binary_logloss: 0.391454
# [209]	valid_0's binary_logloss: 0.391208
# [210]	valid_0's binary_logloss: 0.390948
# [211]	valid_0's binary_logloss: 0.390688
# [212]	valid_0's binary_logloss: 0.390431
# [213]	valid_0's binary_logloss: 0.390177
# [214]	valid_0's binary_logloss: 0.389928
# [215]	valid_0's binary_logloss: 0.389682
# [216]	valid_0's binary_logloss: 0.38944
# [217]	valid_0's binary_logloss: 0.389194
# [218]	valid_0's binary_logloss: 0.388952
# [219]	valid_0's binary_logloss: 0.3887
# [220]	valid_0's binary_logloss: 0.388468
# [221]	valid_0's binary_logloss: 0.388236
# [222]	valid_0's binary_logloss: 0.38801
# [223]	valid_0's binary_logloss: 0.387777
# [224]	valid_0's binary_logloss: 0.387552
# [225]	valid_0's binary_logloss: 0.387327
# [226]	valid_0's binary_logloss: 0.387106
# [227]	valid_0's binary_logloss: 0.386874
# [228]	valid_0's binary_logloss: 0.386645
# [229]	valid_0's binary_logloss: 0.386429
# [230]	valid_0's binary_logloss: 0.386186
# [231]	valid_0's binary_logloss: 0.38597
# [232]	valid_0's binary_logloss: 0.385757
# [233]	valid_0's binary_logloss: 0.385551
# [234]	valid_0's binary_logloss: 0.385347
# [235]	valid_0's binary_logloss: 0.385141
# [236]	valid_0's binary_logloss: 0.384967
# [237]	valid_0's binary_logloss: 0.384782
# [238]	valid_0's binary_logloss: 0.384574
# [239]	valid_0's binary_logloss: 0.384366
# [240]	valid_0's binary_logloss: 0.384168
# [241]	valid_0's binary_logloss: 0.383976
# [242]	valid_0's binary_logloss: 0.38379
# [243]	valid_0's binary_logloss: 0.383594
# [244]	valid_0's binary_logloss: 0.383395
# [245]	valid_0's binary_logloss: 0.383192
# [246]	valid_0's binary_logloss: 0.383032
# [247]	valid_0's binary_logloss: 0.382828
# [248]	valid_0's binary_logloss: 0.382644
# [249]	valid_0's binary_logloss: 0.382459
# [250]	valid_0's binary_logloss: 0.382276
# [251]	valid_0's binary_logloss: 0.382088
# [252]	valid_0's binary_logloss: 0.381916
# [253]	valid_0's binary_logloss: 0.381729
# [254]	valid_0's binary_logloss: 0.381562
# [255]	valid_0's binary_logloss: 0.381367
# [256]	valid_0's binary_logloss: 0.381196
# [257]	valid_0's binary_logloss: 0.381001
# [258]	valid_0's binary_logloss: 0.380835
# [259]	valid_0's binary_logloss: 0.380669
# [260]	valid_0's binary_logloss: 0.380507
# [261]	valid_0's binary_logloss: 0.380336
# [262]	valid_0's binary_logloss: 0.380172
# [263]	valid_0's binary_logloss: 0.380003
# [264]	valid_0's binary_logloss: 0.379883
# [265]	valid_0's binary_logloss: 0.379741
# [266]	valid_0's binary_logloss: 0.379548
# [267]	valid_0's binary_logloss: 0.379383
# [268]	valid_0's binary_logloss: 0.379214
# [269]	valid_0's binary_logloss: 0.379027
# [270]	valid_0's binary_logloss: 0.37887
# [271]	valid_0's binary_logloss: 0.378698
# [272]	valid_0's binary_logloss: 0.378549
# [273]	valid_0's binary_logloss: 0.378399
# [274]	valid_0's binary_logloss: 0.378233
# [275]	valid_0's binary_logloss: 0.378064
# [276]	valid_0's binary_logloss: 0.377905
# [277]	valid_0's binary_logloss: 0.377767
# [278]	valid_0's binary_logloss: 0.377642
# [279]	valid_0's binary_logloss: 0.377481
# [280]	valid_0's binary_logloss: 0.377335
# [281]	valid_0's binary_logloss: 0.377203
# [282]	valid_0's binary_logloss: 0.377062
# [283]	valid_0's binary_logloss: 0.376912
# [284]	valid_0's binary_logloss: 0.376774
# [285]	valid_0's binary_logloss: 0.376628
# [286]	valid_0's binary_logloss: 0.376517
# [287]	valid_0's binary_logloss: 0.37635
# [288]	valid_0's binary_logloss: 0.376207
# [289]	valid_0's binary_logloss: 0.376058
# [290]	valid_0's binary_logloss: 0.375918
# [291]	valid_0's binary_logloss: 0.375807
# [292]	valid_0's binary_logloss: 0.375676
# [293]	valid_0's binary_logloss: 0.375547
# [294]	valid_0's binary_logloss: 0.375393
# [295]	valid_0's binary_logloss: 0.37525
# [296]	valid_0's binary_logloss: 0.375111
# [297]	valid_0's binary_logloss: 0.375001
# [298]	valid_0's binary_logloss: 0.374872
# [299]	valid_0's binary_logloss: 0.374742
# [300]	valid_0's binary_logloss: 0.374595
# [301]	valid_0's binary_logloss: 0.374466
# [302]	valid_0's binary_logloss: 0.374333
# [303]	valid_0's binary_logloss: 0.374196
# [304]	valid_0's binary_logloss: 0.374076
# [305]	valid_0's binary_logloss: 0.373936
# [306]	valid_0's binary_logloss: 0.373813
# [307]	valid_0's binary_logloss: 0.373692
# [308]	valid_0's binary_logloss: 0.373562
# [309]	valid_0's binary_logloss: 0.373416
# [310]	valid_0's binary_logloss: 0.373298
# [311]	valid_0's binary_logloss: 0.37318
# [312]	valid_0's binary_logloss: 0.373054
# [313]	valid_0's binary_logloss: 0.372921
# [314]	valid_0's binary_logloss: 0.372809
# [315]	valid_0's binary_logloss: 0.372717
# [316]	valid_0's binary_logloss: 0.372593
# [317]	valid_0's binary_logloss: 0.372479
# [318]	valid_0's binary_logloss: 0.372365
# [319]	valid_0's binary_logloss: 0.372227
# [320]	valid_0's binary_logloss: 0.372136
# [321]	valid_0's binary_logloss: 0.372049
# [322]	valid_0's binary_logloss: 0.371934
# [323]	valid_0's binary_logloss: 0.371805
# [324]	valid_0's binary_logloss: 0.371717
# [325]	valid_0's binary_logloss: 0.371612
# [326]	valid_0's binary_logloss: 0.371488
# [327]	valid_0's binary_logloss: 0.37136
# [328]	valid_0's binary_logloss: 0.371254
# [329]	valid_0's binary_logloss: 0.371167
# [330]	valid_0's binary_logloss: 0.37106
# [331]	valid_0's binary_logloss: 0.370956
# [332]	valid_0's binary_logloss: 0.370848
# [333]	valid_0's binary_logloss: 0.370724
# [334]	valid_0's binary_logloss: 0.37065
# [335]	valid_0's binary_logloss: 0.370527
# [336]	valid_0's binary_logloss: 0.370433
# [337]	valid_0's binary_logloss: 0.370349
# [338]	valid_0's binary_logloss: 0.370251
# [339]	valid_0's binary_logloss: 0.370148
# [340]	valid_0's binary_logloss: 0.370049
# [341]	valid_0's binary_logloss: 0.369931
# [342]	valid_0's binary_logloss: 0.369809
# [343]	valid_0's binary_logloss: 0.369715
# [344]	valid_0's binary_logloss: 0.369613
# [345]	valid_0's binary_logloss: 0.369513
# [346]	valid_0's binary_logloss: 0.369423
# [347]	valid_0's binary_logloss: 0.369334
# [348]	valid_0's binary_logloss: 0.369247
# [349]	valid_0's binary_logloss: 0.369128
# [350]	valid_0's binary_logloss: 0.36904
# [351]	valid_0's binary_logloss: 0.368952
# [352]	valid_0's binary_logloss: 0.368856
# [353]	valid_0's binary_logloss: 0.368763
# [354]	valid_0's binary_logloss: 0.36868
# [355]	valid_0's binary_logloss: 0.36858
# [356]	valid_0's binary_logloss: 0.368478
# [357]	valid_0's binary_logloss: 0.368382
# [358]	valid_0's binary_logloss: 0.368298
# [359]	valid_0's binary_logloss: 0.3682
# [360]	valid_0's binary_logloss: 0.368115
# [361]	valid_0's binary_logloss: 0.36804
# [362]	valid_0's binary_logloss: 0.367957
# [363]	valid_0's binary_logloss: 0.367863
# [364]	valid_0's binary_logloss: 0.367767
# [365]	valid_0's binary_logloss: 0.367678
# [366]	valid_0's binary_logloss: 0.367602
# [367]	valid_0's binary_logloss: 0.367528
# [368]	valid_0's binary_logloss: 0.367452
# [369]	valid_0's binary_logloss: 0.367356
# [370]	valid_0's binary_logloss: 0.367288
# [371]	valid_0's binary_logloss: 0.367202
# [372]	valid_0's binary_logloss: 0.367121
# [373]	valid_0's binary_logloss: 0.367052
# [374]	valid_0's binary_logloss: 0.366978
# [375]	valid_0's binary_logloss: 0.366905
# [376]	valid_0's binary_logloss: 0.366839
# [377]	valid_0's binary_logloss: 0.366773
# [378]	valid_0's binary_logloss: 0.36669
# [379]	valid_0's binary_logloss: 0.366629
# [380]	valid_0's binary_logloss: 0.366549
# [381]	valid_0's binary_logloss: 0.366474
# [382]	valid_0's binary_logloss: 0.366388
# [383]	valid_0's binary_logloss: 0.366322
# [384]	valid_0's binary_logloss: 0.366244
# [385]	valid_0's binary_logloss: 0.366163
# [386]	valid_0's binary_logloss: 0.366082
# [387]	valid_0's binary_logloss: 0.365997
# [388]	valid_0's binary_logloss: 0.365917
# [389]	valid_0's binary_logloss: 0.365834
# [390]	valid_0's binary_logloss: 0.365765
# [391]	valid_0's binary_logloss: 0.365687
# [392]	valid_0's binary_logloss: 0.365614
# [393]	valid_0's binary_logloss: 0.365533
# [394]	valid_0's binary_logloss: 0.365451
# [395]	valid_0's binary_logloss: 0.365373
# [396]	valid_0's binary_logloss: 0.365302
# [397]	valid_0's binary_logloss: 0.365217
# [398]	valid_0's binary_logloss: 0.36514
# [399]	valid_0's binary_logloss: 0.365082
# [400]	valid_0's binary_logloss: 0.364999
# [401]	valid_0's binary_logloss: 0.364927
# [402]	valid_0's binary_logloss: 0.364848
# [403]	valid_0's binary_logloss: 0.36477
# [404]	valid_0's binary_logloss: 0.364694
# [405]	valid_0's binary_logloss: 0.364632
# [406]	valid_0's binary_logloss: 0.364557
# [407]	valid_0's binary_logloss: 0.364477
# [408]	valid_0's binary_logloss: 0.364418
# [409]	valid_0's binary_logloss: 0.364349
# [410]	valid_0's binary_logloss: 0.36429
# [411]	valid_0's binary_logloss: 0.36421
# [412]	valid_0's binary_logloss: 0.364136
# [413]	valid_0's binary_logloss: 0.364062
# [414]	valid_0's binary_logloss: 0.363996
# [415]	valid_0's binary_logloss: 0.363905
# [416]	valid_0's binary_logloss: 0.363823
# [417]	valid_0's binary_logloss: 0.363754
# [418]	valid_0's binary_logloss: 0.363667
# [419]	valid_0's binary_logloss: 0.363596
# [420]	valid_0's binary_logloss: 0.36352
# [421]	valid_0's binary_logloss: 0.363464
# [422]	valid_0's binary_logloss: 0.363391
# [423]	valid_0's binary_logloss: 0.36332
# [424]	valid_0's binary_logloss: 0.363244
# [425]	valid_0's binary_logloss: 0.363178
# [426]	valid_0's binary_logloss: 0.363119
# [427]	valid_0's binary_logloss: 0.363064
# [428]	valid_0's binary_logloss: 0.36302
# [429]	valid_0's binary_logloss: 0.362947
# [430]	valid_0's binary_logloss: 0.362868
# [431]	valid_0's binary_logloss: 0.362795
# [432]	valid_0's binary_logloss: 0.362713
# [433]	valid_0's binary_logloss: 0.362636
# [434]	valid_0's binary_logloss: 0.362555
# [435]	valid_0's binary_logloss: 0.362483
# [436]	valid_0's binary_logloss: 0.362426
# [437]	valid_0's binary_logloss: 0.362336
# [438]	valid_0's binary_logloss: 0.362261
# [439]	valid_0's binary_logloss: 0.362212
# [440]	valid_0's binary_logloss: 0.362145
# [441]	valid_0's binary_logloss: 0.362099
# [442]	valid_0's binary_logloss: 0.362026
# [443]	valid_0's binary_logloss: 0.361969
# [444]	valid_0's binary_logloss: 0.361896
# [445]	valid_0's binary_logloss: 0.361841
# [446]	valid_0's binary_logloss: 0.361775
# [447]	valid_0's binary_logloss: 0.361725
# [448]	valid_0's binary_logloss: 0.361643
# [449]	valid_0's binary_logloss: 0.361581
# [450]	valid_0's binary_logloss: 0.361504
# [451]	valid_0's binary_logloss: 0.361447
# [452]	valid_0's binary_logloss: 0.361381
# [453]	valid_0's binary_logloss: 0.361335
# [454]	valid_0's binary_logloss: 0.361288
# [455]	valid_0's binary_logloss: 0.361241
# [456]	valid_0's binary_logloss: 0.361179
# [457]	valid_0's binary_logloss: 0.36111
# [458]	valid_0's binary_logloss: 0.361049
# [459]	valid_0's binary_logloss: 0.360998
# [460]	valid_0's binary_logloss: 0.360938
# [461]	valid_0's binary_logloss: 0.360873
# [462]	valid_0's binary_logloss: 0.360829
# [463]	valid_0's binary_logloss: 0.36077
# [464]	valid_0's binary_logloss: 0.360706
# [465]	valid_0's binary_logloss: 0.360632
# [466]	valid_0's binary_logloss: 0.360579
# [467]	valid_0's binary_logloss: 0.360521
# [468]	valid_0's binary_logloss: 0.360474
# [469]	valid_0's binary_logloss: 0.36043
# [470]	valid_0's binary_logloss: 0.360341
# [471]	valid_0's binary_logloss: 0.360276
# [472]	valid_0's binary_logloss: 0.36022
# [473]	valid_0's binary_logloss: 0.360157
# [474]	valid_0's binary_logloss: 0.36012
# [475]	valid_0's binary_logloss: 0.360068
# [476]	valid_0's binary_logloss: 0.360016
# [477]	valid_0's binary_logloss: 0.359937
# [478]	valid_0's binary_logloss: 0.359878
# [479]	valid_0's binary_logloss: 0.359825
# [480]	valid_0's binary_logloss: 0.359784
# [481]	valid_0's binary_logloss: 0.359727
# [482]	valid_0's binary_logloss: 0.359675
# [483]	valid_0's binary_logloss: 0.359622
# [484]	valid_0's binary_logloss: 0.359585
# [485]	valid_0's binary_logloss: 0.359528
# [486]	valid_0's binary_logloss: 0.359479
# [487]	valid_0's binary_logloss: 0.359422
# [488]	valid_0's binary_logloss: 0.359376
# [489]	valid_0's binary_logloss: 0.359329
# [490]	valid_0's binary_logloss: 0.359279
# [491]	valid_0's binary_logloss: 0.359228
# [492]	valid_0's binary_logloss: 0.359183
# [493]	valid_0's binary_logloss: 0.359106
# [494]	valid_0's binary_logloss: 0.359063
# [495]	valid_0's binary_logloss: 0.359015
# [496]	valid_0's binary_logloss: 0.358959
# [497]	valid_0's binary_logloss: 0.358916
# [498]	valid_0's binary_logloss: 0.35886
# [499]	valid_0's binary_logloss: 0.358794
# [500]	valid_0's binary_logloss: 0.358741
# [501]	valid_0's binary_logloss: 0.358695
# [502]	valid_0's binary_logloss: 0.358653
# [503]	valid_0's binary_logloss: 0.358604
# [504]	valid_0's binary_logloss: 0.358558
# [505]	valid_0's binary_logloss: 0.35848
# [506]	valid_0's binary_logloss: 0.358418
# [507]	valid_0's binary_logloss: 0.358378
# [508]	valid_0's binary_logloss: 0.358318
# [509]	valid_0's binary_logloss: 0.358278
# [510]	valid_0's binary_logloss: 0.358219
# [511]	valid_0's binary_logloss: 0.358171
# [512]	valid_0's binary_logloss: 0.358129
# [513]	valid_0's binary_logloss: 0.358088
# [514]	valid_0's binary_logloss: 0.35805
# [515]	valid_0's binary_logloss: 0.358004
# [516]	valid_0's binary_logloss: 0.357962
# [517]	valid_0's binary_logloss: 0.357898
# [518]	valid_0's binary_logloss: 0.357863
# [519]	valid_0's binary_logloss: 0.35782
# [520]	valid_0's binary_logloss: 0.357765
# [521]	valid_0's binary_logloss: 0.357726
# [522]	valid_0's binary_logloss: 0.357675
# [523]	valid_0's binary_logloss: 0.357624
# [524]	valid_0's binary_logloss: 0.357591
# [525]	valid_0's binary_logloss: 0.357552
# [526]	valid_0's binary_logloss: 0.357519
# [527]	valid_0's binary_logloss: 0.357474
# [528]	valid_0's binary_logloss: 0.357431
# [529]	valid_0's binary_logloss: 0.357392
# [530]	valid_0's binary_logloss: 0.357349
# [531]	valid_0's binary_logloss: 0.357309
# [532]	valid_0's binary_logloss: 0.357266
# [533]	valid_0's binary_logloss: 0.357217
# [534]	valid_0's binary_logloss: 0.357188
# [535]	valid_0's binary_logloss: 0.357147
# [536]	valid_0's binary_logloss: 0.357109
# [537]	valid_0's binary_logloss: 0.357067
# [538]	valid_0's binary_logloss: 0.357026
# [539]	valid_0's binary_logloss: 0.356983
# [540]	valid_0's binary_logloss: 0.356945
# [541]	valid_0's binary_logloss: 0.356917
# [542]	valid_0's binary_logloss: 0.356872
# [543]	valid_0's binary_logloss: 0.356804
# [544]	valid_0's binary_logloss: 0.356772
# [545]	valid_0's binary_logloss: 0.356738
# [546]	valid_0's binary_logloss: 0.35669
# [547]	valid_0's binary_logloss: 0.356644
# [548]	valid_0's binary_logloss: 0.356604
# [549]	valid_0's binary_logloss: 0.356568
# [550]	valid_0's binary_logloss: 0.356536
# [551]	valid_0's binary_logloss: 0.356501
# [552]	valid_0's binary_logloss: 0.356453
# [553]	valid_0's binary_logloss: 0.356411
# [554]	valid_0's binary_logloss: 0.356376
# [555]	valid_0's binary_logloss: 0.35634
# [556]	valid_0's binary_logloss: 0.356282
# [557]	valid_0's binary_logloss: 0.356244
# [558]	valid_0's binary_logloss: 0.356208
# [559]	valid_0's binary_logloss: 0.356171
# [560]	valid_0's binary_logloss: 0.356127
# [561]	valid_0's binary_logloss: 0.356086
# [562]	valid_0's binary_logloss: 0.356051
# [563]	valid_0's binary_logloss: 0.356014
# [564]	valid_0's binary_logloss: 0.355981
# [565]	valid_0's binary_logloss: 0.355926
# [566]	valid_0's binary_logloss: 0.355889
# [567]	valid_0's binary_logloss: 0.355846
# [568]	valid_0's binary_logloss: 0.355813
# [569]	valid_0's binary_logloss: 0.35578
# [570]	valid_0's binary_logloss: 0.355749
# [571]	valid_0's binary_logloss: 0.355717
# [572]	valid_0's binary_logloss: 0.355665
# [573]	valid_0's binary_logloss: 0.355632
# [574]	valid_0's binary_logloss: 0.355595
# [575]	valid_0's binary_logloss: 0.355559
# [576]	valid_0's binary_logloss: 0.355525
# [577]	valid_0's binary_logloss: 0.355497
# [578]	valid_0's binary_logloss: 0.355454
# [579]	valid_0's binary_logloss: 0.355408
# [580]	valid_0's binary_logloss: 0.355369
# [581]	valid_0's binary_logloss: 0.35533
# [582]	valid_0's binary_logloss: 0.355299
# [583]	valid_0's binary_logloss: 0.355274
# [584]	valid_0's binary_logloss: 0.35523
# [585]	valid_0's binary_logloss: 0.355194
# [586]	valid_0's binary_logloss: 0.355159
# [587]	valid_0's binary_logloss: 0.355131
# [588]	valid_0's binary_logloss: 0.355092
# [589]	valid_0's binary_logloss: 0.355064
# [590]	valid_0's binary_logloss: 0.355031
# [591]	valid_0's binary_logloss: 0.355
# [592]	valid_0's binary_logloss: 0.354961
# [593]	valid_0's binary_logloss: 0.354916
# [594]	valid_0's binary_logloss: 0.354891
# [595]	valid_0's binary_logloss: 0.354859
# [596]	valid_0's binary_logloss: 0.354829
# [597]	valid_0's binary_logloss: 0.354787
# [598]	valid_0's binary_logloss: 0.354746
# [599]	valid_0's binary_logloss: 0.354724
# [600]	valid_0's binary_logloss: 0.354695
# [601]	valid_0's binary_logloss: 0.354664
# [602]	valid_0's binary_logloss: 0.354634
# [603]	valid_0's binary_logloss: 0.354593
# [604]	valid_0's binary_logloss: 0.354565
# [605]	valid_0's binary_logloss: 0.354538
# [606]	valid_0's binary_logloss: 0.354507
# [607]	valid_0's binary_logloss: 0.354485
# [608]	valid_0's binary_logloss: 0.354448
# [609]	valid_0's binary_logloss: 0.354419
# [610]	valid_0's binary_logloss: 0.354358
# [611]	valid_0's binary_logloss: 0.354335
# [612]	valid_0's binary_logloss: 0.354306
# [613]	valid_0's binary_logloss: 0.354275
# [614]	valid_0's binary_logloss: 0.354245
# [615]	valid_0's binary_logloss: 0.354212
# [616]	valid_0's binary_logloss: 0.354187
# [617]	valid_0's binary_logloss: 0.354161
# [618]	valid_0's binary_logloss: 0.354132
# [619]	valid_0's binary_logloss: 0.354114
# [620]	valid_0's binary_logloss: 0.354087
# [621]	valid_0's binary_logloss: 0.354052
# [622]	valid_0's binary_logloss: 0.354034
# [623]	valid_0's binary_logloss: 0.354009
# [624]	valid_0's binary_logloss: 0.353982
# [625]	valid_0's binary_logloss: 0.353946
# [626]	valid_0's binary_logloss: 0.353905
# [627]	valid_0's binary_logloss: 0.353879
# [628]	valid_0's binary_logloss: 0.353854
# [629]	valid_0's binary_logloss: 0.353824
# [630]	valid_0's binary_logloss: 0.353799
# [631]	valid_0's binary_logloss: 0.353783
# [632]	valid_0's binary_logloss: 0.353767
# [633]	valid_0's binary_logloss: 0.353746
# [634]	valid_0's binary_logloss: 0.353684
# [635]	valid_0's binary_logloss: 0.353652
# [636]	valid_0's binary_logloss: 0.353632
# [637]	valid_0's binary_logloss: 0.353609
# [638]	valid_0's binary_logloss: 0.353571
# [639]	valid_0's binary_logloss: 0.353531
# [640]	valid_0's binary_logloss: 0.353506
# [641]	valid_0's binary_logloss: 0.353478
# [642]	valid_0's binary_logloss: 0.353448
# [643]	valid_0's binary_logloss: 0.353421
# [644]	valid_0's binary_logloss: 0.353393
# [645]	valid_0's binary_logloss: 0.353364
# [646]	valid_0's binary_logloss: 0.35334
# [647]	valid_0's binary_logloss: 0.353304
# [648]	valid_0's binary_logloss: 0.35327
# [649]	valid_0's binary_logloss: 0.353232
# [650]	valid_0's binary_logloss: 0.353197
# [651]	valid_0's binary_logloss: 0.35317
# [652]	valid_0's binary_logloss: 0.353141
# [653]	valid_0's binary_logloss: 0.353122
# [654]	valid_0's binary_logloss: 0.353097
# [655]	valid_0's binary_logloss: 0.353077
# [656]	valid_0's binary_logloss: 0.353049
# [657]	valid_0's binary_logloss: 0.353015
# [658]	valid_0's binary_logloss: 0.352995
# [659]	valid_0's binary_logloss: 0.352965
# [660]	valid_0's binary_logloss: 0.352933
# [661]	valid_0's binary_logloss: 0.352911
# [662]	valid_0's binary_logloss: 0.352897
# [663]	valid_0's binary_logloss: 0.352864
# [664]	valid_0's binary_logloss: 0.352852
# [665]	valid_0's binary_logloss: 0.352834
# [666]	valid_0's binary_logloss: 0.352813
# [667]	valid_0's binary_logloss: 0.352792
# [668]	valid_0's binary_logloss: 0.352761
# [669]	valid_0's binary_logloss: 0.352744
# [670]	valid_0's binary_logloss: 0.352724
# [671]	valid_0's binary_logloss: 0.352699
# [672]	valid_0's binary_logloss: 0.352677
# [673]	valid_0's binary_logloss: 0.352661
# [674]	valid_0's binary_logloss: 0.352637
# [675]	valid_0's binary_logloss: 0.3526
# [676]	valid_0's binary_logloss: 0.35258
# [677]	valid_0's binary_logloss: 0.35255
# [678]	valid_0's binary_logloss: 0.352529
# [679]	valid_0's binary_logloss: 0.352495
# [680]	valid_0's binary_logloss: 0.352465
# [681]	valid_0's binary_logloss: 0.352453
# [682]	valid_0's binary_logloss: 0.352422
# [683]	valid_0's binary_logloss: 0.3524
# [684]	valid_0's binary_logloss: 0.352388
# [685]	valid_0's binary_logloss: 0.352373
# [686]	valid_0's binary_logloss: 0.352347
# [687]	valid_0's binary_logloss: 0.352306
# [688]	valid_0's binary_logloss: 0.352285
# [689]	valid_0's binary_logloss: 0.35226
# [690]	valid_0's binary_logloss: 0.352247
# [691]	valid_0's binary_logloss: 0.352221
# [692]	valid_0's binary_logloss: 0.352199
# [693]	valid_0's binary_logloss: 0.352178
# [694]	valid_0's binary_logloss: 0.352147
# [695]	valid_0's binary_logloss: 0.352129
# [696]	valid_0's binary_logloss: 0.352105
# [697]	valid_0's binary_logloss: 0.352079
# [698]	valid_0's binary_logloss: 0.352053
# [699]	valid_0's binary_logloss: 0.352027
# [700]	valid_0's binary_logloss: 0.352009
# [701]	valid_0's binary_logloss: 0.351982
# [702]	valid_0's binary_logloss: 0.351956
# [703]	valid_0's binary_logloss: 0.351934
# [704]	valid_0's binary_logloss: 0.351906
# [705]	valid_0's binary_logloss: 0.351873
# [706]	valid_0's binary_logloss: 0.35184
# [707]	valid_0's binary_logloss: 0.3518
# [708]	valid_0's binary_logloss: 0.351767
# [709]	valid_0's binary_logloss: 0.351739
# [710]	valid_0's binary_logloss: 0.351715
# [711]	valid_0's binary_logloss: 0.351684
# [712]	valid_0's binary_logloss: 0.351669
# [713]	valid_0's binary_logloss: 0.351652
# [714]	valid_0's binary_logloss: 0.351639
# [715]	valid_0's binary_logloss: 0.351612
# [716]	valid_0's binary_logloss: 0.351595
# [717]	valid_0's binary_logloss: 0.351568
# [718]	valid_0's binary_logloss: 0.351548
# [719]	valid_0's binary_logloss: 0.351522
# [720]	valid_0's binary_logloss: 0.351501
# [721]	valid_0's binary_logloss: 0.351473
# [722]	valid_0's binary_logloss: 0.351442
# [723]	valid_0's binary_logloss: 0.351423
# [724]	valid_0's binary_logloss: 0.351394
# [725]	valid_0's binary_logloss: 0.351362
# [726]	valid_0's binary_logloss: 0.35134
# [727]	valid_0's binary_logloss: 0.351317
# [728]	valid_0's binary_logloss: 0.351283
# [729]	valid_0's binary_logloss: 0.351253
# [730]	valid_0's binary_logloss: 0.351235
# [731]	valid_0's binary_logloss: 0.351221
# [732]	valid_0's binary_logloss: 0.351207
# [733]	valid_0's binary_logloss: 0.351186
# [734]	valid_0's binary_logloss: 0.35117
# [735]	valid_0's binary_logloss: 0.351137
# [736]	valid_0's binary_logloss: 0.351115
# [737]	valid_0's binary_logloss: 0.351102
# [738]	valid_0's binary_logloss: 0.351069
# [739]	valid_0's binary_logloss: 0.351037
# [740]	valid_0's binary_logloss: 0.351004
# [741]	valid_0's binary_logloss: 0.350988
# [742]	valid_0's binary_logloss: 0.350967
# [743]	valid_0's binary_logloss: 0.350957
# [744]	valid_0's binary_logloss: 0.350938
# [745]	valid_0's binary_logloss: 0.350922
# [746]	valid_0's binary_logloss: 0.350891
# [747]	valid_0's binary_logloss: 0.350865
# [748]	valid_0's binary_logloss: 0.350848
# [749]	valid_0's binary_logloss: 0.350823
# [750]	valid_0's binary_logloss: 0.350806
# [751]	valid_0's binary_logloss: 0.350785
# [752]	valid_0's binary_logloss: 0.350767
# [753]	valid_0's binary_logloss: 0.350749
# [754]	valid_0's binary_logloss: 0.350737
# [755]	valid_0's binary_logloss: 0.350709
# [756]	valid_0's binary_logloss: 0.350687
# [757]	valid_0's binary_logloss: 0.350671
# [758]	valid_0's binary_logloss: 0.350639
# [759]	valid_0's binary_logloss: 0.350616
# [760]	valid_0's binary_logloss: 0.350601
# [761]	valid_0's binary_logloss: 0.350586
# [762]	valid_0's binary_logloss: 0.350561
# [763]	valid_0's binary_logloss: 0.350538
# [764]	valid_0's binary_logloss: 0.350525
# [765]	valid_0's binary_logloss: 0.350509
# [766]	valid_0's binary_logloss: 0.350494
# [767]	valid_0's binary_logloss: 0.350471
# [768]	valid_0's binary_logloss: 0.350444
# [769]	valid_0's binary_logloss: 0.350424
# [770]	valid_0's binary_logloss: 0.350388
# [771]	valid_0's binary_logloss: 0.350355
# [772]	valid_0's binary_logloss: 0.350344
# [773]	valid_0's binary_logloss: 0.350316
# [774]	valid_0's binary_logloss: 0.350297
# [775]	valid_0's binary_logloss: 0.350284
# [776]	valid_0's binary_logloss: 0.350266
# [777]	valid_0's binary_logloss: 0.350247
# [778]	valid_0's binary_logloss: 0.350224
# [779]	valid_0's binary_logloss: 0.350192
# [780]	valid_0's binary_logloss: 0.350175
# [781]	valid_0's binary_logloss: 0.350169
# [782]	valid_0's binary_logloss: 0.350137
# [783]	valid_0's binary_logloss: 0.350115
# [784]	valid_0's binary_logloss: 0.35011
# [785]	valid_0's binary_logloss: 0.350085
# [786]	valid_0's binary_logloss: 0.35006
# [787]	valid_0's binary_logloss: 0.350047
# [788]	valid_0's binary_logloss: 0.350033
# [789]	valid_0's binary_logloss: 0.350013
# [790]	valid_0's binary_logloss: 0.349979
# [791]	valid_0's binary_logloss: 0.349966
# [792]	valid_0's binary_logloss: 0.349953
# [793]	valid_0's binary_logloss: 0.349939
# [794]	valid_0's binary_logloss: 0.349924
# [795]	valid_0's binary_logloss: 0.349903
# [796]	valid_0's binary_logloss: 0.349891
# [797]	valid_0's binary_logloss: 0.349856
# [798]	valid_0's binary_logloss: 0.349847
# [799]	valid_0's binary_logloss: 0.34983
# [800]	valid_0's binary_logloss: 0.349791
# [801]	valid_0's binary_logloss: 0.349761
# [802]	valid_0's binary_logloss: 0.349749
# [803]	valid_0's binary_logloss: 0.349734
# [804]	valid_0's binary_logloss: 0.349715
# [805]	valid_0's binary_logloss: 0.3497
# [806]	valid_0's binary_logloss: 0.349678
# [807]	valid_0's binary_logloss: 0.349657
# [808]	valid_0's binary_logloss: 0.349644
# [809]	valid_0's binary_logloss: 0.349615
# [810]	valid_0's binary_logloss: 0.349595
# [811]	valid_0's binary_logloss: 0.349575
# [812]	valid_0's binary_logloss: 0.349544
# [813]	valid_0's binary_logloss: 0.34954
# [814]	valid_0's binary_logloss: 0.349531
# [815]	valid_0's binary_logloss: 0.349514
# [816]	valid_0's binary_logloss: 0.349481
# [817]	valid_0's binary_logloss: 0.349471
# [818]	valid_0's binary_logloss: 0.349439
# [819]	valid_0's binary_logloss: 0.349427
# [820]	valid_0's binary_logloss: 0.349409
# [821]	valid_0's binary_logloss: 0.349384
# [822]	valid_0's binary_logloss: 0.349374
# [823]	valid_0's binary_logloss: 0.349338
# [824]	valid_0's binary_logloss: 0.349333
# [825]	valid_0's binary_logloss: 0.349315
# [826]	valid_0's binary_logloss: 0.349287
# [827]	valid_0's binary_logloss: 0.349266
# [828]	valid_0's binary_logloss: 0.349241
# [829]	valid_0's binary_logloss: 0.349214
# [830]	valid_0's binary_logloss: 0.349202
# [831]	valid_0's binary_logloss: 0.349183
# [832]	valid_0's binary_logloss: 0.349169
# [833]	valid_0's binary_logloss: 0.349162
# [834]	valid_0's binary_logloss: 0.349125
# [835]	valid_0's binary_logloss: 0.349111
# [836]	valid_0's binary_logloss: 0.349083
# [837]	valid_0's binary_logloss: 0.34907
# [838]	valid_0's binary_logloss: 0.349053
# [839]	valid_0's binary_logloss: 0.349039
# [840]	valid_0's binary_logloss: 0.349027
# [841]	valid_0's binary_logloss: 0.348998
# [842]	valid_0's binary_logloss: 0.34897
# [843]	valid_0's binary_logloss: 0.348942
# [844]	valid_0's binary_logloss: 0.348927
# [845]	valid_0's binary_logloss: 0.348894
# [846]	valid_0's binary_logloss: 0.348888
# [847]	valid_0's binary_logloss: 0.348875
# [848]	valid_0's binary_logloss: 0.348839
# [849]	valid_0's binary_logloss: 0.34883
# [850]	valid_0's binary_logloss: 0.348817
# [851]	valid_0's binary_logloss: 0.348796
# [852]	valid_0's binary_logloss: 0.348783
# [853]	valid_0's binary_logloss: 0.34877
# [854]	valid_0's binary_logloss: 0.348743
# [855]	valid_0's binary_logloss: 0.348725
# [856]	valid_0's binary_logloss: 0.348703
# [857]	valid_0's binary_logloss: 0.348685
# [858]	valid_0's binary_logloss: 0.348668
# [859]	valid_0's binary_logloss: 0.348644
# [860]	valid_0's binary_logloss: 0.348622
# [861]	valid_0's binary_logloss: 0.348613
# [862]	valid_0's binary_logloss: 0.348604
# [863]	valid_0's binary_logloss: 0.348592
# [864]	valid_0's binary_logloss: 0.34858
# [865]	valid_0's binary_logloss: 0.348567
# [866]	valid_0's binary_logloss: 0.348555
# [867]	valid_0's binary_logloss: 0.348548
# [868]	valid_0's binary_logloss: 0.34854
# [869]	valid_0's binary_logloss: 0.348531
# [870]	valid_0's binary_logloss: 0.348518
# [871]	valid_0's binary_logloss: 0.348501
# [872]	valid_0's binary_logloss: 0.348484
# [873]	valid_0's binary_logloss: 0.348466
# [874]	valid_0's binary_logloss: 0.348451
# [875]	valid_0's binary_logloss: 0.348438
# [876]	valid_0's binary_logloss: 0.348422
# [877]	valid_0's binary_logloss: 0.348395
# [878]	valid_0's binary_logloss: 0.348373
# [879]	valid_0's binary_logloss: 0.348356
# [880]	valid_0's binary_logloss: 0.348338
# [881]	valid_0's binary_logloss: 0.34833
# [882]	valid_0's binary_logloss: 0.34831
# [883]	valid_0's binary_logloss: 0.348289
# [884]	valid_0's binary_logloss: 0.348281
# [885]	valid_0's binary_logloss: 0.348268
# [886]	valid_0's binary_logloss: 0.348244
# [887]	valid_0's binary_logloss: 0.348224
# [888]	valid_0's binary_logloss: 0.348198
# [889]	valid_0's binary_logloss: 0.34819
# [890]	valid_0's binary_logloss: 0.348184
# [891]	valid_0's binary_logloss: 0.348163
# [892]	valid_0's binary_logloss: 0.348151
# [893]	valid_0's binary_logloss: 0.34812
# [894]	valid_0's binary_logloss: 0.348102
# [895]	valid_0's binary_logloss: 0.348085
# [896]	valid_0's binary_logloss: 0.348074
# [897]	valid_0's binary_logloss: 0.348052
# [898]	valid_0's binary_logloss: 0.348045
# [899]	valid_0's binary_logloss: 0.348041
# [900]	valid_0's binary_logloss: 0.348021
# [901]	valid_0's binary_logloss: 0.348017
# [902]	valid_0's binary_logloss: 0.347995
# [903]	valid_0's binary_logloss: 0.347979
# [904]	valid_0's binary_logloss: 0.347957
# [905]	valid_0's binary_logloss: 0.347941
# [906]	valid_0's binary_logloss: 0.347934
# [907]	valid_0's binary_logloss: 0.34792
# [908]	valid_0's binary_logloss: 0.347916
# [909]	valid_0's binary_logloss: 0.347898
# [910]	valid_0's binary_logloss: 0.347882
# [911]	valid_0's binary_logloss: 0.347862
# [912]	valid_0's binary_logloss: 0.347836
# [913]	valid_0's binary_logloss: 0.347828
# [914]	valid_0's binary_logloss: 0.347812
# [915]	valid_0's binary_logloss: 0.347796
# [916]	valid_0's binary_logloss: 0.347783
# [917]	valid_0's binary_logloss: 0.347767
# [918]	valid_0's binary_logloss: 0.347763
# [919]	valid_0's binary_logloss: 0.347741
# [920]	valid_0's binary_logloss: 0.347725
# [921]	valid_0's binary_logloss: 0.347705
# [922]	valid_0's binary_logloss: 0.347685
# [923]	valid_0's binary_logloss: 0.347675
# [924]	valid_0's binary_logloss: 0.347671
# [925]	valid_0's binary_logloss: 0.347669
# [926]	valid_0's binary_logloss: 0.34765
# [927]	valid_0's binary_logloss: 0.347631
# [928]	valid_0's binary_logloss: 0.34762
# [929]	valid_0's binary_logloss: 0.347597
# [930]	valid_0's binary_logloss: 0.347581
# [931]	valid_0's binary_logloss: 0.347554
# [932]	valid_0's binary_logloss: 0.347543
# [933]	valid_0's binary_logloss: 0.347536
# [934]	valid_0's binary_logloss: 0.347512
# [935]	valid_0's binary_logloss: 0.347495
# [936]	valid_0's binary_logloss: 0.347469
# [937]	valid_0's binary_logloss: 0.347452
# [938]	valid_0's binary_logloss: 0.347441
# [939]	valid_0's binary_logloss: 0.34743
# [940]	valid_0's binary_logloss: 0.347414
# [941]	valid_0's binary_logloss: 0.347409
# [942]	valid_0's binary_logloss: 0.3474
# [943]	valid_0's binary_logloss: 0.347386
# [944]	valid_0's binary_logloss: 0.347367
# [945]	valid_0's binary_logloss: 0.347357
# [946]	valid_0's binary_logloss: 0.347346
# [947]	valid_0's binary_logloss: 0.34734
# [948]	valid_0's binary_logloss: 0.347328
# [949]	valid_0's binary_logloss: 0.347324
# [950]	valid_0's binary_logloss: 0.347299
# [951]	valid_0's binary_logloss: 0.347271
# [952]	valid_0's binary_logloss: 0.347263
# [953]	valid_0's binary_logloss: 0.347251
# [954]	valid_0's binary_logloss: 0.347239
# [955]	valid_0's binary_logloss: 0.347229
# [956]	valid_0's binary_logloss: 0.347224
# [957]	valid_0's binary_logloss: 0.347209
# [958]	valid_0's binary_logloss: 0.347188
# [959]	valid_0's binary_logloss: 0.347173
# [960]	valid_0's binary_logloss: 0.347155
# [961]	valid_0's binary_logloss: 0.347151
# [962]	valid_0's binary_logloss: 0.347136
# [963]	valid_0's binary_logloss: 0.347128
# [964]	valid_0's binary_logloss: 0.347111
# [965]	valid_0's binary_logloss: 0.347107
# [966]	valid_0's binary_logloss: 0.347087
# [967]	valid_0's binary_logloss: 0.347076
# [968]	valid_0's binary_logloss: 0.347061
# [969]	valid_0's binary_logloss: 0.347053
# [970]	valid_0's binary_logloss: 0.347029
# [971]	valid_0's binary_logloss: 0.347026
# [972]	valid_0's binary_logloss: 0.347013
# [973]	valid_0's binary_logloss: 0.347001
# [974]	valid_0's binary_logloss: 0.346979
# [975]	valid_0's binary_logloss: 0.346971
# [976]	valid_0's binary_logloss: 0.346966
# [977]	valid_0's binary_logloss: 0.346949
# [978]	valid_0's binary_logloss: 0.346935
# [979]	valid_0's binary_logloss: 0.346932
# [980]	valid_0's binary_logloss: 0.346919
# [981]	valid_0's binary_logloss: 0.346902
# [982]	valid_0's binary_logloss: 0.346878
# [983]	valid_0's binary_logloss: 0.346871
# [984]	valid_0's binary_logloss: 0.346862
# [985]	valid_0's binary_logloss: 0.346851
# [986]	valid_0's binary_logloss: 0.346834
# [987]	valid_0's binary_logloss: 0.346827
# [988]	valid_0's binary_logloss: 0.346819
# [989]	valid_0's binary_logloss: 0.346813
# [990]	valid_0's binary_logloss: 0.346794
# [991]	valid_0's binary_logloss: 0.346775
# [992]	valid_0's binary_logloss: 0.346765
# [993]	valid_0's binary_logloss: 0.346753
# [994]	valid_0's binary_logloss: 0.346732
# [995]	valid_0's binary_logloss: 0.346729
# [996]	valid_0's binary_logloss: 0.346707
# [997]	valid_0's binary_logloss: 0.3467
# [998]	valid_0's binary_logloss: 0.34669
# [999]	valid_0's binary_logloss: 0.346677
# [1000]	valid_0's binary_logloss: 0.346653
# [1001]	valid_0's binary_logloss: 0.346643
# [1002]	valid_0's binary_logloss: 0.346642
# [1003]	valid_0's binary_logloss: 0.346628
# [1004]	valid_0's binary_logloss: 0.346618
# [1005]	valid_0's binary_logloss: 0.34659
# [1006]	valid_0's binary_logloss: 0.346575
# [1007]	valid_0's binary_logloss: 0.346562
# [1008]	valid_0's binary_logloss: 0.346554
# [1009]	valid_0's binary_logloss: 0.346545
# [1010]	valid_0's binary_logloss: 0.346542
# [1011]	valid_0's binary_logloss: 0.346535
# [1012]	valid_0's binary_logloss: 0.346525
# [1013]	valid_0's binary_logloss: 0.346507
# [1014]	valid_0's binary_logloss: 0.346502
# [1015]	valid_0's binary_logloss: 0.346493
# [1016]	valid_0's binary_logloss: 0.346485
# [1017]	valid_0's binary_logloss: 0.346482
# [1018]	valid_0's binary_logloss: 0.34647
# [1019]	valid_0's binary_logloss: 0.34645
# [1020]	valid_0's binary_logloss: 0.346433
# [1021]	valid_0's binary_logloss: 0.34643
# [1022]	valid_0's binary_logloss: 0.34642
# [1023]	valid_0's binary_logloss: 0.346399
# [1024]	valid_0's binary_logloss: 0.346397
# [1025]	valid_0's binary_logloss: 0.346389
# [1026]	valid_0's binary_logloss: 0.34638
# [1027]	valid_0's binary_logloss: 0.346366
# [1028]	valid_0's binary_logloss: 0.346359
# [1029]	valid_0's binary_logloss: 0.34635
# [1030]	valid_0's binary_logloss: 0.346334
# [1031]	valid_0's binary_logloss: 0.346325
# [1032]	valid_0's binary_logloss: 0.346321
# [1033]	valid_0's binary_logloss: 0.3463
# [1034]	valid_0's binary_logloss: 0.346294
# [1035]	valid_0's binary_logloss: 0.346293
# [1036]	valid_0's binary_logloss: 0.346278
# [1037]	valid_0's binary_logloss: 0.346255
# [1038]	valid_0's binary_logloss: 0.346234
# [1039]	valid_0's binary_logloss: 0.346232
# [1040]	valid_0's binary_logloss: 0.34622
# [1041]	valid_0's binary_logloss: 0.346211
# [1042]	valid_0's binary_logloss: 0.346199
# [1043]	valid_0's binary_logloss: 0.346196
# [1044]	valid_0's binary_logloss: 0.346172
# [1045]	valid_0's binary_logloss: 0.346154
# [1046]	valid_0's binary_logloss: 0.346153
# [1047]	valid_0's binary_logloss: 0.346143
# [1048]	valid_0's binary_logloss: 0.34613
# [1049]	valid_0's binary_logloss: 0.346125
# [1050]	valid_0's binary_logloss: 0.346112
# [1051]	valid_0's binary_logloss: 0.346111
# [1052]	valid_0's binary_logloss: 0.34609
# [1053]	valid_0's binary_logloss: 0.346088
# [1054]	valid_0's binary_logloss: 0.34607
# [1055]	valid_0's binary_logloss: 0.34606
# [1056]	valid_0's binary_logloss: 0.346044
# [1057]	valid_0's binary_logloss: 0.346028
# [1058]	valid_0's binary_logloss: 0.346019
# [1059]	valid_0's binary_logloss: 0.346015
# [1060]	valid_0's binary_logloss: 0.346001
# [1061]	valid_0's binary_logloss: 0.345998
# [1062]	valid_0's binary_logloss: 0.345995
# [1063]	valid_0's binary_logloss: 0.345981
# [1064]	valid_0's binary_logloss: 0.345974
# [1065]	valid_0's binary_logloss: 0.345969
# [1066]	valid_0's binary_logloss: 0.345957
# [1067]	valid_0's binary_logloss: 0.345943
# [1068]	valid_0's binary_logloss: 0.345933
# [1069]	valid_0's binary_logloss: 0.345909
# [1070]	valid_0's binary_logloss: 0.345904
# [1071]	valid_0's binary_logloss: 0.345887
# [1072]	valid_0's binary_logloss: 0.34588
# [1073]	valid_0's binary_logloss: 0.345863
# [1074]	valid_0's binary_logloss: 0.34585
# [1075]	valid_0's binary_logloss: 0.345845
# [1076]	valid_0's binary_logloss: 0.345842
# [1077]	valid_0's binary_logloss: 0.34583
# [1078]	valid_0's binary_logloss: 0.345827
# [1079]	valid_0's binary_logloss: 0.345822
# [1080]	valid_0's binary_logloss: 0.345807
# [1081]	valid_0's binary_logloss: 0.345803
# [1082]	valid_0's binary_logloss: 0.345797
# [1083]	valid_0's binary_logloss: 0.345784
# [1084]	valid_0's binary_logloss: 0.345765
# [1085]	valid_0's binary_logloss: 0.345759
# [1086]	valid_0's binary_logloss: 0.345755
# [1087]	valid_0's binary_logloss: 0.345735
# [1088]	valid_0's binary_logloss: 0.345725
# [1089]	valid_0's binary_logloss: 0.345722
# [1090]	valid_0's binary_logloss: 0.345709
# [1091]	valid_0's binary_logloss: 0.345702
# [1092]	valid_0's binary_logloss: 0.34568
# [1093]	valid_0's binary_logloss: 0.345668
# [1094]	valid_0's binary_logloss: 0.345659
# [1095]	valid_0's binary_logloss: 0.345641
# [1096]	valid_0's binary_logloss: 0.345639
# [1097]	valid_0's binary_logloss: 0.345627
# [1098]	valid_0's binary_logloss: 0.345608
# [1099]	valid_0's binary_logloss: 0.345604
# [1100]	valid_0's binary_logloss: 0.345604
# [1101]	valid_0's binary_logloss: 0.345597
# [1102]	valid_0's binary_logloss: 0.34558
# [1103]	valid_0's binary_logloss: 0.345578
# [1104]	valid_0's binary_logloss: 0.345566
# [1105]	valid_0's binary_logloss: 0.345559
# [1106]	valid_0's binary_logloss: 0.345545
# [1107]	valid_0's binary_logloss: 0.34554
# [1108]	valid_0's binary_logloss: 0.345536
# [1109]	valid_0's binary_logloss: 0.34553
# [1110]	valid_0's binary_logloss: 0.345516
# [1111]	valid_0's binary_logloss: 0.345512
# [1112]	valid_0's binary_logloss: 0.345505
# [1113]	valid_0's binary_logloss: 0.345492
# [1114]	valid_0's binary_logloss: 0.345477
# [1115]	valid_0's binary_logloss: 0.34547
# [1116]	valid_0's binary_logloss: 0.345456
# [1117]	valid_0's binary_logloss: 0.34545
# [1118]	valid_0's binary_logloss: 0.345434
# [1119]	valid_0's binary_logloss: 0.34542
# [1120]	valid_0's binary_logloss: 0.345411
# [1121]	valid_0's binary_logloss: 0.345397
# [1122]	valid_0's binary_logloss: 0.345382
# [1123]	valid_0's binary_logloss: 0.345372
# [1124]	valid_0's binary_logloss: 0.345362
# [1125]	valid_0's binary_logloss: 0.345353
# [1126]	valid_0's binary_logloss: 0.345345
# [1127]	valid_0's binary_logloss: 0.345344
# [1128]	valid_0's binary_logloss: 0.345328
# [1129]	valid_0's binary_logloss: 0.345316
# [1130]	valid_0's binary_logloss: 0.34531
# [1131]	valid_0's binary_logloss: 0.345298
# [1132]	valid_0's binary_logloss: 0.345289
# [1133]	valid_0's binary_logloss: 0.345281
# [1134]	valid_0's binary_logloss: 0.345276
# [1135]	valid_0's binary_logloss: 0.345274
# [1136]	valid_0's binary_logloss: 0.345272
# [1137]	valid_0's binary_logloss: 0.345268
# [1138]	valid_0's binary_logloss: 0.345267
# [1139]	valid_0's binary_logloss: 0.345249
# [1140]	valid_0's binary_logloss: 0.345243
# [1141]	valid_0's binary_logloss: 0.345232
# [1142]	valid_0's binary_logloss: 0.345214
# [1143]	valid_0's binary_logloss: 0.345208
# [1144]	valid_0's binary_logloss: 0.345193
# [1145]	valid_0's binary_logloss: 0.345171
# [1146]	valid_0's binary_logloss: 0.345159
# [1147]	valid_0's binary_logloss: 0.345154
# [1148]	valid_0's binary_logloss: 0.345136
# [1149]	valid_0's binary_logloss: 0.345134
# [1150]	valid_0's binary_logloss: 0.345113
# [1151]	valid_0's binary_logloss: 0.345099
# [1152]	valid_0's binary_logloss: 0.345084
# [1153]	valid_0's binary_logloss: 0.345065
# [1154]	valid_0's binary_logloss: 0.345063
# [1155]	valid_0's binary_logloss: 0.345063
# [1156]	valid_0's binary_logloss: 0.345058
# [1157]	valid_0's binary_logloss: 0.345048
# [1158]	valid_0's binary_logloss: 0.345032
# [1159]	valid_0's binary_logloss: 0.345023
# [1160]	valid_0's binary_logloss: 0.345012
# [1161]	valid_0's binary_logloss: 0.34499
# [1162]	valid_0's binary_logloss: 0.344987
# [1163]	valid_0's binary_logloss: 0.344979
# [1164]	valid_0's binary_logloss: 0.344963
# [1165]	valid_0's binary_logloss: 0.344961
# [1166]	valid_0's binary_logloss: 0.344941
# [1167]	valid_0's binary_logloss: 0.344937
# [1168]	valid_0's binary_logloss: 0.344933
# [1169]	valid_0's binary_logloss: 0.344928
# [1170]	valid_0's binary_logloss: 0.344922
# ...
# [2122]	valid_0's binary_logloss: 0.340761
# [2123]	valid_0's binary_logloss: 0.340759
# [2124]	valid_0's binary_logloss: 0.340756
# [2125]	valid_0's binary_logloss: 0.340753
# [2126]	valid_0's binary_logloss: 0.340745
# [2127]	valid_0's binary_logloss: 0.340741
# [2128]	valid_0's binary_logloss: 0.340741
# [2129]	valid_0's binary_logloss: 0.340741
# [2130]	valid_0's binary_logloss: 0.340739
# [2131]	valid_0's binary_logloss: 0.340737
# [2132]	valid_0's binary_logloss: 0.340733
# [2133]	valid_0's binary_logloss: 0.340735
# [2134]	valid_0's binary_logloss: 0.340731
# [2135]	valid_0's binary_logloss: 0.340732
# [2136]	valid_0's binary_logloss: 0.340729
# [2137]	valid_0's binary_logloss: 0.340728
# [2138]	valid_0's binary_logloss: 0.340723
# [2139]	valid_0's binary_logloss: 0.340718
# [2140]	valid_0's binary_logloss: 0.340716
# [2141]	valid_0's binary_logloss: 0.340716
# [2142]	valid_0's binary_logloss: 0.340718
# [2143]	valid_0's binary_logloss: 0.340715
# [2144]	valid_0's binary_logloss: 0.340712
# [2145]	valid_0's binary_logloss: 0.340712
# [2146]	valid_0's binary_logloss: 0.340703
# [2147]	valid_0's binary_logloss: 0.340701
# [2148]	valid_0's binary_logloss: 0.340698
# [2149]	valid_0's binary_logloss: 0.340697
# [2150]	valid_0's binary_logloss: 0.340694
# [2151]	valid_0's binary_logloss: 0.340693
# [2152]	valid_0's binary_logloss: 0.340692
# [2153]	valid_0's binary_logloss: 0.34069
# [2154]	valid_0's binary_logloss: 0.340686
# [2155]	valid_0's binary_logloss: 0.340687
# [2156]	valid_0's binary_logloss: 0.340686
# [2157]	valid_0's binary_logloss: 0.340682
# [2158]	valid_0's binary_logloss: 0.34068
# [2159]	valid_0's binary_logloss: 0.34068
# [2160]	valid_0's binary_logloss: 0.34068
# [2161]	valid_0's binary_logloss: 0.340677
# [2162]	valid_0's binary_logloss: 0.340675
# [2163]	valid_0's binary_logloss: 0.340675
# [2164]	valid_0's binary_logloss: 0.340676
# [2165]	valid_0's binary_logloss: 0.340677
# [2166]	valid_0's binary_logloss: 0.340675
# [2167]	valid_0's binary_logloss: 0.340671
# [2168]	valid_0's binary_logloss: 0.340668
# [2169]	valid_0's binary_logloss: 0.340666
# [2170]	valid_0's binary_logloss: 0.340663
# [2171]	valid_0's binary_logloss: 0.340662
# [2172]	valid_0's binary_logloss: 0.340662
# [2173]	valid_0's binary_logloss: 0.340658
# [2174]	valid_0's binary_logloss: 0.340657
# [2175]	valid_0's binary_logloss: 0.34066
# [2176]	valid_0's binary_logloss: 0.34066
# [2177]	valid_0's binary_logloss: 0.340659
# [2178]	valid_0's binary_logloss: 0.340654
# [2179]	valid_0's binary_logloss: 0.340652
# [2180]	valid_0's binary_logloss: 0.340652
# [2181]	valid_0's binary_logloss: 0.340653
# [2182]	valid_0's binary_logloss: 0.34065
# [2183]	valid_0's binary_logloss: 0.340647
# [2184]	valid_0's binary_logloss: 0.340644
# [2185]	valid_0's binary_logloss: 0.340637
# [2186]	valid_0's binary_logloss: 0.340636
# [2187]	valid_0's binary_logloss: 0.340638
# [2188]	valid_0's binary_logloss: 0.340638
# [2189]	valid_0's binary_logloss: 0.340634
# [2190]	valid_0's binary_logloss: 0.340634
# [2191]	valid_0's binary_logloss: 0.340635
# [2192]	valid_0's binary_logloss: 0.340632
# [2193]	valid_0's binary_logloss: 0.34063
# [2194]	valid_0's binary_logloss: 0.340629
# [2195]	valid_0's binary_logloss: 0.34063
# [2196]	valid_0's binary_logloss: 0.340627
# [2197]	valid_0's binary_logloss: 0.340622
# [2198]	valid_0's binary_logloss: 0.340618
# [2199]	valid_0's binary_logloss: 0.340616
# [2200]	valid_0's binary_logloss: 0.340617
# [2201]	valid_0's binary_logloss: 0.340619
# [2202]	valid_0's binary_logloss: 0.340618
# [2203]	valid_0's binary_logloss: 0.340615
# [2204]	valid_0's binary_logloss: 0.340615
# [2205]	valid_0's binary_logloss: 0.340615
# [2206]	valid_0's binary_logloss: 0.340617
# [2207]	valid_0's binary_logloss: 0.340611
# [2208]	valid_0's binary_logloss: 0.34061
# [2209]	valid_0's binary_logloss: 0.340611
# [2210]	valid_0's binary_logloss: 0.340614
# [2211]	valid_0's binary_logloss: 0.340612
# [2212]	valid_0's binary_logloss: 0.340612
# [2213]	valid_0's binary_logloss: 0.340603
# [2214]	valid_0's binary_logloss: 0.3406
# [2215]	valid_0's binary_logloss: 0.340598
# [2216]	valid_0's binary_logloss: 0.340593
# [2217]	valid_0's binary_logloss: 0.340587
# [2218]	valid_0's binary_logloss: 0.340584
# [2219]	valid_0's binary_logloss: 0.34058
# [2220]	valid_0's binary_logloss: 0.340579
# [2221]	valid_0's binary_logloss: 0.340573
# [2222]	valid_0's binary_logloss: 0.340573
# [2223]	valid_0's binary_logloss: 0.34057
# [2224]	valid_0's binary_logloss: 0.340571
# [2225]	valid_0's binary_logloss: 0.340569
# [2226]	valid_0's binary_logloss: 0.340565
# [2227]	valid_0's binary_logloss: 0.340561
# [2228]	valid_0's binary_logloss: 0.34056
# [2229]	valid_0's binary_logloss: 0.34056
# [2230]	valid_0's binary_logloss: 0.340559
# [2231]	valid_0's binary_logloss: 0.34056
# [2232]	valid_0's binary_logloss: 0.34056
# [2233]	valid_0's binary_logloss: 0.340559
# [2234]	valid_0's binary_logloss: 0.340557
# [2235]	valid_0's binary_logloss: 0.340558
# [2236]	valid_0's binary_logloss: 0.340558
# [2237]	valid_0's binary_logloss: 0.340558
# [2238]	valid_0's binary_logloss: 0.340556
# [2239]	valid_0's binary_logloss: 0.340557
# [2240]	valid_0's binary_logloss: 0.340557
# [2241]	valid_0's binary_logloss: 0.340557
# [2242]	valid_0's binary_logloss: 0.340555
# [2243]	valid_0's binary_logloss: 0.340552
# [2244]	valid_0's binary_logloss: 0.340548
# [2245]	valid_0's binary_logloss: 0.340548
# [2246]	valid_0's binary_logloss: 0.340548
# [2247]	valid_0's binary_logloss: 0.340542
# [2248]	valid_0's binary_logloss: 0.340534
# [2249]	valid_0's binary_logloss: 0.340534
# [2250]	valid_0's binary_logloss: 0.340531
# [2251]	valid_0's binary_logloss: 0.34053
# [2252]	valid_0's binary_logloss: 0.340529
# [2253]	valid_0's binary_logloss: 0.340529
# [2254]	valid_0's binary_logloss: 0.34053
# [2255]	valid_0's binary_logloss: 0.340529
# [2256]	valid_0's binary_logloss: 0.34053
# [2257]	valid_0's binary_logloss: 0.340529
# [2258]	valid_0's binary_logloss: 0.340525
# [2259]	valid_0's binary_logloss: 0.340527
# [2260]	valid_0's binary_logloss: 0.340527
# [2261]	valid_0's binary_logloss: 0.340526
# [2262]	valid_0's binary_logloss: 0.340527
# [2263]	valid_0's binary_logloss: 0.340525
# [2264]	valid_0's binary_logloss: 0.340523
# [2265]	valid_0's binary_logloss: 0.340519
# [2266]	valid_0's binary_logloss: 0.340516
# [2267]	valid_0's binary_logloss: 0.340514
# [2268]	valid_0's binary_logloss: 0.340511
# [2269]	valid_0's binary_logloss: 0.340508
# [2270]	valid_0's binary_logloss: 0.340507
# [2271]	valid_0's binary_logloss: 0.340506
# [2272]	valid_0's binary_logloss: 0.340499
# [2273]	valid_0's binary_logloss: 0.340497
# [2274]	valid_0's binary_logloss: 0.340492
# [2275]	valid_0's binary_logloss: 0.340492
# [2276]	valid_0's binary_logloss: 0.34049
# [2277]	valid_0's binary_logloss: 0.340484
# [2278]	valid_0's binary_logloss: 0.340482
# [2279]	valid_0's binary_logloss: 0.340476
# [2280]	valid_0's binary_logloss: 0.340474
# [2281]	valid_0's binary_logloss: 0.340472
# [2282]	valid_0's binary_logloss: 0.340473
# [2283]	valid_0's binary_logloss: 0.340475
# [2284]	valid_0's binary_logloss: 0.340474
# [2285]	valid_0's binary_logloss: 0.340471
# [2286]	valid_0's binary_logloss: 0.340472
# [2287]	valid_0's binary_logloss: 0.340472
# [2288]	valid_0's binary_logloss: 0.34047
# [2289]	valid_0's binary_logloss: 0.340467
# [2290]	valid_0's binary_logloss: 0.340467
# [2291]	valid_0's binary_logloss: 0.340466
# [2292]	valid_0's binary_logloss: 0.340466
# [2293]	valid_0's binary_logloss: 0.340466
# [2294]	valid_0's binary_logloss: 0.34046
# [2295]	valid_0's binary_logloss: 0.34046
# [2296]	valid_0's binary_logloss: 0.340459
# [2297]	valid_0's binary_logloss: 0.340458
# [2298]	valid_0's binary_logloss: 0.340458
# [2299]	valid_0's binary_logloss: 0.340456
# [2300]	valid_0's binary_logloss: 0.340453
# [2301]	valid_0's binary_logloss: 0.340453
# [2302]	valid_0's binary_logloss: 0.340452
# [2303]	valid_0's binary_logloss: 0.34045
# [2304]	valid_0's binary_logloss: 0.340451
# [2305]	valid_0's binary_logloss: 0.34045
# [2306]	valid_0's binary_logloss: 0.340449
# [2307]	valid_0's binary_logloss: 0.340445
# [2308]	valid_0's binary_logloss: 0.340441
# [2309]	valid_0's binary_logloss: 0.340441
# [2310]	valid_0's binary_logloss: 0.34044
# [2311]	valid_0's binary_logloss: 0.340438
# [2312]	valid_0's binary_logloss: 0.340437
# [2313]	valid_0's binary_logloss: 0.340435
# [2314]	valid_0's binary_logloss: 0.340435
# [2315]	valid_0's binary_logloss: 0.340432
# [2316]	valid_0's binary_logloss: 0.340431
# [2317]	valid_0's binary_logloss: 0.340429
# [2318]	valid_0's binary_logloss: 0.340429
# [2319]	valid_0's binary_logloss: 0.34043
# [2320]	valid_0's binary_logloss: 0.340431
# [2321]	valid_0's binary_logloss: 0.340429
# [2322]	valid_0's binary_logloss: 0.340422
# [2323]	valid_0's binary_logloss: 0.340422
# [2324]	valid_0's binary_logloss: 0.34042
# [2325]	valid_0's binary_logloss: 0.340422
# [2326]	valid_0's binary_logloss: 0.340419
# [2327]	valid_0's binary_logloss: 0.340417
# [2328]	valid_0's binary_logloss: 0.340414
# [2329]	valid_0's binary_logloss: 0.340413
# [2330]	valid_0's binary_logloss: 0.340411
# [2331]	valid_0's binary_logloss: 0.340409
# [2332]	valid_0's binary_logloss: 0.340406
# [2333]	valid_0's binary_logloss: 0.340407
# [2334]	valid_0's binary_logloss: 0.340405
# [2335]	valid_0's binary_logloss: 0.340407
# [2336]	valid_0's binary_logloss: 0.340404
# [2337]	valid_0's binary_logloss: 0.340403
# [2338]	valid_0's binary_logloss: 0.340403
# [2339]	valid_0's binary_logloss: 0.340395
# [2340]	valid_0's binary_logloss: 0.340394
# [2341]	valid_0's binary_logloss: 0.340391
# [2342]	valid_0's binary_logloss: 0.34039
# [2343]	valid_0's binary_logloss: 0.340389
# [2344]	valid_0's binary_logloss: 0.340385
# [2345]	valid_0's binary_logloss: 0.340383
# [2346]	valid_0's binary_logloss: 0.340382
# [2347]	valid_0's binary_logloss: 0.34038
# [2348]	valid_0's binary_logloss: 0.340377
# [2349]	valid_0's binary_logloss: 0.340374
# [2350]	valid_0's binary_logloss: 0.340375
# [2351]	valid_0's binary_logloss: 0.340373
# [2352]	valid_0's binary_logloss: 0.340375
# [2353]	valid_0's binary_logloss: 0.340371
# [2354]	valid_0's binary_logloss: 0.340373
# [2355]	valid_0's binary_logloss: 0.340373
# [2356]	valid_0's binary_logloss: 0.340374
# [2357]	valid_0's binary_logloss: 0.34037
# [2358]	valid_0's binary_logloss: 0.340371
# [2359]	valid_0's binary_logloss: 0.340367
# [2360]	valid_0's binary_logloss: 0.34036
# [2361]	valid_0's binary_logloss: 0.340362
# [2362]	valid_0's binary_logloss: 0.340358
# [2363]	valid_0's binary_logloss: 0.340356
# [2364]	valid_0's binary_logloss: 0.340353
# [2365]	valid_0's binary_logloss: 0.340351
# [2366]	valid_0's binary_logloss: 0.340344
# [2367]	valid_0's binary_logloss: 0.340344
# [2368]	valid_0's binary_logloss: 0.340343
# [2369]	valid_0's binary_logloss: 0.340339
# [2370]	valid_0's binary_logloss: 0.340338
# [2371]	valid_0's binary_logloss: 0.340339
# [2372]	valid_0's binary_logloss: 0.340338
# [2373]	valid_0's binary_logloss: 0.340338
# [2374]	valid_0's binary_logloss: 0.340337
# [2375]	valid_0's binary_logloss: 0.340336
# [2376]	valid_0's binary_logloss: 0.340335
# [2377]	valid_0's binary_logloss: 0.340334
# [2378]	valid_0's binary_logloss: 0.340332
# [2379]	valid_0's binary_logloss: 0.340328
# [2380]	valid_0's binary_logloss: 0.340329
# [2381]	valid_0's binary_logloss: 0.34033
# [2382]	valid_0's binary_logloss: 0.34033
# [2383]	valid_0's binary_logloss: 0.340329
# [2384]	valid_0's binary_logloss: 0.340328
# [2385]	valid_0's binary_logloss: 0.340328
# [2386]	valid_0's binary_logloss: 0.340328
# [2387]	valid_0's binary_logloss: 0.340327
# [2388]	valid_0's binary_logloss: 0.340324
# [2389]	valid_0's binary_logloss: 0.34032
# [2390]	valid_0's binary_logloss: 0.340316
# [2391]	valid_0's binary_logloss: 0.340313
# [2392]	valid_0's binary_logloss: 0.340312
# [2393]	valid_0's binary_logloss: 0.340311
# [2394]	valid_0's binary_logloss: 0.34031
# [2395]	valid_0's binary_logloss: 0.340305
# [2396]	valid_0's binary_logloss: 0.340305
# [2397]	valid_0's binary_logloss: 0.340302
# [2398]	valid_0's binary_logloss: 0.3403
# [2399]	valid_0's binary_logloss: 0.340295
# [2400]	valid_0's binary_logloss: 0.340291
# [2401]	valid_0's binary_logloss: 0.340289
# [2402]	valid_0's binary_logloss: 0.34029
# [2403]	valid_0's binary_logloss: 0.34029
# [2404]	valid_0's binary_logloss: 0.340293
# [2405]	valid_0's binary_logloss: 0.340292
# [2406]	valid_0's binary_logloss: 0.340288
# [2407]	valid_0's binary_logloss: 0.340289
# [2408]	valid_0's binary_logloss: 0.340289
# [2409]	valid_0's binary_logloss: 0.340289
# [2410]	valid_0's binary_logloss: 0.340287
# [2411]	valid_0's binary_logloss: 0.340283
# [2412]	valid_0's binary_logloss: 0.340282
# [2413]	valid_0's binary_logloss: 0.340278
# [2414]	valid_0's binary_logloss: 0.340277
# [2415]	valid_0's binary_logloss: 0.340277
# [2416]	valid_0's binary_logloss: 0.340273
# [2417]	valid_0's binary_logloss: 0.340271
# [2418]	valid_0's binary_logloss: 0.34027
# [2419]	valid_0's binary_logloss: 0.34027
# [2420]	valid_0's binary_logloss: 0.340267
# [2421]	valid_0's binary_logloss: 0.340267
# [2422]	valid_0's binary_logloss: 0.340264
# [2423]	valid_0's binary_logloss: 0.340261
# [2424]	valid_0's binary_logloss: 0.340253
# [2425]	valid_0's binary_logloss: 0.340253
# [2426]	valid_0's binary_logloss: 0.340254
# [2427]	valid_0's binary_logloss: 0.340249
# [2428]	valid_0's binary_logloss: 0.340246
# [2429]	valid_0's binary_logloss: 0.340245
# [2430]	valid_0's binary_logloss: 0.340244
# [2431]	valid_0's binary_logloss: 0.340241
# [2432]	valid_0's binary_logloss: 0.340238
# [2433]	valid_0's binary_logloss: 0.340237
# [2434]	valid_0's binary_logloss: 0.340237
# [2435]	valid_0's binary_logloss: 0.340235
# [2436]	valid_0's binary_logloss: 0.340235
# [2437]	valid_0's binary_logloss: 0.340235
# [2438]	valid_0's binary_logloss: 0.340233
# [2439]	valid_0's binary_logloss: 0.340231
# [2440]	valid_0's binary_logloss: 0.340229
# [2441]	valid_0's binary_logloss: 0.34023
# [2442]	valid_0's binary_logloss: 0.340227
# [2443]	valid_0's binary_logloss: 0.340229
# [2444]	valid_0's binary_logloss: 0.340227
# [2445]	valid_0's binary_logloss: 0.340225
# [2446]	valid_0's binary_logloss: 0.340224
# [2447]	valid_0's binary_logloss: 0.340222
# [2448]	valid_0's binary_logloss: 0.340217
# [2449]	valid_0's binary_logloss: 0.340216
# [2450]	valid_0's binary_logloss: 0.340213
# [2451]	valid_0's binary_logloss: 0.340209
# [2452]	valid_0's binary_logloss: 0.34021
# [2453]	valid_0's binary_logloss: 0.34021
# [2454]	valid_0's binary_logloss: 0.340208
# [2455]	valid_0's binary_logloss: 0.340208
# [2456]	valid_0's binary_logloss: 0.340204
# [2457]	valid_0's binary_logloss: 0.340202
# [2458]	valid_0's binary_logloss: 0.340201
# [2459]	valid_0's binary_logloss: 0.340202
# [2460]	valid_0's binary_logloss: 0.3402
# [2461]	valid_0's binary_logloss: 0.340198
# [2462]	valid_0's binary_logloss: 0.340197
# [2463]	valid_0's binary_logloss: 0.340199
# [2464]	valid_0's binary_logloss: 0.340195
# [2465]	valid_0's binary_logloss: 0.340195
# [2466]	valid_0's binary_logloss: 0.340195
# [2467]	valid_0's binary_logloss: 0.340192
# [2468]	valid_0's binary_logloss: 0.340192
# [2469]	valid_0's binary_logloss: 0.340191
# [2470]	valid_0's binary_logloss: 0.34019
# [2471]	valid_0's binary_logloss: 0.340188
# [2472]	valid_0's binary_logloss: 0.340186
# [2473]	valid_0's binary_logloss: 0.340184
# [2474]	valid_0's binary_logloss: 0.340179
# [2475]	valid_0's binary_logloss: 0.340179
# [2476]	valid_0's binary_logloss: 0.340176
# [2477]	valid_0's binary_logloss: 0.340176
# [2478]	valid_0's binary_logloss: 0.340176
# [2479]	valid_0's binary_logloss: 0.340173
# [2480]	valid_0's binary_logloss: 0.34017
# [2481]	valid_0's binary_logloss: 0.340167
# [2482]	valid_0's binary_logloss: 0.340167
# [2483]	valid_0's binary_logloss: 0.340164
# [2484]	valid_0's binary_logloss: 0.34016
# [2485]	valid_0's binary_logloss: 0.34016
# [2486]	valid_0's binary_logloss: 0.340159
# [2487]	valid_0's binary_logloss: 0.340156
# [2488]	valid_0's binary_logloss: 0.340158
# [2489]	valid_0's binary_logloss: 0.340155
# [2490]	valid_0's binary_logloss: 0.340155
# [2491]	valid_0's binary_logloss: 0.340152
# [2492]	valid_0's binary_logloss: 0.340151
# [2493]	valid_0's binary_logloss: 0.340148
# [2494]	valid_0's binary_logloss: 0.340148
# [2495]	valid_0's binary_logloss: 0.340146
# [2496]	valid_0's binary_logloss: 0.340144
# [2497]	valid_0's binary_logloss: 0.34014
# [2498]	valid_0's binary_logloss: 0.340139
# [2499]	valid_0's binary_logloss: 0.340137
# [2500]	valid_0's binary_logloss: 0.340136
# Did not meet early stopping. Best iteration is:
# [2500]	valid_0's binary_logloss: 0.340136
# Modelo da classe 5 finalizado

# %%
# Treinar 100% modelo da classe 4
m4 = lgb.train(params=hp4, num_boost_round=nbr, train_set=ds4_train, valid_sets=[ds4_valid], 
               verbose_eval=True, categorical_feature=feats_cat)
print('Modelo da classe 4 finalizado')
# Out:
# [1]	valid_0's binary_logloss: 0.601124
# Training until validation scores don't improve for 25 rounds
# [2]	valid_0's binary_logloss: 0.598625
# [3]	valid_0's binary_logloss: 0.595582
# [4]	valid_0's binary_logloss: 0.592895
# [5]	valid_0's binary_logloss: 0.589964
# [6]	valid_0's binary_logloss: 0.587096
# [7]	valid_0's binary_logloss: 0.584288
# [8]	valid_0's binary_logloss: 0.581542
# [9]	valid_0's binary_logloss: 0.578842
# [10]	valid_0's binary_logloss: 0.576211
# [11]	valid_0's binary_logloss: 0.573621
# [12]	valid_0's binary_logloss: 0.571087
# [13]	valid_0's binary_logloss: 0.568844
# [14]	valid_0's binary_logloss: 0.566407
# [15]	valid_0's binary_logloss: 0.564017
# [16]	valid_0's binary_logloss: 0.561674
# [17]	valid_0's binary_logloss: 0.559373
# [18]	valid_0's binary_logloss: 0.557115
# [19]	valid_0's binary_logloss: 0.555197
# [20]	valid_0's binary_logloss: 0.553018
# [21]	valid_0's binary_logloss: 0.551085
# [22]	valid_0's binary_logloss: 0.549153
# [23]	valid_0's binary_logloss: 0.547073
# [24]	valid_0's binary_logloss: 0.545209
# [25]	valid_0's binary_logloss: 0.543205
# [26]	valid_0's binary_logloss: 0.541225
# [27]	valid_0's binary_logloss: 0.539293
# [28]	valid_0's binary_logloss: 0.537555
# [29]	valid_0's binary_logloss: 0.535862
# [30]	valid_0's binary_logloss: 0.534024
# [31]	valid_0's binary_logloss: 0.532212
# [32]	valid_0's binary_logloss: 0.530429
# [33]	valid_0's binary_logloss: 0.528691
# [34]	valid_0's binary_logloss: 0.526968
# [35]	valid_0's binary_logloss: 0.525576
# [36]	valid_0's binary_logloss: 0.524053
# [37]	valid_0's binary_logloss: 0.522407
# [38]	valid_0's binary_logloss: 0.520791
# [39]	valid_0's binary_logloss: 0.519204
# [40]	valid_0's binary_logloss: 0.517655
# [41]	valid_0's binary_logloss: 0.516246
# [42]	valid_0's binary_logloss: 0.514732
# [43]	valid_0's binary_logloss: 0.513249
# [44]	valid_0's binary_logloss: 0.511787
# [45]	valid_0's binary_logloss: 0.510522
# [46]	valid_0's binary_logloss: 0.509215
# [47]	valid_0's binary_logloss: 0.507812
# [48]	valid_0's binary_logloss: 0.506443
# [49]	valid_0's binary_logloss: 0.505101
# [50]	valid_0's binary_logloss: 0.503772
# [51]	valid_0's binary_logloss: 0.50255
# [52]	valid_0's binary_logloss: 0.501249
# [53]	valid_0's binary_logloss: 0.499959
# [54]	valid_0's binary_logloss: 0.4987
# [55]	valid_0's binary_logloss: 0.49748
# [56]	valid_0's binary_logloss: 0.496278
# [57]	valid_0's binary_logloss: 0.495206
# [58]	valid_0's binary_logloss: 0.494261
# [59]	valid_0's binary_logloss: 0.493096
# [60]	valid_0's binary_logloss: 0.491949
# [61]	valid_0's binary_logloss: 0.490918
# [62]	valid_0's binary_logloss: 0.48979
# [63]	valid_0's binary_logloss: 0.488683
# [64]	valid_0's binary_logloss: 0.4876
# [65]	valid_0's binary_logloss: 0.486519
# [66]	valid_0's binary_logloss: 0.485472
# [67]	valid_0's binary_logloss: 0.484516
# [68]	valid_0's binary_logloss: 0.483502
# [69]	valid_0's binary_logloss: 0.482478
# [70]	valid_0's binary_logloss: 0.481493
# [71]	valid_0's binary_logloss: 0.480525
# [72]	valid_0's binary_logloss: 0.479548
# [73]	valid_0's binary_logloss: 0.478599
# [74]	valid_0's binary_logloss: 0.477743
# [75]	valid_0's binary_logloss: 0.476788
# [76]	valid_0's binary_logloss: 0.475864
# [77]	valid_0's binary_logloss: 0.474951
# [78]	valid_0's binary_logloss: 0.474065
# [79]	valid_0's binary_logloss: 0.473175
# [80]	valid_0's binary_logloss: 0.472311
# [81]	valid_0's binary_logloss: 0.471457
# [82]	valid_0's binary_logloss: 0.470659
# [83]	valid_0's binary_logloss: 0.469912
# [84]	valid_0's binary_logloss: 0.469087
# [85]	valid_0's binary_logloss: 0.468268
# [86]	valid_0's binary_logloss: 0.467549
# [87]	valid_0's binary_logloss: 0.466766
# [88]	valid_0's binary_logloss: 0.466028
# [89]	valid_0's binary_logloss: 0.465252
# [90]	valid_0's binary_logloss: 0.464567
# [91]	valid_0's binary_logloss: 0.463825
# [92]	valid_0's binary_logloss: 0.463088
# [93]	valid_0's binary_logloss: 0.462365
# [94]	valid_0's binary_logloss: 0.461649
# [95]	valid_0's binary_logloss: 0.460945
# [96]	valid_0's binary_logloss: 0.460245
# [97]	valid_0's binary_logloss: 0.459556
# [98]	valid_0's binary_logloss: 0.458992
# [99]	valid_0's binary_logloss: 0.458303
# [100]	valid_0's binary_logloss: 0.4577
# [101]	valid_0's binary_logloss: 0.45705
# [102]	valid_0's binary_logloss: 0.456397
# [103]	valid_0's binary_logloss: 0.455773
# [104]	valid_0's binary_logloss: 0.455192
# [105]	valid_0's binary_logloss: 0.454566
# [106]	valid_0's binary_logloss: 0.453937
# [107]	valid_0's binary_logloss: 0.453317
# [108]	valid_0's binary_logloss: 0.452705
# [109]	valid_0's binary_logloss: 0.452089
# [110]	valid_0's binary_logloss: 0.451499
# [111]	valid_0's binary_logloss: 0.45091
# [112]	valid_0's binary_logloss: 0.450329
# [113]	valid_0's binary_logloss: 0.449754
# [114]	valid_0's binary_logloss: 0.449236
# [115]	valid_0's binary_logloss: 0.44868
# [116]	valid_0's binary_logloss: 0.448125
# [117]	valid_0's binary_logloss: 0.447572
# [118]	valid_0's binary_logloss: 0.447028
# [119]	valid_0's binary_logloss: 0.446499
# [120]	valid_0's binary_logloss: 0.445958
# [121]	valid_0's binary_logloss: 0.445447
# [122]	valid_0's binary_logloss: 0.444935
# [123]	valid_0's binary_logloss: 0.444421
# [124]	valid_0's binary_logloss: 0.443921
# [125]	valid_0's binary_logloss: 0.4435
# [126]	valid_0's binary_logloss: 0.443005
# [127]	valid_0's binary_logloss: 0.442513
# [128]	valid_0's binary_logloss: 0.442004
# [129]	valid_0's binary_logloss: 0.441581
# [130]	valid_0's binary_logloss: 0.441169
# [131]	valid_0's binary_logloss: 0.440702
# [132]	valid_0's binary_logloss: 0.440218
# [133]	valid_0's binary_logloss: 0.439759
# [134]	valid_0's binary_logloss: 0.439288
# [135]	valid_0's binary_logloss: 0.438835
# [136]	valid_0's binary_logloss: 0.438398
# [137]	valid_0's binary_logloss: 0.43801
# [138]	valid_0's binary_logloss: 0.437576
# [139]	valid_0's binary_logloss: 0.437142
# [140]	valid_0's binary_logloss: 0.436717
# [141]	valid_0's binary_logloss: 0.436301
# [142]	valid_0's binary_logloss: 0.43588
# [143]	valid_0's binary_logloss: 0.435467
# [144]	valid_0's binary_logloss: 0.435061
# [145]	valid_0's binary_logloss: 0.434653
# [146]	valid_0's binary_logloss: 0.434261
# [147]	valid_0's binary_logloss: 0.433875
# [148]	valid_0's binary_logloss: 0.433489
# [149]	valid_0's binary_logloss: 0.433108
# [150]	valid_0's binary_logloss: 0.432724
# [151]	valid_0's binary_logloss: 0.432363
# [152]	valid_0's binary_logloss: 0.431988
# [153]	valid_0's binary_logloss: 0.431619
# [154]	valid_0's binary_logloss: 0.431244
# [155]	valid_0's binary_logloss: 0.430871
# [156]	valid_0's binary_logloss: 0.430499
# [157]	valid_0's binary_logloss: 0.430131
# [158]	valid_0's binary_logloss: 0.429792
# [159]	valid_0's binary_logloss: 0.429441
# [160]	valid_0's binary_logloss: 0.429085
# [161]	valid_0's binary_logloss: 0.428746
# [162]	valid_0's binary_logloss: 0.428399
# [163]	valid_0's binary_logloss: 0.428114
# [164]	valid_0's binary_logloss: 0.427783
# [165]	valid_0's binary_logloss: 0.427451
# [166]	valid_0's binary_logloss: 0.42714
# [167]	valid_0's binary_logloss: 0.426819
# [168]	valid_0's binary_logloss: 0.426493
# [169]	valid_0's binary_logloss: 0.426177
# [170]	valid_0's binary_logloss: 0.425862
# [171]	valid_0's binary_logloss: 0.425562
# [172]	valid_0's binary_logloss: 0.425238
# [173]	valid_0's binary_logloss: 0.424937
# [174]	valid_0's binary_logloss: 0.424642
# [175]	valid_0's binary_logloss: 0.424335
# [176]	valid_0's binary_logloss: 0.424038
# [177]	valid_0's binary_logloss: 0.42375
# [178]	valid_0's binary_logloss: 0.423471
# [179]	valid_0's binary_logloss: 0.423182
# [180]	valid_0's binary_logloss: 0.422908
# [181]	valid_0's binary_logloss: 0.422684
# [182]	valid_0's binary_logloss: 0.422421
# [183]	valid_0's binary_logloss: 0.422136
# [184]	valid_0's binary_logloss: 0.421856
# [185]	valid_0's binary_logloss: 0.421579
# [186]	valid_0's binary_logloss: 0.42136
# [187]	valid_0's binary_logloss: 0.42108
# [188]	valid_0's binary_logloss: 0.420808
# [189]	valid_0's binary_logloss: 0.42053
# [190]	valid_0's binary_logloss: 0.420274
# [191]	valid_0's binary_logloss: 0.42001
# [192]	valid_0's binary_logloss: 0.41982
# [193]	valid_0's binary_logloss: 0.419566
# [194]	valid_0's binary_logloss: 0.419311
# [195]	valid_0's binary_logloss: 0.419104
# [196]	valid_0's binary_logloss: 0.418906
# [197]	valid_0's binary_logloss: 0.418665
# [198]	valid_0's binary_logloss: 0.418414
# [199]	valid_0's binary_logloss: 0.418185
# [200]	valid_0's binary_logloss: 0.417953
# [201]	valid_0's binary_logloss: 0.417716
# [202]	valid_0's binary_logloss: 0.41749
# [203]	valid_0's binary_logloss: 0.41724
# [204]	valid_0's binary_logloss: 0.417023
# [205]	valid_0's binary_logloss: 0.416788
# [206]	valid_0's binary_logloss: 0.416606
# [207]	valid_0's binary_logloss: 0.416359
# [208]	valid_0's binary_logloss: 0.416139
# [209]	valid_0's binary_logloss: 0.415919
# [210]	valid_0's binary_logloss: 0.415698
# [211]	valid_0's binary_logloss: 0.415467
# [212]	valid_0's binary_logloss: 0.415251
# [213]	valid_0's binary_logloss: 0.41502
# [214]	valid_0's binary_logloss: 0.414825
# [215]	valid_0's binary_logloss: 0.414607
# [216]	valid_0's binary_logloss: 0.414406
# [217]	valid_0's binary_logloss: 0.414191
# [218]	valid_0's binary_logloss: 0.413996
# [219]	valid_0's binary_logloss: 0.413791
# [220]	valid_0's binary_logloss: 0.413594
# [221]	valid_0's binary_logloss: 0.413399
# [222]	valid_0's binary_logloss: 0.413199
# [223]	valid_0's binary_logloss: 0.412996
# [224]	valid_0's binary_logloss: 0.412786
# [225]	valid_0's binary_logloss: 0.412596
# [226]	valid_0's binary_logloss: 0.412411
# [227]	valid_0's binary_logloss: 0.412203
# [228]	valid_0's binary_logloss: 0.412005
# [229]	valid_0's binary_logloss: 0.411799
# [230]	valid_0's binary_logloss: 0.411608
# [231]	valid_0's binary_logloss: 0.411403
# [232]	valid_0's binary_logloss: 0.411208
# [233]	valid_0's binary_logloss: 0.411018
# [234]	valid_0's binary_logloss: 0.410849
# [235]	valid_0's binary_logloss: 0.410669
# [236]	valid_0's binary_logloss: 0.410532
# [237]	valid_0's binary_logloss: 0.410384
# [238]	valid_0's binary_logloss: 0.41021
# [239]	valid_0's binary_logloss: 0.410019
# [240]	valid_0's binary_logloss: 0.409858
# [241]	valid_0's binary_logloss: 0.40967
# [242]	valid_0's binary_logloss: 0.409507
# [243]	valid_0's binary_logloss: 0.409325
# [244]	valid_0's binary_logloss: 0.409173
# [245]	valid_0's binary_logloss: 0.409002
# [246]	valid_0's binary_logloss: 0.408866
# [247]	valid_0's binary_logloss: 0.408693
# [248]	valid_0's binary_logloss: 0.408505
# [249]	valid_0's binary_logloss: 0.408352
# [250]	valid_0's binary_logloss: 0.408202
# [251]	valid_0's binary_logloss: 0.408025
# [252]	valid_0's binary_logloss: 0.407845
# [253]	valid_0's binary_logloss: 0.407678
# [254]	valid_0's binary_logloss: 0.407547
# [255]	valid_0's binary_logloss: 0.4074
# [256]	valid_0's binary_logloss: 0.407235
# [257]	valid_0's binary_logloss: 0.407073
# [258]	valid_0's binary_logloss: 0.406901
# [259]	valid_0's binary_logloss: 0.406768
# [260]	valid_0's binary_logloss: 0.406611
# [261]	valid_0's binary_logloss: 0.406471
# [262]	valid_0's binary_logloss: 0.406308
# [263]	valid_0's binary_logloss: 0.406155
# [264]	valid_0's binary_logloss: 0.406051
# [265]	valid_0's binary_logloss: 0.405934
# [266]	valid_0's binary_logloss: 0.4058
# [267]	valid_0's binary_logloss: 0.405646
# [268]	valid_0's binary_logloss: 0.405516
# [269]	valid_0's binary_logloss: 0.405352
# [270]	valid_0's binary_logloss: 0.40523
# [271]	valid_0's binary_logloss: 0.405087
# [272]	valid_0's binary_logloss: 0.404954
# [273]	valid_0's binary_logloss: 0.404797
# [274]	valid_0's binary_logloss: 0.404633
# [275]	valid_0's binary_logloss: 0.404479
# [276]	valid_0's binary_logloss: 0.404363
# [277]	valid_0's binary_logloss: 0.404215
# [278]	valid_0's binary_logloss: 0.40412
# [279]	valid_0's binary_logloss: 0.403987
# [280]	valid_0's binary_logloss: 0.403848
# [281]	valid_0's binary_logloss: 0.403729
# [282]	valid_0's binary_logloss: 0.403591
# [283]	valid_0's binary_logloss: 0.403459
# [284]	valid_0's binary_logloss: 0.40333
# [285]	valid_0's binary_logloss: 0.403195
# [286]	valid_0's binary_logloss: 0.403095
# [287]	valid_0's binary_logloss: 0.402968
# [288]	valid_0's binary_logloss: 0.402833
# [289]	valid_0's binary_logloss: 0.402693
# [290]	valid_0's binary_logloss: 0.402557
# [291]	valid_0's binary_logloss: 0.40246
# [292]	valid_0's binary_logloss: 0.402325
# [293]	valid_0's binary_logloss: 0.402193
# [294]	valid_0's binary_logloss: 0.402075
# [295]	valid_0's binary_logloss: 0.401941
# [296]	valid_0's binary_logloss: 0.401822
# [297]	valid_0's binary_logloss: 0.401736
# [298]	valid_0's binary_logloss: 0.401601
# [299]	valid_0's binary_logloss: 0.401488
# [300]	valid_0's binary_logloss: 0.401361
# [301]	valid_0's binary_logloss: 0.401247
# [302]	valid_0's binary_logloss: 0.401124
# [303]	valid_0's binary_logloss: 0.401006
# [304]	valid_0's binary_logloss: 0.400879
# [305]	valid_0's binary_logloss: 0.40077
# [306]	valid_0's binary_logloss: 0.40065
# [307]	valid_0's binary_logloss: 0.400537
# [308]	valid_0's binary_logloss: 0.400436
# [309]	valid_0's binary_logloss: 0.400311
# [310]	valid_0's binary_logloss: 0.400191
# [311]	valid_0's binary_logloss: 0.400091
# [312]	valid_0's binary_logloss: 0.399978
# [313]	valid_0's binary_logloss: 0.399875
# [314]	valid_0's binary_logloss: 0.399765
# [315]	valid_0's binary_logloss: 0.399676
# [316]	valid_0's binary_logloss: 0.399563
# [317]	valid_0's binary_logloss: 0.399442
# [318]	valid_0's binary_logloss: 0.399309
# [319]	valid_0's binary_logloss: 0.399202
# [320]	valid_0's binary_logloss: 0.399123
# [321]	valid_0's binary_logloss: 0.399052
# [322]	valid_0's binary_logloss: 0.398938
# [323]	valid_0's binary_logloss: 0.398827
# [324]	valid_0's binary_logloss: 0.39875
# [325]	valid_0's binary_logloss: 0.398646
# [326]	valid_0's binary_logloss: 0.398541
# [327]	valid_0's binary_logloss: 0.398442
# [328]	valid_0's binary_logloss: 0.398335
# [329]	valid_0's binary_logloss: 0.398261
# [330]	valid_0's binary_logloss: 0.398155
# [331]	valid_0's binary_logloss: 0.398061
# [332]	valid_0's binary_logloss: 0.397945
# [333]	valid_0's binary_logloss: 0.397847
# [334]	valid_0's binary_logloss: 0.397777
# [335]	valid_0's binary_logloss: 0.397692
# [336]	valid_0's binary_logloss: 0.397601
# [337]	valid_0's binary_logloss: 0.397529
# [338]	valid_0's binary_logloss: 0.397429
# [339]	valid_0's binary_logloss: 0.397348
# [340]	valid_0's binary_logloss: 0.397247
# [341]	valid_0's binary_logloss: 0.397143
# [342]	valid_0's binary_logloss: 0.397048
# [343]	valid_0's binary_logloss: 0.396955
# [344]	valid_0's binary_logloss: 0.396861
# [345]	valid_0's binary_logloss: 0.396773
# [346]	valid_0's binary_logloss: 0.396715
# [347]	valid_0's binary_logloss: 0.396619
# [348]	valid_0's binary_logloss: 0.396525
# [349]	valid_0's binary_logloss: 0.396443
# [350]	valid_0's binary_logloss: 0.396359
# [351]	valid_0's binary_logloss: 0.39628
# [352]	valid_0's binary_logloss: 0.396202
# [353]	valid_0's binary_logloss: 0.396126
# [354]	valid_0's binary_logloss: 0.396045
# [355]	valid_0's binary_logloss: 0.395941
# [356]	valid_0's binary_logloss: 0.395849
# [357]	valid_0's binary_logloss: 0.395748
# [358]	valid_0's binary_logloss: 0.39566
# [359]	valid_0's binary_logloss: 0.395577
# [360]	valid_0's binary_logloss: 0.395497
# [361]	valid_0's binary_logloss: 0.395415
# [362]	valid_0's binary_logloss: 0.395338
# [363]	valid_0's binary_logloss: 0.395261
# [364]	valid_0's binary_logloss: 0.395172
# [365]	valid_0's binary_logloss: 0.395065
# [366]	valid_0's binary_logloss: 0.394986
# [367]	valid_0's binary_logloss: 0.394906
# [368]	valid_0's binary_logloss: 0.394823
# [369]	valid_0's binary_logloss: 0.394737
# [370]	valid_0's binary_logloss: 0.394678
# [371]	valid_0's binary_logloss: 0.394577
# [372]	valid_0's binary_logloss: 0.394503
# [373]	valid_0's binary_logloss: 0.394452
# [374]	valid_0's binary_logloss: 0.394393
# [375]	valid_0's binary_logloss: 0.394308
# [376]	valid_0's binary_logloss: 0.394228
# [377]	valid_0's binary_logloss: 0.394174
# [378]	valid_0's binary_logloss: 0.394099
# [379]	valid_0's binary_logloss: 0.394046
# [380]	valid_0's binary_logloss: 0.393968
# [381]	valid_0's binary_logloss: 0.393905
# [382]	valid_0's binary_logloss: 0.393843
# [383]	valid_0's binary_logloss: 0.393786
# [384]	valid_0's binary_logloss: 0.39371
# [385]	valid_0's binary_logloss: 0.393637
# [386]	valid_0's binary_logloss: 0.393556
# [387]	valid_0's binary_logloss: 0.393489
# [388]	valid_0's binary_logloss: 0.393416
# [389]	valid_0's binary_logloss: 0.393347
# [390]	valid_0's binary_logloss: 0.393257
# [391]	valid_0's binary_logloss: 0.393167
# [392]	valid_0's binary_logloss: 0.393097
# [393]	valid_0's binary_logloss: 0.393014
# [394]	valid_0's binary_logloss: 0.392943
# [395]	valid_0's binary_logloss: 0.392865
# [396]	valid_0's binary_logloss: 0.392794
# [397]	valid_0's binary_logloss: 0.392729
# [398]	valid_0's binary_logloss: 0.392663
# [399]	valid_0's binary_logloss: 0.392616
# [400]	valid_0's binary_logloss: 0.392548
# [401]	valid_0's binary_logloss: 0.392486
# [402]	valid_0's binary_logloss: 0.392425
# [403]	valid_0's binary_logloss: 0.392359
# [404]	valid_0's binary_logloss: 0.392296
# [405]	valid_0's binary_logloss: 0.392249
# [406]	valid_0's binary_logloss: 0.392182
# [407]	valid_0's binary_logloss: 0.392113
# [408]	valid_0's binary_logloss: 0.39206
# [409]	valid_0's binary_logloss: 0.39199
# [410]	valid_0's binary_logloss: 0.391929
# [411]	valid_0's binary_logloss: 0.391863
# [412]	valid_0's binary_logloss: 0.3918
# [413]	valid_0's binary_logloss: 0.391744
# [414]	valid_0's binary_logloss: 0.391678
# [415]	valid_0's binary_logloss: 0.391616
# [416]	valid_0's binary_logloss: 0.391551
# [417]	valid_0's binary_logloss: 0.391493
# [418]	valid_0's binary_logloss: 0.391436
# [419]	valid_0's binary_logloss: 0.391375
# [420]	valid_0's binary_logloss: 0.391308
# [421]	valid_0's binary_logloss: 0.391255
# [422]	valid_0's binary_logloss: 0.391195
# [423]	valid_0's binary_logloss: 0.391134
# [424]	valid_0's binary_logloss: 0.391073
# [425]	valid_0's binary_logloss: 0.391012
# [426]	valid_0's binary_logloss: 0.390963
# [427]	valid_0's binary_logloss: 0.390918
# [428]	valid_0's binary_logloss: 0.39088
# [429]	valid_0's binary_logloss: 0.39083
# [430]	valid_0's binary_logloss: 0.390771
# [431]	valid_0's binary_logloss: 0.390708
# [432]	valid_0's binary_logloss: 0.390641
# [433]	valid_0's binary_logloss: 0.39058
# [434]	valid_0's binary_logloss: 0.390523
# [435]	valid_0's binary_logloss: 0.390464
# [436]	valid_0's binary_logloss: 0.39041
# [437]	valid_0's binary_logloss: 0.390358
# [438]	valid_0's binary_logloss: 0.390309
# [439]	valid_0's binary_logloss: 0.390259
# [440]	valid_0's binary_logloss: 0.390198
# [441]	valid_0's binary_logloss: 0.390145
# [442]	valid_0's binary_logloss: 0.390095
# [443]	valid_0's binary_logloss: 0.390039
# [444]	valid_0's binary_logloss: 0.389981
# [445]	valid_0's binary_logloss: 0.389943
# [446]	valid_0's binary_logloss: 0.389896
# [447]	valid_0's binary_logloss: 0.38986
# [448]	valid_0's binary_logloss: 0.389796
# [449]	valid_0's binary_logloss: 0.389737
# [450]	valid_0's binary_logloss: 0.38968
# [451]	valid_0's binary_logloss: 0.389636
# [452]	valid_0's binary_logloss: 0.389584
# [453]	valid_0's binary_logloss: 0.38953
# [454]	valid_0's binary_logloss: 0.389476
# [455]	valid_0's binary_logloss: 0.389418
# [456]	valid_0's binary_logloss: 0.389368
# [457]	valid_0's binary_logloss: 0.389308
# [458]	valid_0's binary_logloss: 0.389231
# [459]	valid_0's binary_logloss: 0.389184
# [460]	valid_0's binary_logloss: 0.389118
# [461]	valid_0's binary_logloss: 0.389064
# [462]	valid_0's binary_logloss: 0.389029
# [463]	valid_0's binary_logloss: 0.388979
# [464]	valid_0's binary_logloss: 0.388928
# [465]	valid_0's binary_logloss: 0.38885
# [466]	valid_0's binary_logloss: 0.388796
# [467]	valid_0's binary_logloss: 0.388748
# [468]	valid_0's binary_logloss: 0.388697
# [469]	valid_0's binary_logloss: 0.388653
# [470]	valid_0's binary_logloss: 0.388607
# [471]	valid_0's binary_logloss: 0.388559
# [472]	valid_0's binary_logloss: 0.38851
# [473]	valid_0's binary_logloss: 0.388462
# [474]	valid_0's binary_logloss: 0.388421
# [475]	valid_0's binary_logloss: 0.388376
# [476]	valid_0's binary_logloss: 0.388308
# [477]	valid_0's binary_logloss: 0.388266
# [478]	valid_0's binary_logloss: 0.388203
# [479]	valid_0's binary_logloss: 0.388164
# [480]	valid_0's binary_logloss: 0.388118
# [481]	valid_0's binary_logloss: 0.388071
# [482]	valid_0's binary_logloss: 0.388017
# [483]	valid_0's binary_logloss: 0.387966
# [484]	valid_0's binary_logloss: 0.387925
# [485]	valid_0's binary_logloss: 0.387884
# [486]	valid_0's binary_logloss: 0.387835
# [487]	valid_0's binary_logloss: 0.387794
# [488]	valid_0's binary_logloss: 0.387749
# [489]	valid_0's binary_logloss: 0.387677
# [490]	valid_0's binary_logloss: 0.387634
# [491]	valid_0's binary_logloss: 0.387578
# [492]	valid_0's binary_logloss: 0.387523
# [493]	valid_0's binary_logloss: 0.387487
# [494]	valid_0's binary_logloss: 0.387454
# [495]	valid_0's binary_logloss: 0.387409
# [496]	valid_0's binary_logloss: 0.387365
# [497]	valid_0's binary_logloss: 0.387307
# [498]	valid_0's binary_logloss: 0.387258
# [499]	valid_0's binary_logloss: 0.387209
# [500]	valid_0's binary_logloss: 0.38717
# [501]	valid_0's binary_logloss: 0.387129
# [502]	valid_0's binary_logloss: 0.3871
# [503]	valid_0's binary_logloss: 0.387045
# [504]	valid_0's binary_logloss: 0.386992
# [505]	valid_0's binary_logloss: 0.386931
# [506]	valid_0's binary_logloss: 0.386873
# [507]	valid_0's binary_logloss: 0.386814
# [508]	valid_0's binary_logloss: 0.386755
# [509]	valid_0's binary_logloss: 0.386722
# [510]	valid_0's binary_logloss: 0.386682
# [511]	valid_0's binary_logloss: 0.386642
# [512]	valid_0's binary_logloss: 0.386606
# [513]	valid_0's binary_logloss: 0.386552
# [514]	valid_0's binary_logloss: 0.386499
# [515]	valid_0's binary_logloss: 0.386454
# [516]	valid_0's binary_logloss: 0.386416
# [517]	valid_0's binary_logloss: 0.386364
# [518]	valid_0's binary_logloss: 0.386313
# [519]	valid_0's binary_logloss: 0.386274
# [520]	valid_0's binary_logloss: 0.386231
# [521]	valid_0's binary_logloss: 0.386182
# [522]	valid_0's binary_logloss: 0.386134
# [523]	valid_0's binary_logloss: 0.38611
# [524]	valid_0's binary_logloss: 0.38608
# [525]	valid_0's binary_logloss: 0.386028
# [526]	valid_0's binary_logloss: 0.385989
# [527]	valid_0's binary_logloss: 0.385944
# [528]	valid_0's binary_logloss: 0.385902
# [529]	valid_0's binary_logloss: 0.385859
# [530]	valid_0's binary_logloss: 0.385811
# [531]	valid_0's binary_logloss: 0.385783
# [532]	valid_0's binary_logloss: 0.385747
# [533]	valid_0's binary_logloss: 0.385704
# [534]	valid_0's binary_logloss: 0.385651
# [535]	valid_0's binary_logloss: 0.385616
# [536]	valid_0's binary_logloss: 0.385586
# [537]	valid_0's binary_logloss: 0.385548
# [538]	valid_0's binary_logloss: 0.385515
# [539]	valid_0's binary_logloss: 0.385484
# [540]	valid_0's binary_logloss: 0.385425
# [541]	valid_0's binary_logloss: 0.3854
# [542]	valid_0's binary_logloss: 0.38537
# [543]	valid_0's binary_logloss: 0.385333
# [544]	valid_0's binary_logloss: 0.385304
# [545]	valid_0's binary_logloss: 0.385266
# [546]	valid_0's binary_logloss: 0.385222
# [547]	valid_0's binary_logloss: 0.385172
# [548]	valid_0's binary_logloss: 0.385134
# [549]	valid_0's binary_logloss: 0.385102
# [550]	valid_0's binary_logloss: 0.38507
# [551]	valid_0's binary_logloss: 0.385034
# [552]	valid_0's binary_logloss: 0.384983
# [553]	valid_0's binary_logloss: 0.384941
# [554]	valid_0's binary_logloss: 0.384912
# [555]	valid_0's binary_logloss: 0.38488
# [556]	valid_0's binary_logloss: 0.38482
# [557]	valid_0's binary_logloss: 0.384778
# [558]	valid_0's binary_logloss: 0.384731
# [559]	valid_0's binary_logloss: 0.384699
# [560]	valid_0's binary_logloss: 0.384673
# [561]	valid_0's binary_logloss: 0.384638
# [562]	valid_0's binary_logloss: 0.384604
# [563]	valid_0's binary_logloss: 0.384575
# [564]	valid_0's binary_logloss: 0.384538
# [565]	valid_0's binary_logloss: 0.384488
# [566]	valid_0's binary_logloss: 0.384438
# [567]	valid_0's binary_logloss: 0.384404
# [568]	valid_0's binary_logloss: 0.384347
# [569]	valid_0's binary_logloss: 0.384323
# [570]	valid_0's binary_logloss: 0.384297
# [571]	valid_0's binary_logloss: 0.384274
# [572]	valid_0's binary_logloss: 0.384236
# [573]	valid_0's binary_logloss: 0.384183
# [574]	valid_0's binary_logloss: 0.384154
# [575]	valid_0's binary_logloss: 0.384124
# [576]	valid_0's binary_logloss: 0.384097
# [577]	valid_0's binary_logloss: 0.384077
# [578]	valid_0's binary_logloss: 0.384035
# [579]	valid_0's binary_logloss: 0.384001
# [580]	valid_0's binary_logloss: 0.383974
# [581]	valid_0's binary_logloss: 0.38395
# [582]	valid_0's binary_logloss: 0.383924
# [583]	valid_0's binary_logloss: 0.383882
# [584]	valid_0's binary_logloss: 0.38384
# [585]	valid_0's binary_logloss: 0.383809
# [586]	valid_0's binary_logloss: 0.383791
# [587]	valid_0's binary_logloss: 0.383761
# [588]	valid_0's binary_logloss: 0.383736
# [589]	valid_0's binary_logloss: 0.383704
# [590]	valid_0's binary_logloss: 0.383681
# [591]	valid_0's binary_logloss: 0.383646
# [592]	valid_0's binary_logloss: 0.383629
# [593]	valid_0's binary_logloss: 0.38359
# [594]	valid_0's binary_logloss: 0.383552
# [595]	valid_0's binary_logloss: 0.383532
# [596]	valid_0's binary_logloss: 0.383495
# [597]	valid_0's binary_logloss: 0.383477
# [598]	valid_0's binary_logloss: 0.38345
# [599]	valid_0's binary_logloss: 0.383423
# [600]	valid_0's binary_logloss: 0.383389
# [601]	valid_0's binary_logloss: 0.383361
# [602]	valid_0's binary_logloss: 0.383347
# [603]	valid_0's binary_logloss: 0.383313
# [604]	valid_0's binary_logloss: 0.383289
# [605]	valid_0's binary_logloss: 0.383257
# [606]	valid_0's binary_logloss: 0.383231
# [607]	valid_0's binary_logloss: 0.383208
# [608]	valid_0's binary_logloss: 0.383152
# [609]	valid_0's binary_logloss: 0.383116
# [610]	valid_0's binary_logloss: 0.38308
# [611]	valid_0's binary_logloss: 0.383058
# [612]	valid_0's binary_logloss: 0.383022
# [613]	valid_0's binary_logloss: 0.383001
# [614]	valid_0's binary_logloss: 0.382962
# [615]	valid_0's binary_logloss: 0.382943
# [616]	valid_0's binary_logloss: 0.382906
# [617]	valid_0's binary_logloss: 0.382873
# [618]	valid_0's binary_logloss: 0.382857
# [619]	valid_0's binary_logloss: 0.382827
# [620]	valid_0's binary_logloss: 0.382805
# [621]	valid_0's binary_logloss: 0.382763
# [622]	valid_0's binary_logloss: 0.382734
# [623]	valid_0's binary_logloss: 0.382726
# [624]	valid_0's binary_logloss: 0.382689
# [625]	valid_0's binary_logloss: 0.382648
# [626]	valid_0's binary_logloss: 0.382623
# [627]	valid_0's binary_logloss: 0.382585
# [628]	valid_0's binary_logloss: 0.382572
# [629]	valid_0's binary_logloss: 0.382536
# [630]	valid_0's binary_logloss: 0.382522
# [631]	valid_0's binary_logloss: 0.382499
# [632]	valid_0's binary_logloss: 0.382469
# [633]	valid_0's binary_logloss: 0.382446
# [634]	valid_0's binary_logloss: 0.382431
# [635]	valid_0's binary_logloss: 0.382411
# [636]	valid_0's binary_logloss: 0.382385
# [637]	valid_0's binary_logloss: 0.382365
# [638]	valid_0's binary_logloss: 0.382331
# [639]	valid_0's binary_logloss: 0.382291
# [640]	valid_0's binary_logloss: 0.382279
# [641]	valid_0's binary_logloss: 0.382258
# [642]	valid_0's binary_logloss: 0.38222
# [643]	valid_0's binary_logloss: 0.38219
# [644]	valid_0's binary_logloss: 0.38217
# [645]	valid_0's binary_logloss: 0.382139
# [646]	valid_0's binary_logloss: 0.382115
# [647]	valid_0's binary_logloss: 0.382077
# [648]	valid_0's binary_logloss: 0.382037
# [649]	valid_0's binary_logloss: 0.382015
# [650]	valid_0's binary_logloss: 0.381987
# [651]	valid_0's binary_logloss: 0.381969
# [652]	valid_0's binary_logloss: 0.381947
# [653]	valid_0's binary_logloss: 0.381917
# [654]	valid_0's binary_logloss: 0.381875
# [655]	valid_0's binary_logloss: 0.38184
# [656]	valid_0's binary_logloss: 0.381825
# [657]	valid_0's binary_logloss: 0.381785
# [658]	valid_0's binary_logloss: 0.381762
# [659]	valid_0's binary_logloss: 0.38174
# [660]	valid_0's binary_logloss: 0.381703
# [661]	valid_0's binary_logloss: 0.381666
# [662]	valid_0's binary_logloss: 0.381645
# [663]	valid_0's binary_logloss: 0.381625
# [664]	valid_0's binary_logloss: 0.381592
# [665]	valid_0's binary_logloss: 0.381565
# [666]	valid_0's binary_logloss: 0.38155
# [667]	valid_0's binary_logloss: 0.38153
# [668]	valid_0's binary_logloss: 0.381511
# [669]	valid_0's binary_logloss: 0.381488
# [670]	valid_0's binary_logloss: 0.381473
# [671]	valid_0's binary_logloss: 0.381456
# [672]	valid_0's binary_logloss: 0.381427
# [673]	valid_0's binary_logloss: 0.381407
# [674]	valid_0's binary_logloss: 0.381355
# [675]	valid_0's binary_logloss: 0.381319
# [676]	valid_0's binary_logloss: 0.381296
# [677]	valid_0's binary_logloss: 0.381284
# [678]	valid_0's binary_logloss: 0.381249
# [679]	valid_0's binary_logloss: 0.381225
# [680]	valid_0's binary_logloss: 0.3812
# [681]	valid_0's binary_logloss: 0.38116
# [682]	valid_0's binary_logloss: 0.381126
# [683]	valid_0's binary_logloss: 0.381098
# [684]	valid_0's binary_logloss: 0.381092
# [685]	valid_0's binary_logloss: 0.381061
# [686]	valid_0's binary_logloss: 0.381046
# [687]	valid_0's binary_logloss: 0.381009
# [688]	valid_0's binary_logloss: 0.380977
# [689]	valid_0's binary_logloss: 0.380953
# [690]	valid_0's binary_logloss: 0.380914
# [691]	valid_0's binary_logloss: 0.380882
# [692]	valid_0's binary_logloss: 0.380843
# [693]	valid_0's binary_logloss: 0.380826
# [694]	valid_0's binary_logloss: 0.380777
# [695]	valid_0's binary_logloss: 0.380764
# [696]	valid_0's binary_logloss: 0.380732
# [697]	valid_0's binary_logloss: 0.380688
# [698]	valid_0's binary_logloss: 0.380669
# [699]	valid_0's binary_logloss: 0.380644
# [700]	valid_0's binary_logloss: 0.380631
# [701]	valid_0's binary_logloss: 0.380605
# [702]	valid_0's binary_logloss: 0.380582
# [703]	valid_0's binary_logloss: 0.380562
# [704]	valid_0's binary_logloss: 0.380556
# [705]	valid_0's binary_logloss: 0.380524
# [706]	valid_0's binary_logloss: 0.380479
# [707]	valid_0's binary_logloss: 0.380449
# [708]	valid_0's binary_logloss: 0.380431
# [709]	valid_0's binary_logloss: 0.380411
# [710]	valid_0's binary_logloss: 0.380388
# [711]	valid_0's binary_logloss: 0.380369
# [712]	valid_0's binary_logloss: 0.38036
# [713]	valid_0's binary_logloss: 0.380323
# [714]	valid_0's binary_logloss: 0.380282
# [715]	valid_0's binary_logloss: 0.380266
# [716]	valid_0's binary_logloss: 0.380253
# [717]	valid_0's binary_logloss: 0.380228
# [718]	valid_0's binary_logloss: 0.380199
# [719]	valid_0's binary_logloss: 0.380179
# [720]	valid_0's binary_logloss: 0.380143
# [721]	valid_0's binary_logloss: 0.380133
# [722]	valid_0's binary_logloss: 0.380108
# [723]	valid_0's binary_logloss: 0.380083
# [724]	valid_0's binary_logloss: 0.380056
# [725]	valid_0's binary_logloss: 0.380037
# [726]	valid_0's binary_logloss: 0.380029
# [727]	valid_0's binary_logloss: 0.380006
# [728]	valid_0's binary_logloss: 0.379992
# [729]	valid_0's binary_logloss: 0.379979
# [730]	valid_0's binary_logloss: 0.379935
# [731]	valid_0's binary_logloss: 0.379917
# [732]	valid_0's binary_logloss: 0.379903
# [733]	valid_0's binary_logloss: 0.379878
# [734]	valid_0's binary_logloss: 0.379863
# [735]	valid_0's binary_logloss: 0.379834
# [736]	valid_0's binary_logloss: 0.379818
# [737]	valid_0's binary_logloss: 0.379803
# [738]	valid_0's binary_logloss: 0.379766
# [739]	valid_0's binary_logloss: 0.379739
# [740]	valid_0's binary_logloss: 0.379718
# [741]	valid_0's binary_logloss: 0.379705
# [742]	valid_0's binary_logloss: 0.379682
# [743]	valid_0's binary_logloss: 0.379677
# [744]	valid_0's binary_logloss: 0.379666
# [745]	valid_0's binary_logloss: 0.379641
# [746]	valid_0's binary_logloss: 0.379615
# [747]	valid_0's binary_logloss: 0.379595
# [748]	valid_0's binary_logloss: 0.379574
# [749]	valid_0's binary_logloss: 0.37956
# [750]	valid_0's binary_logloss: 0.379538
# [751]	valid_0's binary_logloss: 0.3795
# [752]	valid_0's binary_logloss: 0.37948
# [753]	valid_0's binary_logloss: 0.379462
# [754]	valid_0's binary_logloss: 0.379441
# [755]	valid_0's binary_logloss: 0.37941
# [756]	valid_0's binary_logloss: 0.379389
# [757]	valid_0's binary_logloss: 0.379382
# [758]	valid_0's binary_logloss: 0.379366
# [759]	valid_0's binary_logloss: 0.379341
# [760]	valid_0's binary_logloss: 0.379322
# [761]	valid_0's binary_logloss: 0.379298
# [762]	valid_0's binary_logloss: 0.379284
# [763]	valid_0's binary_logloss: 0.379273
# [764]	valid_0's binary_logloss: 0.379256
# [765]	valid_0's binary_logloss: 0.379235
# [766]	valid_0's binary_logloss: 0.379217
# [767]	valid_0's binary_logloss: 0.379185
# [768]	valid_0's binary_logloss: 0.379157
# [769]	valid_0's binary_logloss: 0.379152
# [770]	valid_0's binary_logloss: 0.379127
# [771]	valid_0's binary_logloss: 0.379104
# [772]	valid_0's binary_logloss: 0.379094
# [773]	valid_0's binary_logloss: 0.379082
# [774]	valid_0's binary_logloss: 0.379063
# [775]	valid_0's binary_logloss: 0.379054
# [776]	valid_0's binary_logloss: 0.379018
# [777]	valid_0's binary_logloss: 0.379
# [778]	valid_0's binary_logloss: 0.378979
# [779]	valid_0's binary_logloss: 0.378974
# [780]	valid_0's binary_logloss: 0.378961
# [781]	valid_0's binary_logloss: 0.378942
# [782]	valid_0's binary_logloss: 0.378925
# [783]	valid_0's binary_logloss: 0.378912
# [784]	valid_0's binary_logloss: 0.3789
# [785]	valid_0's binary_logloss: 0.378876
# [786]	valid_0's binary_logloss: 0.378848
# [787]	valid_0's binary_logloss: 0.378832
# [788]	valid_0's binary_logloss: 0.378803
# [789]	valid_0's binary_logloss: 0.378772
# [790]	valid_0's binary_logloss: 0.378762
# [791]	valid_0's binary_logloss: 0.378752
# [792]	valid_0's binary_logloss: 0.378733
# [793]	valid_0's binary_logloss: 0.378707
# [794]	valid_0's binary_logloss: 0.378691
# [795]	valid_0's binary_logloss: 0.378663
# [796]	valid_0's binary_logloss: 0.37864
# [797]	valid_0's binary_logloss: 0.378623
# [798]	valid_0's binary_logloss: 0.378602
# [799]	valid_0's binary_logloss: 0.378583
# [800]	valid_0's binary_logloss: 0.37857
# [801]	valid_0's binary_logloss: 0.378539
# [802]	valid_0's binary_logloss: 0.37852
# [803]	valid_0's binary_logloss: 0.378504
# [804]	valid_0's binary_logloss: 0.378498
# [805]	valid_0's binary_logloss: 0.378485
# [806]	valid_0's binary_logloss: 0.378473
# [807]	valid_0's binary_logloss: 0.378442
# [808]	valid_0's binary_logloss: 0.378428
# [809]	valid_0's binary_logloss: 0.37842
# [810]	valid_0's binary_logloss: 0.378407
# [811]	valid_0's binary_logloss: 0.378382
# [812]	valid_0's binary_logloss: 0.378365
# [813]	valid_0's binary_logloss: 0.378357
# [814]	valid_0's binary_logloss: 0.37834
# [815]	valid_0's binary_logloss: 0.3783
# [816]	valid_0's binary_logloss: 0.378291
# [817]	valid_0's binary_logloss: 0.378277
# [818]	valid_0's binary_logloss: 0.37826
# [819]	valid_0's binary_logloss: 0.378237
# [820]	valid_0's binary_logloss: 0.378222
# [821]	valid_0's binary_logloss: 0.378198
# [822]	valid_0's binary_logloss: 0.378182
# [823]	valid_0's binary_logloss: 0.378161
# [824]	valid_0's binary_logloss: 0.378131
# [825]	valid_0's binary_logloss: 0.378115
# [826]	valid_0's binary_logloss: 0.378102
# [827]	valid_0's binary_logloss: 0.378076
# [828]	valid_0's binary_logloss: 0.378059
# [829]	valid_0's binary_logloss: 0.378045
# [830]	valid_0's binary_logloss: 0.378036
# [831]	valid_0's binary_logloss: 0.378021
# [832]	valid_0's binary_logloss: 0.378018
# [833]	valid_0's binary_logloss: 0.378007
# [834]	valid_0's binary_logloss: 0.377999
# [835]	valid_0's binary_logloss: 0.377982
# [836]	valid_0's binary_logloss: 0.377969
# [837]	valid_0's binary_logloss: 0.377956
# [838]	valid_0's binary_logloss: 0.377928
# [839]	valid_0's binary_logloss: 0.377921
# [840]	valid_0's binary_logloss: 0.377907
# [841]	valid_0's binary_logloss: 0.377893
# [842]	valid_0's binary_logloss: 0.377876
# [843]	valid_0's binary_logloss: 0.377865
# [844]	valid_0's binary_logloss: 0.37785
# [845]	valid_0's binary_logloss: 0.377839
# [846]	valid_0's binary_logloss: 0.377825
# [847]	valid_0's binary_logloss: 0.377792
# [848]	valid_0's binary_logloss: 0.377766
# [849]	valid_0's binary_logloss: 0.377757
# [850]	valid_0's binary_logloss: 0.377743
# [851]	valid_0's binary_logloss: 0.377738
# [852]	valid_0's binary_logloss: 0.377718
# [853]	valid_0's binary_logloss: 0.377707
# [854]	valid_0's binary_logloss: 0.377685
# [855]	valid_0's binary_logloss: 0.377677
# [856]	valid_0's binary_logloss: 0.377659
# [857]	valid_0's binary_logloss: 0.377645
# [858]	valid_0's binary_logloss: 0.37762
# [859]	valid_0's binary_logloss: 0.377595
# [860]	valid_0's binary_logloss: 0.37758
# [861]	valid_0's binary_logloss: 0.377553
# [862]	valid_0's binary_logloss: 0.37754
# [863]	valid_0's binary_logloss: 0.377519
# [864]	valid_0's binary_logloss: 0.377495
# [865]	valid_0's binary_logloss: 0.377481
# [866]	valid_0's binary_logloss: 0.377469
# [867]	valid_0's binary_logloss: 0.377463
# [868]	valid_0's binary_logloss: 0.377438
# [869]	valid_0's binary_logloss: 0.377421
# [870]	valid_0's binary_logloss: 0.377413
# [871]	valid_0's binary_logloss: 0.377403
# [872]	valid_0's binary_logloss: 0.377395
# [873]	valid_0's binary_logloss: 0.377377
# [874]	valid_0's binary_logloss: 0.377359
# [875]	valid_0's binary_logloss: 0.377335
# [876]	valid_0's binary_logloss: 0.37731
# [877]	valid_0's binary_logloss: 0.377286
# [878]	valid_0's binary_logloss: 0.377275
# [879]	valid_0's binary_logloss: 0.377263
# [880]	valid_0's binary_logloss: 0.377254
# [881]	valid_0's binary_logloss: 0.377228
# [882]	valid_0's binary_logloss: 0.377209
# [883]	valid_0's binary_logloss: 0.37719
# [884]	valid_0's binary_logloss: 0.377161
# [885]	valid_0's binary_logloss: 0.377147
# [886]	valid_0's binary_logloss: 0.377135
# [887]	valid_0's binary_logloss: 0.377123
# [888]	valid_0's binary_logloss: 0.377097
# [889]	valid_0's binary_logloss: 0.377085
# [890]	valid_0's binary_logloss: 0.377055
# [891]	valid_0's binary_logloss: 0.377046
# [892]	valid_0's binary_logloss: 0.37703
# [893]	valid_0's binary_logloss: 0.377004
# [894]	valid_0's binary_logloss: 0.376983
# [895]	valid_0's binary_logloss: 0.376975
# [896]	valid_0's binary_logloss: 0.376954
# [897]	valid_0's binary_logloss: 0.376946
# [898]	valid_0's binary_logloss: 0.37694
# [899]	valid_0's binary_logloss: 0.376928
# [900]	valid_0's binary_logloss: 0.376918
# [901]	valid_0's binary_logloss: 0.376897
# [902]	valid_0's binary_logloss: 0.37689
# [903]	valid_0's binary_logloss: 0.376883
# [904]	valid_0's binary_logloss: 0.376869
# [905]	valid_0's binary_logloss: 0.376846
# [906]	valid_0's binary_logloss: 0.376836
# [907]	valid_0's binary_logloss: 0.376821
# [908]	valid_0's binary_logloss: 0.376811
# [909]	valid_0's binary_logloss: 0.376795
# [910]	valid_0's binary_logloss: 0.37678
# [911]	valid_0's binary_logloss: 0.376764
# [912]	valid_0's binary_logloss: 0.376755
# [913]	valid_0's binary_logloss: 0.376731
# [914]	valid_0's binary_logloss: 0.376719
# [915]	valid_0's binary_logloss: 0.376712
# [916]	valid_0's binary_logloss: 0.376701
# [917]	valid_0's binary_logloss: 0.376687
# [918]	valid_0's binary_logloss: 0.376669
# [919]	valid_0's binary_logloss: 0.376664
# [920]	valid_0's binary_logloss: 0.37664
# [921]	valid_0's binary_logloss: 0.376631
# [922]	valid_0's binary_logloss: 0.376614
# [923]	valid_0's binary_logloss: 0.376599
# [924]	valid_0's binary_logloss: 0.376572
# [925]	valid_0's binary_logloss: 0.376551
# [926]	valid_0's binary_logloss: 0.376532
# [927]	valid_0's binary_logloss: 0.37651
# [928]	valid_0's binary_logloss: 0.376488
# [929]	valid_0's binary_logloss: 0.376463
# [930]	valid_0's binary_logloss: 0.376461
# [931]	valid_0's binary_logloss: 0.376447
# [932]	valid_0's binary_logloss: 0.376435
# [933]	valid_0's binary_logloss: 0.376415
# [934]	valid_0's binary_logloss: 0.376402
# [935]	valid_0's binary_logloss: 0.376389
# [936]	valid_0's binary_logloss: 0.37638
# [937]	valid_0's binary_logloss: 0.37637
# [938]	valid_0's binary_logloss: 0.376365
# [939]	valid_0's binary_logloss: 0.376344
# [940]	valid_0's binary_logloss: 0.37632
# [941]	valid_0's binary_logloss: 0.376309
# [942]	valid_0's binary_logloss: 0.376289
# [943]	valid_0's binary_logloss: 0.376277
# [944]	valid_0's binary_logloss: 0.376266
# [945]	valid_0's binary_logloss: 0.376263
# [946]	valid_0's binary_logloss: 0.376256
# [947]	valid_0's binary_logloss: 0.376251
# [948]	valid_0's binary_logloss: 0.376241
# [949]	valid_0's binary_logloss: 0.376223
# [950]	valid_0's binary_logloss: 0.376215
# [951]	valid_0's binary_logloss: 0.376196
# [952]	valid_0's binary_logloss: 0.376167
# [953]	valid_0's binary_logloss: 0.376137
# [954]	valid_0's binary_logloss: 0.376125
# [955]	valid_0's binary_logloss: 0.376115
# [956]	valid_0's binary_logloss: 0.376104
# [957]	valid_0's binary_logloss: 0.376083
# [958]	valid_0's binary_logloss: 0.376061
# [959]	valid_0's binary_logloss: 0.376051
# [960]	valid_0's binary_logloss: 0.376044
# [961]	valid_0's binary_logloss: 0.376024
# [962]	valid_0's binary_logloss: 0.376001
# [963]	valid_0's binary_logloss: 0.375999
# [964]	valid_0's binary_logloss: 0.375991
# [965]	valid_0's binary_logloss: 0.375974
# [966]	valid_0's binary_logloss: 0.375962
# [967]	valid_0's binary_logloss: 0.375957
# [968]	valid_0's binary_logloss: 0.375951
# [969]	valid_0's binary_logloss: 0.375937
# [970]	valid_0's binary_logloss: 0.375928
# [971]	valid_0's binary_logloss: 0.375906
# [972]	valid_0's binary_logloss: 0.375891
# [973]	valid_0's binary_logloss: 0.375883
# [974]	valid_0's binary_logloss: 0.375856
# [975]	valid_0's binary_logloss: 0.375844
# [976]	valid_0's binary_logloss: 0.375822
# [977]	valid_0's binary_logloss: 0.375811
# [978]	valid_0's binary_logloss: 0.375795
# [979]	valid_0's binary_logloss: 0.37579
# [980]	valid_0's binary_logloss: 0.375782
# [981]	valid_0's binary_logloss: 0.375752
# [982]	valid_0's binary_logloss: 0.375746
# [983]	valid_0's binary_logloss: 0.375726
# [984]	valid_0's binary_logloss: 0.375718
# [985]	valid_0's binary_logloss: 0.375705
# [986]	valid_0's binary_logloss: 0.375696
# [987]	valid_0's binary_logloss: 0.375682
# [988]	valid_0's binary_logloss: 0.375673
# [989]	valid_0's binary_logloss: 0.375664
# [990]	valid_0's binary_logloss: 0.375653
# [991]	valid_0's binary_logloss: 0.375643
# [992]	valid_0's binary_logloss: 0.375622
# [993]	valid_0's binary_logloss: 0.375614
# [994]	valid_0's binary_logloss: 0.375589
# [995]	valid_0's binary_logloss: 0.375585
# [996]	valid_0's binary_logloss: 0.375564
# [997]	valid_0's binary_logloss: 0.375542
# [998]	valid_0's binary_logloss: 0.37554
# [999]	valid_0's binary_logloss: 0.375529
# [1000]	valid_0's binary_logloss: 0.375526
# [1001]	valid_0's binary_logloss: 0.37552
# [1002]	valid_0's binary_logloss: 0.375512
# [1003]	valid_0's binary_logloss: 0.375498
# [1004]	valid_0's binary_logloss: 0.375487
# [1005]	valid_0's binary_logloss: 0.375476
# [1006]	valid_0's binary_logloss: 0.37547
# [1007]	valid_0's binary_logloss: 0.375454
# [1008]	valid_0's binary_logloss: 0.375445
# [1009]	valid_0's binary_logloss: 0.375441
# [1010]	valid_0's binary_logloss: 0.375426
# [1011]	valid_0's binary_logloss: 0.375419
# [1012]	valid_0's binary_logloss: 0.375397
# [1013]	valid_0's binary_logloss: 0.375375
# [1014]	valid_0's binary_logloss: 0.37536
# [1015]	valid_0's binary_logloss: 0.375339
# [1016]	valid_0's binary_logloss: 0.375327
# [1017]	valid_0's binary_logloss: 0.375314
# [1018]	valid_0's binary_logloss: 0.375304
# [1019]	valid_0's binary_logloss: 0.375289
# [1020]	valid_0's binary_logloss: 0.375266
# [1021]	valid_0's binary_logloss: 0.37526
# [1022]	valid_0's binary_logloss: 0.375255
# [1023]	valid_0's binary_logloss: 0.375249
# [1024]	valid_0's binary_logloss: 0.375244
# [1025]	valid_0's binary_logloss: 0.375228
# [1026]	valid_0's binary_logloss: 0.375221
# [1027]	valid_0's binary_logloss: 0.375209
# [1028]	valid_0's binary_logloss: 0.375184
# [1029]	valid_0's binary_logloss: 0.375179
# [1030]	valid_0's binary_logloss: 0.37517
# [1031]	valid_0's binary_logloss: 0.375165
# [1032]	valid_0's binary_logloss: 0.375146
# [1033]	valid_0's binary_logloss: 0.375135
# [1034]	valid_0's binary_logloss: 0.375121
# [1035]	valid_0's binary_logloss: 0.375113
# [1036]	valid_0's binary_logloss: 0.375095
# [1037]	valid_0's binary_logloss: 0.375081
# [1038]	valid_0's binary_logloss: 0.37508
# [1039]	valid_0's binary_logloss: 0.375069
# [1040]	valid_0's binary_logloss: 0.375054
# [1041]	valid_0's binary_logloss: 0.375046
# [1042]	valid_0's binary_logloss: 0.375041
# [1043]	valid_0's binary_logloss: 0.375038
# [1044]	valid_0's binary_logloss: 0.375021
# [1045]	valid_0's binary_logloss: 0.375014
# [1046]	valid_0's binary_logloss: 0.375014
# [1047]	valid_0's binary_logloss: 0.375
# [1048]	valid_0's binary_logloss: 0.37499
# [1049]	valid_0's binary_logloss: 0.374979
# [1050]	valid_0's binary_logloss: 0.374973
# [1051]	valid_0's binary_logloss: 0.374972
# [1052]	valid_0's binary_logloss: 0.374964
# [1053]	valid_0's binary_logloss: 0.374963
# [1054]	valid_0's binary_logloss: 0.37494
# [1055]	valid_0's binary_logloss: 0.374924
# [1056]	valid_0's binary_logloss: 0.374905
# [1057]	valid_0's binary_logloss: 0.374895
# [1058]	valid_0's binary_logloss: 0.374889
# [1059]	valid_0's binary_logloss: 0.374883
# [1060]	valid_0's binary_logloss: 0.374869
# [1061]	valid_0's binary_logloss: 0.374862
# [1062]	valid_0's binary_logloss: 0.374854
# [1063]	valid_0's binary_logloss: 0.374847
# [1064]	valid_0's binary_logloss: 0.374838
# [1065]	valid_0's binary_logloss: 0.374816
# [1066]	valid_0's binary_logloss: 0.374807
# [1067]	valid_0's binary_logloss: 0.374792
# [1068]	valid_0's binary_logloss: 0.374785
# [1069]	valid_0's binary_logloss: 0.374773
# [1070]	valid_0's binary_logloss: 0.374764
# [1071]	valid_0's binary_logloss: 0.374753
# [1072]	valid_0's binary_logloss: 0.37475
# [1073]	valid_0's binary_logloss: 0.374749
# [1074]	valid_0's binary_logloss: 0.374728
# [1075]	valid_0's binary_logloss: 0.374709
# [1076]	valid_0's binary_logloss: 0.374703
# [1077]	valid_0's binary_logloss: 0.374698
# [1078]	valid_0's binary_logloss: 0.374695
# [1079]	valid_0's binary_logloss: 0.37469
# [1080]	valid_0's binary_logloss: 0.374685
# [1081]	valid_0's binary_logloss: 0.374661
# [1082]	valid_0's binary_logloss: 0.374636
# [1083]	valid_0's binary_logloss: 0.37463
# [1084]	valid_0's binary_logloss: 0.374615
# [1085]	valid_0's binary_logloss: 0.374602
# [1086]	valid_0's binary_logloss: 0.374594
# [1087]	valid_0's binary_logloss: 0.374575
# [1088]	valid_0's binary_logloss: 0.374565
# [1089]	valid_0's binary_logloss: 0.374545
# [1090]	valid_0's binary_logloss: 0.374525
# [1091]	valid_0's binary_logloss: 0.374516
# [1092]	valid_0's binary_logloss: 0.37451
# [1093]	valid_0's binary_logloss: 0.374508
# [1094]	valid_0's binary_logloss: 0.374492
# [1095]	valid_0's binary_logloss: 0.374487
# [1096]	valid_0's binary_logloss: 0.374482
# [1097]	valid_0's binary_logloss: 0.374469
# [1098]	valid_0's binary_logloss: 0.374455
# [1099]	valid_0's binary_logloss: 0.374448
# [1100]	valid_0's binary_logloss: 0.374439
# [1101]	valid_0's binary_logloss: 0.374428
# [1102]	valid_0's binary_logloss: 0.374408
# [1103]	valid_0's binary_logloss: 0.374404
# [1104]	valid_0's binary_logloss: 0.374399
# [1105]	valid_0's binary_logloss: 0.374386
# [1106]	valid_0's binary_logloss: 0.374377
# [1107]	valid_0's binary_logloss: 0.37437
# [1108]	valid_0's binary_logloss: 0.374354
# [1109]	valid_0's binary_logloss: 0.374346
# [1110]	valid_0's binary_logloss: 0.374339
# [1111]	valid_0's binary_logloss: 0.374324
# [1112]	valid_0's binary_logloss: 0.374305
# [1113]	valid_0's binary_logloss: 0.374306
# [1114]	valid_0's binary_logloss: 0.374292
# [1115]	valid_0's binary_logloss: 0.374288
# [1116]	valid_0's binary_logloss: 0.374275
# [1117]	valid_0's binary_logloss: 0.374267
# [1118]	valid_0's binary_logloss: 0.374258
# [1119]	valid_0's binary_logloss: 0.374254
# [1120]	valid_0's binary_logloss: 0.374243
# [1121]	valid_0's binary_logloss: 0.374243
# [1122]	valid_0's binary_logloss: 0.374238
# [1123]	valid_0's binary_logloss: 0.374233
# [1124]	valid_0's binary_logloss: 0.374218
# [1125]	valid_0's binary_logloss: 0.374205
# [1126]	valid_0's binary_logloss: 0.374199
# [1127]	valid_0's binary_logloss: 0.374186
# [1128]	valid_0's binary_logloss: 0.374171
# [1129]	valid_0's binary_logloss: 0.374164
# [1130]	valid_0's binary_logloss: 0.374155
# [1131]	valid_0's binary_logloss: 0.374153
# [1132]	valid_0's binary_logloss: 0.374149
# [1133]	valid_0's binary_logloss: 0.374145
# [1134]	valid_0's binary_logloss: 0.374136
# [1135]	valid_0's binary_logloss: 0.374133
# [1136]	valid_0's binary_logloss: 0.374133
# [1137]	valid_0's binary_logloss: 0.374126
# [1138]	valid_0's binary_logloss: 0.374111
# [1139]	valid_0's binary_logloss: 0.374092
# [1140]	valid_0's binary_logloss: 0.374085
# [1141]	valid_0's binary_logloss: 0.374071
# [1142]	valid_0's binary_logloss: 0.374069
# [1143]	valid_0's binary_logloss: 0.374059
# [1144]	valid_0's binary_logloss: 0.374057
# [1145]	valid_0's binary_logloss: 0.374042
# [1146]	valid_0's binary_logloss: 0.374038
# [1147]	valid_0's binary_logloss: 0.374031
# [1148]	valid_0's binary_logloss: 0.374021
# [1149]	valid_0's binary_logloss: 0.374014
# [1150]	valid_0's binary_logloss: 0.37401
# [1151]	valid_0's binary_logloss: 0.37399
# [1152]	valid_0's binary_logloss: 0.37397
# [1153]	valid_0's binary_logloss: 0.373958
# [1154]	valid_0's binary_logloss: 0.373955
# [1155]	valid_0's binary_logloss: 0.373951
# [1156]	valid_0's binary_logloss: 0.373936
# [1157]	valid_0's binary_logloss: 0.373925
# [1158]	valid_0's binary_logloss: 0.373922
# [1159]	valid_0's binary_logloss: 0.3739
# [1160]	valid_0's binary_logloss: 0.373897
# [1161]	valid_0's binary_logloss: 0.373878
# [1162]	valid_0's binary_logloss: 0.373868
# [1163]	valid_0's binary_logloss: 0.37386
# [1164]	valid_0's binary_logloss: 0.373852
# [1165]	valid_0's binary_logloss: 0.373839
# [1166]	valid_0's binary_logloss: 0.37383
# [1167]	valid_0's binary_logloss: 0.373819
# [1168]	valid_0's binary_logloss: 0.373809
# [1169]	valid_0's binary_logloss: 0.373805
# [1170]	valid_0's binary_logloss: 0.373798
# [1171]	valid_0's binary_logloss: 0.373787
# ...
# [2123]	valid_0's binary_logloss: 0.369314
# [2124]	valid_0's binary_logloss: 0.369313
# [2125]	valid_0's binary_logloss: 0.36931
# [2126]	valid_0's binary_logloss: 0.369311
# [2127]	valid_0's binary_logloss: 0.369306
# [2128]	valid_0's binary_logloss: 0.369305
# [2129]	valid_0's binary_logloss: 0.369306
# [2130]	valid_0's binary_logloss: 0.369301
# [2131]	valid_0's binary_logloss: 0.369298
# [2132]	valid_0's binary_logloss: 0.369294
# [2133]	valid_0's binary_logloss: 0.369293
# [2134]	valid_0's binary_logloss: 0.369293
# [2135]	valid_0's binary_logloss: 0.369295
# [2136]	valid_0's binary_logloss: 0.369293
# [2137]	valid_0's binary_logloss: 0.369291
# [2138]	valid_0's binary_logloss: 0.369287
# [2139]	valid_0's binary_logloss: 0.369286
# [2140]	valid_0's binary_logloss: 0.369282
# [2141]	valid_0's binary_logloss: 0.369285
# [2142]	valid_0's binary_logloss: 0.369287
# [2143]	valid_0's binary_logloss: 0.369289
# [2144]	valid_0's binary_logloss: 0.369288
# [2145]	valid_0's binary_logloss: 0.369285
# [2146]	valid_0's binary_logloss: 0.369281
# [2147]	valid_0's binary_logloss: 0.369276
# [2148]	valid_0's binary_logloss: 0.369273
# [2149]	valid_0's binary_logloss: 0.369272
# [2150]	valid_0's binary_logloss: 0.369269
# [2151]	valid_0's binary_logloss: 0.369268
# [2152]	valid_0's binary_logloss: 0.369259
# [2153]	valid_0's binary_logloss: 0.369255
# [2154]	valid_0's binary_logloss: 0.369257
# [2155]	valid_0's binary_logloss: 0.369258
# [2156]	valid_0's binary_logloss: 0.369257
# [2157]	valid_0's binary_logloss: 0.369252
# [2158]	valid_0's binary_logloss: 0.369248
# [2159]	valid_0's binary_logloss: 0.369244
# [2160]	valid_0's binary_logloss: 0.369239
# [2161]	valid_0's binary_logloss: 0.369235
# [2162]	valid_0's binary_logloss: 0.369233
# [2163]	valid_0's binary_logloss: 0.369229
# [2164]	valid_0's binary_logloss: 0.369223
# [2165]	valid_0's binary_logloss: 0.36922
# [2166]	valid_0's binary_logloss: 0.36922
# [2167]	valid_0's binary_logloss: 0.369211
# [2168]	valid_0's binary_logloss: 0.369207
# [2169]	valid_0's binary_logloss: 0.369207
# [2170]	valid_0's binary_logloss: 0.369208
# [2171]	valid_0's binary_logloss: 0.369205
# [2172]	valid_0's binary_logloss: 0.369201
# [2173]	valid_0's binary_logloss: 0.369198
# [2174]	valid_0's binary_logloss: 0.369193
# [2175]	valid_0's binary_logloss: 0.369192
# [2176]	valid_0's binary_logloss: 0.369187
# [2177]	valid_0's binary_logloss: 0.369184
# [2178]	valid_0's binary_logloss: 0.369178
# [2179]	valid_0's binary_logloss: 0.369177
# [2180]	valid_0's binary_logloss: 0.369179
# [2181]	valid_0's binary_logloss: 0.369176
# [2182]	valid_0's binary_logloss: 0.369173
# [2183]	valid_0's binary_logloss: 0.369175
# [2184]	valid_0's binary_logloss: 0.369166
# [2185]	valid_0's binary_logloss: 0.369164
# [2186]	valid_0's binary_logloss: 0.369165
# [2187]	valid_0's binary_logloss: 0.369164
# [2188]	valid_0's binary_logloss: 0.369166
# [2189]	valid_0's binary_logloss: 0.369163
# [2190]	valid_0's binary_logloss: 0.369164
# [2191]	valid_0's binary_logloss: 0.369163
# [2192]	valid_0's binary_logloss: 0.369161
# [2193]	valid_0's binary_logloss: 0.369161
# [2194]	valid_0's binary_logloss: 0.369162
# [2195]	valid_0's binary_logloss: 0.369159
# [2196]	valid_0's binary_logloss: 0.369155
# [2197]	valid_0's binary_logloss: 0.369155
# [2198]	valid_0's binary_logloss: 0.369153
# [2199]	valid_0's binary_logloss: 0.369151
# [2200]	valid_0's binary_logloss: 0.369153
# [2201]	valid_0's binary_logloss: 0.369152
# [2202]	valid_0's binary_logloss: 0.369148
# [2203]	valid_0's binary_logloss: 0.369147
# [2204]	valid_0's binary_logloss: 0.369143
# [2205]	valid_0's binary_logloss: 0.369143
# [2206]	valid_0's binary_logloss: 0.369145
# [2207]	valid_0's binary_logloss: 0.36914
# [2208]	valid_0's binary_logloss: 0.369139
# [2209]	valid_0's binary_logloss: 0.369137
# [2210]	valid_0's binary_logloss: 0.369138
# [2211]	valid_0's binary_logloss: 0.369136
# [2212]	valid_0's binary_logloss: 0.369134
# [2213]	valid_0's binary_logloss: 0.369129
# [2214]	valid_0's binary_logloss: 0.369126
# [2215]	valid_0's binary_logloss: 0.369123
# [2216]	valid_0's binary_logloss: 0.369119
# [2217]	valid_0's binary_logloss: 0.369116
# [2218]	valid_0's binary_logloss: 0.369112
# [2219]	valid_0's binary_logloss: 0.369107
# [2220]	valid_0's binary_logloss: 0.369103
# [2221]	valid_0's binary_logloss: 0.369104
# [2222]	valid_0's binary_logloss: 0.369103
# [2223]	valid_0's binary_logloss: 0.369104
# [2224]	valid_0's binary_logloss: 0.369101
# [2225]	valid_0's binary_logloss: 0.369099
# [2226]	valid_0's binary_logloss: 0.369096
# [2227]	valid_0's binary_logloss: 0.369094
# [2228]	valid_0's binary_logloss: 0.369092
# [2229]	valid_0's binary_logloss: 0.369094
# [2230]	valid_0's binary_logloss: 0.369093
# [2231]	valid_0's binary_logloss: 0.36909
# [2232]	valid_0's binary_logloss: 0.369085
# [2233]	valid_0's binary_logloss: 0.369082
# [2234]	valid_0's binary_logloss: 0.369081
# [2235]	valid_0's binary_logloss: 0.369074
# [2236]	valid_0's binary_logloss: 0.369071
# [2237]	valid_0's binary_logloss: 0.369066
# [2238]	valid_0's binary_logloss: 0.369061
# [2239]	valid_0's binary_logloss: 0.36906
# [2240]	valid_0's binary_logloss: 0.369061
# [2241]	valid_0's binary_logloss: 0.369061
# [2242]	valid_0's binary_logloss: 0.36906
# [2243]	valid_0's binary_logloss: 0.369057
# [2244]	valid_0's binary_logloss: 0.369057
# [2245]	valid_0's binary_logloss: 0.369052
# [2246]	valid_0's binary_logloss: 0.369047
# [2247]	valid_0's binary_logloss: 0.369043
# [2248]	valid_0's binary_logloss: 0.369043
# [2249]	valid_0's binary_logloss: 0.369037
# [2250]	valid_0's binary_logloss: 0.369033
# [2251]	valid_0's binary_logloss: 0.369033
# [2252]	valid_0's binary_logloss: 0.369033
# [2253]	valid_0's binary_logloss: 0.369031
# [2254]	valid_0's binary_logloss: 0.369028
# [2255]	valid_0's binary_logloss: 0.369026
# [2256]	valid_0's binary_logloss: 0.369021
# [2257]	valid_0's binary_logloss: 0.369019
# [2258]	valid_0's binary_logloss: 0.369019
# [2259]	valid_0's binary_logloss: 0.369018
# [2260]	valid_0's binary_logloss: 0.369017
# [2261]	valid_0's binary_logloss: 0.369016
# [2262]	valid_0's binary_logloss: 0.369015
# [2263]	valid_0's binary_logloss: 0.36901
# [2264]	valid_0's binary_logloss: 0.369007
# [2265]	valid_0's binary_logloss: 0.369004
# [2266]	valid_0's binary_logloss: 0.369
# [2267]	valid_0's binary_logloss: 0.368996
# [2268]	valid_0's binary_logloss: 0.368993
# [2269]	valid_0's binary_logloss: 0.36899
# [2270]	valid_0's binary_logloss: 0.368983
# [2271]	valid_0's binary_logloss: 0.368983
# [2272]	valid_0's binary_logloss: 0.368983
# [2273]	valid_0's binary_logloss: 0.368983
# [2274]	valid_0's binary_logloss: 0.368977
# [2275]	valid_0's binary_logloss: 0.368977
# [2276]	valid_0's binary_logloss: 0.368976
# [2277]	valid_0's binary_logloss: 0.368972
# [2278]	valid_0's binary_logloss: 0.368969
# [2279]	valid_0's binary_logloss: 0.368968
# [2280]	valid_0's binary_logloss: 0.368966
# [2281]	valid_0's binary_logloss: 0.368962
# [2282]	valid_0's binary_logloss: 0.368961
# [2283]	valid_0's binary_logloss: 0.368957
# [2284]	valid_0's binary_logloss: 0.368953
# [2285]	valid_0's binary_logloss: 0.36895
# [2286]	valid_0's binary_logloss: 0.36895
# [2287]	valid_0's binary_logloss: 0.368946
# [2288]	valid_0's binary_logloss: 0.368946
# [2289]	valid_0's binary_logloss: 0.368944
# [2290]	valid_0's binary_logloss: 0.368941
# [2291]	valid_0's binary_logloss: 0.368939
# [2292]	valid_0's binary_logloss: 0.368938
# [2293]	valid_0's binary_logloss: 0.368936
# [2294]	valid_0's binary_logloss: 0.368935
# [2295]	valid_0's binary_logloss: 0.36893
# [2296]	valid_0's binary_logloss: 0.36893
# [2297]	valid_0's binary_logloss: 0.368925
# [2298]	valid_0's binary_logloss: 0.368924
# [2299]	valid_0's binary_logloss: 0.36892
# [2300]	valid_0's binary_logloss: 0.368918
# [2301]	valid_0's binary_logloss: 0.368917
# [2302]	valid_0's binary_logloss: 0.368914
# [2303]	valid_0's binary_logloss: 0.368914
# [2304]	valid_0's binary_logloss: 0.368911
# [2305]	valid_0's binary_logloss: 0.368912
# [2306]	valid_0's binary_logloss: 0.368909
# [2307]	valid_0's binary_logloss: 0.368906
# [2308]	valid_0's binary_logloss: 0.368906
# [2309]	valid_0's binary_logloss: 0.368904
# [2310]	valid_0's binary_logloss: 0.368902
# [2311]	valid_0's binary_logloss: 0.368903
# [2312]	valid_0's binary_logloss: 0.368901
# [2313]	valid_0's binary_logloss: 0.368896
# [2314]	valid_0's binary_logloss: 0.368892
# [2315]	valid_0's binary_logloss: 0.36889
# [2316]	valid_0's binary_logloss: 0.36889
# [2317]	valid_0's binary_logloss: 0.368886
# [2318]	valid_0's binary_logloss: 0.368885
# [2319]	valid_0's binary_logloss: 0.368882
# [2320]	valid_0's binary_logloss: 0.368878
# [2321]	valid_0's binary_logloss: 0.368876
# [2322]	valid_0's binary_logloss: 0.368871
# [2323]	valid_0's binary_logloss: 0.368871
# [2324]	valid_0's binary_logloss: 0.368869
# [2325]	valid_0's binary_logloss: 0.368869
# [2326]	valid_0's binary_logloss: 0.368866
# [2327]	valid_0's binary_logloss: 0.368858
# [2328]	valid_0's binary_logloss: 0.368854
# [2329]	valid_0's binary_logloss: 0.368851
# [2330]	valid_0's binary_logloss: 0.368849
# [2331]	valid_0's binary_logloss: 0.368846
# [2332]	valid_0's binary_logloss: 0.368845
# [2333]	valid_0's binary_logloss: 0.368841
# [2334]	valid_0's binary_logloss: 0.368838
# [2335]	valid_0's binary_logloss: 0.368836
# [2336]	valid_0's binary_logloss: 0.368835
# [2337]	valid_0's binary_logloss: 0.368836
# [2338]	valid_0's binary_logloss: 0.368833
# [2339]	valid_0's binary_logloss: 0.368831
# [2340]	valid_0's binary_logloss: 0.368831
# [2341]	valid_0's binary_logloss: 0.368829
# [2342]	valid_0's binary_logloss: 0.368826
# [2343]	valid_0's binary_logloss: 0.368825
# [2344]	valid_0's binary_logloss: 0.368825
# [2345]	valid_0's binary_logloss: 0.368825
# [2346]	valid_0's binary_logloss: 0.368824
# [2347]	valid_0's binary_logloss: 0.368821
# [2348]	valid_0's binary_logloss: 0.368819
# [2349]	valid_0's binary_logloss: 0.36882
# [2350]	valid_0's binary_logloss: 0.368819
# [2351]	valid_0's binary_logloss: 0.368821
# [2352]	valid_0's binary_logloss: 0.36882
# [2353]	valid_0's binary_logloss: 0.368822
# [2354]	valid_0's binary_logloss: 0.368818
# [2355]	valid_0's binary_logloss: 0.368817
# [2356]	valid_0's binary_logloss: 0.368814
# [2357]	valid_0's binary_logloss: 0.368811
# [2358]	valid_0's binary_logloss: 0.368807
# [2359]	valid_0's binary_logloss: 0.368803
# [2360]	valid_0's binary_logloss: 0.368803
# [2361]	valid_0's binary_logloss: 0.368799
# [2362]	valid_0's binary_logloss: 0.368794
# [2363]	valid_0's binary_logloss: 0.368791
# [2364]	valid_0's binary_logloss: 0.368786
# [2365]	valid_0's binary_logloss: 0.368784
# [2366]	valid_0's binary_logloss: 0.36878
# [2367]	valid_0's binary_logloss: 0.368783
# [2368]	valid_0's binary_logloss: 0.368781
# [2369]	valid_0's binary_logloss: 0.36878
# [2370]	valid_0's binary_logloss: 0.368775
# [2371]	valid_0's binary_logloss: 0.368769
# [2372]	valid_0's binary_logloss: 0.368768
# [2373]	valid_0's binary_logloss: 0.368764
# [2374]	valid_0's binary_logloss: 0.368761
# [2375]	valid_0's binary_logloss: 0.368758
# [2376]	valid_0's binary_logloss: 0.368756
# [2377]	valid_0's binary_logloss: 0.368752
# [2378]	valid_0's binary_logloss: 0.368751
# [2379]	valid_0's binary_logloss: 0.368748
# [2380]	valid_0's binary_logloss: 0.368744
# [2381]	valid_0's binary_logloss: 0.368742
# [2382]	valid_0's binary_logloss: 0.368743
# [2383]	valid_0's binary_logloss: 0.36874
# [2384]	valid_0's binary_logloss: 0.368738
# [2385]	valid_0's binary_logloss: 0.368735
# [2386]	valid_0's binary_logloss: 0.368736
# [2387]	valid_0's binary_logloss: 0.368739
# [2388]	valid_0's binary_logloss: 0.368734
# [2389]	valid_0's binary_logloss: 0.368731
# [2390]	valid_0's binary_logloss: 0.368731
# [2391]	valid_0's binary_logloss: 0.36873
# [2392]	valid_0's binary_logloss: 0.368728
# [2393]	valid_0's binary_logloss: 0.368727
# [2394]	valid_0's binary_logloss: 0.368728
# [2395]	valid_0's binary_logloss: 0.368726
# [2396]	valid_0's binary_logloss: 0.368724
# [2397]	valid_0's binary_logloss: 0.368719
# [2398]	valid_0's binary_logloss: 0.368715
# [2399]	valid_0's binary_logloss: 0.368715
# [2400]	valid_0's binary_logloss: 0.368711
# [2401]	valid_0's binary_logloss: 0.368708
# [2402]	valid_0's binary_logloss: 0.368708
# [2403]	valid_0's binary_logloss: 0.368703
# [2404]	valid_0's binary_logloss: 0.368704
# [2405]	valid_0's binary_logloss: 0.368704
# [2406]	valid_0's binary_logloss: 0.368702
# [2407]	valid_0's binary_logloss: 0.3687
# [2408]	valid_0's binary_logloss: 0.368698
# [2409]	valid_0's binary_logloss: 0.368695
# [2410]	valid_0's binary_logloss: 0.368695
# [2411]	valid_0's binary_logloss: 0.368694
# [2412]	valid_0's binary_logloss: 0.36869
# [2413]	valid_0's binary_logloss: 0.368686
# [2414]	valid_0's binary_logloss: 0.368685
# [2415]	valid_0's binary_logloss: 0.368683
# [2416]	valid_0's binary_logloss: 0.368682
# [2417]	valid_0's binary_logloss: 0.36868
# [2418]	valid_0's binary_logloss: 0.368678
# [2419]	valid_0's binary_logloss: 0.368672
# [2420]	valid_0's binary_logloss: 0.368671
# [2421]	valid_0's binary_logloss: 0.368668
# [2422]	valid_0's binary_logloss: 0.368667
# [2423]	valid_0's binary_logloss: 0.368665
# [2424]	valid_0's binary_logloss: 0.368663
# [2425]	valid_0's binary_logloss: 0.368661
# [2426]	valid_0's binary_logloss: 0.368663
# [2427]	valid_0's binary_logloss: 0.368664
# [2428]	valid_0's binary_logloss: 0.368662
# [2429]	valid_0's binary_logloss: 0.368662
# [2430]	valid_0's binary_logloss: 0.36866
# [2431]	valid_0's binary_logloss: 0.368659
# [2432]	valid_0's binary_logloss: 0.368657
# [2433]	valid_0's binary_logloss: 0.368654
# [2434]	valid_0's binary_logloss: 0.368655
# [2435]	valid_0's binary_logloss: 0.368656
# [2436]	valid_0's binary_logloss: 0.368655
# [2437]	valid_0's binary_logloss: 0.368653
# [2438]	valid_0's binary_logloss: 0.368654
# [2439]	valid_0's binary_logloss: 0.368654
# [2440]	valid_0's binary_logloss: 0.368653
# [2441]	valid_0's binary_logloss: 0.368654
# [2442]	valid_0's binary_logloss: 0.368649
# [2443]	valid_0's binary_logloss: 0.368649
# [2444]	valid_0's binary_logloss: 0.368647
# [2445]	valid_0's binary_logloss: 0.368648
# [2446]	valid_0's binary_logloss: 0.368643
# [2447]	valid_0's binary_logloss: 0.368643
# [2448]	valid_0's binary_logloss: 0.368639
# [2449]	valid_0's binary_logloss: 0.368639
# [2450]	valid_0's binary_logloss: 0.36864
# [2451]	valid_0's binary_logloss: 0.368637
# [2452]	valid_0's binary_logloss: 0.368635
# [2453]	valid_0's binary_logloss: 0.368633
# [2454]	valid_0's binary_logloss: 0.368633
# [2455]	valid_0's binary_logloss: 0.368629
# [2456]	valid_0's binary_logloss: 0.368626
# [2457]	valid_0's binary_logloss: 0.368626
# [2458]	valid_0's binary_logloss: 0.368624
# [2459]	valid_0's binary_logloss: 0.368623
# [2460]	valid_0's binary_logloss: 0.368621
# [2461]	valid_0's binary_logloss: 0.368621
# [2462]	valid_0's binary_logloss: 0.36862
# [2463]	valid_0's binary_logloss: 0.368617
# [2464]	valid_0's binary_logloss: 0.368614
# [2465]	valid_0's binary_logloss: 0.368618
# [2466]	valid_0's binary_logloss: 0.368614
# [2467]	valid_0's binary_logloss: 0.368613
# [2468]	valid_0's binary_logloss: 0.368615
# [2469]	valid_0's binary_logloss: 0.368613
# [2470]	valid_0's binary_logloss: 0.368607
# [2471]	valid_0's binary_logloss: 0.368608
# [2472]	valid_0's binary_logloss: 0.368609
# [2473]	valid_0's binary_logloss: 0.368607
# [2474]	valid_0's binary_logloss: 0.368601
# [2475]	valid_0's binary_logloss: 0.368598
# [2476]	valid_0's binary_logloss: 0.368599
# [2477]	valid_0's binary_logloss: 0.368599
# [2478]	valid_0's binary_logloss: 0.3686
# [2479]	valid_0's binary_logloss: 0.368599
# [2480]	valid_0's binary_logloss: 0.368592
# [2481]	valid_0's binary_logloss: 0.368593
# [2482]	valid_0's binary_logloss: 0.368592
# [2483]	valid_0's binary_logloss: 0.368591
# [2484]	valid_0's binary_logloss: 0.368591
# [2485]	valid_0's binary_logloss: 0.368587
# [2486]	valid_0's binary_logloss: 0.368587
# [2487]	valid_0's binary_logloss: 0.368589
# [2488]	valid_0's binary_logloss: 0.368589
# [2489]	valid_0's binary_logloss: 0.368585
# [2490]	valid_0's binary_logloss: 0.368586
# [2491]	valid_0's binary_logloss: 0.368583
# [2492]	valid_0's binary_logloss: 0.368581
# [2493]	valid_0's binary_logloss: 0.368579
# [2494]	valid_0's binary_logloss: 0.368576
# [2495]	valid_0's binary_logloss: 0.36857
# [2496]	valid_0's binary_logloss: 0.368566
# [2497]	valid_0's binary_logloss: 0.368563
# [2498]	valid_0's binary_logloss: 0.368558
# [2499]	valid_0's binary_logloss: 0.368557
# [2500]	valid_0's binary_logloss: 0.368555
# Did not meet early stopping. Best iteration is:
# [2500]	valid_0's binary_logloss: 0.368555
# Modelo da classe 4 finalizado

# %%
# Treinar 100% modelo da classe 3
m3 = lgb.train(params=hp3, num_boost_round=nbr, train_set=ds3_train, valid_sets=[ds3_valid], 
               verbose_eval=True, categorical_feature=feats_cat)
print('Modelo da classe 3 finalizado')
# Out:
# [1]	valid_0's binary_logloss: 0.0279432
# Training until validation scores don't improve for 25 rounds
# [2]	valid_0's binary_logloss: 0.0277376
# [3]	valid_0's binary_logloss: 0.0272779
# [4]	valid_0's binary_logloss: 0.0269112
# [5]	valid_0's binary_logloss: 0.0265756
# [6]	valid_0's binary_logloss: 0.026297
# [7]	valid_0's binary_logloss: 0.026049
# [8]	valid_0's binary_logloss: 0.0258286
# [9]	valid_0's binary_logloss: 0.0256253
# [10]	valid_0's binary_logloss: 0.0254339
# [11]	valid_0's binary_logloss: 0.0252598
# [12]	valid_0's binary_logloss: 0.0250955
# [13]	valid_0's binary_logloss: 0.0249406
# [14]	valid_0's binary_logloss: 0.0247933
# [15]	valid_0's binary_logloss: 0.0246555
# [16]	valid_0's binary_logloss: 0.0245181
# [17]	valid_0's binary_logloss: 0.0243867
# [18]	valid_0's binary_logloss: 0.0242676
# [19]	valid_0's binary_logloss: 0.0241498
# [20]	valid_0's binary_logloss: 0.0240356
# [21]	valid_0's binary_logloss: 0.0239351
# [22]	valid_0's binary_logloss: 0.0238672
# [23]	valid_0's binary_logloss: 0.0237665
# [24]	valid_0's binary_logloss: 0.0237033
# [25]	valid_0's binary_logloss: 0.0236082
# [26]	valid_0's binary_logloss: 0.0235085
# [27]	valid_0's binary_logloss: 0.0234195
# [28]	valid_0's binary_logloss: 0.0233351
# [29]	valid_0's binary_logloss: 0.02325
# [30]	valid_0's binary_logloss: 0.0231606
# [31]	valid_0's binary_logloss: 0.0230758
# [32]	valid_0's binary_logloss: 0.0229936
# [33]	valid_0's binary_logloss: 0.0229215
# [34]	valid_0's binary_logloss: 0.0228477
# [35]	valid_0's binary_logloss: 0.0227958
# [36]	valid_0's binary_logloss: 0.0227192
# [37]	valid_0's binary_logloss: 0.0226487
# [38]	valid_0's binary_logloss: 0.0225816
# [39]	valid_0's binary_logloss: 0.0225155
# [40]	valid_0's binary_logloss: 0.0224543
# [41]	valid_0's binary_logloss: 0.0224097
# [42]	valid_0's binary_logloss: 0.0223468
# [43]	valid_0's binary_logloss: 0.0222884
# [44]	valid_0's binary_logloss: 0.0222319
# [45]	valid_0's binary_logloss: 0.0221777
# [46]	valid_0's binary_logloss: 0.022139
# [47]	valid_0's binary_logloss: 0.0220849
# [48]	valid_0's binary_logloss: 0.02203
# [49]	valid_0's binary_logloss: 0.0219777
# [50]	valid_0's binary_logloss: 0.0219267
# [51]	valid_0's binary_logloss: 0.0218775
# [52]	valid_0's binary_logloss: 0.0218282
# [53]	valid_0's binary_logloss: 0.0217815
# [54]	valid_0's binary_logloss: 0.0217344
# [55]	valid_0's binary_logloss: 0.0216905
# [56]	valid_0's binary_logloss: 0.0216463
# [57]	valid_0's binary_logloss: 0.0216231
# [58]	valid_0's binary_logloss: 0.021599
# [59]	valid_0's binary_logloss: 0.0215575
# [60]	valid_0's binary_logloss: 0.021503
# [61]	valid_0's binary_logloss: 0.0214715
# [62]	valid_0's binary_logloss: 0.0214292
# [63]	valid_0's binary_logloss: 0.0213882
# [64]	valid_0's binary_logloss: 0.0213506
# [65]	valid_0's binary_logloss: 0.0213097
# [66]	valid_0's binary_logloss: 0.0212682
# [67]	valid_0's binary_logloss: 0.0212412
# [68]	valid_0's binary_logloss: 0.021206
# [69]	valid_0's binary_logloss: 0.0211651
# [70]	valid_0's binary_logloss: 0.021128
# [71]	valid_0's binary_logloss: 0.0210905
# [72]	valid_0's binary_logloss: 0.021055
# [73]	valid_0's binary_logloss: 0.0210199
# [74]	valid_0's binary_logloss: 0.0209887
# [75]	valid_0's binary_logloss: 0.020956
# [76]	valid_0's binary_logloss: 0.0209244
# [77]	valid_0's binary_logloss: 0.020891
# [78]	valid_0's binary_logloss: 0.0208621
# [79]	valid_0's binary_logloss: 0.0208295
# [80]	valid_0's binary_logloss: 0.0207975
# [81]	valid_0's binary_logloss: 0.0207657
# [82]	valid_0's binary_logloss: 0.0207355
# [83]	valid_0's binary_logloss: 0.020719
# [84]	valid_0's binary_logloss: 0.020688
# [85]	valid_0's binary_logloss: 0.0206579
# [86]	valid_0's binary_logloss: 0.020642
# [87]	valid_0's binary_logloss: 0.0206148
# [88]	valid_0's binary_logloss: 0.0205867
# [89]	valid_0's binary_logloss: 0.0205605
# [90]	valid_0's binary_logloss: 0.0205394
# [91]	valid_0's binary_logloss: 0.0205108
# [92]	valid_0's binary_logloss: 0.0204837
# [93]	valid_0's binary_logloss: 0.0204576
# [94]	valid_0's binary_logloss: 0.0204308
# [95]	valid_0's binary_logloss: 0.0204065
# [96]	valid_0's binary_logloss: 0.0203815
# [97]	valid_0's binary_logloss: 0.0203572
# [98]	valid_0's binary_logloss: 0.02034
# [99]	valid_0's binary_logloss: 0.0203167
# [100]	valid_0's binary_logloss: 0.0202992
# [101]	valid_0's binary_logloss: 0.0202747
# [102]	valid_0's binary_logloss: 0.0202514
# [103]	valid_0's binary_logloss: 0.0202276
# [104]	valid_0's binary_logloss: 0.0202105
# [105]	valid_0's binary_logloss: 0.0201894
# [106]	valid_0's binary_logloss: 0.0201671
# [107]	valid_0's binary_logloss: 0.0201455
# [108]	valid_0's binary_logloss: 0.0201243
# [109]	valid_0's binary_logloss: 0.0201019
# [110]	valid_0's binary_logloss: 0.0200829
# [111]	valid_0's binary_logloss: 0.0200635
# [112]	valid_0's binary_logloss: 0.0200432
# [113]	valid_0's binary_logloss: 0.0200221
# [114]	valid_0's binary_logloss: 0.0200063
# [115]	valid_0's binary_logloss: 0.0199868
# [116]	valid_0's binary_logloss: 0.0199688
# [117]	valid_0's binary_logloss: 0.0199508
# [118]	valid_0's binary_logloss: 0.0199294
# [119]	valid_0's binary_logloss: 0.0199113
# [120]	valid_0's binary_logloss: 0.0198934
# [121]	valid_0's binary_logloss: 0.0198751
# [122]	valid_0's binary_logloss: 0.0198587
# [123]	valid_0's binary_logloss: 0.0198398
# [124]	valid_0's binary_logloss: 0.0198208
# [125]	valid_0's binary_logloss: 0.0198071
# [126]	valid_0's binary_logloss: 0.0197893
# [127]	valid_0's binary_logloss: 0.0197721
# [128]	valid_0's binary_logloss: 0.0197552
# [129]	valid_0's binary_logloss: 0.0197403
# [130]	valid_0's binary_logloss: 0.0197267
# [131]	valid_0's binary_logloss: 0.0197088
# [132]	valid_0's binary_logloss: 0.0196909
# [133]	valid_0's binary_logloss: 0.0196752
# [134]	valid_0's binary_logloss: 0.0196586
# [135]	valid_0's binary_logloss: 0.0196416
# [136]	valid_0's binary_logloss: 0.0196235
# [137]	valid_0's binary_logloss: 0.0196103
# [138]	valid_0's binary_logloss: 0.0195921
# [139]	valid_0's binary_logloss: 0.0195762
# [140]	valid_0's binary_logloss: 0.0195589
# [141]	valid_0's binary_logloss: 0.0195435
# [142]	valid_0's binary_logloss: 0.0195277
# [143]	valid_0's binary_logloss: 0.0195134
# [144]	valid_0's binary_logloss: 0.0194968
# [145]	valid_0's binary_logloss: 0.019481
# [146]	valid_0's binary_logloss: 0.0194656
# [147]	valid_0's binary_logloss: 0.0194522
# [148]	valid_0's binary_logloss: 0.0194347
# [149]	valid_0's binary_logloss: 0.0194172
# [150]	valid_0's binary_logloss: 0.0194006
# [151]	valid_0's binary_logloss: 0.0193858
# [152]	valid_0's binary_logloss: 0.0193708
# [153]	valid_0's binary_logloss: 0.0193572
# [154]	valid_0's binary_logloss: 0.0193437
# [155]	valid_0's binary_logloss: 0.0193284
# [156]	valid_0's binary_logloss: 0.0193129
# [157]	valid_0's binary_logloss: 0.0192961
# [158]	valid_0's binary_logloss: 0.0192838
# [159]	valid_0's binary_logloss: 0.0192694
# [160]	valid_0's binary_logloss: 0.0192592
# [161]	valid_0's binary_logloss: 0.0192459
# [162]	valid_0's binary_logloss: 0.019234
# [163]	valid_0's binary_logloss: 0.019225
# [164]	valid_0's binary_logloss: 0.0192103
# [165]	valid_0's binary_logloss: 0.0191959
# [166]	valid_0's binary_logloss: 0.0191819
# [167]	valid_0's binary_logloss: 0.0191688
# [168]	valid_0's binary_logloss: 0.0191562
# [169]	valid_0's binary_logloss: 0.019144
# [170]	valid_0's binary_logloss: 0.0191301
# [171]	valid_0's binary_logloss: 0.0191166
# [172]	valid_0's binary_logloss: 0.0191033
# [173]	valid_0's binary_logloss: 0.0190925
# [174]	valid_0's binary_logloss: 0.0190796
# [175]	valid_0's binary_logloss: 0.0190688
# [176]	valid_0's binary_logloss: 0.0190553
# [177]	valid_0's binary_logloss: 0.0190444
# [178]	valid_0's binary_logloss: 0.0190328
# [179]	valid_0's binary_logloss: 0.0190216
# [180]	valid_0's binary_logloss: 0.0190087
# [181]	valid_0's binary_logloss: 0.0190012
# [182]	valid_0's binary_logloss: 0.0189908
# [183]	valid_0's binary_logloss: 0.0189805
# [184]	valid_0's binary_logloss: 0.0189717
# [185]	valid_0's binary_logloss: 0.0189624
# [186]	valid_0's binary_logloss: 0.0189554
# [187]	valid_0's binary_logloss: 0.0189455
# [188]	valid_0's binary_logloss: 0.0189361
# [189]	valid_0's binary_logloss: 0.0189264
# [190]	valid_0's binary_logloss: 0.0189172
# [191]	valid_0's binary_logloss: 0.0189077
# [192]	valid_0's binary_logloss: 0.0189026
# [193]	valid_0's binary_logloss: 0.0188935
# [194]	valid_0's binary_logloss: 0.0188845
# [195]	valid_0's binary_logloss: 0.0188755
# [196]	valid_0's binary_logloss: 0.0188665
# [197]	valid_0's binary_logloss: 0.0188588
# [198]	valid_0's binary_logloss: 0.018851
# [199]	valid_0's binary_logloss: 0.0188422
# [200]	valid_0's binary_logloss: 0.0188338
# [201]	valid_0's binary_logloss: 0.0188221
# [202]	valid_0's binary_logloss: 0.0188134
# [203]	valid_0's binary_logloss: 0.0188034
# [204]	valid_0's binary_logloss: 0.018795
# [205]	valid_0's binary_logloss: 0.0187859
# [206]	valid_0's binary_logloss: 0.0187791
# [207]	valid_0's binary_logloss: 0.0187713
# [208]	valid_0's binary_logloss: 0.0187643
# [209]	valid_0's binary_logloss: 0.0187572
# [210]	valid_0's binary_logloss: 0.0187473
# [211]	valid_0's binary_logloss: 0.0187384
# [212]	valid_0's binary_logloss: 0.0187299
# [213]	valid_0's binary_logloss: 0.018721
# [214]	valid_0's binary_logloss: 0.0187134
# [215]	valid_0's binary_logloss: 0.0187057
# [216]	valid_0's binary_logloss: 0.0186984
# [217]	valid_0's binary_logloss: 0.0186905
# [218]	valid_0's binary_logloss: 0.0186829
# [219]	valid_0's binary_logloss: 0.0186745
# [220]	valid_0's binary_logloss: 0.0186669
# [221]	valid_0's binary_logloss: 0.0186583
# [222]	valid_0's binary_logloss: 0.0186501
# [223]	valid_0's binary_logloss: 0.0186408
# [224]	valid_0's binary_logloss: 0.0186338
# [225]	valid_0's binary_logloss: 0.0186261
# [226]	valid_0's binary_logloss: 0.0186183
# [227]	valid_0's binary_logloss: 0.0186117
# [228]	valid_0's binary_logloss: 0.0186032
# [229]	valid_0's binary_logloss: 0.0185953
# [230]	valid_0's binary_logloss: 0.0185879
# [231]	valid_0's binary_logloss: 0.0185805
# [232]	valid_0's binary_logloss: 0.0185734
# [233]	valid_0's binary_logloss: 0.0185643
# [234]	valid_0's binary_logloss: 0.0185589
# [235]	valid_0's binary_logloss: 0.0185529
# [236]	valid_0's binary_logloss: 0.0185469
# [237]	valid_0's binary_logloss: 0.0185376
# [238]	valid_0's binary_logloss: 0.0185289
# [239]	valid_0's binary_logloss: 0.0185214
# [240]	valid_0's binary_logloss: 0.0185138
# [241]	valid_0's binary_logloss: 0.0185064
# [242]	valid_0's binary_logloss: 0.0184999
# [243]	valid_0's binary_logloss: 0.018493
# [244]	valid_0's binary_logloss: 0.0184879
# [245]	valid_0's binary_logloss: 0.0184824
# [246]	valid_0's binary_logloss: 0.018477
# [247]	valid_0's binary_logloss: 0.0184708
# [248]	valid_0's binary_logloss: 0.0184656
# [249]	valid_0's binary_logloss: 0.0184584
# [250]	valid_0's binary_logloss: 0.0184526
# [251]	valid_0's binary_logloss: 0.0184468
# [252]	valid_0's binary_logloss: 0.0184404
# [253]	valid_0's binary_logloss: 0.018435
# [254]	valid_0's binary_logloss: 0.0184283
# [255]	valid_0's binary_logloss: 0.018421
# [256]	valid_0's binary_logloss: 0.0184151
# [257]	valid_0's binary_logloss: 0.0184078
# [258]	valid_0's binary_logloss: 0.0184025
# [259]	valid_0's binary_logloss: 0.0183991
# [260]	valid_0's binary_logloss: 0.018394
# [261]	valid_0's binary_logloss: 0.0183888
# [262]	valid_0's binary_logloss: 0.0183844
# [263]	valid_0's binary_logloss: 0.0183786
# [264]	valid_0's binary_logloss: 0.0183763
# [265]	valid_0's binary_logloss: 0.0183699
# [266]	valid_0's binary_logloss: 0.0183656
# [267]	valid_0's binary_logloss: 0.0183608
# [268]	valid_0's binary_logloss: 0.018356
# [269]	valid_0's binary_logloss: 0.0183495
# [270]	valid_0's binary_logloss: 0.0183452
# [271]	valid_0's binary_logloss: 0.01834
# [272]	valid_0's binary_logloss: 0.0183353
# [273]	valid_0's binary_logloss: 0.0183307
# [274]	valid_0's binary_logloss: 0.0183258
# [275]	valid_0's binary_logloss: 0.0183204
# [276]	valid_0's binary_logloss: 0.0183151
# [277]	valid_0's binary_logloss: 0.0183111
# [278]	valid_0's binary_logloss: 0.0183063
# [279]	valid_0's binary_logloss: 0.0183019
# [280]	valid_0's binary_logloss: 0.0182975
# [281]	valid_0's binary_logloss: 0.0182927
# [282]	valid_0's binary_logloss: 0.0182883
# [283]	valid_0's binary_logloss: 0.018282
# [284]	valid_0's binary_logloss: 0.0182774
# [285]	valid_0's binary_logloss: 0.0182725
# [286]	valid_0's binary_logloss: 0.0182682
# [287]	valid_0's binary_logloss: 0.0182641
# [288]	valid_0's binary_logloss: 0.0182599
# [289]	valid_0's binary_logloss: 0.0182552
# [290]	valid_0's binary_logloss: 0.0182499
# [291]	valid_0's binary_logloss: 0.0182459
# [292]	valid_0's binary_logloss: 0.0182418
# [293]	valid_0's binary_logloss: 0.018236
# [294]	valid_0's binary_logloss: 0.0182312
# [295]	valid_0's binary_logloss: 0.0182273
# [296]	valid_0's binary_logloss: 0.0182233
# [297]	valid_0's binary_logloss: 0.0182203
# [298]	valid_0's binary_logloss: 0.0182164
# [299]	valid_0's binary_logloss: 0.0182124
# [300]	valid_0's binary_logloss: 0.0182067
# [301]	valid_0's binary_logloss: 0.0182039
# [302]	valid_0's binary_logloss: 0.0181999
# [303]	valid_0's binary_logloss: 0.0181942
# [304]	valid_0's binary_logloss: 0.0181904
# [305]	valid_0's binary_logloss: 0.0181866
# [306]	valid_0's binary_logloss: 0.0181824
# [307]	valid_0's binary_logloss: 0.0181765
# [308]	valid_0's binary_logloss: 0.0181731
# [309]	valid_0's binary_logloss: 0.0181702
# [310]	valid_0's binary_logloss: 0.0181657
# [311]	valid_0's binary_logloss: 0.0181603
# [312]	valid_0's binary_logloss: 0.0181555
# [313]	valid_0's binary_logloss: 0.0181521
# [314]	valid_0's binary_logloss: 0.0181493
# [315]	valid_0's binary_logloss: 0.0181467
# [316]	valid_0's binary_logloss: 0.0181428
# [317]	valid_0's binary_logloss: 0.0181396
# [318]	valid_0's binary_logloss: 0.0181368
# [319]	valid_0's binary_logloss: 0.0181337
# [320]	valid_0's binary_logloss: 0.0181309
# [321]	valid_0's binary_logloss: 0.0181274
# [322]	valid_0's binary_logloss: 0.0181243
# [323]	valid_0's binary_logloss: 0.018122
# [324]	valid_0's binary_logloss: 0.0181186
# [325]	valid_0's binary_logloss: 0.018115
# [326]	valid_0's binary_logloss: 0.0181114
# [327]	valid_0's binary_logloss: 0.0181081
# [328]	valid_0's binary_logloss: 0.0181048
# [329]	valid_0's binary_logloss: 0.0181022
# [330]	valid_0's binary_logloss: 0.0180973
# [331]	valid_0's binary_logloss: 0.0180926
# [332]	valid_0's binary_logloss: 0.018089
# [333]	valid_0's binary_logloss: 0.0180855
# [334]	valid_0's binary_logloss: 0.018083
# [335]	valid_0's binary_logloss: 0.0180793
# [336]	valid_0's binary_logloss: 0.0180766
# [337]	valid_0's binary_logloss: 0.0180731
# [338]	valid_0's binary_logloss: 0.0180693
# [339]	valid_0's binary_logloss: 0.0180674
# [340]	valid_0's binary_logloss: 0.0180651
# [341]	valid_0's binary_logloss: 0.0180614
# [342]	valid_0's binary_logloss: 0.0180576
# [343]	valid_0's binary_logloss: 0.0180526
# [344]	valid_0's binary_logloss: 0.0180503
# [345]	valid_0's binary_logloss: 0.0180461
# [346]	valid_0's binary_logloss: 0.018044
# [347]	valid_0's binary_logloss: 0.0180411
# [348]	valid_0's binary_logloss: 0.0180394
# [349]	valid_0's binary_logloss: 0.018036
# [350]	valid_0's binary_logloss: 0.0180345
# [351]	valid_0's binary_logloss: 0.0180288
# [352]	valid_0's binary_logloss: 0.0180246
# [353]	valid_0's binary_logloss: 0.0180204
# [354]	valid_0's binary_logloss: 0.0180177
# [355]	valid_0's binary_logloss: 0.0180135
# [356]	valid_0's binary_logloss: 0.01801
# [357]	valid_0's binary_logloss: 0.0180067
# [358]	valid_0's binary_logloss: 0.0180039
# [359]	valid_0's binary_logloss: 0.0180014
# [360]	valid_0's binary_logloss: 0.0179983
# [361]	valid_0's binary_logloss: 0.0179968
# [362]	valid_0's binary_logloss: 0.0179935
# [363]	valid_0's binary_logloss: 0.0179899
# [364]	valid_0's binary_logloss: 0.017985
# [365]	valid_0's binary_logloss: 0.0179817
# [366]	valid_0's binary_logloss: 0.0179805
# [367]	valid_0's binary_logloss: 0.0179789
# [368]	valid_0's binary_logloss: 0.0179746
# [369]	valid_0's binary_logloss: 0.0179722
# [370]	valid_0's binary_logloss: 0.0179702
# [371]	valid_0's binary_logloss: 0.0179662
# [372]	valid_0's binary_logloss: 0.0179633
# [373]	valid_0's binary_logloss: 0.0179607
# [374]	valid_0's binary_logloss: 0.0179586
# [375]	valid_0's binary_logloss: 0.017957
# [376]	valid_0's binary_logloss: 0.0179553
# [377]	valid_0's binary_logloss: 0.0179529
# [378]	valid_0's binary_logloss: 0.017951
# [379]	valid_0's binary_logloss: 0.0179483
# [380]	valid_0's binary_logloss: 0.0179458
# [381]	valid_0's binary_logloss: 0.0179432
# [382]	valid_0's binary_logloss: 0.0179403
# [383]	valid_0's binary_logloss: 0.0179383
# [384]	valid_0's binary_logloss: 0.0179357
# [385]	valid_0's binary_logloss: 0.0179327
# [386]	valid_0's binary_logloss: 0.0179311
# [387]	valid_0's binary_logloss: 0.0179284
# [388]	valid_0's binary_logloss: 0.0179256
# [389]	valid_0's binary_logloss: 0.0179225
# [390]	valid_0's binary_logloss: 0.0179203
# [391]	valid_0's binary_logloss: 0.017918
# [392]	valid_0's binary_logloss: 0.0179159
# [393]	valid_0's binary_logloss: 0.0179134
# [394]	valid_0's binary_logloss: 0.0179113
# [395]	valid_0's binary_logloss: 0.0179075
# [396]	valid_0's binary_logloss: 0.0179053
# [397]	valid_0's binary_logloss: 0.0179034
# [398]	valid_0's binary_logloss: 0.0179016
# [399]	valid_0's binary_logloss: 0.0178999
# [400]	valid_0's binary_logloss: 0.0178966
# [401]	valid_0's binary_logloss: 0.0178946
# [402]	valid_0's binary_logloss: 0.0178922
# [403]	valid_0's binary_logloss: 0.0178889
# [404]	valid_0's binary_logloss: 0.0178869
# [405]	valid_0's binary_logloss: 0.0178847
# [406]	valid_0's binary_logloss: 0.0178834
# [407]	valid_0's binary_logloss: 0.0178809
# [408]	valid_0's binary_logloss: 0.0178796
# [409]	valid_0's binary_logloss: 0.0178778
# [410]	valid_0's binary_logloss: 0.0178763
# [411]	valid_0's binary_logloss: 0.017874
# [412]	valid_0's binary_logloss: 0.0178724
# [413]	valid_0's binary_logloss: 0.0178704
# [414]	valid_0's binary_logloss: 0.0178676
# [415]	valid_0's binary_logloss: 0.0178647
# [416]	valid_0's binary_logloss: 0.0178634
# [417]	valid_0's binary_logloss: 0.017861
# [418]	valid_0's binary_logloss: 0.0178586
# [419]	valid_0's binary_logloss: 0.0178564
# [420]	valid_0's binary_logloss: 0.017854
# [421]	valid_0's binary_logloss: 0.0178527
# [422]	valid_0's binary_logloss: 0.0178511
# [423]	valid_0's binary_logloss: 0.0178483
# [424]	valid_0's binary_logloss: 0.0178459
# [425]	valid_0's binary_logloss: 0.0178434
# [426]	valid_0's binary_logloss: 0.0178419
# [427]	valid_0's binary_logloss: 0.01784
# [428]	valid_0's binary_logloss: 0.017839
# [429]	valid_0's binary_logloss: 0.0178379
# [430]	valid_0's binary_logloss: 0.0178363
# [431]	valid_0's binary_logloss: 0.0178341
# [432]	valid_0's binary_logloss: 0.0178328
# [433]	valid_0's binary_logloss: 0.0178313
# [434]	valid_0's binary_logloss: 0.0178293
# [435]	valid_0's binary_logloss: 0.017828
# [436]	valid_0's binary_logloss: 0.0178262
# [437]	valid_0's binary_logloss: 0.0178244
# [438]	valid_0's binary_logloss: 0.0178219
# [439]	valid_0's binary_logloss: 0.0178211
# [440]	valid_0's binary_logloss: 0.0178198
# [441]	valid_0's binary_logloss: 0.0178177
# [442]	valid_0's binary_logloss: 0.0178154
# [443]	valid_0's binary_logloss: 0.0178134
# [444]	valid_0's binary_logloss: 0.0178122
# [445]	valid_0's binary_logloss: 0.0178112
# [446]	valid_0's binary_logloss: 0.0178084
# [447]	valid_0's binary_logloss: 0.0178078
# [448]	valid_0's binary_logloss: 0.0178056
# [449]	valid_0's binary_logloss: 0.0178023
# [450]	valid_0's binary_logloss: 0.0178007
# [451]	valid_0's binary_logloss: 0.0177986
# [452]	valid_0's binary_logloss: 0.0177974
# [453]	valid_0's binary_logloss: 0.0177962
# [454]	valid_0's binary_logloss: 0.017795
# [455]	valid_0's binary_logloss: 0.0177923
# [456]	valid_0's binary_logloss: 0.0177905
# [457]	valid_0's binary_logloss: 0.0177889
# [458]	valid_0's binary_logloss: 0.0177883
# [459]	valid_0's binary_logloss: 0.0177869
# [460]	valid_0's binary_logloss: 0.0177848
# [461]	valid_0's binary_logloss: 0.0177833
# [462]	valid_0's binary_logloss: 0.0177815
# [463]	valid_0's binary_logloss: 0.0177801
# [464]	valid_0's binary_logloss: 0.0177769
# [465]	valid_0's binary_logloss: 0.0177745
# [466]	valid_0's binary_logloss: 0.0177733
# [467]	valid_0's binary_logloss: 0.0177718
# [468]	valid_0's binary_logloss: 0.0177708
# [469]	valid_0's binary_logloss: 0.0177699
# [470]	valid_0's binary_logloss: 0.017768
# [471]	valid_0's binary_logloss: 0.017766
# [472]	valid_0's binary_logloss: 0.0177651
# [473]	valid_0's binary_logloss: 0.0177622
# [474]	valid_0's binary_logloss: 0.0177613
# [475]	valid_0's binary_logloss: 0.0177602
# [476]	valid_0's binary_logloss: 0.0177594
# [477]	valid_0's binary_logloss: 0.0177575
# [478]	valid_0's binary_logloss: 0.0177559
# [479]	valid_0's binary_logloss: 0.0177562
# [480]	valid_0's binary_logloss: 0.0177555
# [481]	valid_0's binary_logloss: 0.0177534
# [482]	valid_0's binary_logloss: 0.0177522
# [483]	valid_0's binary_logloss: 0.0177504
# [484]	valid_0's binary_logloss: 0.0177494
# [485]	valid_0's binary_logloss: 0.0177482
# [486]	valid_0's binary_logloss: 0.0177461
# [487]	valid_0's binary_logloss: 0.017744
# [488]	valid_0's binary_logloss: 0.0177428
# [489]	valid_0's binary_logloss: 0.017742
# [490]	valid_0's binary_logloss: 0.0177395
# [491]	valid_0's binary_logloss: 0.0177389
# [492]	valid_0's binary_logloss: 0.0177381
# [493]	valid_0's binary_logloss: 0.0177355
# [494]	valid_0's binary_logloss: 0.0177337
# [495]	valid_0's binary_logloss: 0.0177323
# [496]	valid_0's binary_logloss: 0.0177307
# [497]	valid_0's binary_logloss: 0.0177284
# [498]	valid_0's binary_logloss: 0.0177267
# [499]	valid_0's binary_logloss: 0.0177259
# [500]	valid_0's binary_logloss: 0.0177239
# [501]	valid_0's binary_logloss: 0.0177231
# [502]	valid_0's binary_logloss: 0.0177223
# [503]	valid_0's binary_logloss: 0.0177205
# [504]	valid_0's binary_logloss: 0.0177191
# [505]	valid_0's binary_logloss: 0.0177191
# [506]	valid_0's binary_logloss: 0.0177176
# [507]	valid_0's binary_logloss: 0.0177166
# [508]	valid_0's binary_logloss: 0.0177159
# [509]	valid_0's binary_logloss: 0.0177144
# [510]	valid_0's binary_logloss: 0.0177133
# [511]	valid_0's binary_logloss: 0.0177112
# [512]	valid_0's binary_logloss: 0.0177097
# [513]	valid_0's binary_logloss: 0.0177081
# [514]	valid_0's binary_logloss: 0.0177066
# [515]	valid_0's binary_logloss: 0.0177055
# [516]	valid_0's binary_logloss: 0.0177037
# [517]	valid_0's binary_logloss: 0.0177014
# [518]	valid_0's binary_logloss: 0.0176999
# [519]	valid_0's binary_logloss: 0.0176992
# [520]	valid_0's binary_logloss: 0.0176975
# [521]	valid_0's binary_logloss: 0.0176964
# [522]	valid_0's binary_logloss: 0.0176947
# [523]	valid_0's binary_logloss: 0.0176937
# [524]	valid_0's binary_logloss: 0.0176927
# [525]	valid_0's binary_logloss: 0.0176918
# [526]	valid_0's binary_logloss: 0.0176889
# [527]	valid_0's binary_logloss: 0.0176879
# [528]	valid_0's binary_logloss: 0.0176873
# [529]	valid_0's binary_logloss: 0.0176871
# [530]	valid_0's binary_logloss: 0.0176856
# [531]	valid_0's binary_logloss: 0.0176851
# [532]	valid_0's binary_logloss: 0.0176841
# [533]	valid_0's binary_logloss: 0.0176821
# [534]	valid_0's binary_logloss: 0.0176805
# [535]	valid_0's binary_logloss: 0.0176792
# [536]	valid_0's binary_logloss: 0.0176781
# [537]	valid_0's binary_logloss: 0.017677
# [538]	valid_0's binary_logloss: 0.0176746
# [539]	valid_0's binary_logloss: 0.0176745
# [540]	valid_0's binary_logloss: 0.0176738
# [541]	valid_0's binary_logloss: 0.0176723
# [542]	valid_0's binary_logloss: 0.0176697
# [543]	valid_0's binary_logloss: 0.017669
# [544]	valid_0's binary_logloss: 0.0176658
# [545]	valid_0's binary_logloss: 0.0176638
# [546]	valid_0's binary_logloss: 0.0176638
# [547]	valid_0's binary_logloss: 0.0176618
# [548]	valid_0's binary_logloss: 0.0176612
# [549]	valid_0's binary_logloss: 0.0176597
# [550]	valid_0's binary_logloss: 0.0176576
# [551]	valid_0's binary_logloss: 0.0176559
# [552]	valid_0's binary_logloss: 0.0176535
# [553]	valid_0's binary_logloss: 0.0176527
# [554]	valid_0's binary_logloss: 0.0176516
# [555]	valid_0's binary_logloss: 0.0176502
# [556]	valid_0's binary_logloss: 0.0176486
# [557]	valid_0's binary_logloss: 0.0176488
# [558]	valid_0's binary_logloss: 0.0176475
# [559]	valid_0's binary_logloss: 0.0176464
# [560]	valid_0's binary_logloss: 0.017645
# [561]	valid_0's binary_logloss: 0.0176435
# [562]	valid_0's binary_logloss: 0.0176426
# [563]	valid_0's binary_logloss: 0.0176414
# [564]	valid_0's binary_logloss: 0.0176401
# [565]	valid_0's binary_logloss: 0.0176384
# [566]	valid_0's binary_logloss: 0.0176365
# [567]	valid_0's binary_logloss: 0.0176336
# [568]	valid_0's binary_logloss: 0.0176321
# [569]	valid_0's binary_logloss: 0.0176308
# [570]	valid_0's binary_logloss: 0.0176301
# [571]	valid_0's binary_logloss: 0.0176284
# [572]	valid_0's binary_logloss: 0.0176285
# [573]	valid_0's binary_logloss: 0.0176289
# [574]	valid_0's binary_logloss: 0.0176276
# [575]	valid_0's binary_logloss: 0.0176268
# [576]	valid_0's binary_logloss: 0.0176254
# [577]	valid_0's binary_logloss: 0.0176251
# [578]	valid_0's binary_logloss: 0.0176241
# [579]	valid_0's binary_logloss: 0.0176229
# [580]	valid_0's binary_logloss: 0.0176227
# [581]	valid_0's binary_logloss: 0.0176209
# [582]	valid_0's binary_logloss: 0.0176204
# [583]	valid_0's binary_logloss: 0.0176198
# [584]	valid_0's binary_logloss: 0.0176191
# [585]	valid_0's binary_logloss: 0.0176176
# [586]	valid_0's binary_logloss: 0.0176165
# [587]	valid_0's binary_logloss: 0.0176149
# [588]	valid_0's binary_logloss: 0.0176139
# [589]	valid_0's binary_logloss: 0.0176128
# [590]	valid_0's binary_logloss: 0.0176123
# [591]	valid_0's binary_logloss: 0.0176127
# [592]	valid_0's binary_logloss: 0.0176122
# [593]	valid_0's binary_logloss: 0.0176105
# [594]	valid_0's binary_logloss: 0.0176091
# [595]	valid_0's binary_logloss: 0.0176089
# [596]	valid_0's binary_logloss: 0.0176095
# [597]	valid_0's binary_logloss: 0.0176088
# [598]	valid_0's binary_logloss: 0.0176074
# [599]	valid_0's binary_logloss: 0.0176072
# [600]	valid_0's binary_logloss: 0.0176055
# [601]	valid_0's binary_logloss: 0.0176054
# [602]	valid_0's binary_logloss: 0.0176044
# [603]	valid_0's binary_logloss: 0.0176036
# [604]	valid_0's binary_logloss: 0.0176027
# [605]	valid_0's binary_logloss: 0.0176027
# [606]	valid_0's binary_logloss: 0.0176017
# [607]	valid_0's binary_logloss: 0.0176006
# [608]	valid_0's binary_logloss: 0.0175998
# [609]	valid_0's binary_logloss: 0.0175991
# [610]	valid_0's binary_logloss: 0.0175986
# [611]	valid_0's binary_logloss: 0.0175982
# [612]	valid_0's binary_logloss: 0.0175967
# [613]	valid_0's binary_logloss: 0.0175952
# [614]	valid_0's binary_logloss: 0.017594
# [615]	valid_0's binary_logloss: 0.0175926
# [616]	valid_0's binary_logloss: 0.017592
# [617]	valid_0's binary_logloss: 0.0175924
# [618]	valid_0's binary_logloss: 0.0175922
# [619]	valid_0's binary_logloss: 0.0175918
# [620]	valid_0's binary_logloss: 0.0175916
# [621]	valid_0's binary_logloss: 0.0175918
# [622]	valid_0's binary_logloss: 0.0175914
# [623]	valid_0's binary_logloss: 0.0175911
# [624]	valid_0's binary_logloss: 0.0175906
# [625]	valid_0's binary_logloss: 0.0175894
# [626]	valid_0's binary_logloss: 0.017589
# [627]	valid_0's binary_logloss: 0.0175879
# [628]	valid_0's binary_logloss: 0.0175867
# [629]	valid_0's binary_logloss: 0.0175858
# [630]	valid_0's binary_logloss: 0.0175849
# [631]	valid_0's binary_logloss: 0.017584
# [632]	valid_0's binary_logloss: 0.0175818
# [633]	valid_0's binary_logloss: 0.0175815
# [634]	valid_0's binary_logloss: 0.0175821
# [635]	valid_0's binary_logloss: 0.0175822
# [636]	valid_0's binary_logloss: 0.0175812
# [637]	valid_0's binary_logloss: 0.0175804
# [638]	valid_0's binary_logloss: 0.0175796
# [639]	valid_0's binary_logloss: 0.0175793
# [640]	valid_0's binary_logloss: 0.0175786
# [641]	valid_0's binary_logloss: 0.017578
# [642]	valid_0's binary_logloss: 0.0175777
# [643]	valid_0's binary_logloss: 0.0175776
# [644]	valid_0's binary_logloss: 0.0175767
# [645]	valid_0's binary_logloss: 0.0175766
# [646]	valid_0's binary_logloss: 0.0175752
# [647]	valid_0's binary_logloss: 0.0175748
# [648]	valid_0's binary_logloss: 0.0175748
# [649]	valid_0's binary_logloss: 0.0175744
# [650]	valid_0's binary_logloss: 0.0175729
# [651]	valid_0's binary_logloss: 0.0175726
# [652]	valid_0's binary_logloss: 0.0175721
# [653]	valid_0's binary_logloss: 0.0175714
# [654]	valid_0's binary_logloss: 0.0175708
# [655]	valid_0's binary_logloss: 0.017569
# [656]	valid_0's binary_logloss: 0.0175692
# [657]	valid_0's binary_logloss: 0.0175679
# [658]	valid_0's binary_logloss: 0.017568
# [659]	valid_0's binary_logloss: 0.017567
# [660]	valid_0's binary_logloss: 0.0175664
# [661]	valid_0's binary_logloss: 0.017566
# [662]	valid_0's binary_logloss: 0.0175657
# [663]	valid_0's binary_logloss: 0.0175652
# [664]	valid_0's binary_logloss: 0.0175645
# [665]	valid_0's binary_logloss: 0.0175629
# [666]	valid_0's binary_logloss: 0.0175623
# [667]	valid_0's binary_logloss: 0.0175619
# [668]	valid_0's binary_logloss: 0.0175618
# [669]	valid_0's binary_logloss: 0.0175613
# [670]	valid_0's binary_logloss: 0.0175608
# [671]	valid_0's binary_logloss: 0.0175594
# [672]	valid_0's binary_logloss: 0.0175592
# [673]	valid_0's binary_logloss: 0.017559
# [674]	valid_0's binary_logloss: 0.0175585
# [675]	valid_0's binary_logloss: 0.0175579
# [676]	valid_0's binary_logloss: 0.017558
# [677]	valid_0's binary_logloss: 0.0175573
# [678]	valid_0's binary_logloss: 0.0175566
# [679]	valid_0's binary_logloss: 0.0175563
# [680]	valid_0's binary_logloss: 0.0175553
# [681]	valid_0's binary_logloss: 0.0175555
# [682]	valid_0's binary_logloss: 0.0175553
# [683]	valid_0's binary_logloss: 0.0175558
# [684]	valid_0's binary_logloss: 0.0175546
# [685]	valid_0's binary_logloss: 0.0175538
# [686]	valid_0's binary_logloss: 0.017554
# [687]	valid_0's binary_logloss: 0.0175523
# [688]	valid_0's binary_logloss: 0.0175512
# [689]	valid_0's binary_logloss: 0.0175504
# [690]	valid_0's binary_logloss: 0.0175482
# [691]	valid_0's binary_logloss: 0.0175463
# [692]	valid_0's binary_logloss: 0.0175455
# [693]	valid_0's binary_logloss: 0.0175447
# [694]	valid_0's binary_logloss: 0.0175444
# [695]	valid_0's binary_logloss: 0.0175436
# [696]	valid_0's binary_logloss: 0.0175431
# [697]	valid_0's binary_logloss: 0.0175426
# [698]	valid_0's binary_logloss: 0.0175415
# [699]	valid_0's binary_logloss: 0.0175412
# [700]	valid_0's binary_logloss: 0.0175406
# [701]	valid_0's binary_logloss: 0.0175386
# [702]	valid_0's binary_logloss: 0.0175376
# [703]	valid_0's binary_logloss: 0.0175375
# [704]	valid_0's binary_logloss: 0.0175374
# [705]	valid_0's binary_logloss: 0.0175366
# [706]	valid_0's binary_logloss: 0.0175364
# [707]	valid_0's binary_logloss: 0.0175348
# [708]	valid_0's binary_logloss: 0.0175346
# [709]	valid_0's binary_logloss: 0.0175342
# [710]	valid_0's binary_logloss: 0.0175336
# [711]	valid_0's binary_logloss: 0.0175331
# [712]	valid_0's binary_logloss: 0.0175314
# [713]	valid_0's binary_logloss: 0.0175306
# [714]	valid_0's binary_logloss: 0.0175298
# [715]	valid_0's binary_logloss: 0.0175294
# [716]	valid_0's binary_logloss: 0.0175293
# [717]	valid_0's binary_logloss: 0.0175281
# [718]	valid_0's binary_logloss: 0.0175278
# [719]	valid_0's binary_logloss: 0.0175278
# [720]	valid_0's binary_logloss: 0.0175283
# [721]	valid_0's binary_logloss: 0.0175274
# [722]	valid_0's binary_logloss: 0.0175279
# [723]	valid_0's binary_logloss: 0.0175272
# [724]	valid_0's binary_logloss: 0.0175268
# [725]	valid_0's binary_logloss: 0.0175262
# [726]	valid_0's binary_logloss: 0.0175243
# [727]	valid_0's binary_logloss: 0.0175228
# [728]	valid_0's binary_logloss: 0.0175225
# [729]	valid_0's binary_logloss: 0.0175216
# [730]	valid_0's binary_logloss: 0.0175218
# [731]	valid_0's binary_logloss: 0.0175223
# [732]	valid_0's binary_logloss: 0.0175215
# [733]	valid_0's binary_logloss: 0.0175208
# [734]	valid_0's binary_logloss: 0.017521
# [735]	valid_0's binary_logloss: 0.0175194
# [736]	valid_0's binary_logloss: 0.0175189
# [737]	valid_0's binary_logloss: 0.0175182
# [738]	valid_0's binary_logloss: 0.0175167
# [739]	valid_0's binary_logloss: 0.0175163
# [740]	valid_0's binary_logloss: 0.017515
# [741]	valid_0's binary_logloss: 0.0175146
# [742]	valid_0's binary_logloss: 0.0175138
# [743]	valid_0's binary_logloss: 0.0175142
# [744]	valid_0's binary_logloss: 0.0175138
# [745]	valid_0's binary_logloss: 0.0175135
# [746]	valid_0's binary_logloss: 0.0175133
# [747]	valid_0's binary_logloss: 0.0175125
# [748]	valid_0's binary_logloss: 0.0175118
# [749]	valid_0's binary_logloss: 0.0175113
# [750]	valid_0's binary_logloss: 0.017511
# [751]	valid_0's binary_logloss: 0.0175106
# [752]	valid_0's binary_logloss: 0.0175093
# [753]	valid_0's binary_logloss: 0.0175096
# [754]	valid_0's binary_logloss: 0.0175101
# [755]	valid_0's binary_logloss: 0.0175085
# [756]	valid_0's binary_logloss: 0.0175078
# [757]	valid_0's binary_logloss: 0.0175078
# [758]	valid_0's binary_logloss: 0.017507
# [759]	valid_0's binary_logloss: 0.0175066
# [760]	valid_0's binary_logloss: 0.0175068
# [761]	valid_0's binary_logloss: 0.0175058
# [762]	valid_0's binary_logloss: 0.0175056
# [763]	valid_0's binary_logloss: 0.0175055
# [764]	valid_0's binary_logloss: 0.0175057
# [765]	valid_0's binary_logloss: 0.0175061
# [766]	valid_0's binary_logloss: 0.0175062
# [767]	valid_0's binary_logloss: 0.0175061
# [768]	valid_0's binary_logloss: 0.0175044
# [769]	valid_0's binary_logloss: 0.0175049
# [770]	valid_0's binary_logloss: 0.017505
# [771]	valid_0's binary_logloss: 0.0175043
# [772]	valid_0's binary_logloss: 0.0175042
# [773]	valid_0's binary_logloss: 0.0175037
# [774]	valid_0's binary_logloss: 0.0175033
# [775]	valid_0's binary_logloss: 0.0175029
# [776]	valid_0's binary_logloss: 0.0175019
# [777]	valid_0's binary_logloss: 0.0175003
# [778]	valid_0's binary_logloss: 0.0175005
# [779]	valid_0's binary_logloss: 0.0174995
# [780]	valid_0's binary_logloss: 0.0174987
# [781]	valid_0's binary_logloss: 0.0174983
# [782]	valid_0's binary_logloss: 0.0174974
# [783]	valid_0's binary_logloss: 0.0174962
# [784]	valid_0's binary_logloss: 0.0174955
# [785]	valid_0's binary_logloss: 0.0174943
# [786]	valid_0's binary_logloss: 0.0174937
# [787]	valid_0's binary_logloss: 0.017493
# [788]	valid_0's binary_logloss: 0.0174932
# [789]	valid_0's binary_logloss: 0.0174929
# [790]	valid_0's binary_logloss: 0.0174924
# [791]	valid_0's binary_logloss: 0.0174917
# [792]	valid_0's binary_logloss: 0.0174908
# [793]	valid_0's binary_logloss: 0.0174905
# [794]	valid_0's binary_logloss: 0.0174903
# [795]	valid_0's binary_logloss: 0.0174897
# [796]	valid_0's binary_logloss: 0.0174892
# [797]	valid_0's binary_logloss: 0.0174893
# [798]	valid_0's binary_logloss: 0.0174881
# [799]	valid_0's binary_logloss: 0.0174882
# [800]	valid_0's binary_logloss: 0.0174885
# [801]	valid_0's binary_logloss: 0.0174882
# [802]	valid_0's binary_logloss: 0.017488
# [803]	valid_0's binary_logloss: 0.017488
# [804]	valid_0's binary_logloss: 0.0174881
# [805]	valid_0's binary_logloss: 0.0174877
# [806]	valid_0's binary_logloss: 0.0174876
# [807]	valid_0's binary_logloss: 0.0174879
# [808]	valid_0's binary_logloss: 0.0174882
# [809]	valid_0's binary_logloss: 0.0174879
# [810]	valid_0's binary_logloss: 0.0174881
# [811]	valid_0's binary_logloss: 0.0174881
# [812]	valid_0's binary_logloss: 0.0174883
# [813]	valid_0's binary_logloss: 0.0174884
# [814]	valid_0's binary_logloss: 0.0174881
# [815]	valid_0's binary_logloss: 0.0174884
# [816]	valid_0's binary_logloss: 0.0174882
# [817]	valid_0's binary_logloss: 0.0174879
# [818]	valid_0's binary_logloss: 0.0174878
# [819]	valid_0's binary_logloss: 0.017487
# [820]	valid_0's binary_logloss: 0.0174868
# [821]	valid_0's binary_logloss: 0.0174863
# [822]	valid_0's binary_logloss: 0.0174861
# [823]	valid_0's binary_logloss: 0.0174856
# [824]	valid_0's binary_logloss: 0.0174846
# [825]	valid_0's binary_logloss: 0.0174843
# [826]	valid_0's binary_logloss: 0.0174839
# [827]	valid_0's binary_logloss: 0.0174832
# [828]	valid_0's binary_logloss: 0.0174822
# [829]	valid_0's binary_logloss: 0.017482
# [830]	valid_0's binary_logloss: 0.0174817
# [831]	valid_0's binary_logloss: 0.0174814
# [832]	valid_0's binary_logloss: 0.0174809
# [833]	valid_0's binary_logloss: 0.0174803
# [834]	valid_0's binary_logloss: 0.01748
# [835]	valid_0's binary_logloss: 0.0174796
# [836]	valid_0's binary_logloss: 0.0174786
# [837]	valid_0's binary_logloss: 0.0174785
# [838]	valid_0's binary_logloss: 0.017478
# [839]	valid_0's binary_logloss: 0.0174779
# [840]	valid_0's binary_logloss: 0.017478
# [841]	valid_0's binary_logloss: 0.0174781
# [842]	valid_0's binary_logloss: 0.0174777
# [843]	valid_0's binary_logloss: 0.017477
# [844]	valid_0's binary_logloss: 0.0174766
# [845]	valid_0's binary_logloss: 0.0174751
# [846]	valid_0's binary_logloss: 0.0174753
# [847]	valid_0's binary_logloss: 0.0174747
# [848]	valid_0's binary_logloss: 0.0174738
# [849]	valid_0's binary_logloss: 0.0174725
# [850]	valid_0's binary_logloss: 0.0174711
# [851]	valid_0's binary_logloss: 0.0174711
# [852]	valid_0's binary_logloss: 0.0174717
# [853]	valid_0's binary_logloss: 0.0174724
# [854]	valid_0's binary_logloss: 0.0174713
# [855]	valid_0's binary_logloss: 0.0174706
# [856]	valid_0's binary_logloss: 0.0174708
# [857]	valid_0's binary_logloss: 0.01747
# [858]	valid_0's binary_logloss: 0.0174694
# [859]	valid_0's binary_logloss: 0.0174683
# [860]	valid_0's binary_logloss: 0.0174674
# [861]	valid_0's binary_logloss: 0.0174676
# [862]	valid_0's binary_logloss: 0.0174667
# [863]	valid_0's binary_logloss: 0.0174661
# [864]	valid_0's binary_logloss: 0.0174653
# [865]	valid_0's binary_logloss: 0.0174658
# [866]	valid_0's binary_logloss: 0.0174658
# [867]	valid_0's binary_logloss: 0.0174664
# [868]	valid_0's binary_logloss: 0.0174666
# [869]	valid_0's binary_logloss: 0.0174659
# [870]	valid_0's binary_logloss: 0.0174653
# [871]	valid_0's binary_logloss: 0.0174652
# [872]	valid_0's binary_logloss: 0.0174639
# [873]	valid_0's binary_logloss: 0.0174635
# [874]	valid_0's binary_logloss: 0.0174631
# [875]	valid_0's binary_logloss: 0.0174624
# [876]	valid_0's binary_logloss: 0.0174621
# [877]	valid_0's binary_logloss: 0.0174608
# [878]	valid_0's binary_logloss: 0.0174603
# [879]	valid_0's binary_logloss: 0.0174604
# [880]	valid_0's binary_logloss: 0.01746
# [881]	valid_0's binary_logloss: 0.0174598
# [882]	valid_0's binary_logloss: 0.0174597
# [883]	valid_0's binary_logloss: 0.0174598
# [884]	valid_0's binary_logloss: 0.0174589
# [885]	valid_0's binary_logloss: 0.0174585
# [886]	valid_0's binary_logloss: 0.0174583
# [887]	valid_0's binary_logloss: 0.0174577
# [888]	valid_0's binary_logloss: 0.0174572
# [889]	valid_0's binary_logloss: 0.0174571
# [890]	valid_0's binary_logloss: 0.0174561
# [891]	valid_0's binary_logloss: 0.0174555
# [892]	valid_0's binary_logloss: 0.0174557
# [893]	valid_0's binary_logloss: 0.0174559
# [894]	valid_0's binary_logloss: 0.0174546
# [895]	valid_0's binary_logloss: 0.0174539
# [896]	valid_0's binary_logloss: 0.0174534
# [897]	valid_0's binary_logloss: 0.0174538
# [898]	valid_0's binary_logloss: 0.0174536
# [899]	valid_0's binary_logloss: 0.0174527
# [900]	valid_0's binary_logloss: 0.0174523
# [901]	valid_0's binary_logloss: 0.0174517
# [902]	valid_0's binary_logloss: 0.0174507
# [903]	valid_0's binary_logloss: 0.01745
# [904]	valid_0's binary_logloss: 0.0174493
# [905]	valid_0's binary_logloss: 0.0174492
# [906]	valid_0's binary_logloss: 0.0174487
# [907]	valid_0's binary_logloss: 0.0174479
# [908]	valid_0's binary_logloss: 0.0174476
# [909]	valid_0's binary_logloss: 0.0174465
# [910]	valid_0's binary_logloss: 0.0174467
# [911]	valid_0's binary_logloss: 0.0174456
# [912]	valid_0's binary_logloss: 0.0174453
# [913]	valid_0's binary_logloss: 0.0174448
# [914]	valid_0's binary_logloss: 0.0174439
# [915]	valid_0's binary_logloss: 0.0174431
# [916]	valid_0's binary_logloss: 0.0174426
# [917]	valid_0's binary_logloss: 0.0174433
# [918]	valid_0's binary_logloss: 0.0174429
# [919]	valid_0's binary_logloss: 0.0174431
# [920]	valid_0's binary_logloss: 0.0174432
# [921]	valid_0's binary_logloss: 0.0174436
# [922]	valid_0's binary_logloss: 0.0174436
# [923]	valid_0's binary_logloss: 0.017444
# [924]	valid_0's binary_logloss: 0.0174445
# [925]	valid_0's binary_logloss: 0.0174447
# [926]	valid_0's binary_logloss: 0.0174458
# [927]	valid_0's binary_logloss: 0.0174456
# [928]	valid_0's binary_logloss: 0.0174448
# [929]	valid_0's binary_logloss: 0.0174452
# [930]	valid_0's binary_logloss: 0.0174456
# [931]	valid_0's binary_logloss: 0.0174454
# [932]	valid_0's binary_logloss: 0.0174451
# [933]	valid_0's binary_logloss: 0.0174443
# [934]	valid_0's binary_logloss: 0.0174438
# [935]	valid_0's binary_logloss: 0.0174441
# [936]	valid_0's binary_logloss: 0.0174434
# [937]	valid_0's binary_logloss: 0.0174426
# [938]	valid_0's binary_logloss: 0.0174423
# [939]	valid_0's binary_logloss: 0.0174425
# [940]	valid_0's binary_logloss: 0.017443
# [941]	valid_0's binary_logloss: 0.0174429
# [942]	valid_0's binary_logloss: 0.0174433
# [943]	valid_0's binary_logloss: 0.0174428
# [944]	valid_0's binary_logloss: 0.017443
# [945]	valid_0's binary_logloss: 0.0174423
# [946]	valid_0's binary_logloss: 0.0174418
# [947]	valid_0's binary_logloss: 0.0174415
# [948]	valid_0's binary_logloss: 0.017441
# [949]	valid_0's binary_logloss: 0.0174408
# [950]	valid_0's binary_logloss: 0.0174404
# [951]	valid_0's binary_logloss: 0.0174394
# [952]	valid_0's binary_logloss: 0.0174398
# [953]	valid_0's binary_logloss: 0.017439
# [954]	valid_0's binary_logloss: 0.0174394
# [955]	valid_0's binary_logloss: 0.0174389
# [956]	valid_0's binary_logloss: 0.0174383
# [957]	valid_0's binary_logloss: 0.0174379
# [958]	valid_0's binary_logloss: 0.0174373
# [959]	valid_0's binary_logloss: 0.0174369
# [960]	valid_0's binary_logloss: 0.0174358
# [961]	valid_0's binary_logloss: 0.0174356
# [962]	valid_0's binary_logloss: 0.0174354
# [963]	valid_0's binary_logloss: 0.0174354
# [964]	valid_0's binary_logloss: 0.0174345
# [965]	valid_0's binary_logloss: 0.0174331
# [966]	valid_0's binary_logloss: 0.0174331
# [967]	valid_0's binary_logloss: 0.0174331
# [968]	valid_0's binary_logloss: 0.0174327
# [969]	valid_0's binary_logloss: 0.0174326
# [970]	valid_0's binary_logloss: 0.0174329
# [971]	valid_0's binary_logloss: 0.0174323
# [972]	valid_0's binary_logloss: 0.0174323
# [973]	valid_0's binary_logloss: 0.0174318
# [974]	valid_0's binary_logloss: 0.0174314
# [975]	valid_0's binary_logloss: 0.017431
# [976]	valid_0's binary_logloss: 0.0174315
# [977]	valid_0's binary_logloss: 0.0174312
# [978]	valid_0's binary_logloss: 0.0174309
# [979]	valid_0's binary_logloss: 0.0174307
# [980]	valid_0's binary_logloss: 0.0174294
# [981]	valid_0's binary_logloss: 0.0174281
# [982]	valid_0's binary_logloss: 0.0174278
# [983]	valid_0's binary_logloss: 0.0174278
# [984]	valid_0's binary_logloss: 0.0174274
# [985]	valid_0's binary_logloss: 0.0174271
# [986]	valid_0's binary_logloss: 0.0174271
# [987]	valid_0's binary_logloss: 0.0174275
# [988]	valid_0's binary_logloss: 0.0174271
# [989]	valid_0's binary_logloss: 0.0174271
# [990]	valid_0's binary_logloss: 0.017427
# [991]	valid_0's binary_logloss: 0.0174271
# [992]	valid_0's binary_logloss: 0.0174269
# [993]	valid_0's binary_logloss: 0.0174275
# [994]	valid_0's binary_logloss: 0.0174272
# [995]	valid_0's binary_logloss: 0.0174272
# [996]	valid_0's binary_logloss: 0.0174272
# [997]	valid_0's binary_logloss: 0.0174273
# [998]	valid_0's binary_logloss: 0.0174274
# [999]	valid_0's binary_logloss: 0.0174275
# [1000]	valid_0's binary_logloss: 0.0174264
# [1001]	valid_0's binary_logloss: 0.0174262
# [1002]	valid_0's binary_logloss: 0.0174265
# [1003]	valid_0's binary_logloss: 0.0174262
# [1004]	valid_0's binary_logloss: 0.0174258
# [1005]	valid_0's binary_logloss: 0.0174258
# [1006]	valid_0's binary_logloss: 0.0174254
# [1007]	valid_0's binary_logloss: 0.0174248
# [1008]	valid_0's binary_logloss: 0.0174252
# [1009]	valid_0's binary_logloss: 0.017425
# [1010]	valid_0's binary_logloss: 0.017425
# [1011]	valid_0's binary_logloss: 0.0174244
# [1012]	valid_0's binary_logloss: 0.0174246
# [1013]	valid_0's binary_logloss: 0.0174247
# [1014]	valid_0's binary_logloss: 0.0174248
# [1015]	valid_0's binary_logloss: 0.0174253
# [1016]	valid_0's binary_logloss: 0.0174242
# [1017]	valid_0's binary_logloss: 0.0174241
# [1018]	valid_0's binary_logloss: 0.0174238
# [1019]	valid_0's binary_logloss: 0.0174237
# [1020]	valid_0's binary_logloss: 0.0174238
# [1021]	valid_0's binary_logloss: 0.0174235
# [1022]	valid_0's binary_logloss: 0.0174237
# [1023]	valid_0's binary_logloss: 0.017424
# [1024]	valid_0's binary_logloss: 0.0174245
# [1025]	valid_0's binary_logloss: 0.0174244
# [1026]	valid_0's binary_logloss: 0.0174237
# [1027]	valid_0's binary_logloss: 0.0174237
# [1028]	valid_0's binary_logloss: 0.0174238
# [1029]	valid_0's binary_logloss: 0.0174235
# [1030]	valid_0's binary_logloss: 0.0174225
# [1031]	valid_0's binary_logloss: 0.0174222
# [1032]	valid_0's binary_logloss: 0.0174225
# [1033]	valid_0's binary_logloss: 0.0174217
# [1034]	valid_0's binary_logloss: 0.017422
# [1035]	valid_0's binary_logloss: 0.0174225
# [1036]	valid_0's binary_logloss: 0.0174225
# [1037]	valid_0's binary_logloss: 0.0174223
# [1038]	valid_0's binary_logloss: 0.0174217
# [1039]	valid_0's binary_logloss: 0.0174206
# [1040]	valid_0's binary_logloss: 0.0174206
# [1041]	valid_0's binary_logloss: 0.0174212
# [1042]	valid_0's binary_logloss: 0.0174211
# [1043]	valid_0's binary_logloss: 0.0174204
# [1044]	valid_0's binary_logloss: 0.0174203
# [1045]	valid_0's binary_logloss: 0.0174201
# [1046]	valid_0's binary_logloss: 0.0174196
# [1047]	valid_0's binary_logloss: 0.0174197
# [1048]	valid_0's binary_logloss: 0.0174194
# [1049]	valid_0's binary_logloss: 0.0174191
# [1050]	valid_0's binary_logloss: 0.0174187
# [1051]	valid_0's binary_logloss: 0.0174186
# [1052]	valid_0's binary_logloss: 0.0174174
# [1053]	valid_0's binary_logloss: 0.0174172
# [1054]	valid_0's binary_logloss: 0.0174175
# [1055]	valid_0's binary_logloss: 0.0174173
# [1056]	valid_0's binary_logloss: 0.0174177
# [1057]	valid_0's binary_logloss: 0.0174167
# [1058]	valid_0's binary_logloss: 0.0174158
# [1059]	valid_0's binary_logloss: 0.0174155
# [1060]	valid_0's binary_logloss: 0.0174159
# [1061]	valid_0's binary_logloss: 0.0174156
# [1062]	valid_0's binary_logloss: 0.0174154
# [1063]	valid_0's binary_logloss: 0.0174153
# [1064]	valid_0's binary_logloss: 0.0174146
# [1065]	valid_0's binary_logloss: 0.0174148
# [1066]	valid_0's binary_logloss: 0.0174146
# [1067]	valid_0's binary_logloss: 0.0174148
# [1068]	valid_0's binary_logloss: 0.0174146
# [1069]	valid_0's binary_logloss: 0.0174142
# [1070]	valid_0's binary_logloss: 0.0174146
# [1071]	valid_0's binary_logloss: 0.0174151
# [1072]	valid_0's binary_logloss: 0.0174147
# [1073]	valid_0's binary_logloss: 0.0174147
# [1074]	valid_0's binary_logloss: 0.0174151
# [1075]	valid_0's binary_logloss: 0.0174153
# [1076]	valid_0's binary_logloss: 0.0174159
# [1077]	valid_0's binary_logloss: 0.0174166
# [1078]	valid_0's binary_logloss: 0.0174167
# [1079]	valid_0's binary_logloss: 0.0174166
# [1080]	valid_0's binary_logloss: 0.0174173
# [1081]	valid_0's binary_logloss: 0.0174174
# [1082]	valid_0's binary_logloss: 0.0174171
# [1083]	valid_0's binary_logloss: 0.0174174
# [1084]	valid_0's binary_logloss: 0.0174175
# [1085]	valid_0's binary_logloss: 0.0174179
# [1086]	valid_0's binary_logloss: 0.0174177
# [1087]	valid_0's binary_logloss: 0.0174181
# [1088]	valid_0's binary_logloss: 0.0174181
# [1089]	valid_0's binary_logloss: 0.0174184
# [1090]	valid_0's binary_logloss: 0.0174186
# [1091]	valid_0's binary_logloss: 0.0174184
# [1092]	valid_0's binary_logloss: 0.0174184
# [1093]	valid_0's binary_logloss: 0.0174186
# [1094]	valid_0's binary_logloss: 0.0174182
# Early stopping, best iteration is:
# [1069]	valid_0's binary_logloss: 0.0174142
# Modelo da classe 3 finalizado

# %%
# Treinar 100% modelo da classe 2
m2 = lgb.train(params=hp2, num_boost_round=nbr, train_set=ds2_train, valid_sets=[ds2_valid], 
               verbose_eval=True, categorical_feature=feats_cat)
print('Modelo da classe 2 finalizado')
# Out:
# [1]	valid_0's binary_logloss: 0.111189
# Training until validation scores don't improve for 25 rounds
# [2]	valid_0's binary_logloss: 0.109087
# [3]	valid_0's binary_logloss: 0.107097
# [4]	valid_0's binary_logloss: 0.105283
# [5]	valid_0's binary_logloss: 0.103643
# [6]	valid_0's binary_logloss: 0.102146
# [7]	valid_0's binary_logloss: 0.100767
# [8]	valid_0's binary_logloss: 0.099472
# [9]	valid_0's binary_logloss: 0.0982501
# [10]	valid_0's binary_logloss: 0.0971251
# [11]	valid_0's binary_logloss: 0.0960573
# [12]	valid_0's binary_logloss: 0.0950475
# [13]	valid_0's binary_logloss: 0.0941728
# [14]	valid_0's binary_logloss: 0.0932589
# [15]	valid_0's binary_logloss: 0.0923837
# [16]	valid_0's binary_logloss: 0.09156
# [17]	valid_0's binary_logloss: 0.0907644
# [18]	valid_0's binary_logloss: 0.0900092
# [19]	valid_0's binary_logloss: 0.089355
# [20]	valid_0's binary_logloss: 0.0886435
# [21]	valid_0's binary_logloss: 0.0880378
# [22]	valid_0's binary_logloss: 0.0874101
# [23]	valid_0's binary_logloss: 0.0867778
# [24]	valid_0's binary_logloss: 0.0861859
# [25]	valid_0's binary_logloss: 0.0856008
# [26]	valid_0's binary_logloss: 0.08502
# [27]	valid_0's binary_logloss: 0.0844466
# [28]	valid_0's binary_logloss: 0.0839559
# [29]	valid_0's binary_logloss: 0.0834885
# [30]	valid_0's binary_logloss: 0.0829668
# [31]	valid_0's binary_logloss: 0.0824629
# [32]	valid_0's binary_logloss: 0.0819767
# [33]	valid_0's binary_logloss: 0.0815113
# [34]	valid_0's binary_logloss: 0.0810578
# [35]	valid_0's binary_logloss: 0.0806853
# [36]	valid_0's binary_logloss: 0.0802987
# [37]	valid_0's binary_logloss: 0.0798762
# [38]	valid_0's binary_logloss: 0.0794569
# [39]	valid_0's binary_logloss: 0.0790484
# [40]	valid_0's binary_logloss: 0.0786491
# [41]	valid_0's binary_logloss: 0.0782812
# [42]	valid_0's binary_logloss: 0.0779031
# [43]	valid_0's binary_logloss: 0.0775381
# [44]	valid_0's binary_logloss: 0.0771859
# [45]	valid_0's binary_logloss: 0.0768407
# [46]	valid_0's binary_logloss: 0.076513
# [47]	valid_0's binary_logloss: 0.0761867
# [48]	valid_0's binary_logloss: 0.0758594
# [49]	valid_0's binary_logloss: 0.0755339
# [50]	valid_0's binary_logloss: 0.0752278
# [51]	valid_0's binary_logloss: 0.0749562
# [52]	valid_0's binary_logloss: 0.0746614
# [53]	valid_0's binary_logloss: 0.0743775
# [54]	valid_0's binary_logloss: 0.0740932
# [55]	valid_0's binary_logloss: 0.0738222
# [56]	valid_0's binary_logloss: 0.0735526
# [57]	valid_0's binary_logloss: 0.0733183
# [58]	valid_0's binary_logloss: 0.0731146
# [59]	valid_0's binary_logloss: 0.0728598
# [60]	valid_0's binary_logloss: 0.0726085
# [61]	valid_0's binary_logloss: 0.0723693
# [62]	valid_0's binary_logloss: 0.072129
# [63]	valid_0's binary_logloss: 0.0718948
# [64]	valid_0's binary_logloss: 0.0716627
# [65]	valid_0's binary_logloss: 0.0714334
# [66]	valid_0's binary_logloss: 0.0712102
# [67]	valid_0's binary_logloss: 0.0709962
# [68]	valid_0's binary_logloss: 0.0707807
# [69]	valid_0's binary_logloss: 0.0705702
# [70]	valid_0's binary_logloss: 0.0703628
# [71]	valid_0's binary_logloss: 0.0701562
# [72]	valid_0's binary_logloss: 0.0699591
# [73]	valid_0's binary_logloss: 0.0697607
# [74]	valid_0's binary_logloss: 0.069588
# [75]	valid_0's binary_logloss: 0.0693905
# [76]	valid_0's binary_logloss: 0.0692032
# [77]	valid_0's binary_logloss: 0.0690225
# [78]	valid_0's binary_logloss: 0.0688416
# [79]	valid_0's binary_logloss: 0.0686583
# [80]	valid_0's binary_logloss: 0.0684789
# [81]	valid_0's binary_logloss: 0.068303
# [82]	valid_0's binary_logloss: 0.0681448
# [83]	valid_0's binary_logloss: 0.067996
# [84]	valid_0's binary_logloss: 0.06782
# [85]	valid_0's binary_logloss: 0.0676491
# [86]	valid_0's binary_logloss: 0.0675087
# [87]	valid_0's binary_logloss: 0.067343
# [88]	valid_0's binary_logloss: 0.0672009
# [89]	valid_0's binary_logloss: 0.0670399
# [90]	valid_0's binary_logloss: 0.0668908
# [91]	valid_0's binary_logloss: 0.0667403
# [92]	valid_0's binary_logloss: 0.0665908
# [93]	valid_0's binary_logloss: 0.0664441
# [94]	valid_0's binary_logloss: 0.0662929
# [95]	valid_0's binary_logloss: 0.0661482
# [96]	valid_0's binary_logloss: 0.0660019
# [97]	valid_0's binary_logloss: 0.0658637
# [98]	valid_0's binary_logloss: 0.0657532
# [99]	valid_0's binary_logloss: 0.0656151
# [100]	valid_0's binary_logloss: 0.0654886
# [101]	valid_0's binary_logloss: 0.0653585
# [102]	valid_0's binary_logloss: 0.0652249
# [103]	valid_0's binary_logloss: 0.0650936
# [104]	valid_0's binary_logloss: 0.0649735
# [105]	valid_0's binary_logloss: 0.0648525
# [106]	valid_0's binary_logloss: 0.0647337
# [107]	valid_0's binary_logloss: 0.0646158
# [108]	valid_0's binary_logloss: 0.0644985
# [109]	valid_0's binary_logloss: 0.0643844
# [110]	valid_0's binary_logloss: 0.0642729
# [111]	valid_0's binary_logloss: 0.0641609
# [112]	valid_0's binary_logloss: 0.0640473
# [113]	valid_0's binary_logloss: 0.0639307
# [114]	valid_0's binary_logloss: 0.0638267
# [115]	valid_0's binary_logloss: 0.0637147
# [116]	valid_0's binary_logloss: 0.0636045
# [117]	valid_0's binary_logloss: 0.063503
# [118]	valid_0's binary_logloss: 0.0633954
# [119]	valid_0's binary_logloss: 0.0632884
# [120]	valid_0's binary_logloss: 0.0631763
# [121]	valid_0's binary_logloss: 0.0630894
# [122]	valid_0's binary_logloss: 0.0630036
# [123]	valid_0's binary_logloss: 0.0629057
# [124]	valid_0's binary_logloss: 0.0628041
# [125]	valid_0's binary_logloss: 0.0627262
# [126]	valid_0's binary_logloss: 0.0626315
# [127]	valid_0's binary_logloss: 0.0625338
# [128]	valid_0's binary_logloss: 0.0624441
# [129]	valid_0's binary_logloss: 0.0623565
# [130]	valid_0's binary_logloss: 0.0622741
# [131]	valid_0's binary_logloss: 0.0621844
# [132]	valid_0's binary_logloss: 0.0620921
# [133]	valid_0's binary_logloss: 0.0620034
# [134]	valid_0's binary_logloss: 0.0619195
# [135]	valid_0's binary_logloss: 0.0618336
# [136]	valid_0's binary_logloss: 0.0617598
# [137]	valid_0's binary_logloss: 0.0616786
# [138]	valid_0's binary_logloss: 0.0615955
# [139]	valid_0's binary_logloss: 0.0615182
# [140]	valid_0's binary_logloss: 0.0614376
# [141]	valid_0's binary_logloss: 0.061361
# [142]	valid_0's binary_logloss: 0.0612821
# [143]	valid_0's binary_logloss: 0.0612102
# [144]	valid_0's binary_logloss: 0.0611362
# [145]	valid_0's binary_logloss: 0.0610623
# [146]	valid_0's binary_logloss: 0.060989
# [147]	valid_0's binary_logloss: 0.0609161
# [148]	valid_0's binary_logloss: 0.0608444
# [149]	valid_0's binary_logloss: 0.0607751
# [150]	valid_0's binary_logloss: 0.0606998
# [151]	valid_0's binary_logloss: 0.060627
# [152]	valid_0's binary_logloss: 0.060554
# [153]	valid_0's binary_logloss: 0.0604849
# [154]	valid_0's binary_logloss: 0.0604236
# [155]	valid_0's binary_logloss: 0.0603561
# [156]	valid_0's binary_logloss: 0.060291
# [157]	valid_0's binary_logloss: 0.060226
# [158]	valid_0's binary_logloss: 0.0601573
# [159]	valid_0's binary_logloss: 0.0600927
# [160]	valid_0's binary_logloss: 0.0600268
# [161]	valid_0's binary_logloss: 0.0599636
# [162]	valid_0's binary_logloss: 0.0599049
# [163]	valid_0's binary_logloss: 0.0598467
# [164]	valid_0's binary_logloss: 0.0597871
# [165]	valid_0's binary_logloss: 0.0597212
# [166]	valid_0's binary_logloss: 0.0596582
# [167]	valid_0's binary_logloss: 0.0595996
# [168]	valid_0's binary_logloss: 0.0595411
# [169]	valid_0's binary_logloss: 0.0594852
# [170]	valid_0's binary_logloss: 0.0594221
# [171]	valid_0's binary_logloss: 0.0593631
# [172]	valid_0's binary_logloss: 0.0593029
# [173]	valid_0's binary_logloss: 0.0592452
# [174]	valid_0's binary_logloss: 0.05919
# [175]	valid_0's binary_logloss: 0.0591337
# [176]	valid_0's binary_logloss: 0.0590772
# [177]	valid_0's binary_logloss: 0.0590212
# [178]	valid_0's binary_logloss: 0.0589689
# [179]	valid_0's binary_logloss: 0.0589121
# [180]	valid_0's binary_logloss: 0.0588581
# [181]	valid_0's binary_logloss: 0.0588183
# [182]	valid_0's binary_logloss: 0.0587688
# [183]	valid_0's binary_logloss: 0.0587216
# [184]	valid_0's binary_logloss: 0.0586725
# [185]	valid_0's binary_logloss: 0.0586264
# [186]	valid_0's binary_logloss: 0.0585885
# [187]	valid_0's binary_logloss: 0.0585435
# [188]	valid_0's binary_logloss: 0.0584941
# [189]	valid_0's binary_logloss: 0.0584436
# [190]	valid_0's binary_logloss: 0.0583912
# [191]	valid_0's binary_logloss: 0.0583413
# [192]	valid_0's binary_logloss: 0.0583092
# [193]	valid_0's binary_logloss: 0.0582649
# [194]	valid_0's binary_logloss: 0.0582221
# [195]	valid_0's binary_logloss: 0.058184
# [196]	valid_0's binary_logloss: 0.0581447
# [197]	valid_0's binary_logloss: 0.0581036
# [198]	valid_0's binary_logloss: 0.0580624
# [199]	valid_0's binary_logloss: 0.0580223
# [200]	valid_0's binary_logloss: 0.0579803
# [201]	valid_0's binary_logloss: 0.0579386
# [202]	valid_0's binary_logloss: 0.057899
# [203]	valid_0's binary_logloss: 0.0578614
# [204]	valid_0's binary_logloss: 0.0578225
# [205]	valid_0's binary_logloss: 0.0577852
# [206]	valid_0's binary_logloss: 0.0577471
# [207]	valid_0's binary_logloss: 0.0577091
# [208]	valid_0's binary_logloss: 0.057668
# [209]	valid_0's binary_logloss: 0.0576346
# [210]	valid_0's binary_logloss: 0.0575973
# [211]	valid_0's binary_logloss: 0.05756
# [212]	valid_0's binary_logloss: 0.0575174
# [213]	valid_0's binary_logloss: 0.0574763
# [214]	valid_0's binary_logloss: 0.0574399
# [215]	valid_0's binary_logloss: 0.0574054
# [216]	valid_0's binary_logloss: 0.057368
# [217]	valid_0's binary_logloss: 0.0573339
# [218]	valid_0's binary_logloss: 0.0572961
# [219]	valid_0's binary_logloss: 0.0572575
# [220]	valid_0's binary_logloss: 0.0572225
# [221]	valid_0's binary_logloss: 0.0571882
# [222]	valid_0's binary_logloss: 0.057154
# [223]	valid_0's binary_logloss: 0.0571199
# [224]	valid_0's binary_logloss: 0.0570883
# [225]	valid_0's binary_logloss: 0.0570554
# [226]	valid_0's binary_logloss: 0.0570226
# [227]	valid_0's binary_logloss: 0.0569918
# [228]	valid_0's binary_logloss: 0.056957
# [229]	valid_0's binary_logloss: 0.0569209
# [230]	valid_0's binary_logloss: 0.0568896
# [231]	valid_0's binary_logloss: 0.0568613
# [232]	valid_0's binary_logloss: 0.0568301
# [233]	valid_0's binary_logloss: 0.0567975
# [234]	valid_0's binary_logloss: 0.0567651
# [235]	valid_0's binary_logloss: 0.0567349
# [236]	valid_0's binary_logloss: 0.0567066
# [237]	valid_0's binary_logloss: 0.0566772
# [238]	valid_0's binary_logloss: 0.0566462
# [239]	valid_0's binary_logloss: 0.0566153
# [240]	valid_0's binary_logloss: 0.0565842
# [241]	valid_0's binary_logloss: 0.0565578
# [242]	valid_0's binary_logloss: 0.0565299
# [243]	valid_0's binary_logloss: 0.0565029
# [244]	valid_0's binary_logloss: 0.0564787
# [245]	valid_0's binary_logloss: 0.0564521
# [246]	valid_0's binary_logloss: 0.0564285
# [247]	valid_0's binary_logloss: 0.0564024
# [248]	valid_0's binary_logloss: 0.0563758
# [249]	valid_0's binary_logloss: 0.0563503
# [250]	valid_0's binary_logloss: 0.056323
# [251]	valid_0's binary_logloss: 0.0562979
# [252]	valid_0's binary_logloss: 0.0562734
# [253]	valid_0's binary_logloss: 0.0562492
# [254]	valid_0's binary_logloss: 0.0562233
# [255]	valid_0's binary_logloss: 0.056198
# [256]	valid_0's binary_logloss: 0.0561726
# [257]	valid_0's binary_logloss: 0.0561472
# [258]	valid_0's binary_logloss: 0.0561222
# [259]	valid_0's binary_logloss: 0.0560971
# [260]	valid_0's binary_logloss: 0.0560753
# [261]	valid_0's binary_logloss: 0.0560516
# [262]	valid_0's binary_logloss: 0.0560282
# [263]	valid_0's binary_logloss: 0.0560068
# [264]	valid_0's binary_logloss: 0.0559904
# [265]	valid_0's binary_logloss: 0.0559675
# [266]	valid_0's binary_logloss: 0.0559448
# [267]	valid_0's binary_logloss: 0.0559232
# [268]	valid_0's binary_logloss: 0.0558998
# [269]	valid_0's binary_logloss: 0.0558763
# [270]	valid_0's binary_logloss: 0.0558554
# [271]	valid_0's binary_logloss: 0.0558323
# [272]	valid_0's binary_logloss: 0.0558113
# [273]	valid_0's binary_logloss: 0.0557902
# [274]	valid_0's binary_logloss: 0.0557697
# [275]	valid_0's binary_logloss: 0.0557492
# [276]	valid_0's binary_logloss: 0.055729
# [277]	valid_0's binary_logloss: 0.0557085
# [278]	valid_0's binary_logloss: 0.0556928
# [279]	valid_0's binary_logloss: 0.0556765
# [280]	valid_0's binary_logloss: 0.055656
# [281]	valid_0's binary_logloss: 0.0556339
# [282]	valid_0's binary_logloss: 0.0556143
# [283]	valid_0's binary_logloss: 0.0555951
# [284]	valid_0's binary_logloss: 0.0555756
# [285]	valid_0's binary_logloss: 0.0555505
# [286]	valid_0's binary_logloss: 0.0555338
# [287]	valid_0's binary_logloss: 0.0555134
# [288]	valid_0's binary_logloss: 0.0554947
# [289]	valid_0's binary_logloss: 0.0554757
# [290]	valid_0's binary_logloss: 0.055459
# [291]	valid_0's binary_logloss: 0.0554428
# [292]	valid_0's binary_logloss: 0.0554257
# [293]	valid_0's binary_logloss: 0.0554048
# [294]	valid_0's binary_logloss: 0.0553916
# [295]	valid_0's binary_logloss: 0.0553744
# [296]	valid_0's binary_logloss: 0.0553603
# [297]	valid_0's binary_logloss: 0.0553463
# [298]	valid_0's binary_logloss: 0.055328
# [299]	valid_0's binary_logloss: 0.0553098
# [300]	valid_0's binary_logloss: 0.0552957
# [301]	valid_0's binary_logloss: 0.0552797
# [302]	valid_0's binary_logloss: 0.0552565
# [303]	valid_0's binary_logloss: 0.0552388
# [304]	valid_0's binary_logloss: 0.0552192
# [305]	valid_0's binary_logloss: 0.0552025
# [306]	valid_0's binary_logloss: 0.0551866
# [307]	valid_0's binary_logloss: 0.0551706
# [308]	valid_0's binary_logloss: 0.0551567
# [309]	valid_0's binary_logloss: 0.0551347
# [310]	valid_0's binary_logloss: 0.0551189
# [311]	valid_0's binary_logloss: 0.0550989
# [312]	valid_0's binary_logloss: 0.0550813
# [313]	valid_0's binary_logloss: 0.0550669
# [314]	valid_0's binary_logloss: 0.0550478
# [315]	valid_0's binary_logloss: 0.0550356
# [316]	valid_0's binary_logloss: 0.0550193
# [317]	valid_0's binary_logloss: 0.0550042
# [318]	valid_0's binary_logloss: 0.0549854
# [319]	valid_0's binary_logloss: 0.0549735
# [320]	valid_0's binary_logloss: 0.0549604
# [321]	valid_0's binary_logloss: 0.054948
# [322]	valid_0's binary_logloss: 0.0549305
# [323]	valid_0's binary_logloss: 0.0549132
# [324]	valid_0's binary_logloss: 0.0549012
# [325]	valid_0's binary_logloss: 0.0548893
# [326]	valid_0's binary_logloss: 0.0548776
# [327]	valid_0's binary_logloss: 0.0548666
# [328]	valid_0's binary_logloss: 0.0548541
# [329]	valid_0's binary_logloss: 0.0548416
# [330]	valid_0's binary_logloss: 0.0548299
# [331]	valid_0's binary_logloss: 0.0548186
# [332]	valid_0's binary_logloss: 0.0548085
# [333]	valid_0's binary_logloss: 0.054797
# [334]	valid_0's binary_logloss: 0.0547873
# [335]	valid_0's binary_logloss: 0.0547745
# [336]	valid_0's binary_logloss: 0.0547621
# [337]	valid_0's binary_logloss: 0.0547503
# [338]	valid_0's binary_logloss: 0.0547353
# [339]	valid_0's binary_logloss: 0.0547247
# [340]	valid_0's binary_logloss: 0.054712
# [341]	valid_0's binary_logloss: 0.0546986
# [342]	valid_0's binary_logloss: 0.0546836
# [343]	valid_0's binary_logloss: 0.0546693
# [344]	valid_0's binary_logloss: 0.0546594
# [345]	valid_0's binary_logloss: 0.0546482
# [346]	valid_0's binary_logloss: 0.0546381
# [347]	valid_0's binary_logloss: 0.0546225
# [348]	valid_0's binary_logloss: 0.054607
# [349]	valid_0's binary_logloss: 0.0545971
# [350]	valid_0's binary_logloss: 0.0545844
# [351]	valid_0's binary_logloss: 0.0545698
# [352]	valid_0's binary_logloss: 0.0545606
# [353]	valid_0's binary_logloss: 0.0545454
# [354]	valid_0's binary_logloss: 0.0545318
# [355]	valid_0's binary_logloss: 0.0545198
# [356]	valid_0's binary_logloss: 0.0545054
# [357]	valid_0's binary_logloss: 0.0544942
# [358]	valid_0's binary_logloss: 0.0544796
# [359]	valid_0's binary_logloss: 0.0544659
# [360]	valid_0's binary_logloss: 0.0544545
# [361]	valid_0's binary_logloss: 0.0544433
# [362]	valid_0's binary_logloss: 0.0544342
# [363]	valid_0's binary_logloss: 0.0544236
# [364]	valid_0's binary_logloss: 0.0544145
# [365]	valid_0's binary_logloss: 0.0544023
# [366]	valid_0's binary_logloss: 0.0543862
# [367]	valid_0's binary_logloss: 0.0543768
# [368]	valid_0's binary_logloss: 0.0543654
# [369]	valid_0's binary_logloss: 0.0543551
# [370]	valid_0's binary_logloss: 0.0543454
# [371]	valid_0's binary_logloss: 0.0543329
# [372]	valid_0's binary_logloss: 0.0543237
# [373]	valid_0's binary_logloss: 0.0543144
# [374]	valid_0's binary_logloss: 0.0543055
# [375]	valid_0's binary_logloss: 0.0542939
# [376]	valid_0's binary_logloss: 0.0542846
# [377]	valid_0's binary_logloss: 0.0542785
# [378]	valid_0's binary_logloss: 0.0542679
# [379]	valid_0's binary_logloss: 0.0542594
# [380]	valid_0's binary_logloss: 0.054247
# [381]	valid_0's binary_logloss: 0.0542394
# [382]	valid_0's binary_logloss: 0.0542261
# [383]	valid_0's binary_logloss: 0.0542169
# [384]	valid_0's binary_logloss: 0.0542079
# [385]	valid_0's binary_logloss: 0.0542005
# [386]	valid_0's binary_logloss: 0.0541904
# [387]	valid_0's binary_logloss: 0.0541802
# [388]	valid_0's binary_logloss: 0.05417
# [389]	valid_0's binary_logloss: 0.0541627
# [390]	valid_0's binary_logloss: 0.0541503
# [391]	valid_0's binary_logloss: 0.0541412
# [392]	valid_0's binary_logloss: 0.0541323
# [393]	valid_0's binary_logloss: 0.054126
# [394]	valid_0's binary_logloss: 0.0541155
# [395]	valid_0's binary_logloss: 0.0541056
# [396]	valid_0's binary_logloss: 0.0540949
# [397]	valid_0's binary_logloss: 0.0540843
# [398]	valid_0's binary_logloss: 0.0540708
# [399]	valid_0's binary_logloss: 0.0540626
# [400]	valid_0's binary_logloss: 0.0540574
# [401]	valid_0's binary_logloss: 0.0540463
# [402]	valid_0's binary_logloss: 0.054039
# [403]	valid_0's binary_logloss: 0.0540288
# [404]	valid_0's binary_logloss: 0.0540243
# [405]	valid_0's binary_logloss: 0.0540151
# [406]	valid_0's binary_logloss: 0.0540054
# [407]	valid_0's binary_logloss: 0.0539929
# [408]	valid_0's binary_logloss: 0.0539871
# [409]	valid_0's binary_logloss: 0.0539769
# [410]	valid_0's binary_logloss: 0.0539712
# [411]	valid_0's binary_logloss: 0.0539618
# [412]	valid_0's binary_logloss: 0.0539553
# [413]	valid_0's binary_logloss: 0.0539483
# [414]	valid_0's binary_logloss: 0.0539413
# [415]	valid_0's binary_logloss: 0.0539312
# [416]	valid_0's binary_logloss: 0.0539229
# [417]	valid_0's binary_logloss: 0.0539145
# [418]	valid_0's binary_logloss: 0.0539029
# [419]	valid_0's binary_logloss: 0.0538938
# [420]	valid_0's binary_logloss: 0.0538837
# [421]	valid_0's binary_logloss: 0.0538791
# [422]	valid_0's binary_logloss: 0.0538725
# [423]	valid_0's binary_logloss: 0.0538638
# [424]	valid_0's binary_logloss: 0.053858
# [425]	valid_0's binary_logloss: 0.0538489
# [426]	valid_0's binary_logloss: 0.0538417
# [427]	valid_0's binary_logloss: 0.0538343
# [428]	valid_0's binary_logloss: 0.0538309
# [429]	valid_0's binary_logloss: 0.0538257
# [430]	valid_0's binary_logloss: 0.053816
# [431]	valid_0's binary_logloss: 0.0538086
# [432]	valid_0's binary_logloss: 0.0538028
# [433]	valid_0's binary_logloss: 0.0537939
# [434]	valid_0's binary_logloss: 0.0537837
# [435]	valid_0's binary_logloss: 0.0537786
# [436]	valid_0's binary_logloss: 0.053774
# [437]	valid_0's binary_logloss: 0.053766
# [438]	valid_0's binary_logloss: 0.0537556
# [439]	valid_0's binary_logloss: 0.0537508
# [440]	valid_0's binary_logloss: 0.0537446
# [441]	valid_0's binary_logloss: 0.0537385
# [442]	valid_0's binary_logloss: 0.0537291
# [443]	valid_0's binary_logloss: 0.0537239
# [444]	valid_0's binary_logloss: 0.0537176
# [445]	valid_0's binary_logloss: 0.0537123
# [446]	valid_0's binary_logloss: 0.0537055
# [447]	valid_0's binary_logloss: 0.0536993
# [448]	valid_0's binary_logloss: 0.0536958
# [449]	valid_0's binary_logloss: 0.0536893
# [450]	valid_0's binary_logloss: 0.0536799
# [451]	valid_0's binary_logloss: 0.0536731
# [452]	valid_0's binary_logloss: 0.0536684
# [453]	valid_0's binary_logloss: 0.0536638
# [454]	valid_0's binary_logloss: 0.0536567
# [455]	valid_0's binary_logloss: 0.0536466
# [456]	valid_0's binary_logloss: 0.0536395
# [457]	valid_0's binary_logloss: 0.0536345
# [458]	valid_0's binary_logloss: 0.0536291
# [459]	valid_0's binary_logloss: 0.0536219
# [460]	valid_0's binary_logloss: 0.0536106
# [461]	valid_0's binary_logloss: 0.0536004
# [462]	valid_0's binary_logloss: 0.0535969
# [463]	valid_0's binary_logloss: 0.0535901
# [464]	valid_0's binary_logloss: 0.053579
# [465]	valid_0's binary_logloss: 0.0535713
# [466]	valid_0's binary_logloss: 0.0535682
# [467]	valid_0's binary_logloss: 0.0535631
# [468]	valid_0's binary_logloss: 0.0535549
# [469]	valid_0's binary_logloss: 0.0535504
# [470]	valid_0's binary_logloss: 0.0535436
# [471]	valid_0's binary_logloss: 0.0535375
# [472]	valid_0's binary_logloss: 0.0535333
# [473]	valid_0's binary_logloss: 0.0535281
# [474]	valid_0's binary_logloss: 0.0535225
# [475]	valid_0's binary_logloss: 0.0535186
# [476]	valid_0's binary_logloss: 0.0535125
# [477]	valid_0's binary_logloss: 0.0535052
# [478]	valid_0's binary_logloss: 0.0535018
# [479]	valid_0's binary_logloss: 0.0534965
# [480]	valid_0's binary_logloss: 0.0534913
# [481]	valid_0's binary_logloss: 0.0534836
# [482]	valid_0's binary_logloss: 0.0534789
# [483]	valid_0's binary_logloss: 0.0534722
# [484]	valid_0's binary_logloss: 0.053465
# [485]	valid_0's binary_logloss: 0.0534629
# [486]	valid_0's binary_logloss: 0.0534545
# [487]	valid_0's binary_logloss: 0.0534486
# [488]	valid_0's binary_logloss: 0.053445
# [489]	valid_0's binary_logloss: 0.0534376
# [490]	valid_0's binary_logloss: 0.0534275
# [491]	valid_0's binary_logloss: 0.0534236
# [492]	valid_0's binary_logloss: 0.0534193
# [493]	valid_0's binary_logloss: 0.0534098
# [494]	valid_0's binary_logloss: 0.0534052
# [495]	valid_0's binary_logloss: 0.0533967
# [496]	valid_0's binary_logloss: 0.0533894
# [497]	valid_0's binary_logloss: 0.0533853
# [498]	valid_0's binary_logloss: 0.0533825
# [499]	valid_0's binary_logloss: 0.0533747
# [500]	valid_0's binary_logloss: 0.0533674
# [501]	valid_0's binary_logloss: 0.0533599
# [502]	valid_0's binary_logloss: 0.0533568
# [503]	valid_0's binary_logloss: 0.0533497
# [504]	valid_0's binary_logloss: 0.053342
# [505]	valid_0's binary_logloss: 0.0533371
# [506]	valid_0's binary_logloss: 0.0533305
# [507]	valid_0's binary_logloss: 0.0533261
# [508]	valid_0's binary_logloss: 0.0533235
# [509]	valid_0's binary_logloss: 0.0533196
# [510]	valid_0's binary_logloss: 0.0533151
# [511]	valid_0's binary_logloss: 0.0533104
# [512]	valid_0's binary_logloss: 0.0533029
# [513]	valid_0's binary_logloss: 0.0532973
# [514]	valid_0's binary_logloss: 0.0532884
# [515]	valid_0's binary_logloss: 0.0532846
# [516]	valid_0's binary_logloss: 0.0532805
# [517]	valid_0's binary_logloss: 0.0532736
# [518]	valid_0's binary_logloss: 0.0532707
# [519]	valid_0's binary_logloss: 0.0532645
# [520]	valid_0's binary_logloss: 0.053263
# [521]	valid_0's binary_logloss: 0.0532585
# [522]	valid_0's binary_logloss: 0.0532504
# [523]	valid_0's binary_logloss: 0.0532441
# [524]	valid_0's binary_logloss: 0.053239
# [525]	valid_0's binary_logloss: 0.0532358
# [526]	valid_0's binary_logloss: 0.0532306
# [527]	valid_0's binary_logloss: 0.0532245
# [528]	valid_0's binary_logloss: 0.0532195
# [529]	valid_0's binary_logloss: 0.0532138
# [530]	valid_0's binary_logloss: 0.0532068
# [531]	valid_0's binary_logloss: 0.0532048
# [532]	valid_0's binary_logloss: 0.0532
# [533]	valid_0's binary_logloss: 0.0531944
# [534]	valid_0's binary_logloss: 0.05319
# [535]	valid_0's binary_logloss: 0.0531854
# [536]	valid_0's binary_logloss: 0.053182
# [537]	valid_0's binary_logloss: 0.0531783
# [538]	valid_0's binary_logloss: 0.0531731
# [539]	valid_0's binary_logloss: 0.0531701
# [540]	valid_0's binary_logloss: 0.0531663
# [541]	valid_0's binary_logloss: 0.0531607
# [542]	valid_0's binary_logloss: 0.0531573
# [543]	valid_0's binary_logloss: 0.0531518
# [544]	valid_0's binary_logloss: 0.0531502
# [545]	valid_0's binary_logloss: 0.0531463
# [546]	valid_0's binary_logloss: 0.0531414
# [547]	valid_0's binary_logloss: 0.0531362
# [548]	valid_0's binary_logloss: 0.0531335
# [549]	valid_0's binary_logloss: 0.0531297
# [550]	valid_0's binary_logloss: 0.0531249
# [551]	valid_0's binary_logloss: 0.0531211
# [552]	valid_0's binary_logloss: 0.0531179
# [553]	valid_0's binary_logloss: 0.0531137
# [554]	valid_0's binary_logloss: 0.0531106
# [555]	valid_0's binary_logloss: 0.0531075
# [556]	valid_0's binary_logloss: 0.0531032
# [557]	valid_0's binary_logloss: 0.0531006
# [558]	valid_0's binary_logloss: 0.0530962
# [559]	valid_0's binary_logloss: 0.0530911
# [560]	valid_0's binary_logloss: 0.0530845
# [561]	valid_0's binary_logloss: 0.0530768
# [562]	valid_0's binary_logloss: 0.0530715
# [563]	valid_0's binary_logloss: 0.0530654
# [564]	valid_0's binary_logloss: 0.0530624
# [565]	valid_0's binary_logloss: 0.0530594
# [566]	valid_0's binary_logloss: 0.0530541
# [567]	valid_0's binary_logloss: 0.0530508
# [568]	valid_0's binary_logloss: 0.0530461
# [569]	valid_0's binary_logloss: 0.0530425
# [570]	valid_0's binary_logloss: 0.0530402
# [571]	valid_0's binary_logloss: 0.0530373
# [572]	valid_0's binary_logloss: 0.0530332
# [573]	valid_0's binary_logloss: 0.0530267
# [574]	valid_0's binary_logloss: 0.0530258
# [575]	valid_0's binary_logloss: 0.0530208
# [576]	valid_0's binary_logloss: 0.0530146
# [577]	valid_0's binary_logloss: 0.0530094
# [578]	valid_0's binary_logloss: 0.0530067
# [579]	valid_0's binary_logloss: 0.0530045
# [580]	valid_0's binary_logloss: 0.0529996
# [581]	valid_0's binary_logloss: 0.0529977
# [582]	valid_0's binary_logloss: 0.052995
# [583]	valid_0's binary_logloss: 0.0529907
# [584]	valid_0's binary_logloss: 0.0529876
# [585]	valid_0's binary_logloss: 0.0529859
# [586]	valid_0's binary_logloss: 0.0529845
# [587]	valid_0's binary_logloss: 0.052979
# [588]	valid_0's binary_logloss: 0.0529735
# [589]	valid_0's binary_logloss: 0.0529704
# [590]	valid_0's binary_logloss: 0.0529677
# [591]	valid_0's binary_logloss: 0.0529639
# [592]	valid_0's binary_logloss: 0.0529607
# [593]	valid_0's binary_logloss: 0.0529573
# [594]	valid_0's binary_logloss: 0.0529563
# [595]	valid_0's binary_logloss: 0.0529554
# [596]	valid_0's binary_logloss: 0.0529475
# [597]	valid_0's binary_logloss: 0.0529452
# [598]	valid_0's binary_logloss: 0.0529433
# [599]	valid_0's binary_logloss: 0.0529411
# [600]	valid_0's binary_logloss: 0.0529409
# [601]	valid_0's binary_logloss: 0.0529377
# [602]	valid_0's binary_logloss: 0.0529348
# [603]	valid_0's binary_logloss: 0.0529316
# [604]	valid_0's binary_logloss: 0.0529289
# [605]	valid_0's binary_logloss: 0.0529257
# [606]	valid_0's binary_logloss: 0.0529231
# [607]	valid_0's binary_logloss: 0.0529182
# [608]	valid_0's binary_logloss: 0.0529167
# [609]	valid_0's binary_logloss: 0.0529143
# [610]	valid_0's binary_logloss: 0.0529105
# [611]	valid_0's binary_logloss: 0.0529075
# [612]	valid_0's binary_logloss: 0.0529012
# [613]	valid_0's binary_logloss: 0.0528989
# [614]	valid_0's binary_logloss: 0.0528926
# [615]	valid_0's binary_logloss: 0.0528869
# [616]	valid_0's binary_logloss: 0.0528829
# [617]	valid_0's binary_logloss: 0.0528786
# [618]	valid_0's binary_logloss: 0.0528755
# [619]	valid_0's binary_logloss: 0.0528747
# [620]	valid_0's binary_logloss: 0.0528719
# [621]	valid_0's binary_logloss: 0.0528657
# [622]	valid_0's binary_logloss: 0.0528625
# [623]	valid_0's binary_logloss: 0.0528617
# [624]	valid_0's binary_logloss: 0.0528612
# [625]	valid_0's binary_logloss: 0.0528543
# [626]	valid_0's binary_logloss: 0.0528501
# [627]	valid_0's binary_logloss: 0.0528485
# [628]	valid_0's binary_logloss: 0.052846
# [629]	valid_0's binary_logloss: 0.0528429
# [630]	valid_0's binary_logloss: 0.0528399
# [631]	valid_0's binary_logloss: 0.0528381
# [632]	valid_0's binary_logloss: 0.0528341
# [633]	valid_0's binary_logloss: 0.052831
# [634]	valid_0's binary_logloss: 0.05283
# [635]	valid_0's binary_logloss: 0.052827
# [636]	valid_0's binary_logloss: 0.0528262
# [637]	valid_0's binary_logloss: 0.0528229
# [638]	valid_0's binary_logloss: 0.0528221
# [639]	valid_0's binary_logloss: 0.0528191
# [640]	valid_0's binary_logloss: 0.0528164
# [641]	valid_0's binary_logloss: 0.0528134
# [642]	valid_0's binary_logloss: 0.0528136
# [643]	valid_0's binary_logloss: 0.0528131
# [644]	valid_0's binary_logloss: 0.0528088
# [645]	valid_0's binary_logloss: 0.0528065
# [646]	valid_0's binary_logloss: 0.0528032
# [647]	valid_0's binary_logloss: 0.0528023
# [648]	valid_0's binary_logloss: 0.0527985
# [649]	valid_0's binary_logloss: 0.0527962
# [650]	valid_0's binary_logloss: 0.0527905
# [651]	valid_0's binary_logloss: 0.0527903
# [652]	valid_0's binary_logloss: 0.0527877
# [653]	valid_0's binary_logloss: 0.0527835
# [654]	valid_0's binary_logloss: 0.05278
# [655]	valid_0's binary_logloss: 0.0527774
# [656]	valid_0's binary_logloss: 0.0527762
# [657]	valid_0's binary_logloss: 0.0527749
# [658]	valid_0's binary_logloss: 0.0527734
# [659]	valid_0's binary_logloss: 0.0527707
# [660]	valid_0's binary_logloss: 0.0527671
# [661]	valid_0's binary_logloss: 0.0527632
# [662]	valid_0's binary_logloss: 0.0527619
# [663]	valid_0's binary_logloss: 0.0527609
# [664]	valid_0's binary_logloss: 0.05276
# [665]	valid_0's binary_logloss: 0.0527563
# [666]	valid_0's binary_logloss: 0.0527523
# [667]	valid_0's binary_logloss: 0.0527485
# [668]	valid_0's binary_logloss: 0.0527476
# [669]	valid_0's binary_logloss: 0.0527458
# [670]	valid_0's binary_logloss: 0.0527437
# [671]	valid_0's binary_logloss: 0.0527403
# [672]	valid_0's binary_logloss: 0.0527371
# [673]	valid_0's binary_logloss: 0.0527355
# [674]	valid_0's binary_logloss: 0.0527325
# [675]	valid_0's binary_logloss: 0.0527291
# [676]	valid_0's binary_logloss: 0.0527284
# [677]	valid_0's binary_logloss: 0.0527272
# [678]	valid_0's binary_logloss: 0.0527247
# [679]	valid_0's binary_logloss: 0.0527218
# [680]	valid_0's binary_logloss: 0.0527214
# [681]	valid_0's binary_logloss: 0.0527174
# [682]	valid_0's binary_logloss: 0.0527154
# [683]	valid_0's binary_logloss: 0.0527154
# [684]	valid_0's binary_logloss: 0.052714
# [685]	valid_0's binary_logloss: 0.0527102
# [686]	valid_0's binary_logloss: 0.0527092
# [687]	valid_0's binary_logloss: 0.052708
# [688]	valid_0's binary_logloss: 0.0527037
# [689]	valid_0's binary_logloss: 0.0527014
# [690]	valid_0's binary_logloss: 0.0527003
# [691]	valid_0's binary_logloss: 0.0526962
# [692]	valid_0's binary_logloss: 0.0526939
# [693]	valid_0's binary_logloss: 0.0526921
# [694]	valid_0's binary_logloss: 0.0526875
# [695]	valid_0's binary_logloss: 0.0526857
# [696]	valid_0's binary_logloss: 0.0526841
# [697]	valid_0's binary_logloss: 0.0526832
# [698]	valid_0's binary_logloss: 0.0526812
# [699]	valid_0's binary_logloss: 0.0526781
# [700]	valid_0's binary_logloss: 0.0526743
# [701]	valid_0's binary_logloss: 0.0526698
# [702]	valid_0's binary_logloss: 0.0526677
# [703]	valid_0's binary_logloss: 0.0526658
# [704]	valid_0's binary_logloss: 0.0526632
# [705]	valid_0's binary_logloss: 0.0526609
# [706]	valid_0's binary_logloss: 0.0526577
# [707]	valid_0's binary_logloss: 0.0526548
# [708]	valid_0's binary_logloss: 0.0526518
# [709]	valid_0's binary_logloss: 0.0526492
# [710]	valid_0's binary_logloss: 0.0526456
# [711]	valid_0's binary_logloss: 0.0526436
# [712]	valid_0's binary_logloss: 0.0526387
# [713]	valid_0's binary_logloss: 0.0526356
# [714]	valid_0's binary_logloss: 0.0526323
# [715]	valid_0's binary_logloss: 0.0526311
# [716]	valid_0's binary_logloss: 0.0526289
# [717]	valid_0's binary_logloss: 0.0526266
# [718]	valid_0's binary_logloss: 0.0526263
# [719]	valid_0's binary_logloss: 0.0526242
# [720]	valid_0's binary_logloss: 0.0526213
# [721]	valid_0's binary_logloss: 0.0526209
# [722]	valid_0's binary_logloss: 0.0526182
# [723]	valid_0's binary_logloss: 0.0526166
# [724]	valid_0's binary_logloss: 0.0526142
# [725]	valid_0's binary_logloss: 0.0526119
# [726]	valid_0's binary_logloss: 0.0526087
# [727]	valid_0's binary_logloss: 0.0526036
# [728]	valid_0's binary_logloss: 0.0526007
# [729]	valid_0's binary_logloss: 0.0525994
# [730]	valid_0's binary_logloss: 0.0525951
# [731]	valid_0's binary_logloss: 0.052594
# [732]	valid_0's binary_logloss: 0.0525928
# [733]	valid_0's binary_logloss: 0.0525904
# [734]	valid_0's binary_logloss: 0.0525878
# [735]	valid_0's binary_logloss: 0.0525849
# [736]	valid_0's binary_logloss: 0.0525817
# [737]	valid_0's binary_logloss: 0.052582
# [738]	valid_0's binary_logloss: 0.0525806
# [739]	valid_0's binary_logloss: 0.0525787
# [740]	valid_0's binary_logloss: 0.0525776
# [741]	valid_0's binary_logloss: 0.0525756
# [742]	valid_0's binary_logloss: 0.0525756
# [743]	valid_0's binary_logloss: 0.0525753
# [744]	valid_0's binary_logloss: 0.0525738
# [745]	valid_0's binary_logloss: 0.0525725
# [746]	valid_0's binary_logloss: 0.0525706
# [747]	valid_0's binary_logloss: 0.0525694
# [748]	valid_0's binary_logloss: 0.0525663
# [749]	valid_0's binary_logloss: 0.0525657
# [750]	valid_0's binary_logloss: 0.0525636
# [751]	valid_0's binary_logloss: 0.0525636
# [752]	valid_0's binary_logloss: 0.0525606
# [753]	valid_0's binary_logloss: 0.0525606
# [754]	valid_0's binary_logloss: 0.0525573
# [755]	valid_0's binary_logloss: 0.052553
# [756]	valid_0's binary_logloss: 0.0525517
# [757]	valid_0's binary_logloss: 0.0525499
# [758]	valid_0's binary_logloss: 0.0525478
# [759]	valid_0's binary_logloss: 0.0525467
# [760]	valid_0's binary_logloss: 0.0525441
# [761]	valid_0's binary_logloss: 0.0525416
# [762]	valid_0's binary_logloss: 0.0525397
# [763]	valid_0's binary_logloss: 0.0525371
# [764]	valid_0's binary_logloss: 0.0525364
# [765]	valid_0's binary_logloss: 0.0525348
# [766]	valid_0's binary_logloss: 0.0525347
# [767]	valid_0's binary_logloss: 0.0525332
# [768]	valid_0's binary_logloss: 0.0525304
# [769]	valid_0's binary_logloss: 0.0525276
# [770]	valid_0's binary_logloss: 0.0525249
# [771]	valid_0's binary_logloss: 0.0525214
# [772]	valid_0's binary_logloss: 0.052522
# [773]	valid_0's binary_logloss: 0.0525189
# [774]	valid_0's binary_logloss: 0.052518
# [775]	valid_0's binary_logloss: 0.0525175
# [776]	valid_0's binary_logloss: 0.0525158
# [777]	valid_0's binary_logloss: 0.0525135
# [778]	valid_0's binary_logloss: 0.0525119
# [779]	valid_0's binary_logloss: 0.0525113
# [780]	valid_0's binary_logloss: 0.0525091
# [781]	valid_0's binary_logloss: 0.052506
# [782]	valid_0's binary_logloss: 0.0525044
# [783]	valid_0's binary_logloss: 0.0525024
# [784]	valid_0's binary_logloss: 0.0525032
# [785]	valid_0's binary_logloss: 0.0524995
# [786]	valid_0's binary_logloss: 0.0524975
# [787]	valid_0's binary_logloss: 0.0524956
# [788]	valid_0's binary_logloss: 0.052495
# [789]	valid_0's binary_logloss: 0.0524926
# [790]	valid_0's binary_logloss: 0.0524906
# [791]	valid_0's binary_logloss: 0.0524916
# [792]	valid_0's binary_logloss: 0.0524889
# [793]	valid_0's binary_logloss: 0.0524872
# [794]	valid_0's binary_logloss: 0.0524836
# [795]	valid_0's binary_logloss: 0.0524792
# [796]	valid_0's binary_logloss: 0.0524766
# [797]	valid_0's binary_logloss: 0.052473
# [798]	valid_0's binary_logloss: 0.0524698
# [799]	valid_0's binary_logloss: 0.0524678
# [800]	valid_0's binary_logloss: 0.0524644
# [801]	valid_0's binary_logloss: 0.0524631
# [802]	valid_0's binary_logloss: 0.0524615
# [803]	valid_0's binary_logloss: 0.0524616
# [804]	valid_0's binary_logloss: 0.0524603
# [805]	valid_0's binary_logloss: 0.0524576
# [806]	valid_0's binary_logloss: 0.052455
# [807]	valid_0's binary_logloss: 0.0524532
# [808]	valid_0's binary_logloss: 0.0524494
# [809]	valid_0's binary_logloss: 0.0524482
# [810]	valid_0's binary_logloss: 0.0524464
# [811]	valid_0's binary_logloss: 0.0524448
# [812]	valid_0's binary_logloss: 0.0524442
# [813]	valid_0's binary_logloss: 0.0524426
# [814]	valid_0's binary_logloss: 0.0524404
# [815]	valid_0's binary_logloss: 0.0524374
# [816]	valid_0's binary_logloss: 0.0524364
# [817]	valid_0's binary_logloss: 0.0524348
# [818]	valid_0's binary_logloss: 0.0524337
# [819]	valid_0's binary_logloss: 0.0524312
# [820]	valid_0's binary_logloss: 0.0524293
# [821]	valid_0's binary_logloss: 0.0524283
# [822]	valid_0's binary_logloss: 0.0524274
# [823]	valid_0's binary_logloss: 0.0524251
# [824]	valid_0's binary_logloss: 0.0524215
# [825]	valid_0's binary_logloss: 0.0524184
# [826]	valid_0's binary_logloss: 0.0524178
# [827]	valid_0's binary_logloss: 0.0524162
# [828]	valid_0's binary_logloss: 0.0524144
# [829]	valid_0's binary_logloss: 0.052413
# [830]	valid_0's binary_logloss: 0.052411
# [831]	valid_0's binary_logloss: 0.0524097
# [832]	valid_0's binary_logloss: 0.0524075
# [833]	valid_0's binary_logloss: 0.052406
# [834]	valid_0's binary_logloss: 0.0524051
# [835]	valid_0's binary_logloss: 0.052405
# [836]	valid_0's binary_logloss: 0.0524007
# [837]	valid_0's binary_logloss: 0.0524009
# [838]	valid_0's binary_logloss: 0.0523984
# [839]	valid_0's binary_logloss: 0.0523987
# [840]	valid_0's binary_logloss: 0.0523986
# [841]	valid_0's binary_logloss: 0.0523965
# [842]	valid_0's binary_logloss: 0.0523944
# [843]	valid_0's binary_logloss: 0.0523949
# [844]	valid_0's binary_logloss: 0.052394
# [845]	valid_0's binary_logloss: 0.0523917
# [846]	valid_0's binary_logloss: 0.0523894
# [847]	valid_0's binary_logloss: 0.0523865
# [848]	valid_0's binary_logloss: 0.0523841
# [849]	valid_0's binary_logloss: 0.0523841
# [850]	valid_0's binary_logloss: 0.0523841
# [851]	valid_0's binary_logloss: 0.0523818
# [852]	valid_0's binary_logloss: 0.0523812
# [853]	valid_0's binary_logloss: 0.0523805
# [854]	valid_0's binary_logloss: 0.0523775
# [855]	valid_0's binary_logloss: 0.0523768
# [856]	valid_0's binary_logloss: 0.0523757
# [857]	valid_0's binary_logloss: 0.0523723
# [858]	valid_0's binary_logloss: 0.0523698
# [859]	valid_0's binary_logloss: 0.0523672
# [860]	valid_0's binary_logloss: 0.0523673
# [861]	valid_0's binary_logloss: 0.0523649
# [862]	valid_0's binary_logloss: 0.0523635
# [863]	valid_0's binary_logloss: 0.0523622
# [864]	valid_0's binary_logloss: 0.0523613
# [865]	valid_0's binary_logloss: 0.0523608
# [866]	valid_0's binary_logloss: 0.0523581
# [867]	valid_0's binary_logloss: 0.0523573
# [868]	valid_0's binary_logloss: 0.0523548
# [869]	valid_0's binary_logloss: 0.0523511
# [870]	valid_0's binary_logloss: 0.0523511
# [871]	valid_0's binary_logloss: 0.0523505
# [872]	valid_0's binary_logloss: 0.0523507
# [873]	valid_0's binary_logloss: 0.0523498
# [874]	valid_0's binary_logloss: 0.0523485
# [875]	valid_0's binary_logloss: 0.0523476
# [876]	valid_0's binary_logloss: 0.0523451
# [877]	valid_0's binary_logloss: 0.0523429
# [878]	valid_0's binary_logloss: 0.0523416
# [879]	valid_0's binary_logloss: 0.0523415
# [880]	valid_0's binary_logloss: 0.0523402
# [881]	valid_0's binary_logloss: 0.0523393
# [882]	valid_0's binary_logloss: 0.0523394
# [883]	valid_0's binary_logloss: 0.0523379
# [884]	valid_0's binary_logloss: 0.052336
# [885]	valid_0's binary_logloss: 0.0523357
# [886]	valid_0's binary_logloss: 0.0523352
# [887]	valid_0's binary_logloss: 0.052332
# [888]	valid_0's binary_logloss: 0.0523319
# [889]	valid_0's binary_logloss: 0.0523309
# [890]	valid_0's binary_logloss: 0.0523292
# [891]	valid_0's binary_logloss: 0.0523287
# [892]	valid_0's binary_logloss: 0.0523279
# [893]	valid_0's binary_logloss: 0.0523267
# [894]	valid_0's binary_logloss: 0.0523248
# [895]	valid_0's binary_logloss: 0.0523248
# [896]	valid_0's binary_logloss: 0.0523246
# [897]	valid_0's binary_logloss: 0.0523235
# [898]	valid_0's binary_logloss: 0.0523214
# [899]	valid_0's binary_logloss: 0.052321
# [900]	valid_0's binary_logloss: 0.0523215
# [901]	valid_0's binary_logloss: 0.0523182
# [902]	valid_0's binary_logloss: 0.0523182
# [903]	valid_0's binary_logloss: 0.0523175
# [904]	valid_0's binary_logloss: 0.0523174
# [905]	valid_0's binary_logloss: 0.0523168
# [906]	valid_0's binary_logloss: 0.0523154
# [907]	valid_0's binary_logloss: 0.0523136
# [908]	valid_0's binary_logloss: 0.05231
# [909]	valid_0's binary_logloss: 0.0523093
# [910]	valid_0's binary_logloss: 0.0523076
# [911]	valid_0's binary_logloss: 0.0523066
# [912]	valid_0's binary_logloss: 0.0523037
# [913]	valid_0's binary_logloss: 0.0523019
# [914]	valid_0's binary_logloss: 0.0523006
# [915]	valid_0's binary_logloss: 0.0523
# [916]	valid_0's binary_logloss: 0.0522994
# [917]	valid_0's binary_logloss: 0.0522952
# [918]	valid_0's binary_logloss: 0.0522935
# [919]	valid_0's binary_logloss: 0.0522939
# [920]	valid_0's binary_logloss: 0.0522913
# [921]	valid_0's binary_logloss: 0.052291
# [922]	valid_0's binary_logloss: 0.0522889
# [923]	valid_0's binary_logloss: 0.0522866
# [924]	valid_0's binary_logloss: 0.052287
# [925]	valid_0's binary_logloss: 0.0522866
# [926]	valid_0's binary_logloss: 0.0522868
# [927]	valid_0's binary_logloss: 0.0522855
# [928]	valid_0's binary_logloss: 0.0522824
# [929]	valid_0's binary_logloss: 0.0522809
# [930]	valid_0's binary_logloss: 0.0522819
# [931]	valid_0's binary_logloss: 0.0522794
# [932]	valid_0's binary_logloss: 0.0522789
# [933]	valid_0's binary_logloss: 0.0522774
# [934]	valid_0's binary_logloss: 0.0522758
# [935]	valid_0's binary_logloss: 0.0522747
# [936]	valid_0's binary_logloss: 0.0522723
# [937]	valid_0's binary_logloss: 0.0522711
# [938]	valid_0's binary_logloss: 0.0522715
# [939]	valid_0's binary_logloss: 0.0522706
# [940]	valid_0's binary_logloss: 0.0522698
# [941]	valid_0's binary_logloss: 0.0522703
# [942]	valid_0's binary_logloss: 0.0522703
# [943]	valid_0's binary_logloss: 0.0522698
# [944]	valid_0's binary_logloss: 0.0522691
# [945]	valid_0's binary_logloss: 0.0522684
# [946]	valid_0's binary_logloss: 0.0522674
# [947]	valid_0's binary_logloss: 0.0522658
# [948]	valid_0's binary_logloss: 0.0522655
# [949]	valid_0's binary_logloss: 0.0522638
# [950]	valid_0's binary_logloss: 0.0522636
# [951]	valid_0's binary_logloss: 0.0522621
# [952]	valid_0's binary_logloss: 0.0522597
# [953]	valid_0's binary_logloss: 0.0522586
# [954]	valid_0's binary_logloss: 0.0522576
# [955]	valid_0's binary_logloss: 0.0522585
# [956]	valid_0's binary_logloss: 0.0522577
# [957]	valid_0's binary_logloss: 0.0522584
# [958]	valid_0's binary_logloss: 0.0522564
# [959]	valid_0's binary_logloss: 0.0522562
# [960]	valid_0's binary_logloss: 0.0522554
# [961]	valid_0's binary_logloss: 0.0522555
# [962]	valid_0's binary_logloss: 0.0522549
# [963]	valid_0's binary_logloss: 0.0522537
# [964]	valid_0's binary_logloss: 0.0522525
# [965]	valid_0's binary_logloss: 0.0522521
# [966]	valid_0's binary_logloss: 0.0522514
# [967]	valid_0's binary_logloss: 0.0522486
# [968]	valid_0's binary_logloss: 0.0522467
# [969]	valid_0's binary_logloss: 0.0522456
# [970]	valid_0's binary_logloss: 0.0522446
# [971]	valid_0's binary_logloss: 0.0522436
# [972]	valid_0's binary_logloss: 0.0522428
# [973]	valid_0's binary_logloss: 0.0522428
# [974]	valid_0's binary_logloss: 0.0522437
# [975]	valid_0's binary_logloss: 0.0522429
# [976]	valid_0's binary_logloss: 0.052242
# [977]	valid_0's binary_logloss: 0.0522406
# [978]	valid_0's binary_logloss: 0.0522388
# [979]	valid_0's binary_logloss: 0.0522385
# [980]	valid_0's binary_logloss: 0.0522366
# [981]	valid_0's binary_logloss: 0.0522366
# [982]	valid_0's binary_logloss: 0.0522358
# [983]	valid_0's binary_logloss: 0.0522339
# [984]	valid_0's binary_logloss: 0.0522326
# [985]	valid_0's binary_logloss: 0.0522328
# [986]	valid_0's binary_logloss: 0.0522327
# [987]	valid_0's binary_logloss: 0.0522311
# [988]	valid_0's binary_logloss: 0.0522299
# [989]	valid_0's binary_logloss: 0.0522294
# [990]	valid_0's binary_logloss: 0.0522294
# [991]	valid_0's binary_logloss: 0.0522297
# [992]	valid_0's binary_logloss: 0.0522289
# [993]	valid_0's binary_logloss: 0.0522275
# [994]	valid_0's binary_logloss: 0.052227
# [995]	valid_0's binary_logloss: 0.0522271
# [996]	valid_0's binary_logloss: 0.0522278
# [997]	valid_0's binary_logloss: 0.0522271
# [998]	valid_0's binary_logloss: 0.0522282
# [999]	valid_0's binary_logloss: 0.0522272
# [1000]	valid_0's binary_logloss: 0.0522249
# [1001]	valid_0's binary_logloss: 0.0522228
# [1002]	valid_0's binary_logloss: 0.0522213
# [1003]	valid_0's binary_logloss: 0.0522197
# [1004]	valid_0's binary_logloss: 0.0522198
# [1005]	valid_0's binary_logloss: 0.0522182
# [1006]	valid_0's binary_logloss: 0.052218
# [1007]	valid_0's binary_logloss: 0.0522151
# [1008]	valid_0's binary_logloss: 0.0522132
# [1009]	valid_0's binary_logloss: 0.0522132
# [1010]	valid_0's binary_logloss: 0.0522136
# [1011]	valid_0's binary_logloss: 0.0522132
# [1012]	valid_0's binary_logloss: 0.0522133
# [1013]	valid_0's binary_logloss: 0.0522128
# [1014]	valid_0's binary_logloss: 0.0522109
# [1015]	valid_0's binary_logloss: 0.0522083
# [1016]	valid_0's binary_logloss: 0.0522094
# [1017]	valid_0's binary_logloss: 0.0522096
# [1018]	valid_0's binary_logloss: 0.0522094
# [1019]	valid_0's binary_logloss: 0.0522077
# [1020]	valid_0's binary_logloss: 0.0522077
# [1021]	valid_0's binary_logloss: 0.0522054
# [1022]	valid_0's binary_logloss: 0.0522055
# [1023]	valid_0's binary_logloss: 0.0522031
# [1024]	valid_0's binary_logloss: 0.0522035
# [1025]	valid_0's binary_logloss: 0.0522028
# [1026]	valid_0's binary_logloss: 0.0522005
# [1027]	valid_0's binary_logloss: 0.0521994
# [1028]	valid_0's binary_logloss: 0.0521997
# [1029]	valid_0's binary_logloss: 0.0521998
# [1030]	valid_0's binary_logloss: 0.0521977
# [1031]	valid_0's binary_logloss: 0.0521973
# [1032]	valid_0's binary_logloss: 0.052196
# [1033]	valid_0's binary_logloss: 0.0521957
# [1034]	valid_0's binary_logloss: 0.0521956
# [1035]	valid_0's binary_logloss: 0.0521951
# [1036]	valid_0's binary_logloss: 0.0521952
# [1037]	valid_0's binary_logloss: 0.0521938
# [1038]	valid_0's binary_logloss: 0.0521928
# [1039]	valid_0's binary_logloss: 0.0521916
# [1040]	valid_0's binary_logloss: 0.0521908
# [1041]	valid_0's binary_logloss: 0.0521914
# [1042]	valid_0's binary_logloss: 0.052193
# [1043]	valid_0's binary_logloss: 0.0521938
# [1044]	valid_0's binary_logloss: 0.0521929
# [1045]	valid_0's binary_logloss: 0.0521937
# [1046]	valid_0's binary_logloss: 0.052194
# [1047]	valid_0's binary_logloss: 0.0521926
# [1048]	valid_0's binary_logloss: 0.0521923
# [1049]	valid_0's binary_logloss: 0.0521919
# [1050]	valid_0's binary_logloss: 0.0521917
# [1051]	valid_0's binary_logloss: 0.052191
# [1052]	valid_0's binary_logloss: 0.0521905
# [1053]	valid_0's binary_logloss: 0.052191
# [1054]	valid_0's binary_logloss: 0.0521898
# [1055]	valid_0's binary_logloss: 0.0521893
# [1056]	valid_0's binary_logloss: 0.0521892
# [1057]	valid_0's binary_logloss: 0.0521887
# [1058]	valid_0's binary_logloss: 0.0521867
# [1059]	valid_0's binary_logloss: 0.0521861
# [1060]	valid_0's binary_logloss: 0.0521858
# [1061]	valid_0's binary_logloss: 0.0521853
# [1062]	valid_0's binary_logloss: 0.0521864
# [1063]	valid_0's binary_logloss: 0.0521862
# [1064]	valid_0's binary_logloss: 0.0521852
# [1065]	valid_0's binary_logloss: 0.052186
# [1066]	valid_0's binary_logloss: 0.0521848
# [1067]	valid_0's binary_logloss: 0.0521839
# [1068]	valid_0's binary_logloss: 0.0521829
# [1069]	valid_0's binary_logloss: 0.0521811
# [1070]	valid_0's binary_logloss: 0.0521809
# [1071]	valid_0's binary_logloss: 0.0521813
# [1072]	valid_0's binary_logloss: 0.0521808
# [1073]	valid_0's binary_logloss: 0.0521809
# [1074]	valid_0's binary_logloss: 0.0521805
# [1075]	valid_0's binary_logloss: 0.0521808
# [1076]	valid_0's binary_logloss: 0.0521804
# [1077]	valid_0's binary_logloss: 0.0521806
# [1078]	valid_0's binary_logloss: 0.0521796
# [1079]	valid_0's binary_logloss: 0.0521797
# [1080]	valid_0's binary_logloss: 0.0521803
# [1081]	valid_0's binary_logloss: 0.0521787
# [1082]	valid_0's binary_logloss: 0.0521789
# [1083]	valid_0's binary_logloss: 0.0521788
# [1084]	valid_0's binary_logloss: 0.0521779
# [1085]	valid_0's binary_logloss: 0.052178
# [1086]	valid_0's binary_logloss: 0.0521777
# [1087]	valid_0's binary_logloss: 0.0521765
# [1088]	valid_0's binary_logloss: 0.0521767
# [1089]	valid_0's binary_logloss: 0.0521773
# [1090]	valid_0's binary_logloss: 0.0521755
# [1091]	valid_0's binary_logloss: 0.0521752
# [1092]	valid_0's binary_logloss: 0.0521754
# [1093]	valid_0's binary_logloss: 0.0521746
# [1094]	valid_0's binary_logloss: 0.0521745
# [1095]	valid_0's binary_logloss: 0.0521741
# [1096]	valid_0's binary_logloss: 0.0521729
# [1097]	valid_0's binary_logloss: 0.0521736
# [1098]	valid_0's binary_logloss: 0.0521712
# [1099]	valid_0's binary_logloss: 0.0521704
# [1100]	valid_0's binary_logloss: 0.0521701
# [1101]	valid_0's binary_logloss: 0.0521695
# [1102]	valid_0's binary_logloss: 0.0521689
# [1103]	valid_0's binary_logloss: 0.0521693
# [1104]	valid_0's binary_logloss: 0.0521688
# [1105]	valid_0's binary_logloss: 0.0521691
# [1106]	valid_0's binary_logloss: 0.0521684
# [1107]	valid_0's binary_logloss: 0.0521682
# [1108]	valid_0's binary_logloss: 0.0521656
# [1109]	valid_0's binary_logloss: 0.0521652
# [1110]	valid_0's binary_logloss: 0.0521659
# [1111]	valid_0's binary_logloss: 0.0521652
# [1112]	valid_0's binary_logloss: 0.0521653
# [1113]	valid_0's binary_logloss: 0.052164
# [1114]	valid_0's binary_logloss: 0.0521641
# [1115]	valid_0's binary_logloss: 0.0521641
# [1116]	valid_0's binary_logloss: 0.0521645
# [1117]	valid_0's binary_logloss: 0.0521634
# [1118]	valid_0's binary_logloss: 0.0521632
# [1119]	valid_0's binary_logloss: 0.0521631
# [1120]	valid_0's binary_logloss: 0.0521629
# [1121]	valid_0's binary_logloss: 0.0521631
# [1122]	valid_0's binary_logloss: 0.0521634
# [1123]	valid_0's binary_logloss: 0.0521636
# [1124]	valid_0's binary_logloss: 0.0521635
# [1125]	valid_0's binary_logloss: 0.0521636
# [1126]	valid_0's binary_logloss: 0.052163
# [1127]	valid_0's binary_logloss: 0.052163
# [1128]	valid_0's binary_logloss: 0.0521614
# [1129]	valid_0's binary_logloss: 0.0521596
# [1130]	valid_0's binary_logloss: 0.052158
# [1131]	valid_0's binary_logloss: 0.0521589
# [1132]	valid_0's binary_logloss: 0.0521587
# [1133]	valid_0's binary_logloss: 0.0521579
# [1134]	valid_0's binary_logloss: 0.052158
# [1135]	valid_0's binary_logloss: 0.0521575
# [1136]	valid_0's binary_logloss: 0.0521588
# [1137]	valid_0's binary_logloss: 0.0521584
# [1138]	valid_0's binary_logloss: 0.0521574
# [1139]	valid_0's binary_logloss: 0.0521568
# [1140]	valid_0's binary_logloss: 0.0521571
# [1141]	valid_0's binary_logloss: 0.0521574
# [1142]	valid_0's binary_logloss: 0.0521578
# [1143]	valid_0's binary_logloss: 0.0521567
# [1144]	valid_0's binary_logloss: 0.0521559
# [1145]	valid_0's binary_logloss: 0.0521569
# [1146]	valid_0's binary_logloss: 0.0521565
# [1147]	valid_0's binary_logloss: 0.0521567
# [1148]	valid_0's binary_logloss: 0.0521554
# [1149]	valid_0's binary_logloss: 0.0521554
# [1150]	valid_0's binary_logloss: 0.0521547
# [1151]	valid_0's binary_logloss: 0.0521541
# [1152]	valid_0's binary_logloss: 0.0521542
# [1153]	valid_0's binary_logloss: 0.052154
# [1154]	valid_0's binary_logloss: 0.0521536
# [1155]	valid_0's binary_logloss: 0.0521548
# [1156]	valid_0's binary_logloss: 0.0521547
# [1157]	valid_0's binary_logloss: 0.0521561
# [1158]	valid_0's binary_logloss: 0.0521563
# [1159]	valid_0's binary_logloss: 0.0521557
# [1160]	valid_0's binary_logloss: 0.0521557
# [1161]	valid_0's binary_logloss: 0.0521552
# [1162]	valid_0's binary_logloss: 0.052155
# [1163]	valid_0's binary_logloss: 0.0521553
# [1164]	valid_0's binary_logloss: 0.0521549
# [1165]	valid_0's binary_logloss: 0.0521545
# [1166]	valid_0's binary_logloss: 0.0521546
# [1167]	valid_0's binary_logloss: 0.0521542
# [1168]	valid_0's binary_logloss: 0.0521531
# [1169]	valid_0's binary_logloss: 0.0521545
# [1170]	valid_0's binary_logloss: 0.0521531
# [1171]	valid_0's binary_logloss: 0.0521533
# [1172]	valid_0's binary_logloss: 0.0521527
# [1173]	valid_0's binary_logloss: 0.0521525
# [1174]	valid_0's binary_logloss: 0.0521525
# [1175]	valid_0's binary_logloss: 0.0521519
# [1176]	valid_0's binary_logloss: 0.0521519
# [1177]	valid_0's binary_logloss: 0.0521528
# [1178]	valid_0's binary_logloss: 0.0521529
# [1179]	valid_0's binary_logloss: 0.0521535
# [1180]	valid_0's binary_logloss: 0.0521529
# [1181]	valid_0's binary_logloss: 0.0521535
# [1182]	valid_0's binary_logloss: 0.0521525
# [1183]	valid_0's binary_logloss: 0.0521513
# [1184]	valid_0's binary_logloss: 0.0521505
# [1185]	valid_0's binary_logloss: 0.0521499
# [1186]	valid_0's binary_logloss: 0.0521503
# [1187]	valid_0's binary_logloss: 0.0521505
# [1188]	valid_0's binary_logloss: 0.0521507
# [1189]	valid_0's binary_logloss: 0.0521513
# [1190]	valid_0's binary_logloss: 0.0521514
# [1191]	valid_0's binary_logloss: 0.0521515
# [1192]	valid_0's binary_logloss: 0.0521511
# [1193]	valid_0's binary_logloss: 0.0521519
# [1194]	valid_0's binary_logloss: 0.052152
# [1195]	valid_0's binary_logloss: 0.0521529
# [1196]	valid_0's binary_logloss: 0.0521516
# [1197]	valid_0's binary_logloss: 0.0521509
# [1198]	valid_0's binary_logloss: 0.0521505
# [1199]	valid_0's binary_logloss: 0.05215
# [1200]	valid_0's binary_logloss: 0.0521499
# [1201]	valid_0's binary_logloss: 0.0521524
# [1202]	valid_0's binary_logloss: 0.0521519
# [1203]	valid_0's binary_logloss: 0.0521509
# [1204]	valid_0's binary_logloss: 0.0521499
# [1205]	valid_0's binary_logloss: 0.0521502
# [1206]	valid_0's binary_logloss: 0.0521501
# [1207]	valid_0's binary_logloss: 0.0521501
# [1208]	valid_0's binary_logloss: 0.0521492
# [1209]	valid_0's binary_logloss: 0.0521485
# [1210]	valid_0's binary_logloss: 0.0521486
# [1211]	valid_0's binary_logloss: 0.0521482
# [1212]	valid_0's binary_logloss: 0.0521468
# [1213]	valid_0's binary_logloss: 0.0521455
# [1214]	valid_0's binary_logloss: 0.0521451
# [1215]	valid_0's binary_logloss: 0.0521453
# [1216]	valid_0's binary_logloss: 0.0521452
# [1217]	valid_0's binary_logloss: 0.0521452
# [1218]	valid_0's binary_logloss: 0.0521448
# [1219]	valid_0's binary_logloss: 0.0521449
# [1220]	valid_0's binary_logloss: 0.052145
# [1221]	valid_0's binary_logloss: 0.0521455
# [1222]	valid_0's binary_logloss: 0.0521461
# [1223]	valid_0's binary_logloss: 0.0521461
# [1224]	valid_0's binary_logloss: 0.0521453
# [1225]	valid_0's binary_logloss: 0.0521449
# [1226]	valid_0's binary_logloss: 0.0521442
# [1227]	valid_0's binary_logloss: 0.0521427
# [1228]	valid_0's binary_logloss: 0.0521426
# [1229]	valid_0's binary_logloss: 0.052142
# [1230]	valid_0's binary_logloss: 0.0521415
# [1231]	valid_0's binary_logloss: 0.0521411
# [1232]	valid_0's binary_logloss: 0.0521407
# [1233]	valid_0's binary_logloss: 0.0521402
# [1234]	valid_0's binary_logloss: 0.0521406
# [1235]	valid_0's binary_logloss: 0.0521402
# [1236]	valid_0's binary_logloss: 0.0521404
# [1237]	valid_0's binary_logloss: 0.0521406
# [1238]	valid_0's binary_logloss: 0.0521411
# [1239]	valid_0's binary_logloss: 0.0521405
# [1240]	valid_0's binary_logloss: 0.0521405
# [1241]	valid_0's binary_logloss: 0.0521409
# [1242]	valid_0's binary_logloss: 0.0521399
# [1243]	valid_0's binary_logloss: 0.0521383
# [1244]	valid_0's binary_logloss: 0.0521382
# [1245]	valid_0's binary_logloss: 0.0521382
# [1246]	valid_0's binary_logloss: 0.0521383
# [1247]	valid_0's binary_logloss: 0.0521382
# [1248]	valid_0's binary_logloss: 0.0521378
# [1249]	valid_0's binary_logloss: 0.0521362
# [1250]	valid_0's binary_logloss: 0.0521362
# [1251]	valid_0's binary_logloss: 0.0521354
# [1252]	valid_0's binary_logloss: 0.052136
# [1253]	valid_0's binary_logloss: 0.0521347
# [1254]	valid_0's binary_logloss: 0.0521345
# [1255]	valid_0's binary_logloss: 0.0521334
# [1256]	valid_0's binary_logloss: 0.0521321
# [1257]	valid_0's binary_logloss: 0.0521324
# [1258]	valid_0's binary_logloss: 0.0521324
# [1259]	valid_0's binary_logloss: 0.0521326
# [1260]	valid_0's binary_logloss: 0.0521319
# [1261]	valid_0's binary_logloss: 0.0521313
# [1262]	valid_0's binary_logloss: 0.0521311
# [1263]	valid_0's binary_logloss: 0.0521311
# [1264]	valid_0's binary_logloss: 0.0521309
# [1265]	valid_0's binary_logloss: 0.0521295
# [1266]	valid_0's binary_logloss: 0.0521294
# [1267]	valid_0's binary_logloss: 0.05213
# [1268]	valid_0's binary_logloss: 0.0521297
# [1269]	valid_0's binary_logloss: 0.0521301
# [1270]	valid_0's binary_logloss: 0.0521291
# [1271]	valid_0's binary_logloss: 0.052129
# [1272]	valid_0's binary_logloss: 0.0521271
# [1273]	valid_0's binary_logloss: 0.0521266
# [1274]	valid_0's binary_logloss: 0.0521252
# [1275]	valid_0's binary_logloss: 0.0521247
# [1276]	valid_0's binary_logloss: 0.0521252
# [1277]	valid_0's binary_logloss: 0.0521249
# [1278]	valid_0's binary_logloss: 0.0521245
# [1279]	valid_0's binary_logloss: 0.0521244
# [1280]	valid_0's binary_logloss: 0.0521242
# [1281]	valid_0's binary_logloss: 0.0521245
# [1282]	valid_0's binary_logloss: 0.052123
# [1283]	valid_0's binary_logloss: 0.0521237
# [1284]	valid_0's binary_logloss: 0.052123
# [1285]	valid_0's binary_logloss: 0.0521231
# [1286]	valid_0's binary_logloss: 0.0521232
# [1287]	valid_0's binary_logloss: 0.0521232
# [1288]	valid_0's binary_logloss: 0.0521223
# [1289]	valid_0's binary_logloss: 0.0521232
# [1290]	valid_0's binary_logloss: 0.0521239
# [1291]	valid_0's binary_logloss: 0.0521239
# [1292]	valid_0's binary_logloss: 0.0521233
# [1293]	valid_0's binary_logloss: 0.0521246
# [1294]	valid_0's binary_logloss: 0.0521239
# [1295]	valid_0's binary_logloss: 0.0521235
# [1296]	valid_0's binary_logloss: 0.0521229
# [1297]	valid_0's binary_logloss: 0.0521222
# [1298]	valid_0's binary_logloss: 0.0521207
# [1299]	valid_0's binary_logloss: 0.052121
# [1300]	valid_0's binary_logloss: 0.052121
# [1301]	valid_0's binary_logloss: 0.05212
# [1302]	valid_0's binary_logloss: 0.05212
# [1303]	valid_0's binary_logloss: 0.0521196
# [1304]	valid_0's binary_logloss: 0.0521202
# [1305]	valid_0's binary_logloss: 0.0521205
# [1306]	valid_0's binary_logloss: 0.0521207
# [1307]	valid_0's binary_logloss: 0.052121
# [1308]	valid_0's binary_logloss: 0.0521218
# [1309]	valid_0's binary_logloss: 0.0521218
# [1310]	valid_0's binary_logloss: 0.0521216
# [1311]	valid_0's binary_logloss: 0.0521216
# [1312]	valid_0's binary_logloss: 0.0521211
# [1313]	valid_0's binary_logloss: 0.0521209
# [1314]	valid_0's binary_logloss: 0.0521212
# [1315]	valid_0's binary_logloss: 0.0521216
# [1316]	valid_0's binary_logloss: 0.0521212
# [1317]	valid_0's binary_logloss: 0.0521208
# [1318]	valid_0's binary_logloss: 0.0521211
# [1319]	valid_0's binary_logloss: 0.0521221
# [1320]	valid_0's binary_logloss: 0.0521215
# [1321]	valid_0's binary_logloss: 0.0521211
# [1322]	valid_0's binary_logloss: 0.0521219
# [1323]	valid_0's binary_logloss: 0.0521225
# [1324]	valid_0's binary_logloss: 0.052123
# [1325]	valid_0's binary_logloss: 0.0521229
# [1326]	valid_0's binary_logloss: 0.0521241
# [1327]	valid_0's binary_logloss: 0.052124
# [1328]	valid_0's binary_logloss: 0.0521244
# Early stopping, best iteration is:
# [1303]	valid_0's binary_logloss: 0.0521196
# Modelo da classe 2 finalizado

# %%
# Treinar 100% modelo da classe 1
m1 = lgb.train(params=hp1, num_boost_round=nbr, train_set=ds1_train, valid_sets=[ds1_valid], 
               verbose_eval=True, categorical_feature=feats_cat)
print('Modelo da classe 1 finalizado')
# Out:
# [1]	valid_0's binary_logloss: 0.0633144
# Training until validation scores don't improve for 25 rounds
# [2]	valid_0's binary_logloss: 0.0620583
# [3]	valid_0's binary_logloss: 0.0609959
# [4]	valid_0's binary_logloss: 0.0600462
# [5]	valid_0's binary_logloss: 0.0591971
# [6]	valid_0's binary_logloss: 0.0584526
# [7]	valid_0's binary_logloss: 0.0577502
# [8]	valid_0's binary_logloss: 0.0571318
# [9]	valid_0's binary_logloss: 0.0565437
# [10]	valid_0's binary_logloss: 0.0559677
# [11]	valid_0's binary_logloss: 0.0554408
# [12]	valid_0's binary_logloss: 0.0549541
# [13]	valid_0's binary_logloss: 0.0544898
# [14]	valid_0's binary_logloss: 0.0540297
# [15]	valid_0's binary_logloss: 0.0536046
# [16]	valid_0's binary_logloss: 0.0531958
# [17]	valid_0's binary_logloss: 0.0528203
# [18]	valid_0's binary_logloss: 0.0524557
# [19]	valid_0's binary_logloss: 0.0522183
# [20]	valid_0's binary_logloss: 0.0518692
# [21]	valid_0's binary_logloss: 0.0515491
# [22]	valid_0's binary_logloss: 0.0512458
# [23]	valid_0's binary_logloss: 0.0509366
# [24]	valid_0's binary_logloss: 0.0506496
# [25]	valid_0's binary_logloss: 0.0503612
# [26]	valid_0's binary_logloss: 0.0500888
# [27]	valid_0's binary_logloss: 0.0498188
# [28]	valid_0's binary_logloss: 0.0495596
# [29]	valid_0's binary_logloss: 0.0493138
# [30]	valid_0's binary_logloss: 0.0490723
# [31]	valid_0's binary_logloss: 0.0488429
# [32]	valid_0's binary_logloss: 0.0486149
# [33]	valid_0's binary_logloss: 0.048395
# [34]	valid_0's binary_logloss: 0.0481796
# [35]	valid_0's binary_logloss: 0.0479827
# [36]	valid_0's binary_logloss: 0.0477787
# [37]	valid_0's binary_logloss: 0.0475801
# [38]	valid_0's binary_logloss: 0.0473863
# [39]	valid_0's binary_logloss: 0.0471995
# [40]	valid_0's binary_logloss: 0.0470194
# [41]	valid_0's binary_logloss: 0.0468454
# [42]	valid_0's binary_logloss: 0.0466652
# [43]	valid_0's binary_logloss: 0.0464935
# [44]	valid_0's binary_logloss: 0.0463295
# [45]	valid_0's binary_logloss: 0.0461676
# [46]	valid_0's binary_logloss: 0.0460118
# [47]	valid_0's binary_logloss: 0.0458544
# [48]	valid_0's binary_logloss: 0.0457018
# [49]	valid_0's binary_logloss: 0.0455535
# [50]	valid_0's binary_logloss: 0.0454078
# [51]	valid_0's binary_logloss: 0.0452666
# [52]	valid_0's binary_logloss: 0.045126
# [53]	valid_0's binary_logloss: 0.0449831
# [54]	valid_0's binary_logloss: 0.0448461
# [55]	valid_0's binary_logloss: 0.0447089
# [56]	valid_0's binary_logloss: 0.0445754
# [57]	valid_0's binary_logloss: 0.0444614
# [58]	valid_0's binary_logloss: 0.0443507
# [59]	valid_0's binary_logloss: 0.0442209
# [60]	valid_0's binary_logloss: 0.0440954
# [61]	valid_0's binary_logloss: 0.0439789
# [62]	valid_0's binary_logloss: 0.0438533
# [63]	valid_0's binary_logloss: 0.0437319
# [64]	valid_0's binary_logloss: 0.0436142
# [65]	valid_0's binary_logloss: 0.0434995
# [66]	valid_0's binary_logloss: 0.0433815
# [67]	valid_0's binary_logloss: 0.0432794
# [68]	valid_0's binary_logloss: 0.0431667
# [69]	valid_0's binary_logloss: 0.0430576
# [70]	valid_0's binary_logloss: 0.0429511
# [71]	valid_0's binary_logloss: 0.0428449
# [72]	valid_0's binary_logloss: 0.0427451
# [73]	valid_0's binary_logloss: 0.0426425
# [74]	valid_0's binary_logloss: 0.0425619
# [75]	valid_0's binary_logloss: 0.0424637
# [76]	valid_0's binary_logloss: 0.0423659
# [77]	valid_0's binary_logloss: 0.042273
# [78]	valid_0's binary_logloss: 0.0421811
# [79]	valid_0's binary_logloss: 0.0420891
# [80]	valid_0's binary_logloss: 0.0420009
# [81]	valid_0's binary_logloss: 0.0419122
# [82]	valid_0's binary_logloss: 0.041822
# [83]	valid_0's binary_logloss: 0.0417506
# [84]	valid_0's binary_logloss: 0.0416652
# [85]	valid_0's binary_logloss: 0.041583
# [86]	valid_0's binary_logloss: 0.0415133
# [87]	valid_0's binary_logloss: 0.0414339
# [88]	valid_0's binary_logloss: 0.0413517
# [89]	valid_0's binary_logloss: 0.0412735
# [90]	valid_0's binary_logloss: 0.041202
# [91]	valid_0's binary_logloss: 0.0411263
# [92]	valid_0's binary_logloss: 0.0410522
# [93]	valid_0's binary_logloss: 0.0409765
# [94]	valid_0's binary_logloss: 0.040903
# [95]	valid_0's binary_logloss: 0.040831
# [96]	valid_0's binary_logloss: 0.0407606
# [97]	valid_0's binary_logloss: 0.0406884
# [98]	valid_0's binary_logloss: 0.0406285
# [99]	valid_0's binary_logloss: 0.040561
# [100]	valid_0's binary_logloss: 0.0405011
# [101]	valid_0's binary_logloss: 0.0404352
# [102]	valid_0's binary_logloss: 0.0403681
# [103]	valid_0's binary_logloss: 0.0403028
# [104]	valid_0's binary_logloss: 0.0402452
# [105]	valid_0's binary_logloss: 0.0401828
# [106]	valid_0's binary_logloss: 0.0401194
# [107]	valid_0's binary_logloss: 0.0400577
# [108]	valid_0's binary_logloss: 0.0399979
# [109]	valid_0's binary_logloss: 0.0399409
# [110]	valid_0's binary_logloss: 0.0398777
# [111]	valid_0's binary_logloss: 0.039821
# [112]	valid_0's binary_logloss: 0.0397658
# [113]	valid_0's binary_logloss: 0.0397101
# [114]	valid_0's binary_logloss: 0.0396599
# [115]	valid_0's binary_logloss: 0.039601
# [116]	valid_0's binary_logloss: 0.039547
# [117]	valid_0's binary_logloss: 0.0394902
# [118]	valid_0's binary_logloss: 0.0394365
# [119]	valid_0's binary_logloss: 0.0393835
# [120]	valid_0's binary_logloss: 0.0393318
# [121]	valid_0's binary_logloss: 0.03928
# [122]	valid_0's binary_logloss: 0.0392303
# [123]	valid_0's binary_logloss: 0.0391803
# [124]	valid_0's binary_logloss: 0.0391302
# [125]	valid_0's binary_logloss: 0.0390879
# [126]	valid_0's binary_logloss: 0.0390372
# [127]	valid_0's binary_logloss: 0.0389896
# [128]	valid_0's binary_logloss: 0.0389429
# [129]	valid_0's binary_logloss: 0.0389033
# [130]	valid_0's binary_logloss: 0.0388636
# [131]	valid_0's binary_logloss: 0.0388167
# [132]	valid_0's binary_logloss: 0.0387707
# [133]	valid_0's binary_logloss: 0.0387263
# [134]	valid_0's binary_logloss: 0.0386831
# [135]	valid_0's binary_logloss: 0.0386388
# [136]	valid_0's binary_logloss: 0.038594
# [137]	valid_0's binary_logloss: 0.0385571
# [138]	valid_0's binary_logloss: 0.0385112
# [139]	valid_0's binary_logloss: 0.0384701
# [140]	valid_0's binary_logloss: 0.0384303
# [141]	valid_0's binary_logloss: 0.0383851
# [142]	valid_0's binary_logloss: 0.038345
# [143]	valid_0's binary_logloss: 0.0383028
# [144]	valid_0's binary_logloss: 0.0382634
# [145]	valid_0's binary_logloss: 0.0382237
# [146]	valid_0's binary_logloss: 0.0381819
# [147]	valid_0's binary_logloss: 0.0381436
# [148]	valid_0's binary_logloss: 0.0381044
# [149]	valid_0's binary_logloss: 0.0380654
# [150]	valid_0's binary_logloss: 0.0380272
# [151]	valid_0's binary_logloss: 0.0379883
# [152]	valid_0's binary_logloss: 0.0379509
# [153]	valid_0's binary_logloss: 0.0379113
# [154]	valid_0's binary_logloss: 0.0378758
# [155]	valid_0's binary_logloss: 0.037839
# [156]	valid_0's binary_logloss: 0.0378015
# [157]	valid_0's binary_logloss: 0.0377645
# [158]	valid_0's binary_logloss: 0.0377279
# [159]	valid_0's binary_logloss: 0.0376935
# [160]	valid_0's binary_logloss: 0.0376573
# [161]	valid_0's binary_logloss: 0.0376252
# [162]	valid_0's binary_logloss: 0.037592
# [163]	valid_0's binary_logloss: 0.0375626
# [164]	valid_0's binary_logloss: 0.0375296
# [165]	valid_0's binary_logloss: 0.0374961
# [166]	valid_0's binary_logloss: 0.0374641
# [167]	valid_0's binary_logloss: 0.0374304
# [168]	valid_0's binary_logloss: 0.0373984
# [169]	valid_0's binary_logloss: 0.0373673
# [170]	valid_0's binary_logloss: 0.0373361
# [171]	valid_0's binary_logloss: 0.0373055
# [172]	valid_0's binary_logloss: 0.0372753
# [173]	valid_0's binary_logloss: 0.0372441
# [174]	valid_0's binary_logloss: 0.0372166
# [175]	valid_0's binary_logloss: 0.0371878
# [176]	valid_0's binary_logloss: 0.0371573
# [177]	valid_0's binary_logloss: 0.0371277
# [178]	valid_0's binary_logloss: 0.0371012
# [179]	valid_0's binary_logloss: 0.0370752
# [180]	valid_0's binary_logloss: 0.0370476
# [181]	valid_0's binary_logloss: 0.037025
# [182]	valid_0's binary_logloss: 0.0369967
# [183]	valid_0's binary_logloss: 0.0369685
# [184]	valid_0's binary_logloss: 0.0369399
# [185]	valid_0's binary_logloss: 0.0369162
# [186]	valid_0's binary_logloss: 0.0368967
# [187]	valid_0's binary_logloss: 0.0368696
# [188]	valid_0's binary_logloss: 0.0368441
# [189]	valid_0's binary_logloss: 0.0368189
# [190]	valid_0's binary_logloss: 0.0367941
# [191]	valid_0's binary_logloss: 0.0367692
# [192]	valid_0's binary_logloss: 0.0367544
# [193]	valid_0's binary_logloss: 0.03673
# [194]	valid_0's binary_logloss: 0.036708
# [195]	valid_0's binary_logloss: 0.0366847
# [196]	valid_0's binary_logloss: 0.0366622
# [197]	valid_0's binary_logloss: 0.0366399
# [198]	valid_0's binary_logloss: 0.0366174
# [199]	valid_0's binary_logloss: 0.0365953
# [200]	valid_0's binary_logloss: 0.0365744
# [201]	valid_0's binary_logloss: 0.0365517
# [202]	valid_0's binary_logloss: 0.0365296
# [203]	valid_0's binary_logloss: 0.0365075
# [204]	valid_0's binary_logloss: 0.0364858
# [205]	valid_0's binary_logloss: 0.0364646
# [206]	valid_0's binary_logloss: 0.0364472
# [207]	valid_0's binary_logloss: 0.0364272
# [208]	valid_0's binary_logloss: 0.0364073
# [209]	valid_0's binary_logloss: 0.0363835
# [210]	valid_0's binary_logloss: 0.0363604
# [211]	valid_0's binary_logloss: 0.0363405
# [212]	valid_0's binary_logloss: 0.0363178
# [213]	valid_0's binary_logloss: 0.036299
# [214]	valid_0's binary_logloss: 0.0362782
# [215]	valid_0's binary_logloss: 0.0362581
# [216]	valid_0's binary_logloss: 0.0362366
# [217]	valid_0's binary_logloss: 0.0362173
# [218]	valid_0's binary_logloss: 0.0361972
# [219]	valid_0's binary_logloss: 0.0361781
# [220]	valid_0's binary_logloss: 0.0361598
# [221]	valid_0's binary_logloss: 0.036142
# [222]	valid_0's binary_logloss: 0.0361231
# [223]	valid_0's binary_logloss: 0.0361067
# [224]	valid_0's binary_logloss: 0.036087
# [225]	valid_0's binary_logloss: 0.0360697
# [226]	valid_0's binary_logloss: 0.0360518
# [227]	valid_0's binary_logloss: 0.0360334
# [228]	valid_0's binary_logloss: 0.0360173
# [229]	valid_0's binary_logloss: 0.0360007
# [230]	valid_0's binary_logloss: 0.0359837
# [231]	valid_0's binary_logloss: 0.0359667
# [232]	valid_0's binary_logloss: 0.0359484
# [233]	valid_0's binary_logloss: 0.0359329
# [234]	valid_0's binary_logloss: 0.0359165
# [235]	valid_0's binary_logloss: 0.0359005
# [236]	valid_0's binary_logloss: 0.0358873
# [237]	valid_0's binary_logloss: 0.0358719
# [238]	valid_0's binary_logloss: 0.0358582
# [239]	valid_0's binary_logloss: 0.0358413
# [240]	valid_0's binary_logloss: 0.0358257
# [241]	valid_0's binary_logloss: 0.0358098
# [242]	valid_0's binary_logloss: 0.0357953
# [243]	valid_0's binary_logloss: 0.0357812
# [244]	valid_0's binary_logloss: 0.0357682
# [245]	valid_0's binary_logloss: 0.0357539
# [246]	valid_0's binary_logloss: 0.0357413
# [247]	valid_0's binary_logloss: 0.0357275
# [248]	valid_0's binary_logloss: 0.0357123
# [249]	valid_0's binary_logloss: 0.0356996
# [250]	valid_0's binary_logloss: 0.0356885
# [251]	valid_0's binary_logloss: 0.0356743
# [252]	valid_0's binary_logloss: 0.0356615
# [253]	valid_0's binary_logloss: 0.0356495
# [254]	valid_0's binary_logloss: 0.0356352
# [255]	valid_0's binary_logloss: 0.0356218
# [256]	valid_0's binary_logloss: 0.0356101
# [257]	valid_0's binary_logloss: 0.0355986
# [258]	valid_0's binary_logloss: 0.0355847
# [259]	valid_0's binary_logloss: 0.0355742
# [260]	valid_0's binary_logloss: 0.0355614
# [261]	valid_0's binary_logloss: 0.0355493
# [262]	valid_0's binary_logloss: 0.0355384
# [263]	valid_0's binary_logloss: 0.0355274
# [264]	valid_0's binary_logloss: 0.0355189
# [265]	valid_0's binary_logloss: 0.0355075
# [266]	valid_0's binary_logloss: 0.0354961
# [267]	valid_0's binary_logloss: 0.0354848
# [268]	valid_0's binary_logloss: 0.0354719
# [269]	valid_0's binary_logloss: 0.0354604
# [270]	valid_0's binary_logloss: 0.0354488
# [271]	valid_0's binary_logloss: 0.035439
# [272]	valid_0's binary_logloss: 0.0354285
# [273]	valid_0's binary_logloss: 0.0354188
# [274]	valid_0's binary_logloss: 0.0354084
# [275]	valid_0's binary_logloss: 0.0353977
# [276]	valid_0's binary_logloss: 0.0353872
# [277]	valid_0's binary_logloss: 0.0353782
# [278]	valid_0's binary_logloss: 0.0353681
# [279]	valid_0's binary_logloss: 0.0353599
# [280]	valid_0's binary_logloss: 0.0353489
# [281]	valid_0's binary_logloss: 0.035339
# [282]	valid_0's binary_logloss: 0.0353302
# [283]	valid_0's binary_logloss: 0.0353213
# [284]	valid_0's binary_logloss: 0.0353098
# [285]	valid_0's binary_logloss: 0.0352998
# [286]	valid_0's binary_logloss: 0.0352913
# [287]	valid_0's binary_logloss: 0.0352831
# [288]	valid_0's binary_logloss: 0.0352739
# [289]	valid_0's binary_logloss: 0.0352653
# [290]	valid_0's binary_logloss: 0.0352552
# [291]	valid_0's binary_logloss: 0.0352463
# [292]	valid_0's binary_logloss: 0.0352389
# [293]	valid_0's binary_logloss: 0.035229
# [294]	valid_0's binary_logloss: 0.0352223
# [295]	valid_0's binary_logloss: 0.0352132
# [296]	valid_0's binary_logloss: 0.0352022
# [297]	valid_0's binary_logloss: 0.035194
# [298]	valid_0's binary_logloss: 0.0351874
# [299]	valid_0's binary_logloss: 0.0351785
# [300]	valid_0's binary_logloss: 0.0351695
# [301]	valid_0's binary_logloss: 0.0351602
# [302]	valid_0's binary_logloss: 0.0351526
# [303]	valid_0's binary_logloss: 0.0351435
# [304]	valid_0's binary_logloss: 0.0351345
# [305]	valid_0's binary_logloss: 0.0351272
# [306]	valid_0's binary_logloss: 0.0351197
# [307]	valid_0's binary_logloss: 0.0351101
# [308]	valid_0's binary_logloss: 0.0350987
# [309]	valid_0's binary_logloss: 0.0350903
# [310]	valid_0's binary_logloss: 0.0350811
# [311]	valid_0's binary_logloss: 0.0350744
# [312]	valid_0's binary_logloss: 0.0350654
# [313]	valid_0's binary_logloss: 0.0350584
# [314]	valid_0's binary_logloss: 0.0350502
# [315]	valid_0's binary_logloss: 0.0350406
# [316]	valid_0's binary_logloss: 0.035034
# [317]	valid_0's binary_logloss: 0.0350243
# [318]	valid_0's binary_logloss: 0.0350185
# [319]	valid_0's binary_logloss: 0.0350095
# [320]	valid_0's binary_logloss: 0.0350003
# [321]	valid_0's binary_logloss: 0.0349928
# [322]	valid_0's binary_logloss: 0.0349845
# [323]	valid_0's binary_logloss: 0.0349787
# [324]	valid_0's binary_logloss: 0.0349713
# [325]	valid_0's binary_logloss: 0.0349644
# [326]	valid_0's binary_logloss: 0.0349564
# [327]	valid_0's binary_logloss: 0.0349482
# [328]	valid_0's binary_logloss: 0.034941
# [329]	valid_0's binary_logloss: 0.0349334
# [330]	valid_0's binary_logloss: 0.0349268
# [331]	valid_0's binary_logloss: 0.0349196
# [332]	valid_0's binary_logloss: 0.0349128
# [333]	valid_0's binary_logloss: 0.0349065
# [334]	valid_0's binary_logloss: 0.0348987
# [335]	valid_0's binary_logloss: 0.0348934
# [336]	valid_0's binary_logloss: 0.0348864
# [337]	valid_0's binary_logloss: 0.0348809
# [338]	valid_0's binary_logloss: 0.0348757
# [339]	valid_0's binary_logloss: 0.0348707
# [340]	valid_0's binary_logloss: 0.0348642
# [341]	valid_0's binary_logloss: 0.0348567
# [342]	valid_0's binary_logloss: 0.0348483
# [343]	valid_0's binary_logloss: 0.0348453
# [344]	valid_0's binary_logloss: 0.0348379
# [345]	valid_0's binary_logloss: 0.0348312
# [346]	valid_0's binary_logloss: 0.0348254
# [347]	valid_0's binary_logloss: 0.0348199
# [348]	valid_0's binary_logloss: 0.0348143
# [349]	valid_0's binary_logloss: 0.0348075
# [350]	valid_0's binary_logloss: 0.034802
# [351]	valid_0's binary_logloss: 0.0347973
# [352]	valid_0's binary_logloss: 0.0347916
# [353]	valid_0's binary_logloss: 0.0347839
# [354]	valid_0's binary_logloss: 0.0347768
# [355]	valid_0's binary_logloss: 0.0347704
# [356]	valid_0's binary_logloss: 0.0347646
# [357]	valid_0's binary_logloss: 0.0347585
# [358]	valid_0's binary_logloss: 0.0347516
# [359]	valid_0's binary_logloss: 0.0347459
# [360]	valid_0's binary_logloss: 0.0347416
# [361]	valid_0's binary_logloss: 0.0347369
# [362]	valid_0's binary_logloss: 0.0347321
# [363]	valid_0's binary_logloss: 0.0347279
# [364]	valid_0's binary_logloss: 0.034722
# [365]	valid_0's binary_logloss: 0.034715
# [366]	valid_0's binary_logloss: 0.0347108
# [367]	valid_0's binary_logloss: 0.0347046
# [368]	valid_0's binary_logloss: 0.0347005
# [369]	valid_0's binary_logloss: 0.0346964
# [370]	valid_0's binary_logloss: 0.0346888
# [371]	valid_0's binary_logloss: 0.0346831
# [372]	valid_0's binary_logloss: 0.0346808
# [373]	valid_0's binary_logloss: 0.034674
# [374]	valid_0's binary_logloss: 0.0346672
# [375]	valid_0's binary_logloss: 0.0346634
# [376]	valid_0's binary_logloss: 0.0346592
# [377]	valid_0's binary_logloss: 0.0346526
# [378]	valid_0's binary_logloss: 0.034649
# [379]	valid_0's binary_logloss: 0.0346436
# [380]	valid_0's binary_logloss: 0.0346383
# [381]	valid_0's binary_logloss: 0.0346325
# [382]	valid_0's binary_logloss: 0.03463
# [383]	valid_0's binary_logloss: 0.0346248
# [384]	valid_0's binary_logloss: 0.0346175
# [385]	valid_0's binary_logloss: 0.0346125
# [386]	valid_0's binary_logloss: 0.034605
# [387]	valid_0's binary_logloss: 0.0346007
# [388]	valid_0's binary_logloss: 0.0345954
# [389]	valid_0's binary_logloss: 0.034591
# [390]	valid_0's binary_logloss: 0.0345881
# [391]	valid_0's binary_logloss: 0.0345823
# [392]	valid_0's binary_logloss: 0.0345787
# [393]	valid_0's binary_logloss: 0.0345744
# [394]	valid_0's binary_logloss: 0.034569
# [395]	valid_0's binary_logloss: 0.0345655
# [396]	valid_0's binary_logloss: 0.0345626
# [397]	valid_0's binary_logloss: 0.034559
# [398]	valid_0's binary_logloss: 0.0345563
# [399]	valid_0's binary_logloss: 0.0345522
# [400]	valid_0's binary_logloss: 0.0345477
# [401]	valid_0's binary_logloss: 0.034544
# [402]	valid_0's binary_logloss: 0.0345398
# [403]	valid_0's binary_logloss: 0.0345383
# [404]	valid_0's binary_logloss: 0.0345345
# [405]	valid_0's binary_logloss: 0.0345309
# [406]	valid_0's binary_logloss: 0.0345246
# [407]	valid_0's binary_logloss: 0.0345224
# [408]	valid_0's binary_logloss: 0.034517
# [409]	valid_0's binary_logloss: 0.0345139
# [410]	valid_0's binary_logloss: 0.0345104
# [411]	valid_0's binary_logloss: 0.0345058
# [412]	valid_0's binary_logloss: 0.034501
# [413]	valid_0's binary_logloss: 0.0345012
# [414]	valid_0's binary_logloss: 0.0344969
# [415]	valid_0's binary_logloss: 0.0344938
# [416]	valid_0's binary_logloss: 0.0344897
# [417]	valid_0's binary_logloss: 0.0344857
# [418]	valid_0's binary_logloss: 0.0344832
# [419]	valid_0's binary_logloss: 0.034478
# [420]	valid_0's binary_logloss: 0.0344745
# [421]	valid_0's binary_logloss: 0.0344703
# [422]	valid_0's binary_logloss: 0.0344645
# [423]	valid_0's binary_logloss: 0.0344611
# [424]	valid_0's binary_logloss: 0.0344566
# [425]	valid_0's binary_logloss: 0.0344522
# [426]	valid_0's binary_logloss: 0.0344482
# [427]	valid_0's binary_logloss: 0.0344428
# [428]	valid_0's binary_logloss: 0.0344415
# [429]	valid_0's binary_logloss: 0.0344363
# [430]	valid_0's binary_logloss: 0.0344331
# [431]	valid_0's binary_logloss: 0.0344298
# [432]	valid_0's binary_logloss: 0.0344241
# [433]	valid_0's binary_logloss: 0.0344236
# [434]	valid_0's binary_logloss: 0.0344192
# [435]	valid_0's binary_logloss: 0.034417
# [436]	valid_0's binary_logloss: 0.034413
# [437]	valid_0's binary_logloss: 0.0344102
# [438]	valid_0's binary_logloss: 0.0344059
# [439]	valid_0's binary_logloss: 0.0344016
# [440]	valid_0's binary_logloss: 0.0343999
# [441]	valid_0's binary_logloss: 0.0343968
# [442]	valid_0's binary_logloss: 0.034394
# [443]	valid_0's binary_logloss: 0.0343918
# [444]	valid_0's binary_logloss: 0.0343895
# [445]	valid_0's binary_logloss: 0.0343858
# [446]	valid_0's binary_logloss: 0.034382
# [447]	valid_0's binary_logloss: 0.034378
# [448]	valid_0's binary_logloss: 0.0343765
# [449]	valid_0's binary_logloss: 0.034374
# [450]	valid_0's binary_logloss: 0.0343717
# [451]	valid_0's binary_logloss: 0.0343684
# [452]	valid_0's binary_logloss: 0.034365
# [453]	valid_0's binary_logloss: 0.0343606
# [454]	valid_0's binary_logloss: 0.034356
# [455]	valid_0's binary_logloss: 0.0343544
# [456]	valid_0's binary_logloss: 0.0343532
# [457]	valid_0's binary_logloss: 0.034348
# [458]	valid_0's binary_logloss: 0.0343472
# [459]	valid_0's binary_logloss: 0.0343444
# [460]	valid_0's binary_logloss: 0.0343417
# [461]	valid_0's binary_logloss: 0.0343394
# [462]	valid_0's binary_logloss: 0.034337
# [463]	valid_0's binary_logloss: 0.0343352
# [464]	valid_0's binary_logloss: 0.034333
# [465]	valid_0's binary_logloss: 0.0343307
# [466]	valid_0's binary_logloss: 0.0343289
# [467]	valid_0's binary_logloss: 0.0343271
# [468]	valid_0's binary_logloss: 0.0343231
# [469]	valid_0's binary_logloss: 0.0343188
# [470]	valid_0's binary_logloss: 0.0343154
# [471]	valid_0's binary_logloss: 0.0343141
# [472]	valid_0's binary_logloss: 0.0343129
# [473]	valid_0's binary_logloss: 0.0343095
# [474]	valid_0's binary_logloss: 0.0343069
# [475]	valid_0's binary_logloss: 0.0343049
# [476]	valid_0's binary_logloss: 0.0343031
# [477]	valid_0's binary_logloss: 0.0342999
# [478]	valid_0's binary_logloss: 0.0342968
# [479]	valid_0's binary_logloss: 0.0342931
# [480]	valid_0's binary_logloss: 0.0342901
# [481]	valid_0's binary_logloss: 0.0342884
# [482]	valid_0's binary_logloss: 0.0342854
# [483]	valid_0's binary_logloss: 0.0342847
# [484]	valid_0's binary_logloss: 0.0342823
# [485]	valid_0's binary_logloss: 0.0342794
# [486]	valid_0's binary_logloss: 0.0342775
# [487]	valid_0's binary_logloss: 0.0342763
# [488]	valid_0's binary_logloss: 0.0342745
# [489]	valid_0's binary_logloss: 0.0342731
# [490]	valid_0's binary_logloss: 0.0342684
# [491]	valid_0's binary_logloss: 0.0342666
# [492]	valid_0's binary_logloss: 0.0342648
# [493]	valid_0's binary_logloss: 0.0342626
# [494]	valid_0's binary_logloss: 0.0342596
# [495]	valid_0's binary_logloss: 0.0342576
# [496]	valid_0's binary_logloss: 0.0342553
# [497]	valid_0's binary_logloss: 0.0342541
# [498]	valid_0's binary_logloss: 0.0342522
# [499]	valid_0's binary_logloss: 0.0342501
# [500]	valid_0's binary_logloss: 0.0342479
# [501]	valid_0's binary_logloss: 0.034247
# [502]	valid_0's binary_logloss: 0.0342452
# [503]	valid_0's binary_logloss: 0.0342434
# [504]	valid_0's binary_logloss: 0.0342413
# [505]	valid_0's binary_logloss: 0.0342413
# [506]	valid_0's binary_logloss: 0.0342386
# [507]	valid_0's binary_logloss: 0.0342377
# [508]	valid_0's binary_logloss: 0.0342356
# [509]	valid_0's binary_logloss: 0.034234
# [510]	valid_0's binary_logloss: 0.0342318
# [511]	valid_0's binary_logloss: 0.0342296
# [512]	valid_0's binary_logloss: 0.0342287
# [513]	valid_0's binary_logloss: 0.0342264
# [514]	valid_0's binary_logloss: 0.0342241
# [515]	valid_0's binary_logloss: 0.0342237
# [516]	valid_0's binary_logloss: 0.0342219
# [517]	valid_0's binary_logloss: 0.0342179
# [518]	valid_0's binary_logloss: 0.0342156
# [519]	valid_0's binary_logloss: 0.0342138
# [520]	valid_0's binary_logloss: 0.0342141
# [521]	valid_0's binary_logloss: 0.0342123
# [522]	valid_0's binary_logloss: 0.0342104
# [523]	valid_0's binary_logloss: 0.0342085
# [524]	valid_0's binary_logloss: 0.0342073
# [525]	valid_0's binary_logloss: 0.034203
# [526]	valid_0's binary_logloss: 0.0342014
# [527]	valid_0's binary_logloss: 0.0342
# [528]	valid_0's binary_logloss: 0.0341952
# [529]	valid_0's binary_logloss: 0.0341919
# [530]	valid_0's binary_logloss: 0.0341896
# [531]	valid_0's binary_logloss: 0.034188
# [532]	valid_0's binary_logloss: 0.0341871
# [533]	valid_0's binary_logloss: 0.0341855
# [534]	valid_0's binary_logloss: 0.0341828
# [535]	valid_0's binary_logloss: 0.0341801
# [536]	valid_0's binary_logloss: 0.0341777
# [537]	valid_0's binary_logloss: 0.0341761
# [538]	valid_0's binary_logloss: 0.0341749
# [539]	valid_0's binary_logloss: 0.0341742
# [540]	valid_0's binary_logloss: 0.0341732
# [541]	valid_0's binary_logloss: 0.0341718
# [542]	valid_0's binary_logloss: 0.0341703
# [543]	valid_0's binary_logloss: 0.0341675
# [544]	valid_0's binary_logloss: 0.0341646
# [545]	valid_0's binary_logloss: 0.0341632
# [546]	valid_0's binary_logloss: 0.0341625
# [547]	valid_0's binary_logloss: 0.0341601
# [548]	valid_0's binary_logloss: 0.0341588
# [549]	valid_0's binary_logloss: 0.0341581
# [550]	valid_0's binary_logloss: 0.0341569
# [551]	valid_0's binary_logloss: 0.0341561
# [552]	valid_0's binary_logloss: 0.0341539
# [553]	valid_0's binary_logloss: 0.0341523
# [554]	valid_0's binary_logloss: 0.0341504
# [555]	valid_0's binary_logloss: 0.0341492
# [556]	valid_0's binary_logloss: 0.0341481
# [557]	valid_0's binary_logloss: 0.0341478
# [558]	valid_0's binary_logloss: 0.0341464
# [559]	valid_0's binary_logloss: 0.0341459
# [560]	valid_0's binary_logloss: 0.0341435
# [561]	valid_0's binary_logloss: 0.0341406
# [562]	valid_0's binary_logloss: 0.0341408
# [563]	valid_0's binary_logloss: 0.034139
# [564]	valid_0's binary_logloss: 0.0341379
# [565]	valid_0's binary_logloss: 0.0341367
# [566]	valid_0's binary_logloss: 0.0341329
# [567]	valid_0's binary_logloss: 0.0341311
# [568]	valid_0's binary_logloss: 0.0341292
# [569]	valid_0's binary_logloss: 0.0341281
# [570]	valid_0's binary_logloss: 0.0341262
# [571]	valid_0's binary_logloss: 0.0341225
# [572]	valid_0's binary_logloss: 0.0341217
# [573]	valid_0's binary_logloss: 0.0341206
# [574]	valid_0's binary_logloss: 0.0341178
# [575]	valid_0's binary_logloss: 0.0341163
# [576]	valid_0's binary_logloss: 0.0341132
# [577]	valid_0's binary_logloss: 0.0341127
# [578]	valid_0's binary_logloss: 0.0341125
# [579]	valid_0's binary_logloss: 0.034112
# [580]	valid_0's binary_logloss: 0.0341088
# [581]	valid_0's binary_logloss: 0.0341067
# [582]	valid_0's binary_logloss: 0.0341063
# [583]	valid_0's binary_logloss: 0.034104
# [584]	valid_0's binary_logloss: 0.0341035
# [585]	valid_0's binary_logloss: 0.034102
# [586]	valid_0's binary_logloss: 0.0341
# [587]	valid_0's binary_logloss: 0.0340984
# [588]	valid_0's binary_logloss: 0.0340975
# [589]	valid_0's binary_logloss: 0.0340966
# [590]	valid_0's binary_logloss: 0.0340939
# [591]	valid_0's binary_logloss: 0.0340921
# [592]	valid_0's binary_logloss: 0.0340916
# [593]	valid_0's binary_logloss: 0.0340876
# [594]	valid_0's binary_logloss: 0.0340869
# [595]	valid_0's binary_logloss: 0.0340864
# [596]	valid_0's binary_logloss: 0.0340841
# [597]	valid_0's binary_logloss: 0.034083
# [598]	valid_0's binary_logloss: 0.0340816
# [599]	valid_0's binary_logloss: 0.0340799
# [600]	valid_0's binary_logloss: 0.0340792
# [601]	valid_0's binary_logloss: 0.0340758
# [602]	valid_0's binary_logloss: 0.0340745
# [603]	valid_0's binary_logloss: 0.0340747
# [604]	valid_0's binary_logloss: 0.0340728
# [605]	valid_0's binary_logloss: 0.0340717
# [606]	valid_0's binary_logloss: 0.0340707
# [607]	valid_0's binary_logloss: 0.0340697
# [608]	valid_0's binary_logloss: 0.0340672
# [609]	valid_0's binary_logloss: 0.0340668
# [610]	valid_0's binary_logloss: 0.0340659
# [611]	valid_0's binary_logloss: 0.0340648
# [612]	valid_0's binary_logloss: 0.0340637
# [613]	valid_0's binary_logloss: 0.034063
# [614]	valid_0's binary_logloss: 0.0340614
# [615]	valid_0's binary_logloss: 0.0340611
# [616]	valid_0's binary_logloss: 0.0340589
# [617]	valid_0's binary_logloss: 0.0340576
# [618]	valid_0's binary_logloss: 0.0340556
# [619]	valid_0's binary_logloss: 0.0340544
# [620]	valid_0's binary_logloss: 0.0340532
# [621]	valid_0's binary_logloss: 0.0340516
# [622]	valid_0's binary_logloss: 0.03405
# [623]	valid_0's binary_logloss: 0.0340484
# [624]	valid_0's binary_logloss: 0.034048
# [625]	valid_0's binary_logloss: 0.0340462
# [626]	valid_0's binary_logloss: 0.0340459
# [627]	valid_0's binary_logloss: 0.0340446
# [628]	valid_0's binary_logloss: 0.0340437
# [629]	valid_0's binary_logloss: 0.0340406
# [630]	valid_0's binary_logloss: 0.0340381
# [631]	valid_0's binary_logloss: 0.0340365
# [632]	valid_0's binary_logloss: 0.0340356
# [633]	valid_0's binary_logloss: 0.0340357
# [634]	valid_0's binary_logloss: 0.0340357
# [635]	valid_0's binary_logloss: 0.034035
# [636]	valid_0's binary_logloss: 0.0340349
# [637]	valid_0's binary_logloss: 0.0340345
# [638]	valid_0's binary_logloss: 0.0340339
# [639]	valid_0's binary_logloss: 0.0340354
# [640]	valid_0's binary_logloss: 0.0340344
# [641]	valid_0's binary_logloss: 0.0340339
# [642]	valid_0's binary_logloss: 0.0340327
# [643]	valid_0's binary_logloss: 0.0340323
# [644]	valid_0's binary_logloss: 0.0340317
# [645]	valid_0's binary_logloss: 0.0340307
# [646]	valid_0's binary_logloss: 0.0340309
# [647]	valid_0's binary_logloss: 0.0340299
# [648]	valid_0's binary_logloss: 0.03403
# [649]	valid_0's binary_logloss: 0.0340302
# [650]	valid_0's binary_logloss: 0.0340304
# [651]	valid_0's binary_logloss: 0.0340285
# [652]	valid_0's binary_logloss: 0.0340275
# [653]	valid_0's binary_logloss: 0.034027
# [654]	valid_0's binary_logloss: 0.0340264
# [655]	valid_0's binary_logloss: 0.0340237
# [656]	valid_0's binary_logloss: 0.0340231
# [657]	valid_0's binary_logloss: 0.0340228
# [658]	valid_0's binary_logloss: 0.034022
# [659]	valid_0's binary_logloss: 0.0340206
# [660]	valid_0's binary_logloss: 0.0340209
# [661]	valid_0's binary_logloss: 0.0340214
# [662]	valid_0's binary_logloss: 0.0340201
# [663]	valid_0's binary_logloss: 0.0340197
# [664]	valid_0's binary_logloss: 0.0340185
# [665]	valid_0's binary_logloss: 0.0340189
# [666]	valid_0's binary_logloss: 0.0340174
# [667]	valid_0's binary_logloss: 0.034016
# [668]	valid_0's binary_logloss: 0.0340143
# [669]	valid_0's binary_logloss: 0.0340127
# [670]	valid_0's binary_logloss: 0.034012
# [671]	valid_0's binary_logloss: 0.0340125
# [672]	valid_0's binary_logloss: 0.0340128
# [673]	valid_0's binary_logloss: 0.0340121
# [674]	valid_0's binary_logloss: 0.0340088
# [675]	valid_0's binary_logloss: 0.0340096
# [676]	valid_0's binary_logloss: 0.0340079
# [677]	valid_0's binary_logloss: 0.0340086
# [678]	valid_0's binary_logloss: 0.0340085
# [679]	valid_0's binary_logloss: 0.0340081
# [680]	valid_0's binary_logloss: 0.0340077
# [681]	valid_0's binary_logloss: 0.0340068
# [682]	valid_0's binary_logloss: 0.0340054
# [683]	valid_0's binary_logloss: 0.0340045
# [684]	valid_0's binary_logloss: 0.0340023
# [685]	valid_0's binary_logloss: 0.0340007
# [686]	valid_0's binary_logloss: 0.0340008
# [687]	valid_0's binary_logloss: 0.0340002
# [688]	valid_0's binary_logloss: 0.033999
# [689]	valid_0's binary_logloss: 0.033998
# [690]	valid_0's binary_logloss: 0.033998
# [691]	valid_0's binary_logloss: 0.0339959
# [692]	valid_0's binary_logloss: 0.0339952
# [693]	valid_0's binary_logloss: 0.0339946
# [694]	valid_0's binary_logloss: 0.0339947
# [695]	valid_0's binary_logloss: 0.0339938
# [696]	valid_0's binary_logloss: 0.0339936
# [697]	valid_0's binary_logloss: 0.0339933
# [698]	valid_0's binary_logloss: 0.0339924
# [699]	valid_0's binary_logloss: 0.0339913
# [700]	valid_0's binary_logloss: 0.0339906
# [701]	valid_0's binary_logloss: 0.0339892
# [702]	valid_0's binary_logloss: 0.0339885
# [703]	valid_0's binary_logloss: 0.0339877
# [704]	valid_0's binary_logloss: 0.0339871
# [705]	valid_0's binary_logloss: 0.0339864
# [706]	valid_0's binary_logloss: 0.0339864
# [707]	valid_0's binary_logloss: 0.0339853
# [708]	valid_0's binary_logloss: 0.0339833
# [709]	valid_0's binary_logloss: 0.0339829
# [710]	valid_0's binary_logloss: 0.0339839
# [711]	valid_0's binary_logloss: 0.0339831
# [712]	valid_0's binary_logloss: 0.0339829
# [713]	valid_0's binary_logloss: 0.0339808
# [714]	valid_0's binary_logloss: 0.0339805
# [715]	valid_0's binary_logloss: 0.0339793
# [716]	valid_0's binary_logloss: 0.033979
# [717]	valid_0's binary_logloss: 0.0339774
# [718]	valid_0's binary_logloss: 0.0339782
# [719]	valid_0's binary_logloss: 0.0339776
# [720]	valid_0's binary_logloss: 0.0339776
# [721]	valid_0's binary_logloss: 0.0339778
# [722]	valid_0's binary_logloss: 0.0339774
# [723]	valid_0's binary_logloss: 0.0339769
# [724]	valid_0's binary_logloss: 0.0339768
# [725]	valid_0's binary_logloss: 0.0339751
# [726]	valid_0's binary_logloss: 0.0339747
# [727]	valid_0's binary_logloss: 0.0339743
# [728]	valid_0's binary_logloss: 0.0339732
# [729]	valid_0's binary_logloss: 0.0339735
# [730]	valid_0's binary_logloss: 0.0339722
# [731]	valid_0's binary_logloss: 0.0339709
# [732]	valid_0's binary_logloss: 0.0339691
# [733]	valid_0's binary_logloss: 0.0339678
# [734]	valid_0's binary_logloss: 0.0339673
# [735]	valid_0's binary_logloss: 0.0339667
# [736]	valid_0's binary_logloss: 0.0339668
# [737]	valid_0's binary_logloss: 0.0339656
# [738]	valid_0's binary_logloss: 0.0339638
# [739]	valid_0's binary_logloss: 0.0339618
# [740]	valid_0's binary_logloss: 0.0339625
# [741]	valid_0's binary_logloss: 0.033961
# [742]	valid_0's binary_logloss: 0.0339614
# [743]	valid_0's binary_logloss: 0.0339601
# [744]	valid_0's binary_logloss: 0.0339584
# [745]	valid_0's binary_logloss: 0.0339577
# [746]	valid_0's binary_logloss: 0.0339572
# [747]	valid_0's binary_logloss: 0.0339549
# [748]	valid_0's binary_logloss: 0.0339531
# [749]	valid_0's binary_logloss: 0.0339531
# [750]	valid_0's binary_logloss: 0.0339534
# [751]	valid_0's binary_logloss: 0.0339513
# [752]	valid_0's binary_logloss: 0.0339505
# [753]	valid_0's binary_logloss: 0.0339509
# [754]	valid_0's binary_logloss: 0.0339496
# [755]	valid_0's binary_logloss: 0.0339508
# [756]	valid_0's binary_logloss: 0.0339488
# [757]	valid_0's binary_logloss: 0.0339485
# [758]	valid_0's binary_logloss: 0.0339473
# [759]	valid_0's binary_logloss: 0.0339467
# [760]	valid_0's binary_logloss: 0.0339467
# [761]	valid_0's binary_logloss: 0.0339451
# [762]	valid_0's binary_logloss: 0.0339442
# [763]	valid_0's binary_logloss: 0.033943
# [764]	valid_0's binary_logloss: 0.0339424
# [765]	valid_0's binary_logloss: 0.0339417
# [766]	valid_0's binary_logloss: 0.0339441
# [767]	valid_0's binary_logloss: 0.033944
# [768]	valid_0's binary_logloss: 0.0339415
# [769]	valid_0's binary_logloss: 0.0339415
# [770]	valid_0's binary_logloss: 0.0339402
# [771]	valid_0's binary_logloss: 0.0339386
# [772]	valid_0's binary_logloss: 0.0339386
# [773]	valid_0's binary_logloss: 0.0339363
# [774]	valid_0's binary_logloss: 0.0339351
# [775]	valid_0's binary_logloss: 0.0339341
# [776]	valid_0's binary_logloss: 0.0339327
# [777]	valid_0's binary_logloss: 0.0339323
# [778]	valid_0's binary_logloss: 0.0339311
# [779]	valid_0's binary_logloss: 0.03393
# [780]	valid_0's binary_logloss: 0.0339289
# [781]	valid_0's binary_logloss: 0.0339286
# [782]	valid_0's binary_logloss: 0.0339287
# [783]	valid_0's binary_logloss: 0.0339273
# [784]	valid_0's binary_logloss: 0.0339274
# [785]	valid_0's binary_logloss: 0.0339268
# [786]	valid_0's binary_logloss: 0.0339268
# [787]	valid_0's binary_logloss: 0.0339257
# [788]	valid_0's binary_logloss: 0.0339227
# [789]	valid_0's binary_logloss: 0.0339222
# [790]	valid_0's binary_logloss: 0.0339222
# [791]	valid_0's binary_logloss: 0.0339208
# [792]	valid_0's binary_logloss: 0.0339183
# [793]	valid_0's binary_logloss: 0.0339189
# [794]	valid_0's binary_logloss: 0.0339191
# [795]	valid_0's binary_logloss: 0.0339168
# [796]	valid_0's binary_logloss: 0.0339147
# [797]	valid_0's binary_logloss: 0.0339151
# [798]	valid_0's binary_logloss: 0.0339123
# [799]	valid_0's binary_logloss: 0.033912
# [800]	valid_0's binary_logloss: 0.0339103
# [801]	valid_0's binary_logloss: 0.0339114
# [802]	valid_0's binary_logloss: 0.033911
# [803]	valid_0's binary_logloss: 0.0339116
# [804]	valid_0's binary_logloss: 0.0339118
# [805]	valid_0's binary_logloss: 0.0339115
# [806]	valid_0's binary_logloss: 0.0339111
# [807]	valid_0's binary_logloss: 0.0339127
# [808]	valid_0's binary_logloss: 0.0339119
# [809]	valid_0's binary_logloss: 0.0339117
# [810]	valid_0's binary_logloss: 0.0339134
# [811]	valid_0's binary_logloss: 0.0339143
# [812]	valid_0's binary_logloss: 0.0339156
# [813]	valid_0's binary_logloss: 0.0339151
# [814]	valid_0's binary_logloss: 0.0339165
# [815]	valid_0's binary_logloss: 0.0339181
# [816]	valid_0's binary_logloss: 0.0339166
# [817]	valid_0's binary_logloss: 0.0339174
# [818]	valid_0's binary_logloss: 0.0339168
# [819]	valid_0's binary_logloss: 0.0339191
# [820]	valid_0's binary_logloss: 0.0339198
# [821]	valid_0's binary_logloss: 0.0339189
# [822]	valid_0's binary_logloss: 0.033918
# [823]	valid_0's binary_logloss: 0.0339175
# [824]	valid_0's binary_logloss: 0.0339176
# [825]	valid_0's binary_logloss: 0.0339181
# Early stopping, best iteration is:
# [800]	valid_0's binary_logloss: 0.0339103
# Modelo da classe 1 finalizado

# %% [markdown]
# **Avaliação do F1-Score em conjunto de validação com thresholding móvel**

# %%
# Checar matrix de confusão
from sklearn.metrics import classification_report, confusion_matrix

# %%
def calcular_f1_score(yt, yp):
    '''
    
    '''
    # Calcular F1-Score Macro para cada threshold
    vTo = list()
    vF1 = list()
    maxF1 = 0
    maxTo = 0
    
    # Loop em diversas possibilidades
    for threshold in np.linspace(0,1, 100):
        # Calcular
        yd = (yp >= threshold).astype(int)
        f1s = f1_score(yt, yd, average='macro')
        # Adicionar
        vTo.append(threshold)
        vF1.append(f1s)
        # Salvar valor maior caso possível
        if f1s > maxF1:
            maxF1 = f1s
            maxTo = threshold
            
    
    # Pegar a mediana para report
    mF1 = round(np.median(vF1), 3)
    nF1 = round(np.mean(vF1), 3)
    # Report
    print(f'> F1 Score Macro mediano = {mF1} e médio = {nF1}')
    
    # Retornar
    return maxF1, maxTo, mF1, nF1

# %%
# Fazer previsões
y1_pred_valid = m1.predict(x_valid)
print(f' # Para classe 1, feito!')
v1 = calcular_f1_score(y1_valid.values, y1_pred_valid)
# Out:
#  # Para classe 1, feito!
# > F1 Score Macro mediano = 0.667 e médio = 0.65

# %%
# Ver resultados mais em foco
print(classification_report(y1_valid.values, (y1_pred_valid >= v1[1]).astype(int)))
print(confusion_matrix(y1_valid.values, (y1_pred_valid >= v1[1]).astype(int)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99    257070
#            1       0.49      0.46      0.47      3126
#
#     accuracy                           0.99    260196
#    macro avg       0.74      0.73      0.73    260196
# weighted avg       0.99      0.99      0.99    260196
#
# [[255578   1492]
#  [  1700   1426]]

# %%
# Fazer previsões
y2_pred_valid = m2.predict(x_valid)
print(f' # Para classe 2, feito!')
v2 = calcular_f1_score(y2_valid.values, y2_pred_valid)
# Ver resultados mais em foco
print(classification_report(y2_valid.values, (y2_pred_valid >= v2[1]).astype(int)))
print(confusion_matrix(y2_valid.values, (y2_pred_valid >= v2[1]).astype(int)))
# Out:
#  # Para classe 2, feito!
# > F1 Score Macro mediano = 0.701 e médio = 0.659
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99    253909
#            1       0.52      0.61      0.56      6287
#
#     accuracy                           0.98    260196
#    macro avg       0.75      0.80      0.77    260196
# weighted avg       0.98      0.98      0.98    260196
#
# [[250279   3630]
#  [  2432   3855]]

# %%
# Fazer previsões
y3_pred_valid = m3.predict(x_valid)
print(f' # Para classe 3, feito!')
v3 = calcular_f1_score(y3_valid.values, y3_pred_valid)
# Ver resultados mais em foco
print(classification_report(y3_valid.values, (y3_pred_valid >= v3[1]).astype(int)))
print(confusion_matrix(y3_valid.values, (y3_pred_valid >= v3[1]).astype(int)))
# Out:
#  # Para classe 3, feito!
# > F1 Score Macro mediano = 0.645 e médio = 0.627
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    259009
#            1       0.43      0.40      0.41      1187
#
#     accuracy                           0.99    260196
#    macro avg       0.71      0.70      0.70    260196
# weighted avg       0.99      0.99      0.99    260196
#
# [[258382    627]
#  [   718    469]]

# %%
# Fazer previsões
y4_pred_valid = m4.predict(x_valid)
print(f' # Para classe 4, feito!')
v4 = calcular_f1_score(y4_valid.values, y4_pred_valid)
# Ver resultados mais em foco
print(classification_report(y4_valid.values, (y4_pred_valid >= v4[1]).astype(int)))
print(confusion_matrix(y4_valid.values, (y4_pred_valid >= v4[1]).astype(int)))
# Out:
#  # Para classe 4, feito!
# > F1 Score Macro mediano = 0.738 e médio = 0.685
#               precision    recall  f1-score   support
#
#            0       0.89      0.86      0.88    184114
#            1       0.69      0.74      0.71     76082
#
#     accuracy                           0.83    260196
#    macro avg       0.79      0.80      0.79    260196
# weighted avg       0.83      0.83      0.83    260196
#
# [[158927  25187]
#  [ 20003  56079]]

# %%
# Fazer previsões
y5_pred_valid = m5.predict(x_valid)
print(f' # Para classe 5, feito!')
v5 = calcular_f1_score(y5_valid.values, y5_pred_valid)
# Ver resultados mais em foco
print(classification_report(y5_valid.values, (y5_pred_valid >= v5[1]).astype(int)))
print(confusion_matrix(y5_valid.values, (y5_pred_valid >= v5[1]).astype(int)))
# Out:
#  # Para classe 5, feito!
# > F1 Score Macro mediano = 0.79 e médio = 0.741
#               precision    recall  f1-score   support
#
#            0       0.77      0.78      0.77     86682
#            1       0.89      0.88      0.89    173514
#
#     accuracy                           0.85    260196
#    macro avg       0.83      0.83      0.83    260196
# weighted avg       0.85      0.85      0.85    260196
#
# [[ 67477  19205]
#  [ 20263 153251]]

# %%
# Calcular F1 Score Macro para todos modelos
print(f' ############ Mediana Geral')
mg = round(np.mean([v1[2], v2[2], v3[2], v4[2], v5[2]]), 5)
print(f'> F1 Score Macro = {mg}')
# Out:
#  ############ Mediana Geral
# > F1 Score Macro = 0.7082

# %%
# Calcular F1 Score Macro para todos modelos
print(f' ############ Média Geral')
mg = round(np.mean([v1[3], v2[3], v3[2], v4[3], v5[3]]), 5)
print(f'> F1 Score Macro = {mg}')
# Out:
#  ############ Média Geral
# > F1 Score Macro = 0.676

# %%
# Calcular F1 Score Macro para todos modelos
print(f' ############ Máxima Geral')
mg = round(np.mean([v1[0], v2[0], v3[0], v4[0], v5[0]]), 5)
print(f'> F1 Score Macro = {mg}')
# Out:
#  ############ Máxima Geral
# > F1 Score Macro = 0.76698

# %%
# Ver valores
for i, v in enumerate([v1, v2, v3, v4, v5]):
    print(f'> Classe {i+1} tem Máximo F1 Score de {v[0]} com threhsold de {v[1]}')
# Out:
# > Classe 1 tem Máximo F1 Score de 0.7328335083859125 com threhsold de 0.23232323232323235
# > Classe 2 tem Máximo F1 Score de 0.7739329832414704 com threhsold de 0.2828282828282829
# > Classe 3 tem Máximo F1 Score de 0.704133460427478 com threhsold de 0.16161616161616163
# > Classe 4 tem Máximo F1 Score de 0.7941634630951195 com threhsold de 0.4141414141414142
# > Classe 5 tem Máximo F1 Score de 0.8298209747335534 com threhsold de 0.5656565656565657

# %% [markdown]
# **Construção de Modelos Finais (treino e validação) após tentativas de otimização**

# %%
# Especificar hiper parâmetros finais
hp5 = {'objective':'binary',
       'is_unbalance': False,
       'boosting_type': 'gbdt',
       'metric': 'binary_logloss', 
       'eta': 0.01,
       'num_leaves': 224,
       'feature_fraction': 0.85,
       #'early_stopping_round': 25,
       "lambda_l1":8.791369324758216,
       "lambda_l2":0.05026876807406415,
       'seed': 1206,
       'verbosity': -1,
       'num_threads':4}
hp4 = {'objective':'binary',
       'is_unbalance': False,
       'boosting_type': 'gbdt',
       'metric': 'binary_logloss', 
       'eta': 0.01,
       'num_leaves': 243,
       'feature_fraction': 0.85,
       #'early_stopping_round': 25,
       "lambda_l1":8.791369324758216,
       "lambda_l2":0.05026876807406415,
       'seed': 1206, 
       'verbosity': -1,
       'num_threads':4}
hp3 = {'objective':'binary',
       'is_unbalance': False,
       'boosting_type': 'gbdt',
       'metric': 'binary_logloss', 
       'eta': 0.01,
       'num_leaves': 243,
       'feature_fraction': 0.85,
       #'early_stopping_round': 25,
       "lambda_l1":8.791369324758216,
       "lambda_l2":0.05026876807406415,
       'seed': 1206, 
       'verbosity': -1,
       'num_threads':4}
hp2 = {'objective':'binary',
       'is_unbalance': False,
       'boosting_type': 'gbdt',
       'metric': 'binary_logloss', 
       'eta': 0.01,
       'num_leaves': 243,
       'feature_fraction': 0.85,
       #'early_stopping_round': 25,
       "lambda_l1":8.791369324758216,
       "lambda_l2":0.05026876807406415,
       'seed': 1206, 
       'verbosity': -1,
       'num_threads':4}
hp1 = {'objective':'binary',
       'is_unbalance': False,
       'boosting_type': 'gbdt',
       'metric': 'binary_logloss', 
       'eta': 0.01,
       'num_leaves': 243,
       'feature_fraction': 0.85,
       #'early_stopping_round': 25,
       "lambda_l1":8.791369324758216,
       "lambda_l2":0.05026876807406415,
       'seed': 1206, 
       'verbosity': -1,
       'num_threads':4}

# %%
# Definir número de rounds
nbr = 2500
print('Inicio de treinamento ...')
# Treinar 100% modelo da classe 5
m5f = lgb.train(params=hp5, num_boost_round=nbr, train_set=ds5_train_valid, verbose_eval=False, categorical_feature=feats_cat)
print('Modelo da classe 5 finalizado')
# Treinar 100% modelo da classe 4
m4f = lgb.train(params=hp4, num_boost_round=nbr, train_set=ds4_train_valid, verbose_eval=False, categorical_feature=feats_cat)
print('Modelo da classe 4 finalizado')
# Treinar 100% modelo da classe 3
m3f = lgb.train(params=hp3, num_boost_round=nbr, train_set=ds3_train_valid, verbose_eval=False, categorical_feature=feats_cat)
print('Modelo da classe 3 finalizado')
# Treinar 100% modelo da classe 2
m2f = lgb.train(params=hp2, num_boost_round=nbr, train_set=ds2_train_valid, verbose_eval=False, categorical_feature=feats_cat)
print('Modelo da classe 2 finalizado')
# Treinar 100% modelo da classe 1
m1f = lgb.train(params=hp1, num_boost_round=nbr, train_set=ds1_train_valid, verbose_eval=False, categorical_feature=feats_cat)
print('Modelo da classe 1 finalizado')
# Out:
# Inicio de treinamento ...
# Modelo da classe 5 finalizado
# Modelo da classe 4 finalizado
# Modelo da classe 3 finalizado
# Modelo da classe 2 finalizado
# Modelo da classe 1 finalizado

# %% [markdown]
# # Previsão
#
# **Probabilidade Máxima**

# %%
# Carregar modelos
#m1_fl = lgb.Booster(model_file='modelos/m1.txt')
#m2_fl = lgb.Booster(model_file='modelos/m2.txt')
#m3_fl = lgb.Booster(model_file='modelos/m3.txt')
#m4_fl = lgb.Booster(model_file='modelos/m4.txt')
#m5_fl = lgb.Booster(model_file='modelos/m5.txt')

# %%
# Fazer previsões
print('Inicio de previsao ...')
y1_pred = m1f.predict(x_test)
print('Previsão da classe 1 finalizado')
y2_pred = m2f.predict(x_test)
print('Previsão da classe 2 finalizado')
y3_pred = m3f.predict(x_test)
print('Previsão da classe 3 finalizado')
y4_pred = m4f.predict(x_test)
print('Previsão da classe 4 finalizado')
y5_pred = m5f.predict(x_test)
print('Previsão da classe 5 finalizado')
# Out:
# Inicio de previsao ...
# Previsão da classe 1 finalizado
# Previsão da classe 2 finalizado
# Previsão da classe 3 finalizado
# Previsão da classe 4 finalizado
# Previsão da classe 5 finalizado

# %%
# Unificar
y_pred = list()

# Loop em cada previsão
for y1,y2,y3,y4,y5 in zip(y1_pred, y2_pred, y3_pred, y4_pred, y5_pred):
    # Listar sequencialmente as previsoes
    l = [y1,y2,y3,y4,y5]
    # Puxar maior previsão
    y_pred.append(l.index(max(l)) + 1)

# %%
# Salvar previsão final
df_sub_desafio['CLASSI_FIN'] = y_pred

# Salvar probabilidades
df_sub_desafio['PROBA_1'] = y1_pred
df_sub_desafio['PROBA_2'] = y2_pred
df_sub_desafio['PROBA_3'] = y3_pred
df_sub_desafio['PROBA_4'] = y4_pred
df_sub_desafio['PROBA_5'] = y5_pred

# %%
# Viz
df_sub_desafio.head()
# Out:
#                                      ID  CLASSI_FIN   PROBA_1   PROBA_2  \
# 0  c42342a4-cfca-497f-8ee6-a6c76ed4bc67           4  0.000833  0.000225
# 1  6c86b555-8bf2-4306-8f2e-db809a98e3c3           4  0.000074  0.000167
# 2  0ac9582e-2683-474b-8316-5e9c0ea6edd5           5  0.000646  0.000134
# 3  7bc6de6f-041c-4866-8778-7542c230a498           4  0.000340  0.001049
# 4  8eefb2e4-626e-4f40-9b93-5146906fe07b           5  0.000194  0.000015
#
#     PROBA_3   PROBA_4   PROBA_5
# 0  0.000136  0.920425  0.104799
# 1  0.000014  0.875260  0.098138
# 2  0.002277  0.358798  0.522043
# 3  0.000659  0.896631  0.146670
# 4  0.000578  0.416102  0.615924

# %% [markdown]
# **Camada Adicional: Melhor modelo(s)**

# %%
# Adicionar previsão do melhor modelo com threshold optimizado
df_sub_desafio_to = df_sub_desafio.copy()
df_sub_desafio_to['THRESH_OPT4'] = (y4_pred >= 0.4141414141414142).astype(int)
df_sub_desafio_to['THRESH_OPT5'] = (y5_pred >= 0.5656565656565657).astype(int)


# Checar contagem de previsoes considerando TO
df_sub_desafio_to.loc[df_sub_desafio_to['THRESH_OPT5'] == 1, 'CLASSI_FIN'].value_counts()
# Out:
# 5    571348
# 4       326
# 1        10
# 3         7
# 2         1
# Name: CLASSI_FIN, dtype: int64

# %%
# Viz distribuição
df_sub_desafio_to['CLASSI_FIN'].value_counts(normalize=True)
# Out:
# 5    0.699573
# 4    0.288047
# 2    0.006353
# 1    0.004755
# 3    0.001273
# Name: CLASSI_FIN, dtype: float64

# %%
# Aplicar TO
df_sub_desafio_to.loc[(df_sub_desafio_to['THRESH_OPT5'] == 1), 'CLASSI_FIN'] = 5

# %%
# Salvar
df_sub_desafio_to[['ID','CLASSI_FIN']].to_csv('ml-olympiad-ensure-healthy-lives/submissao_try_8_pm_to5_without_unbalance.csv',
                                              index=False)

# %%
# Salvar localmente
df_sub_desafio[['ID','CLASSI_FIN']].to_csv('ml-olympiad-ensure-healthy-lives/submissao_try_8_pm_without_unbalance.csv',
                                           index=False)

# %%
# Salvar localmente
df_sub_desafio.to_csv('ml-olympiad-ensure-healthy-lives/completo_try_8_pm_without_unbalance.csv', index=False)
df_sub_desafio_to.to_csv('ml-olympiad-ensure-healthy-lives/completo_try_8_pm_to5_without_unbalance.csv', index=False)

# %% [markdown]
# # Salvar modelos treinados

# %%
# Salvar modelos localmente
m1f.save_model('modelos/m1_v8_unb.txt')
m2f.save_model('modelos/m2_v8_unb.txt')
m3f.save_model('modelos/m3_v8_unb.txt')
m4f.save_model('modelos/m4_v8_unb.txt')
m5f.save_model('modelos/m5_v8_unb.txt')

# %% [markdown]
# # Checar Feature Importance de cada modelo

# %%
# Criar
df_fi = pd.DataFrame()
df_fi['FEAT'] = x_train.columns
df_fi['FI_M1'] = (100*m1f.feature_importance() / m1f.feature_importance().sum()).round(2)
df_fi['FI_M2'] = (100*m2f.feature_importance() / m2f.feature_importance().sum()).round(2)
df_fi['FI_M3'] = (100*m3f.feature_importance() / m3f.feature_importance().sum()).round(2)
df_fi['FI_M4'] = (100*m4f.feature_importance() / m4f.feature_importance().sum()).round(2)
df_fi['FI_M5'] = (100*m5f.feature_importance() / m5f.feature_importance().sum()).round(2)
df_fi['FI_ORDER'] = df_fi[[c for c in df_fi.columns if 'FI_M' in c]].sum(axis=1)

# %%
# Ver
df_fi.sort_values('FI_ORDER', ascending=False).head(25)
# Out:
#                               FEAT  FI_M1  FI_M2  FI_M3  FI_M4  FI_M5  \
# 19                      ID_MUNICIP  23.11  18.26  12.93  42.71  44.54
# 37                       OUTRO_DES   9.39   8.82   8.46   8.65   8.57
# 2                       NU_IDADE_N   9.07   5.51   9.61   4.34   3.93
# 55                       MORB_DESC   6.49   4.49   6.82   6.96   7.30
# 0                          SEM_NOT   3.99   7.85   8.06   3.95   3.80
# 1                          SEM_PRI   3.43   7.79   6.64   4.01   3.82
# 18                       SG_UF_NOT   2.38   1.76   1.87   3.38   3.42
# 5               ACUMULADO_SINTOMAS   3.31   2.99   4.01   0.97   0.98
# 8   ACUMULADO_SAUDE_SINTOMA_VACCOV   3.27   2.43   4.39   0.59   0.55
# 10            SEM_PRI_NOT_DIFF_ABS   1.96   2.97   3.48   1.18   1.20
# 7     ACUMULADO_SAUDE_MAIS_SINTOMA   3.08   2.36   3.77   0.62   0.56
# 57                       RAIOX_RES   2.19   3.31   1.86   1.40   1.12
# 58                  RAIOX_OUT_NOVO   1.97   3.72   2.26   0.81   0.59
# 25                      CS_ESCOL_N   1.95   1.75   1.47   1.25   1.11
# 59                        TOMO_RES   1.62   0.98   1.15   1.42   1.42
# 60                   TOMO_OUT_NOVO   1.85   1.01   1.99   0.88   0.81
# 6                  ACUMULADO_SAUDE   1.33   1.07   2.28   0.45   0.47
# 24                         CS_RACA   0.97   1.46   0.68   0.86   0.75
# 64                      VACINA_COV   0.73   0.90   0.50   0.86   0.92
# 67                      SUPORT_VEN   0.60   0.86   0.45   0.91   0.97
# 69                         AMOSTRA   1.23   0.36   0.81   0.66   0.67
# 68                      NOSOCOMIAL   0.81   0.87   0.99   0.51   0.49
# 20                         CS_ZONA   0.61   0.89   0.77   0.42   0.34
# 29                           TOSSE   0.72   0.86   0.37   0.47   0.53
# 66                             UTI   0.36   0.72   0.50   0.69   0.60
#
#     FI_ORDER
# 19    141.55
# 37     43.89
# 2      32.46
# 55     32.06
# 0      27.65
# 1      25.69
# 18     12.81
# 5      12.26
# 8      11.23
# 10     10.79
# 7      10.39
# 57      9.88
# 58      9.35
# 25      7.53
# 59      6.59
# 60      6.54
# 6       5.60
# 24      4.72
# 64      3.91
# 67      3.79
# 69      3.73
# 68      3.67
# 20      3.03
# 29      2.95
# 66      2.87

# %%
# Salvar localmente
df_fi.to_csv('ml-olympiad-ensure-healthy-lives/feature_importance_models.csv', index=False)

# %%
df_best = pd.read_csv('ml-olympiad-ensure-healthy-lives/blending1.csv', low_memory=False)

# %%
df_aux = pd.merge(df_best, df_sub_desafio_to[['ID','CLASSI_FIN']], on='ID', how='left')

# %%
((df_aux['CLASSI_FIN_x'] != df_aux['CLASSI_FIN_y']).sum()/len(df_aux),
(df_aux['CLASSI_FIN_x'] != df_aux['CLASSI_FIN_y']).sum())
# Out:
# (0.07313785784040741, 63434)

# %%
0.60875*(1-0.05552384872498187)
# Out:
# 0.5749498570886673

# %%
df_aux.loc[(df_aux['CLASSI_FIN_x'] != df_aux['CLASSI_FIN_y']), 'CLASSI_FIN_x'].value_counts()
# Out:
# 2    24358
# 4    23247
# 1     7731
# 5     5899
# 3     2199
# Name: CLASSI_FIN_x, dtype: int64

# %%
df_aux.loc[(df_aux['CLASSI_FIN_x'] != df_aux['CLASSI_FIN_y']), 'CLASSI_FIN_y'].value_counts()
# Out:
# 4    36202
# 5    27115
# 1       85
# 3       18
# 2       14
# Name: CLASSI_FIN_y, dtype: int64

# %%
df_aux['CLASSI_FIN_x'].value_counts(normalize=True)
# Out:
# 5    0.661831
# 4    0.285854
# 2    0.035949
# 1    0.012999
# 3    0.003368
# Name: CLASSI_FIN_x, dtype: float64
